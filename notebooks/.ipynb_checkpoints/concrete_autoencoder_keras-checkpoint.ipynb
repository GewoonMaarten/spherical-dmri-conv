# %%
from tensorflow.keras.layers import Dense, LeakyReLU
import numpy as np

def decoder(x):
    x = Dense(1344)(x)
    return x

def decoder_2l(x):
    x = Dense(800)(x)
    x = LeakyReLU(0.2)(x)
#    x = Dropout(0.1)(x)
    x = Dense(1000)(x)
    x = LeakyReLU(0.2)(x)
#    x = Dropout(0.1)(x)
    x = Dense(1344)(x)
    return x

def decoder_1l(x):
    x = Dense(1000)(x)
    x = LeakyReLU(0.2)(x)
#    x = Dropout(0.1)(x)
    x = Dense(1344)(x)
    return x

# %%
import keras
import tensorflow

# check versions
print(keras.__version__)
print(tensorflow.__version__)
# Out:
# 2.5.0
# 2.5.0

# %%
print("Num GPUs Available: ", len(tensorflow.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# # MUDI data

# %%
import pandas as pd
import os
import numpy as np
import h5py

# %%
# split dataset into batches
class MRISelectorSubjDataset(tensorflow.keras.utils.Sequence):
    """MRI dataset to select features from."""

    def __init__(self, root_dir, dataf, headerf, subj_list, batch_size=100, shuffle=False):
        """
        Args:
            root_dir (string): Directory with the .csv files
            data (string): Data .csv file
            header (string): Header .csv file
            subj_list (list): list of all the subjects to include
        """
        
        self.root_dir = root_dir
        self.dataf = dataf
        self.headerf = headerf
        self.subj_list = subj_list
        self.batch_size = batch_size
        self.shuffle = shuffle
        
        # load the header
        subj = self.subj_list[0]
        self.header = pd.read_csv(os.path.join(self.root_dir,
                                             self.headerf), index_col=0).to_numpy()
        self.ind = self.header[np.isin(self.header[:,1],self.subj_list),0]
#         print(self.ind)
        
        self.indexes = np.arange(len(self.ind)) 

    def __len__(self):
        return int(np.ceil(len(self.ind) / float(self.batch_size)))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
#         print(indexes)

        # Find list of IDs
        list_IDs_temp = [self.ind[k] for k in indexes]
#         print(list_IDs_temp)

        # Generate data
        signals = self.__data_generation(list_IDs_temp)

        return signals, signals

    def on_epoch_end(self):
        self.indexes = np.arange(len(self.ind)) 
        'Updates indexes after each epoch'
        if self.shuffle == True:
            np.random.shuffle(self.indexes)
            
    def __data_generation(self, list_IDs_temp):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Generate data
        # X = pd.read_csv(os.path.join(self.root_dir, self.dataf), index_col=0, skiprows=lambda x: x not in list_IDs_temp).to_numpy()
        h5f = h5py.File(os.path.join(self.root_dir, self.dataf), 'r')
        X = h5f.get('data1')
        X = X[list_IDs_temp,:]

        return X

# %%
import math
from tensorflow.keras import backend as K
from tensorflow.keras import Model
from tensorflow.keras.layers import Layer, Softmax, Input
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import Constant, glorot_normal
from tensorflow.keras.optimizers import Adam

# Concrete-Autoencoders magic
class ConcreteSelect(Layer):
    
    def __init__(self, output_dim, start_temp = 10.0, min_temp = 0.1, alpha = 0.99999, **kwargs):
        self.output_dim = output_dim
        self.start_temp = start_temp
        self.min_temp = K.constant(min_temp)
        self.alpha = K.constant(alpha)
        super(ConcreteSelect, self).__init__(**kwargs)
        
    def build(self, input_shape):
        self.temp = self.add_weight(name = 'temp', shape = [], initializer = Constant(self.start_temp), trainable = False)
        self.logits = self.add_weight(name = 'logits', shape = [self.output_dim, input_shape[1]], initializer = glorot_normal(), trainable = True)
        super(ConcreteSelect, self).build(input_shape)
        
    def call(self, X, training = None):
        uniform = K.random_uniform(self.logits.shape, K.epsilon(), 1.0)
        gumbel = -K.log(-K.log(uniform))
        temp = K.update(self.temp, K.maximum(self.min_temp, self.temp * self.alpha))
        noisy_logits = (self.logits + gumbel) / temp
        samples = K.softmax(noisy_logits)
        
        discrete_logits = K.one_hot(K.argmax(self.logits), self.logits.shape[1])
        
        self.selections = K.in_train_phase(samples, discrete_logits, training)
        Y = K.dot(X, K.transpose(self.selections))
        
        return Y
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.output_dim)

# logging
class StopperCallback(EarlyStopping):
    
    def __init__(self, mean_max_target = 0.998):#, writer=None):
        self.mean_max_target = mean_max_target
        #self.writer = writer
        super(StopperCallback, self).__init__(monitor = '', patience = float('inf'), verbose = 1, mode = 'max')#, baseline = self.mean_max_target)
    
    def on_epoch_begin(self, epoch, logs = None):
        print('mean max of probabilities:', self.get_monitor_value(logs), '- temperature', K.get_value(self.model.get_layer('concrete_select').temp))
        #s1 = self.get_monitor_value(logs)
        #print(s1)
        #s2 = K.get_value(self.model.get_layer('concrete_select').temp)
        #s1 = tf.summary.scalar('mean_max', s1)
        #s2 = tf.summary.scalar('temperature', s2)
        #print(s1)
        #self.writer.add_summary(s1)
        #self.writer.add_summary(s2)
        #print( K.get_value(K.max(K.softmax(self.model.get_layer('concrete_select').logits), axis = -1)))
        #print(K.get_value(K.max(self.model.get_layer('concrete_select').selections, axis = -1)))
    
    def get_monitor_value(self, logs):
        monitor_value = K.get_value(K.mean(K.max(K.softmax(self.model.get_layer('concrete_select').logits), axis = -1)))
        return monitor_value

# more Concrete-Autoencoders magic
class ConcreteAutoencoderFeatureSelector():
    
    def __init__(self, K, output_function, num_epochs = 100, learning_rate = 0.001, start_temp = 10.0, min_temp = 0.1, tryout_limit = 5, input_dim = 1344, callback=None):#, writer=None): #batch_size = None, 
        self.K = K
        self.output_function = output_function
        self.num_epochs = num_epochs
#         self.batch_size = batch_size
        self.learning_rate = learning_rate
        self.start_temp = start_temp
        self.min_temp = min_temp
        self.tryout_limit = tryout_limit
        self.input_dim = input_dim
        self.callback = callback
        #self.writer = writer
        
    def fit(self, X, val_X=None):
        
#         if self.batch_size is None:
#             self.batch_size = max(len(X) // 256, 16)
        
        num_epochs = self.num_epochs
        steps_per_epoch = X.__len__()#(len(X) + self.batch_size - 1) // self.batch_size
        
        for i in range(self.tryout_limit):
            
            K.set_learning_phase(1)
            
            inputs = Input(shape = (self.input_dim,))#X.shape[1:])

            alpha = math.exp(math.log(self.min_temp / self.start_temp) / (num_epochs * steps_per_epoch))
            
            self.concrete_select = ConcreteSelect(self.K, self.start_temp, self.min_temp, alpha, name = 'concrete_select')

            selected_features = self.concrete_select(inputs)

            outputs = self.output_function(selected_features)

            self.model = Model(inputs, outputs)

            self.model.compile(Adam(self.learning_rate), loss = 'mean_squared_error')
            
            print(self.model.summary())
            
            stopper_callback = StopperCallback()#writer=self.writer)
            
            print(self.callback)
            
            # hist = self.model.fit(X, Y, self.batch_size, num_epochs, verbose = 1, callbacks = [stopper_callback, tensorboard_callback], validation_data = validation_data)#, validation_freq = 10)
            hist = self.model.fit_generator(X, epochs=num_epochs, callbacks = [stopper_callback] + self.callback, validation_data=val_X, verbose=0)#, validation_freq = 10) workers=8, use_multiprocessing=True, 
            #fit_generator(generator, steps_per_epoch=None, epochs=1, verbose=1, callbacks=None, validation_data=None, validation_steps=None, validation_freq=1, 
            #              class_weight=None, max_queue_size=10, workers=1, use_multiprocessing=False, shuffle=True, initial_epoch=0)
            
            if K.get_value(K.mean(K.max(K.softmax(self.concrete_select.logits, axis = -1)))) >= stopper_callback.mean_max_target:
                break
            
            num_epochs *= 2
        
        self.probabilities = K.get_value(K.softmax(self.model.get_layer('concrete_select').logits))
        self.indices = K.get_value(K.argmax(self.model.get_layer('concrete_select').logits))
            
        return self
    
    def get_indices(self):
        return K.get_value(K.argmax(self.model.get_layer('concrete_select').logits))
    
    def get_mask(self):
        return K.get_value(K.sum(K.one_hot(K.argmax(self.model.get_layer('concrete_select').logits), self.model.get_layer('concrete_select').logits.shape[1]), axis = 0))
    
#     def transform(self, X):
#         return X[self.get_indices()]
    
#     def fit_transform(self, X, y):
#         self.fit(X, y)
#         return self.transform(X)
    
    def get_support(self, indices = False):
        return self.get_indices() if indices else self.get_mask()
    
    def get_params(self):
        return self.model

# %%
# import modules to build RunBuilder and RunManager helper classes
from collections  import OrderedDict
from collections import namedtuple
from itertools import product

# Read in the hyper-parameters and return a Run namedtuple containing all the 
# combinations of hyper-parameters
class RunBuilder():
  @staticmethod
  def get_runs(params):

    Run = namedtuple('Run', params.keys())

    runs = []
    for v in product(*params.values()):
      runs.append(Run(*v))
    
    return runs

# %%
# put all hyper params into a OrderedDict, easily expandable
params = OrderedDict(
    lr = [.001],
    batch_size = [256]
)

# %%
from datetime import datetime

# %% [markdown]
# ## Experiment 3: 2 layers

# %%
n_meas = 500
num_epochs = 10
dec = decoder_2l
decstr = 'l2'

# %%
testsubj = 15
testsubjstr = '15'

# %%
for run in RunBuilder.get_runs(params):
    logdir = f"./logs/" + datetime.now().strftime("%Y%m%d-%H%M%S") + f"_{run}_K={n_meas}_epoch={num_epochs}_test={testsubjstr}_dec={decstr}"

    tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)
    monitor_callback = keras.callbacks.ModelCheckpoint('./runs/models/' + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '_runtime.h5', monitor='val_loss', verbose=1)
    
    trainset = MRISelectorSubjDataset(root_dir='.', dataf='data_.hdf5', headerf ='header_.csv',
                                  subj_list=np.array([11, 12, 13, 14]), batch_size=run.batch_size)
    testset = MRISelectorSubjDataset(root_dir='.', dataf='data_.hdf5', headerf ='header_.csv',
                                  subj_list=np.array([15]), batch_size=run.batch_size)

    selector = ConcreteAutoencoderFeatureSelector(K=n_meas, output_function=dec, num_epochs=num_epochs, learning_rate=run.lr, start_temp=10.0, min_temp=0.1, 
                                                  tryout_limit=5, input_dim=1344, callback=[tensorboard_callback, monitor_callback])
    
    selector.fit(X=trainset, val_X=testset)
    
    model = selector.get_params()
    
    model.save('./runs/models/' + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.h5')
# Out:
# /home/maarten/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/backend.py:435: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 1344)]            0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 500)               672001
# _________________________________________________________________
# dense (Dense)                (None, 800)               400800
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 800)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              801000
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 1000)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1344)              1345344
# =================================================================
# Total params: 3,219,145
# Trainable params: 3,219,144
# Non-trainable params: 1
# _________________________________________________________________
# None
# [<keras.callbacks.TensorBoard object at 0x7f192a7a00d0>, <keras.callbacks.ModelCheckpoint object at 0x7f192a7a0100>]
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layer ConcreteSelect has arguments in `__init__` and therefore must override `get_config`.
# mean max of probabilities: 0.0008011042 - temperature 10.0
# /home/maarten/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# WARNING:tensorflow:Callback method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0056s vs `on_train_batch_begin` time: 0.0256s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0056s vs `on_train_batch_end` time: 0.0110s). Check your callbacks.
#
# Epoch 00001: saving model to ./runs/models/Run(lr=0.001, batch_size=256)K=500_epoch=10_test15_decl2_runtime.h5
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-14-74dd3c483765> in <module>
#      13                                                   tryout_limit=5, input_dim=1344, callback=[tensorboard_callback, monitor_callback])
#      14
# ---> 15     selector.fit(X=trainset, val_X=testset)
#      16
#      17     model = selector.get_params()
#
# <ipython-input-6-2065623d41dc> in fit(self, X, val_X)
#     113
#     114             # hist = self.model.fit(X, Y, self.batch_size, num_epochs, verbose = 1, callbacks = [stopper_callback, tensorboard_callback], validation_data = validation_data)#, validation_freq = 10)
# --> 115             hist = self.model.fit_generator(X, epochs=num_epochs, callbacks = [stopper_callback] + self.callback, validation_data=val_X, verbose=0)#, validation_freq = 10) workers=8, use_multiprocessing=True,
#     116             #fit_generator(generator, steps_per_epoch=None, epochs=1, verbose=1, callbacks=None, validation_data=None, validation_steps=None, validation_freq=1,
#     117             #              class_weight=None, max_queue_size=10, workers=1, use_multiprocessing=False, shuffle=True, initial_epoch=0)
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1941                   'will be removed in a future version. '
#    1942                   'Please use `Model.fit`, which supports generators.')
# -> 1943     return self.fit(
#    1944         generator,
#    1945         steps_per_epoch=steps_per_epoch,
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1227           epoch_logs.update(val_logs)
#    1228
# -> 1229         callbacks.on_epoch_end(epoch, epoch_logs)
#    1230         training_logs = epoch_logs
#    1231         if self.stop_training:
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#     433     logs = self._process_logs(logs)
#     434     for callback in self.callbacks:
# --> 435       callback.on_epoch_end(epoch, logs)
#     436
#     437   def on_train_batch_begin(self, batch, logs=None):
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#    1374     # pylint: disable=protected-access
#    1375     if self.save_freq == 'epoch':
# -> 1376       self._save_model(epoch=epoch, logs=logs)
#    1377
#    1378   def _should_save_on_batch(self, batch):
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/keras/callbacks.py in _save_model(self, epoch, logs)
#    1438                 filepath, overwrite=True, options=self._options)
#    1439           else:
# -> 1440             self.model.save(filepath, overwrite=True, options=self._options)
#    1441
#    1442         self._maybe_remove_file()
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in save(self, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#    2109     """
#    2110     # pylint: enable=line-too-long
# -> 2111     save.save_model(self, filepath, overwrite, include_optimizer, save_format,
#    2112                     signatures, options, save_traces)
#    2113
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/saving/save.py in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#     144           'to the Tensorflow SavedModel format (by setting save_format="tf") '
#     145           'or using `save_weights`.')
# --> 146     hdf5_format.save_model_to_hdf5(
#     147         model, filepath, overwrite, include_optimizer)
#     148   else:
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/saving/hdf5_format.py in save_model_to_hdf5(model, filepath, overwrite, include_optimizer)
#     108
#     109   try:
# --> 110     model_metadata = saving_utils.model_metadata(model, include_optimizer)
#     111     for k, v in model_metadata.items():
#     112       if isinstance(v, (dict, list, tuple)):
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/saving/saving_utils.py in model_metadata(model, include_optimizer, require_config)
#     151   except NotImplementedError as e:
#     152     if require_config:
# --> 153       raise e
#     154
#     155   metadata = dict(
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/saving/saving_utils.py in model_metadata(model, include_optimizer, require_config)
#     148   model_config = {'class_name': model.__class__.__name__}
#     149   try:
# --> 150     model_config['config'] = model.get_config()
#     151   except NotImplementedError as e:
#     152     if require_config:
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py in get_config(self)
#     647
#     648   def get_config(self):
# --> 649     return copy.deepcopy(get_network_config(self))
#     650
#     651   @classmethod
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py in get_network_config(network, serialize_layer_fn)
#    1353           filtered_inbound_nodes.append(node_data)
#    1354
# -> 1355       layer_config = serialize_layer_fn(layer)
#    1356       layer_config['name'] = layer.name
#    1357       layer_config['inbound_nodes'] = filtered_inbound_nodes
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/utils/generic_utils.py in serialize_keras_object(instance)
#     506         return serialize_keras_class_and_config(
#     507             name, {_LAYER_UNDEFINED_CONFIG_KEY: True})
# --> 508       raise e
#     509     serialization_config = {}
#     510     for key, item in config.items():
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/utils/generic_utils.py in serialize_keras_object(instance)
#     501     name = get_registered_name(instance.__class__)
#     502     try:
# --> 503       config = instance.get_config()
#     504     except NotImplementedError as e:
#     505       if _SKIP_FAILED_SERIALIZATION:
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in get_config(self)
#     717     # or that `get_config` has been overridden:
#     718     if len(extra_args) > 1 and hasattr(self.get_config, '_is_default'):
# --> 719       raise NotImplementedError('Layer %s has arguments in `__init__` and '
#     720                                 'therefore must override `get_config`.' %
#     721                                 self.__class__.__name__)
#
# NotImplementedError: Layer ConcreteSelect has arguments in `__init__` and therefore must override `get_config`.

# %%
print(selector.get_indices())
np.savetxt('./runs/textfiles/' + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.txt', np.array(selector.get_indices(), dtype=int), fmt='%d')
# Out:
# [  55  116   55  195  116  779 1016  209  288   55  503  288   55  116
#   736  116  288  716  288   55  503  288   55  499  288  969  716  500
#   116 1107  116  503  216   55  578  288  288  338  116  288  288   55
#    55  376   55 1028  498  951  736  288  931  564  951  951  503   55
#   195  504   55  376   55  288 1164   55  564  503  736  116  503  288
#   503  288 1297  564  337  288  940   55  503  397  288   61   83  223
#   503  815  564  736  116   55  736 1264   55  336  178  288   55  116
#   288  736 1028   55   55  116  288   55  288   55  736   55  149   55
#   658  192  288   55  116  790  288   55  809   55  288   13   55   55
#   503  288  116   55  288   55   24  288  288   55  116  288  331   55
#   288 1256  116  542 1012   55  288  641  116  376  173   55  448  345
#   503  288  288  824  736  503  116  288  288  552 1184  116  230  503
#   288   55  288  288  643  552  288  376  116  116  736  288   55  307
#   376  288   55 1149  116  376   55   55   55  288   55   55   93  736
#   288 1055  734   55   55  288  307  288  564  288   55  365   55  503
#   116  734   55  503   55  376  513  116  288  116  288  503  800  288
#   824   55   55  288  288    1   55  503   55  376 1263   55  419  288
#    55  116  503  116   55  116  288  736  116  139  288  288   55  265
#   564  116  116  503  288  736  288   55   55  116  288  288  609  288
#   503  701  503   55  116 1227   55  337  868  288 1111   55  288   55
#    55  363   55  564   55   55  141  288 1189  288  503 1340  491   55
#   736  288  376  376  288  736  608  503  503 1168  116 1184  503  288
#    55  288  503 1298  376   55  116   65  156 1194  951   55  736  288
#   503  288   55   55   55  116  288  288   55   55  288   55   55   55
#   736  288 1012  241  376 1012  288  503   55   55  288  288 1044 1000
#  1340  425 1137   55  299  268  240  173   55    5  216   55 1184   55
#   116 1200  824   55  288  503  288  288   55  736  116  116  288  503
#   912  116  288  116  116  116  195   55 1126  288   55   55  188   55
#  1188  288  492  951  116   55  116  116  288  503   13  529  564  736
#    55  288  205  824  746   55  564   55  116   55  716   94   55   55
#    55  824 1090  601 1151  288  376  503  288   55  813  951   55   55
#   905  299  503  116  254  288 1181   55  503  152 1272  503  633  503
#   736  288   55  503  116  116  116  160  503  597  116  815 1108  503
#    55  953   55  288  564   55   55  116  727  503   55  288  736  288
#    55   76   55  288 1316  116   55  288   55  116  594  824   55  288
#   503  503  985  288  288  116  116   55  503  951]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-60673fcb0982> in <module>
#       1 print(selector.get_indices())
# ----> 2 np.savetxt('./runs/textfiles/' + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.txt', np.array(selector.get_indices(), dtype=int), fmt='%d')
#
# <__array_function__ internals> in savetxt(*args, **kwargs)
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1355     if _is_string_like(fname):
#    1356         # datasource doesn't support creating a new file ...
# -> 1357         open(fname, 'wt').close()
#    1358         fh = np.lib._datasource.open(fname, 'wt', encoding=encoding)
#    1359         own_fh = True
#
# FileNotFoundError: [Errno 2] No such file or directory: './runs/textfiles/Run(lr=0.001, batch_size=256)K=500_epoch=10_test15_decl2.txt'

# %%
testsubj = 14
testsubjstr = '14'

# %%
for run in RunBuilder.get_runs(params):
    logdir = "./runs/scalars/" + datetime.now().strftime("%Y%m%d-%H%M%S") + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr

    tensorboard_callback = tensorflow.keras.callbacks.TensorBoard(log_dir=logdir)
    monitor_callback = tensorflow.keras.callbacks.ModelCheckpoint('./runs/models/' + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '_runtime.h5', monitor='val_loss', verbose=0, save_weights_only=True)
    
    trainset = MRISelectorSubjDataset(root_dir='.', dataf='data_.hdf5', headerf ='header_.csv',
                                  subj_list=np.array([11, 12, 13, 15]), batch_size=run.batch_size)
    testset = MRISelectorSubjDataset(root_dir='.', dataf='data_.hdf5', headerf ='header_.csv',
                                  subj_list=np.array([14]), batch_size=run.batch_size)

    selector = ConcreteAutoencoderFeatureSelector(K=n_meas, output_function=dec, num_epochs=num_epochs, learning_rate=run.lr, start_temp=10.0, min_temp=0.1, 
                                                  tryout_limit=5, input_dim=1344, callback=[tensorboard_callback, monitor_callback])
    
    selector.fit(X=trainset, val_X=testset)
    
    model = selector.get_params()
    
    model.save('./runs/models/' + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.h5')
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 1344)]            0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 500)               672001
# _________________________________________________________________
# dense_3 (Dense)              (None, 800)               400800
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 800)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1000)              801000
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 1000)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1344)              1345344
# =================================================================
# Total params: 3,219,145
# Trainable params: 3,219,144
# Non-trainable params: 1
# _________________________________________________________________
# None
# [<tensorflow.python.keras.callbacks.TensorBoard object at 0x7f1928e932b0>, <tensorflow.python.keras.callbacks.ModelCheckpoint object at 0x7f1a98033160>]
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layer ConcreteSelect has arguments in `__init__` and therefore must override `get_config`.
# mean max of probabilities: 0.00080113305 - temperature 10.0
# WARNING:tensorflow:Callback method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0039s vs `on_train_batch_begin` time: 0.0217s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0039s vs `on_train_batch_end` time: 0.0132s). Check your callbacks.
# mean max of probabilities: 0.0009869906 - temperature 5.467802
# mean max of probabilities: 0.0020023398 - temperature 2.9896886
# mean max of probabilities: 0.002240231 - temperature 1.6347033
# mean max of probabilities: 0.0024605857 - temperature 0.8938226
# mean max of probabilities: 0.0026301339 - temperature 0.48872417
# mean max of probabilities: 0.0027463008 - temperature 0.2672246
# mean max of probabilities: 0.0028254136 - temperature 0.14611304
# mean max of probabilities: 0.0028824753 - temperature 0.1
# mean max of probabilities: 0.0029348198 - temperature 0.1
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 1344)]            0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 500)               672001
# _________________________________________________________________
# dense_6 (Dense)              (None, 800)               400800
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 800)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1000)              801000
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 1000)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1344)              1345344
# =================================================================
# Total params: 3,219,145
# Trainable params: 3,219,144
# Non-trainable params: 1
# _________________________________________________________________
# None
# [<tensorflow.python.keras.callbacks.TensorBoard object at 0x7f1928e932b0>, <tensorflow.python.keras.callbacks.ModelCheckpoint object at 0x7f1a98033160>]
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layer ConcreteSelect has arguments in `__init__` and therefore must override `get_config`.
# mean max of probabilities: 0.00080102304 - temperature 10.0
# WARNING:tensorflow:Callback method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0036s vs `on_train_batch_begin` time: 0.0163s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0036s vs `on_train_batch_end` time: 0.0158s). Check your callbacks.
# mean max of probabilities: 0.0009608397 - temperature 7.3941083
# mean max of probabilities: 0.0014031514 - temperature 5.467283
# mean max of probabilities: 0.0026279483 - temperature 4.0425687
# mean max of probabilities: 0.002857345 - temperature 2.9891202
# mean max of probabilities: 0.0029444702 - temperature 2.2101874
# mean max of probabilities: 0.0030312398 - temperature 1.6342368
# mean max of probabilities: 0.0031440128 - temperature 1.2083721
# mean max of probabilities: 0.003299453 - temperature 0.89348316
# mean max of probabilities: 0.00346765 - temperature 0.6606512
# mean max of probabilities: 0.003616356 - temperature 0.4884927
# mean max of probabilities: 0.0037592396 - temperature 0.3611969
# mean max of probabilities: 0.0038817208 - temperature 0.2670728
# mean max of probabilities: 0.003979933 - temperature 0.1974766
# mean max of probabilities: 0.004056638 - temperature 0.14601628
# mean max of probabilities: 0.004135038 - temperature 0.107966
# mean max of probabilities: 0.004188279 - temperature 0.1
# mean max of probabilities: 0.004234818 - temperature 0.1
# mean max of probabilities: 0.0042874673 - temperature 0.1
# mean max of probabilities: 0.004337882 - temperature 0.1
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 1344)]            0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 500)               672001
# _________________________________________________________________
# dense_9 (Dense)              (None, 800)               400800
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 800)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1000)              801000
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 1000)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1344)              1345344
# =================================================================
# Total params: 3,219,145
# Trainable params: 3,219,144
# Non-trainable params: 1
# _________________________________________________________________
# None
# [<tensorflow.python.keras.callbacks.TensorBoard object at 0x7f1928e932b0>, <tensorflow.python.keras.callbacks.ModelCheckpoint object at 0x7f1a98033160>]
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layer ConcreteSelect has arguments in `__init__` and therefore must override `get_config`.
# mean max of probabilities: 0.00080109027 - temperature 10.0
# WARNING:tensorflow:Callback method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0039s vs `on_train_batch_begin` time: 0.0165s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0039s vs `on_train_batch_end` time: 0.0169s). Check your callbacks.
# mean max of probabilities: 0.0009510995 - temperature 8.598941
# mean max of probabilities: 0.0012974273 - temperature 7.3941836
# mean max of probabilities: 0.0026316105 - temperature 6.358217
# mean max of probabilities: 0.0035936567 - temperature 5.467394
# mean max of probabilities: 0.003958587 - temperature 4.7013807
# mean max of probabilities: 0.0041220933 - temperature 4.04269
# mean max of probabilities: 0.0042372253 - temperature 3.476287
# mean max of probabilities: 0.0042669373 - temperature 2.9892392
# mean max of probabilities: 0.0042866515 - temperature 2.57043
# mean max of probabilities: 0.004334918 - temperature 2.2102978
# mean max of probabilities: 0.004449083 - temperature 1.900623
# mean max of probabilities: 0.0048938477 - temperature 1.6343347
# mean max of probabilities: 0.0051151486 - temperature 1.4053555
# mean max of probabilities: 0.005389994 - temperature 1.2084572
# mean max of probabilities: 0.0056839664 - temperature 1.0391452
# mean max of probabilities: 0.0059807925 - temperature 0.8935552
# mean max of probabilities: 0.0062686843 - temperature 0.7683631
# mean max of probabilities: 0.006645831 - temperature 0.6607111
# mean max of probabilities: 0.006957788 - temperature 0.5681418
# mean max of probabilities: 0.0072477376 - temperature 0.4885418
# mean max of probabilities: 0.0075239106 - temperature 0.42009422
# mean max of probabilities: 0.0077890004 - temperature 0.36123678
# mean max of probabilities: 0.008038899 - temperature 0.3106255
# mean max of probabilities: 0.00827822 - temperature 0.2671051
# mean max of probabilities: 0.0084968135 - temperature 0.22968215
# mean max of probabilities: 0.008757264 - temperature 0.1975024
# mean max of probabilities: 0.009019351 - temperature 0.16983128
# mean max of probabilities: 0.009253701 - temperature 0.14603694
# mean max of probabilities: 0.009507713 - temperature 0.12557636
# mean max of probabilities: 0.0096858535 - temperature 0.10798237
# mean max of probabilities: 0.009913262 - temperature 0.1
# mean max of probabilities: 0.010107397 - temperature 0.1
# mean max of probabilities: 0.010308336 - temperature 0.1
# mean max of probabilities: 0.010494873 - temperature 0.1
# mean max of probabilities: 0.0106741255 - temperature 0.1
# mean max of probabilities: 0.010829084 - temperature 0.1
# mean max of probabilities: 0.01102618 - temperature 0.1
# mean max of probabilities: 0.011284714 - temperature 0.1
# mean max of probabilities: 0.011523142 - temperature 0.1
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 1344)]            0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 500)               672001
# _________________________________________________________________
# dense_12 (Dense)             (None, 800)               400800
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 800)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1000)              801000
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 1000)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1344)              1345344
# =================================================================
# Total params: 3,219,145
# Trainable params: 3,219,144
# Non-trainable params: 1
# _________________________________________________________________
# None
# [<tensorflow.python.keras.callbacks.TensorBoard object at 0x7f1928e932b0>, <tensorflow.python.keras.callbacks.ModelCheckpoint object at 0x7f1a98033160>]
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layer ConcreteSelect has arguments in `__init__` and therefore must override `get_config`.
# mean max of probabilities: 0.0008011129 - temperature 10.0
# WARNING:tensorflow:Callback method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0033s vs `on_train_batch_begin` time: 0.0162s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0033s vs `on_train_batch_end` time: 0.0178s). Check your callbacks.
# mean max of probabilities: 0.00095028285 - temperature 9.273689
# mean max of probabilities: 0.0012516889 - temperature 8.600121
# mean max of probabilities: 0.0020322443 - temperature 7.9754753
# mean max of probabilities: 0.003663115 - temperature 7.396203
# mean max of probabilities: 0.0042940397 - temperature 6.8590064
# mean max of probabilities: 0.0046868282 - temperature 6.360826
# mean max of probabilities: 0.0051025124 - temperature 5.8988276
# mean max of probabilities: 0.005275739 - temperature 5.4703856
# mean max of probabilities: 0.005521522 - temperature 5.0730643
# mean max of probabilities: 0.005721416 - temperature 4.704601
# mean max of probabilities: 0.005796576 - temperature 4.3628983
# mean max of probabilities: 0.0059233555 - temperature 4.0460124
# mean max of probabilities: 0.006193459 - temperature 3.7521396
# mean max of probabilities: 0.0065061986 - temperature 3.4796164
# mean max of probabilities: 0.007421153 - temperature 3.226885
# mean max of probabilities: 0.008507992 - temperature 2.9925122
# mean max of probabilities: 0.008925593 - temperature 2.775161
# mean max of probabilities: 0.009285124 - temperature 2.573597
# mean max of probabilities: 0.00954235 - temperature 2.386672
# mean max of probabilities: 0.0097708525 - temperature 2.2133226
# mean max of probabilities: 0.009937604 - temperature 2.0525675
# mean max of probabilities: 0.010089825 - temperature 1.9034839
# mean max of probabilities: 0.010207592 - temperature 1.7652307
# mean max of probabilities: 0.010378166 - temperature 1.6370192
# mean max of probabilities: 0.010631948 - temperature 1.5181199
# mean max of probabilities: 0.01093088 - temperature 1.407857
# mean max of probabilities: 0.011169653 - temperature 1.305602
# mean max of probabilities: 0.011497996 - temperature 1.2107737
# mean max of probabilities: 0.01183543 - temperature 1.1228341
# mean max of probabilities: 0.012302038 - temperature 1.0412812
# mean max of probabilities: 0.012810163 - temperature 0.9656496
# mean max of probabilities: 0.013345428 - temperature 0.8955127
# mean max of probabilities: 0.0140568055 - temperature 0.8304704
# mean max of probabilities: 0.014741526 - temperature 0.77015185
# mean max of probabilities: 0.015448339 - temperature 0.7142144
# mean max of probabilities: 0.016189463 - temperature 0.6623397
# mean max of probabilities: 0.016845174 - temperature 0.6142329
# mean max of probabilities: 0.017564632 - temperature 0.56962025
# mean max of probabilities: 0.018255169 - temperature 0.5282479
# mean max of probabilities: 0.018854296 - temperature 0.48987982
# mean max of probabilities: 0.019684318 - temperature 0.45429912
# mean max of probabilities: 0.0203518 - temperature 0.4213027
# mean max of probabilities: 0.021050548 - temperature 0.39070272
# mean max of probabilities: 0.021741373 - temperature 0.36232525
# mean max of probabilities: 0.022556348 - temperature 0.3360092
# mean max of probabilities: 0.023277778 - temperature 0.31160414
# mean max of probabilities: 0.024015201 - temperature 0.28897193
# mean max of probabilities: 0.024759205 - temperature 0.26798338
# mean max of probabilities: 0.025445288 - temperature 0.24851912
# mean max of probabilities: 0.026251262 - temperature 0.23046876
# mean max of probabilities: 0.026883502 - temperature 0.21372944
# mean max of probabilities: 0.027671523 - temperature 0.19820598
# mean max of probabilities: 0.028318034 - temperature 0.18380988
# mean max of probabilities: 0.029055364 - temperature 0.17045945
# mean max of probabilities: 0.029668875 - temperature 0.15807879
# mean max of probabilities: 0.030378575 - temperature 0.14659734
# mean max of probabilities: 0.030841276 - temperature 0.13594979
# mean max of probabilities: 0.031184493 - temperature 0.1260755
# mean max of probabilities: 0.03193803 - temperature 0.11691826
# mean max of probabilities: 0.032561515 - temperature 0.10842628
# mean max of probabilities: 0.03318262 - temperature 0.10055111
# mean max of probabilities: 0.033683233 - temperature 0.1
# mean max of probabilities: 0.034278158 - temperature 0.1
# mean max of probabilities: 0.034830928 - temperature 0.1
# mean max of probabilities: 0.035367243 - temperature 0.1
# mean max of probabilities: 0.035914235 - temperature 0.1
# mean max of probabilities: 0.036376435 - temperature 0.1
# mean max of probabilities: 0.03705686 - temperature 0.1
# mean max of probabilities: 0.037533175 - temperature 0.1
# mean max of probabilities: 0.03803409 - temperature 0.1
# mean max of probabilities: 0.038632814 - temperature 0.1
# mean max of probabilities: 0.0391869 - temperature 0.1
# mean max of probabilities: 0.039689623 - temperature 0.1
# mean max of probabilities: 0.040179845 - temperature 0.1
# mean max of probabilities: 0.04074913 - temperature 0.1
# mean max of probabilities: 0.04156424 - temperature 0.1
# mean max of probabilities: 0.04217635 - temperature 0.1
# mean max of probabilities: 0.0428953 - temperature 0.1
# mean max of probabilities: 0.04318683 - temperature 0.1
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 1344)]            0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 500)               672001
# _________________________________________________________________
# dense_15 (Dense)             (None, 800)               400800
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 800)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1000)              801000
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 1000)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1344)              1345344
# =================================================================
# Total params: 3,219,145
# Trainable params: 3,219,144
# Non-trainable params: 1
# _________________________________________________________________
# None
# [<tensorflow.python.keras.callbacks.TensorBoard object at 0x7f1928e932b0>, <tensorflow.python.keras.callbacks.ModelCheckpoint object at 0x7f1a98033160>]
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layer ConcreteSelect has arguments in `__init__` and therefore must override `get_config`.
# mean max of probabilities: 0.0008011201 - temperature 10.0
# WARNING:tensorflow:Callback method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0037s vs `on_train_batch_begin` time: 0.0164s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0037s vs `on_train_batch_end` time: 0.0173s). Check your callbacks.
# mean max of probabilities: 0.0009462895 - temperature 9.6293745
# mean max of probabilities: 0.0012416258 - temperature 9.272464
# mean max of probabilities: 0.0019526534 - temperature 8.928782
# mean max of probabilities: 0.0039639496 - temperature 8.597847
# mean max of probabilities: 0.0046323887 - temperature 8.279141
# mean max of probabilities: 0.0052147326 - temperature 7.97226
# mean max of probabilities: 0.0058307964 - temperature 7.6767645
# mean max of probabilities: 0.006235374 - temperature 7.392227
# mean max of probabilities: 0.006656371 - temperature 7.118243
# mean max of probabilities: 0.007059242 - temperature 6.854405
# mean max of probabilities: 0.007302222 - temperature 6.60035
# mean max of probabilities: 0.007597126 - temperature 6.3557086
# mean max of probabilities: 0.0077567967 - temperature 6.12014
# mean max of probabilities: 0.007920856 - temperature 5.8932996
# mean max of probabilities: 0.008207614 - temperature 5.6748595
# mean max of probabilities: 0.008386551 - temperature 5.46453
# mean max of probabilities: 0.008736169 - temperature 5.2619877
# mean max of probabilities: 0.0091651715 - temperature 5.0669565
# mean max of probabilities: 0.010120652 - temperature 4.8791404
# mean max of probabilities: 0.01190638 - temperature 4.6983085
# mean max of probabilities: 0.013397455 - temperature 4.5241675
# mean max of probabilities: 0.014477999 - temperature 4.356482
# mean max of probabilities: 0.015501692 - temperature 4.1949997
# mean max of probabilities: 0.01640543 - temperature 4.039525
# mean max of probabilities: 0.017190125 - temperature 3.889777
# mean max of probabilities: 0.017855326 - temperature 3.7456048
# mean max of probabilities: 0.018614927 - temperature 3.6067717
# mean max of probabilities: 0.019219505 - temperature 3.4730918
# mean max of probabilities: 0.01974045 - temperature 3.3443625
# mean max of probabilities: 0.02017725 - temperature 3.2204034
# mean max of probabilities: 0.020652851 - temperature 3.1010413
# mean max of probabilities: 0.021069014 - temperature 2.9861016
# mean max of probabilities: 0.02161739 - temperature 2.8754249
# mean max of probabilities: 0.022197785 - temperature 2.7688398
# mean max of probabilities: 0.022732764 - temperature 2.6662185
# mean max of probabilities: 0.023201765 - temperature 2.5673943
# mean max of probabilities: 0.023703977 - temperature 2.4722354
# mean max of probabilities: 0.023901982 - temperature 2.3806047
# mean max of probabilities: 0.023972305 - temperature 2.2923708
# mean max of probabilities: 0.023947893 - temperature 2.207405
# mean max of probabilities: 0.023894025 - temperature 2.1255841
# mean max of probabilities: 0.023830477 - temperature 2.046803
# mean max of probabilities: 0.023783548 - temperature 1.9709288
# mean max of probabilities: 0.023754878 - temperature 1.8978755
# mean max of probabilities: 0.023743777 - temperature 1.8275323
# mean max of probabilities: 0.023799492 - temperature 1.7597953
# mean max of probabilities: 0.024043627 - temperature 1.69457
# mean max of probabilities: 0.024368007 - temperature 1.6317602
# mean max of probabilities: 0.024704373 - temperature 1.5712799
# mean max of probabilities: 0.025232533 - temperature 1.5130391
# mean max of probabilities: 0.025914203 - temperature 1.4569603
# mean max of probabilities: 0.026729262 - temperature 1.4029598
# mean max of probabilities: 0.02768759 - temperature 1.3509592
# mean max of probabilities: 0.029157186 - temperature 1.300886
# mean max of probabilities: 0.031127438 - temperature 1.2526702
# mean max of probabilities: 0.033745185 - temperature 1.2062358
# mean max of probabilities: 0.036382187 - temperature 1.161531
# mean max of probabilities: 0.039175384 - temperature 1.1184797
# mean max of probabilities: 0.041782644 - temperature 1.077022
# mean max of probabilities: 0.04416107 - temperature 1.037103
# mean max of probabilities: 0.046731558 - temperature 0.99865824
# mean max of probabilities: 0.049485024 - temperature 0.9616438
# mean max of probabilities: 0.05241159 - temperature 0.92600095
# mean max of probabilities: 0.05589075 - temperature 0.89167804
# mean max of probabilities: 0.059597116 - temperature 0.85862905
# mean max of probabilities: 0.06373387 - temperature 0.826804
# mean max of probabilities: 0.06814094 - temperature 0.796159
# mean max of probabilities: 0.07263019 - temperature 0.76664877
# mean max of probabilities: 0.0771856 - temperature 0.7382331
# mean max of probabilities: 0.08229608 - temperature 0.71087193
# mean max of probabilities: 0.08745368 - temperature 0.6845231
# mean max of probabilities: 0.092671715 - temperature 0.65915215
# mean max of probabilities: 0.09799472 - temperature 0.6347202
# mean max of probabilities: 0.10364337 - temperature 0.61119515
# mean max of probabilities: 0.108914375 - temperature 0.5885406
# mean max of probabilities: 0.11442987 - temperature 0.5667274
# mean max of probabilities: 0.12045306 - temperature 0.5457213
# mean max of probabilities: 0.12629879 - temperature 0.52549446
# mean max of probabilities: 0.132173 - temperature 0.5060181
# mean max of probabilities: 0.13762611 - temperature 0.48726
# mean max of probabilities: 0.14259648 - temperature 0.46919966
# mean max of probabilities: 0.14738648 - temperature 0.45180923
# mean max of probabilities: 0.15175505 - temperature 0.43506226
# mean max of probabilities: 0.15596484 - temperature 0.41893694
# mean max of probabilities: 0.16012041 - temperature 0.40340963
# mean max of probabilities: 0.16396435 - temperature 0.38845733
# mean max of probabilities: 0.16759585 - temperature 0.37405953
# mean max of probabilities: 0.17093934 - temperature 0.3601945
# mean max of probabilities: 0.17385529 - temperature 0.34684482
# mean max of probabilities: 0.17615879 - temperature 0.3339888
# mean max of probabilities: 0.17843148 - temperature 0.3216097
# mean max of probabilities: 0.18074217 - temperature 0.3096897
# mean max of probabilities: 0.18309444 - temperature 0.29821032
# mean max of probabilities: 0.18452765 - temperature 0.28715736
# mean max of probabilities: 0.18663652 - temperature 0.27651387
# mean max of probabilities: 0.18908745 - temperature 0.26626518
# mean max of probabilities: 0.19124857 - temperature 0.25639686
# mean max of probabilities: 0.19357648 - temperature 0.24689175
# mean max of probabilities: 0.19596794 - temperature 0.2377411
# mean max of probabilities: 0.19797996 - temperature 0.2289292
# mean max of probabilities: 0.20030417 - temperature 0.22044411
# mean max of probabilities: 0.20265183 - temperature 0.21227321
# mean max of probabilities: 0.2042115 - temperature 0.20440558
# mean max of probabilities: 0.2057247 - temperature 0.19682936
# mean max of probabilities: 0.20750982 - temperature 0.18953407
# mean max of probabilities: 0.20954344 - temperature 0.18250903
# mean max of probabilities: 0.21036325 - temperature 0.17574397
# mean max of probabilities: 0.21159811 - temperature 0.16923048
# mean max of probabilities: 0.21315773 - temperature 0.16295806
# mean max of probabilities: 0.21481813 - temperature 0.15691781
# mean max of probabilities: 0.21644834 - temperature 0.15110199
# mean max of probabilities: 0.21823522 - temperature 0.14550097
# mean max of probabilities: 0.22012924 - temperature 0.14010794
# mean max of probabilities: 0.2199419 - temperature 0.13491517
# mean max of probabilities: 0.220336 - temperature 0.12991497
# mean max of probabilities: 0.22114125 - temperature 0.12509927
# mean max of probabilities: 0.22221635 - temperature 0.12046217
# mean max of probabilities: 0.2234458 - temperature 0.11599727
# mean max of probabilities: 0.22491887 - temperature 0.1116979
# mean max of probabilities: 0.22630544 - temperature 0.107557826
# mean max of probabilities: 0.22683316 - temperature 0.10357125
# mean max of probabilities: 0.22759622 - temperature 0.1
# mean max of probabilities: 0.22879493 - temperature 0.1
# mean max of probabilities: 0.22983992 - temperature 0.1
# mean max of probabilities: 0.23139334 - temperature 0.1
# mean max of probabilities: 0.23288648 - temperature 0.1
# mean max of probabilities: 0.23429975 - temperature 0.1
# mean max of probabilities: 0.23557863 - temperature 0.1
# mean max of probabilities: 0.23701555 - temperature 0.1
# mean max of probabilities: 0.23816645 - temperature 0.1
# mean max of probabilities: 0.23927563 - temperature 0.1
# mean max of probabilities: 0.24075116 - temperature 0.1
# mean max of probabilities: 0.24196234 - temperature 0.1
# mean max of probabilities: 0.24351855 - temperature 0.1
# mean max of probabilities: 0.24492271 - temperature 0.1
# mean max of probabilities: 0.2463606 - temperature 0.1
# mean max of probabilities: 0.24672586 - temperature 0.1
# mean max of probabilities: 0.24739438 - temperature 0.1
# mean max of probabilities: 0.2485181 - temperature 0.1
# mean max of probabilities: 0.24971904 - temperature 0.1
# mean max of probabilities: 0.25126687 - temperature 0.1
# mean max of probabilities: 0.25253642 - temperature 0.1
# mean max of probabilities: 0.2532515 - temperature 0.1
# mean max of probabilities: 0.2537598 - temperature 0.1
# mean max of probabilities: 0.25455657 - temperature 0.1
# mean max of probabilities: 0.25577223 - temperature 0.1
# mean max of probabilities: 0.25703713 - temperature 0.1
# mean max of probabilities: 0.25847754 - temperature 0.1
# mean max of probabilities: 0.26000035 - temperature 0.1
# mean max of probabilities: 0.26128736 - temperature 0.1
# mean max of probabilities: 0.26264447 - temperature 0.1
# mean max of probabilities: 0.26310834 - temperature 0.1
# mean max of probabilities: 0.263999 - temperature 0.1
# mean max of probabilities: 0.26517373 - temperature 0.1
# mean max of probabilities: 0.26653737 - temperature 0.1
# mean max of probabilities: 0.2681307 - temperature 0.1
# mean max of probabilities: 0.26974517 - temperature 0.1
# mean max of probabilities: 0.27120134 - temperature 0.1
# mean max of probabilities: 0.2726557 - temperature 0.1
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-16-aab2696beb73> in <module>
#      17     model = selector.get_params()
#      18
# ---> 19     model.save('./runs/models/' + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.h5')
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in save(self, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#    2109     """
#    2110     # pylint: enable=line-too-long
# -> 2111     save.save_model(self, filepath, overwrite, include_optimizer, save_format,
#    2112                     signatures, options, save_traces)
#    2113
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/saving/save.py in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#     144           'to the Tensorflow SavedModel format (by setting save_format="tf") '
#     145           'or using `save_weights`.')
# --> 146     hdf5_format.save_model_to_hdf5(
#     147         model, filepath, overwrite, include_optimizer)
#     148   else:
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/saving/hdf5_format.py in save_model_to_hdf5(model, filepath, overwrite, include_optimizer)
#     108
#     109   try:
# --> 110     model_metadata = saving_utils.model_metadata(model, include_optimizer)
#     111     for k, v in model_metadata.items():
#     112       if isinstance(v, (dict, list, tuple)):
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/saving/saving_utils.py in model_metadata(model, include_optimizer, require_config)
#     151   except NotImplementedError as e:
#     152     if require_config:
# --> 153       raise e
#     154
#     155   metadata = dict(
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/saving/saving_utils.py in model_metadata(model, include_optimizer, require_config)
#     148   model_config = {'class_name': model.__class__.__name__}
#     149   try:
# --> 150     model_config['config'] = model.get_config()
#     151   except NotImplementedError as e:
#     152     if require_config:
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py in get_config(self)
#     647
#     648   def get_config(self):
# --> 649     return copy.deepcopy(get_network_config(self))
#     650
#     651   @classmethod
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py in get_network_config(network, serialize_layer_fn)
#    1353           filtered_inbound_nodes.append(node_data)
#    1354
# -> 1355       layer_config = serialize_layer_fn(layer)
#    1356       layer_config['name'] = layer.name
#    1357       layer_config['inbound_nodes'] = filtered_inbound_nodes
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/utils/generic_utils.py in serialize_keras_object(instance)
#     506         return serialize_keras_class_and_config(
#     507             name, {_LAYER_UNDEFINED_CONFIG_KEY: True})
# --> 508       raise e
#     509     serialization_config = {}
#     510     for key, item in config.items():
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/utils/generic_utils.py in serialize_keras_object(instance)
#     501     name = get_registered_name(instance.__class__)
#     502     try:
# --> 503       config = instance.get_config()
#     504     except NotImplementedError as e:
#     505       if _SKIP_FAILED_SERIALIZATION:
#
# ~/Workspace/School/uu/thesis/MUDI/venv/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in get_config(self)
#     717     # or that `get_config` has been overridden:
#     718     if len(extra_args) > 1 and hasattr(self.get_config, '_is_default'):
# --> 719       raise NotImplementedError('Layer %s has arguments in `__init__` and '
#     720                                 'therefore must override `get_config`.' %
#     721                                 self.__class__.__name__)
#
# NotImplementedError: Layer ConcreteSelect has arguments in `__init__` and therefore must override `get_config`.

# %%
model.save_weights('./MUDI/runs/models/' + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.h5')

# %%
print(np.sort(selector.get_indices()))
np.savetxt('./MUDI/runs/textfiles/' + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.txt', np.array(selector.get_indices(), dtype=int), fmt='%d')
# Out:
# [   0    0    2    3    4   15   19   20   24   24   28   35   36   36
#    37   40   40   40   42   48   51   52   59   60   64   64   65   68
#    72   75   80   83   84   92   93   95   99  100  100  101  104  106
#   108  111  115  116  116  117  119  120  123  128  131  132  133  136
#   138  140  154  155  159  163  164  171  176  176  176  177  179  180
#   180  180  183  184  184  188  193  199  200  204  204  210  212  212
#   216  220  220  224  225  230  232  236  240  244  247  252  252  252
#   252  253  254  255  257  258  260  264  267  268  270  273  275  276
#   278  280  283  287  288  293  296  299  300  305  306  309  311  312
#   313  316  319  320  320  324  328  330  331  332  341  343  344  350
#   361  365  366  368  371  372  372  372  373  375  375  376  378  387
#   389  392  393  398  399  400  403  404  407  408  408  408  409  411
#   412  412  412  413  415  419  420  424  428  430  435  438  440  443
#   446  448  448  449  449  452  459  460  461  462  464  464  466  475
#   476  476  477  482  487  491  493  495  500  502  504  504  510  515
#   516  517  520  520  525  527  530  531  532  532  533  542  544  551
#   552  556  560  562  564  566  570  580  585  588  588  592  596  602
#   613  620  624  624  624  625  629  632  632  635  639  643  652  657
#   659  660  663  664  666  671  672  672  683  684  691  692  693  700
#   700  707  710  714  716  718  728  736  740  742  743  744  755  756
#   760  760  762  764  765  773  776  778  780  781  782  787  796  799
#   801  803  805  809  811  812  815  816  824  826  827  831  832  836
#   840  841  850  856  858  867  868  868  868  871  872  875  877  878
#   879  884  885  888  896  896  896  903  904  905  911  912  912  912
#   916  918  922  929  930  936  940  940  940  944  946  948  950  951
#   952  960  964  968  968  968  970  971  972  974  978  980  987  993
#   995  998 1000 1007 1008 1008 1012 1013 1015 1016 1024 1026 1027 1032
#  1035 1036 1047 1048 1050 1051 1052 1054 1055 1056 1056 1059 1063 1072
#  1073 1073 1074 1080 1080 1082 1089 1092 1092 1095 1102 1103 1103 1104
#  1104 1104 1104 1104 1107 1108 1112 1114 1124 1135 1136 1136 1136 1136
#  1140 1146 1148 1148 1159 1160 1160 1161 1164 1165 1166 1169 1175 1184
#  1185 1186 1188 1188 1188 1192 1192 1193 1194 1194 1199 1200 1204 1204
#  1204 1204 1204 1212 1212 1220 1220 1224 1224 1225 1225 1231 1238 1244
#  1246 1247 1250 1260 1261 1272 1275 1280 1281 1282 1285 1287 1288 1288
#  1289 1291 1293 1293 1296 1300 1300 1300 1300 1300 1300 1306 1308 1312
#  1316 1316 1320 1322 1324 1326 1332 1337 1340 1343]

# %%
testsubj = 13
testsubjstr = '13'

# %%
for run in RunBuilder.get_runs(params):
    logdir = "./MUDI/runs/scalars/" + datetime.now().strftime("%Y%m%d-%H%M%S") + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr

    tensorboard_callback = tensorflow.keras.callbacks.TensorBoard(log_dir=logdir)
    monitor_callback = tensorflow.keras.callbacks.ModelCheckpoint('./MUDI/runs/models/' + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '_runtime.h5', monitor='val_loss', verbose=0, save_weights_only=True)
    
    trainset = MRISelectorSubjDataset(root_dir='.', dataf='data_.hdf5', headerf ='header_.csv',
                                  subj_list=np.array([11, 12, 14, 15]), batch_size=run.batch_size)
    testset = MRISelectorSubjDataset(root_dir='.', dataf='data_.hdf5', headerf ='header_.csv',
                                  subj_list=np.array([13]), batch_size=run.batch_size)

    selector = ConcreteAutoencoderFeatureSelector(K=n_meas, output_function=dec, num_epochs=num_epochs, learning_rate=run.lr, start_temp=10.0, min_temp=0.1, 
                                                  tryout_limit=5, input_dim=1344, callback=[tensorboard_callback, monitor_callback])
    
    selector.fit(X=trainset, val_X=testset)
    
    model = selector.get_params()
    
    model.save_weights('./MUDI/runs/models/' + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.h5')
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 1344)]            0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 500)               672001
# _________________________________________________________________
# dense_3 (Dense)              (None, 800)               400800
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 800)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1000)              801000
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 1000)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1344)              1345344
# =================================================================
# Total params: 3,219,145
# Trainable params: 3,219,144
# Non-trainable params: 1
# _________________________________________________________________
# None
# [<tensorflow.python.keras.callbacks.TensorBoard object at 0x7f59180c0cc0>, <tensorflow.python.keras.callbacks.ModelCheckpoint object at 0x7f59180c0e10>]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layers with arguments in `__init__` must override `get_config`.
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layers with arguments in `__init__` must override `get_config`.
# mean max of probabilities: 0.0008010656 - temperature 10.0
# mean max of probabilities: 0.0009401969 - temperature 9.972055
# mean max of probabilities: 0.0012220221 - temperature 9.944111
# mean max of probabilities: 0.0017830977 - temperature 9.916166
# mean max of probabilities: 0.004326556 - temperature 9.888222
# mean max of probabilities: 0.0054269107 - temperature 9.860277
# mean max of probabilities: 0.0065098633 - temperature 9.832333
# mean max of probabilities: 0.007226597 - temperature 9.804388
# mean max of probabilities: 0.007957177 - temperature 9.7764435
# mean max of probabilities: 0.00875089 - temperature 9.748499
# mean max of probabilities: 0.009444526 - temperature 9.720554
# mean max of probabilities: 0.009985643 - temperature 9.69261
# mean max of probabilities: 0.010585929 - temperature 9.664665
# mean max of probabilities: 0.011333459 - temperature 9.636721
# mean max of probabilities: 0.011652138 - temperature 9.608776
# mean max of probabilities: 0.012135823 - temperature 9.580832
# mean max of probabilities: 0.012578949 - temperature 9.552887
# mean max of probabilities: 0.013168688 - temperature 9.524942
# mean max of probabilities: 0.013530192 - temperature 9.49906
# mean max of probabilities: 0.01402124 - temperature 9.473265
# mean max of probabilities: 0.014396526 - temperature 9.44747
# mean max of probabilities: 0.014781134 - temperature 9.421675
# mean max of probabilities: 0.01529221 - temperature 9.39588
# mean max of probabilities: 0.015726613 - temperature 9.370085
# mean max of probabilities: 0.016167823 - temperature 9.34429
# mean max of probabilities: 0.016613528 - temperature 9.318495
# mean max of probabilities: 0.01717495 - temperature 9.2927
# mean max of probabilities: 0.017964222 - temperature 9.266905
# mean max of probabilities: 0.018913403 - temperature 9.24111
# mean max of probabilities: 0.020051772 - temperature 9.215315
# mean max of probabilities: 0.0215625 - temperature 9.18952
# mean max of probabilities: 0.023009667 - temperature 9.163725
# mean max of probabilities: 0.027062293 - temperature 9.13793
# mean max of probabilities: 0.034332257 - temperature 9.112135
# mean max of probabilities: 0.039580133 - temperature 9.08634
# mean max of probabilities: 0.043004233 - temperature 9.060545
# mean max of probabilities: 0.04625972 - temperature 9.03475
# mean max of probabilities: 0.049472213 - temperature 9.008955
# mean max of probabilities: 0.052415457 - temperature 8.98316
# mean max of probabilities: 0.055402804 - temperature 8.957365
# mean max of probabilities: 0.058554016 - temperature 8.93157
# mean max of probabilities: 0.061574243 - temperature 8.905775
# mean max of probabilities: 0.0647589 - temperature 8.87998
# mean max of probabilities: 0.06803373 - temperature 8.854185
# mean max of probabilities: 0.07107151 - temperature 8.82839
# mean max of probabilities: 0.074101955 - temperature 8.802595
# mean max of probabilities: 0.077234894 - temperature 8.7768
# mean max of probabilities: 0.08031471 - temperature 8.751913
# mean max of probabilities: 0.08329465 - temperature 8.728268
# mean max of probabilities: 0.08641802 - temperature 8.704622
# mean max of probabilities: 0.08981057 - temperature 8.680977
# mean max of probabilities: 0.09277678 - temperature 8.657331
# mean max of probabilities: 0.096213385 - temperature 8.633686
# mean max of probabilities: 0.099553056 - temperature 8.610041
# mean max of probabilities: 0.102850206 - temperature 8.586395
# mean max of probabilities: 0.10624176 - temperature 8.56275
# mean max of probabilities: 0.10979745 - temperature 8.539104
# mean max of probabilities: 0.11319422 - temperature 8.515459
# mean max of probabilities: 0.11686839 - temperature 8.491814
# mean max of probabilities: 0.1203532 - temperature 8.468168
# mean max of probabilities: 0.12392275 - temperature 8.444523
# mean max of probabilities: 0.12759106 - temperature 8.420877
# mean max of probabilities: 0.13166507 - temperature 8.397232
# mean max of probabilities: 0.13560909 - temperature 8.373587
# mean max of probabilities: 0.13948736 - temperature 8.349941
# mean max of probabilities: 0.14291255 - temperature 8.326296
# mean max of probabilities: 0.14399877 - temperature 8.30265
# mean max of probabilities: 0.14754903 - temperature 8.279005
# mean max of probabilities: 0.15170744 - temperature 8.25536
# mean max of probabilities: 0.15583117 - temperature 8.231714
# mean max of probabilities: 0.15986553 - temperature 8.208069
# mean max of probabilities: 0.16405411 - temperature 8.184423
# mean max of probabilities: 0.16789897 - temperature 8.160778
# mean max of probabilities: 0.17173214 - temperature 8.137133
# mean max of probabilities: 0.17509298 - temperature 8.113487
# mean max of probabilities: 0.1784094 - temperature 8.089842
# mean max of probabilities: 0.18191238 - temperature 8.066196
# mean max of probabilities: 0.18534786 - temperature 8.042551
# mean max of probabilities: 0.18854922 - temperature 8.018906
# mean max of probabilities: 0.19168347 - temperature 7.995476
# mean max of probabilities: 0.1947795 - temperature 7.972905
# mean max of probabilities: 0.19824274 - temperature 7.9503345
# mean max of probabilities: 0.20174314 - temperature 7.927764
# mean max of probabilities: 0.20521292 - temperature 7.9051933
# mean max of probabilities: 0.208785 - temperature 7.8826227
# mean max of probabilities: 0.2123164 - temperature 7.860052
# mean max of probabilities: 0.21596478 - temperature 7.8374815
# mean max of probabilities: 0.21948363 - temperature 7.814911
# mean max of probabilities: 0.22263446 - temperature 7.7931585
# mean max of probabilities: 0.22566533 - temperature 7.7716627
# mean max of probabilities: 0.22859284 - temperature 7.750167
# mean max of probabilities: 0.23126023 - temperature 7.728671
# mean max of probabilities: 0.2338715 - temperature 7.7071753
# mean max of probabilities: 0.2364313 - temperature 7.6856794
# mean max of probabilities: 0.23903736 - temperature 7.6641836
# mean max of probabilities: 0.24184957 - temperature 7.642688
# mean max of probabilities: 0.24431325 - temperature 7.621192
# mean max of probabilities: 0.24694669 - temperature 7.599696
# mean max of probabilities: 0.24932045 - temperature 7.5782003
# mean max of probabilities: 0.25195652 - temperature 7.5567045
# mean max of probabilities: 0.25457665 - temperature 7.5352087
# mean max of probabilities: 0.257022 - temperature 7.513713
# mean max of probabilities: 0.25951302 - temperature 7.492217
# mean max of probabilities: 0.26202142 - temperature 7.4707212
# mean max of probabilities: 0.26440892 - temperature 7.4492254
# mean max of probabilities: 0.2667684 - temperature 7.4277716
# mean max of probabilities: 0.26911774 - temperature 7.4073505
# mean max of probabilities: 0.27138367 - temperature 7.3869295
# mean max of probabilities: 0.27354816 - temperature 7.3665085
# mean max of probabilities: 0.2757869 - temperature 7.3460875
# mean max of probabilities: 0.27773586 - temperature 7.3256664
# mean max of probabilities: 0.27980804 - temperature 7.3052454
# mean max of probabilities: 0.28168532 - temperature 7.2848244
# mean max of probabilities: 0.28370577 - temperature 7.2644033
# mean max of probabilities: 0.2855634 - temperature 7.2439823
# mean max of probabilities: 0.28749934 - temperature 7.2235613
# mean max of probabilities: 0.28962874 - temperature 7.2031403
# mean max of probabilities: 0.29184893 - temperature 7.182719
# mean max of probabilities: 0.2938798 - temperature 7.162298
# mean max of probabilities: 0.29606965 - temperature 7.141877
# mean max of probabilities: 0.29822582 - temperature 7.121456
# mean max of probabilities: 0.3003829 - temperature 7.101035
# mean max of probabilities: 0.30266687 - temperature 7.080614
# mean max of probabilities: 0.30471638 - temperature 7.060193
# mean max of probabilities: 0.30715078 - temperature 7.040185
# mean max of probabilities: 0.30946767 - temperature 7.0208387
# mean max of probabilities: 0.31184122 - temperature 7.0014925
# mean max of probabilities: 0.3140101 - temperature 6.9821463
# mean max of probabilities: 0.31610653 - temperature 6.9628
# mean max of probabilities: 0.31821704 - temperature 6.943454
# mean max of probabilities: 0.3200678 - temperature 6.9241076
# mean max of probabilities: 0.32212153 - temperature 6.9047613
# mean max of probabilities: 0.32391596 - temperature 6.885415
# mean max of probabilities: 0.32570407 - temperature 6.866069
# mean max of probabilities: 0.327454 - temperature 6.8467226
# mean max of probabilities: 0.32897645 - temperature 6.8273764
# mean max of probabilities: 0.33063048 - temperature 6.80803
# mean max of probabilities: 0.3321295 - temperature 6.788684
# mean max of probabilities: 0.3334167 - temperature 6.7693377
# mean max of probabilities: 0.33445022 - temperature 6.7499914
# mean max of probabilities: 0.33549955 - temperature 6.730645
# mean max of probabilities: 0.3362995 - temperature 6.711299
# mean max of probabilities: 0.33707964 - temperature 6.6919527
# mean max of probabilities: 0.3376596 - temperature 6.6726065
# mean max of probabilities: 0.33799657 - temperature 6.6540046
# mean max of probabilities: 0.33812475 - temperature 6.635733
# mean max of probabilities: 0.3383172 - temperature 6.6174617
# mean max of probabilities: 0.33834842 - temperature 6.59919
# mean max of probabilities: 0.33817315 - temperature 6.580919
# mean max of probabilities: 0.3379185 - temperature 6.5626473
# mean max of probabilities: 0.33762273 - temperature 6.544376
# mean max of probabilities: 0.33732563 - temperature 6.5261045
# mean max of probabilities: 0.3371361 - temperature 6.507833
# mean max of probabilities: 0.33698884 - temperature 6.4895616
# mean max of probabilities: 0.33688077 - temperature 6.47129
# mean max of probabilities: 0.33664143 - temperature 6.4530187
# mean max of probabilities: 0.3364253 - temperature 6.434747
# mean max of probabilities: 0.33627176 - temperature 6.416476
# mean max of probabilities: 0.33618405 - temperature 6.3982043
# mean max of probabilities: 0.33610162 - temperature 6.379933
# mean max of probabilities: 0.33617476 - temperature 6.3616614
# mean max of probabilities: 0.3362397 - temperature 6.34339
# mean max of probabilities: 0.33630684 - temperature 6.3251185
# mean max of probabilities: 0.33633044 - temperature 6.306847
# mean max of probabilities: 0.33649302 - temperature 6.2885756
# mean max of probabilities: 0.33653846 - temperature 6.2712107
# mean max of probabilities: 0.3368103 - temperature 6.254014
# mean max of probabilities: 0.33686012 - temperature 6.2368174
# mean max of probabilities: 0.33675158 - temperature 6.2196207
# mean max of probabilities: 0.33685407 - temperature 6.202424
# mean max of probabilities: 0.33703843 - temperature 6.1852274
# mean max of probabilities: 0.3372591 - temperature 6.1680307
# mean max of probabilities: 0.33760482 - temperature 6.150834
# mean max of probabilities: 0.3380014 - temperature 6.1336374
# mean max of probabilities: 0.33838916 - temperature 6.116441
# mean max of probabilities: 0.3389216 - temperature 6.099244
# mean max of probabilities: 0.33954674 - temperature 6.0820475
# mean max of probabilities: 0.3400494 - temperature 6.064851
# mean max of probabilities: 0.3406411 - temperature 6.047654
# mean max of probabilities: 0.3414792 - temperature 6.0304575
# mean max of probabilities: 0.34244934 - temperature 6.013261
# mean max of probabilities: 0.3432087 - temperature 5.996064
# mean max of probabilities: 0.3441455 - temperature 5.9788675
# mean max of probabilities: 0.34488574 - temperature 5.961671
# mean max of probabilities: 0.34553272 - temperature 5.944474
# mean max of probabilities: 0.346366 - temperature 5.9272776
# mean max of probabilities: 0.3471192 - temperature 5.910081
# mean max of probabilities: 0.34783453 - temperature 5.893626
# mean max of probabilities: 0.34855735 - temperature 5.8775043
# mean max of probabilities: 0.3493412 - temperature 5.8613825
# mean max of probabilities: 0.3499671 - temperature 5.8452606
# mean max of probabilities: 0.35083035 - temperature 5.8291388
# mean max of probabilities: 0.35140514 - temperature 5.813017
# mean max of probabilities: 0.35226104 - temperature 5.796895
# mean max of probabilities: 0.35311478 - temperature 5.780773
# mean max of probabilities: 0.35394934 - temperature 5.7646513
# mean max of probabilities: 0.35493308 - temperature 5.7485294
# mean max of probabilities: 0.35580602 - temperature 5.7324076
# mean max of probabilities: 0.3567266 - temperature 5.7162857
# mean max of probabilities: 0.35721534 - temperature 5.700164
# mean max of probabilities: 0.3581433 - temperature 5.684042
# mean max of probabilities: 0.35900822 - temperature 5.66792
# mean max of probabilities: 0.36010712 - temperature 5.6517982
# mean max of probabilities: 0.36115128 - temperature 5.6356764
# mean max of probabilities: 0.36214086 - temperature 5.6195545
# mean max of probabilities: 0.36320361 - temperature 5.6034327
# mean max of probabilities: 0.36428055 - temperature 5.587311
# mean max of probabilities: 0.36534464 - temperature 5.571189
# mean max of probabilities: 0.36662263 - temperature 5.555067
# mean max of probabilities: 0.36778906 - temperature 5.538945
# mean max of probabilities: 0.36900264 - temperature 5.5228887
# mean max of probabilities: 0.37020433 - temperature 5.5078416
# mean max of probabilities: 0.3712841 - temperature 5.4927945
# mean max of probabilities: 0.37251428 - temperature 5.4777474
# mean max of probabilities: 0.37395215 - temperature 5.4627004
# mean max of probabilities: 0.3754118 - temperature 5.4476533
# mean max of probabilities: 0.3768377 - temperature 5.432606
# mean max of probabilities: 0.3781637 - temperature 5.417559
# mean max of probabilities: 0.37936768 - temperature 5.402512
# mean max of probabilities: 0.38050032 - temperature 5.387465
# mean max of probabilities: 0.38156995 - temperature 5.372418
# mean max of probabilities: 0.38262254 - temperature 5.357371
# mean max of probabilities: 0.38361686 - temperature 5.342324
# mean max of probabilities: 0.3845564 - temperature 5.3272767
# mean max of probabilities: 0.3853734 - temperature 5.3122296
# mean max of probabilities: 0.3861024 - temperature 5.2971826
# mean max of probabilities: 0.38693073 - temperature 5.2821355
# mean max of probabilities: 0.38794065 - temperature 5.2670884
# mean max of probabilities: 0.3888964 - temperature 5.2520413
# mean max of probabilities: 0.38973907 - temperature 5.2369943
# mean max of probabilities: 0.39059517 - temperature 5.221947
# mean max of probabilities: 0.39145464 - temperature 5.2069
# mean max of probabilities: 0.3922737 - temperature 5.191853
# mean max of probabilities: 0.39319256 - temperature 5.176806
# mean max of probabilities: 0.39395165 - temperature 5.161759
# mean max of probabilities: 0.39470327 - temperature 5.146712
# mean max of probabilities: 0.39542493 - temperature 5.132464
# mean max of probabilities: 0.39597413 - temperature 5.1184916
# mean max of probabilities: 0.3966786 - temperature 5.1045194
# mean max of probabilities: 0.39729384 - temperature 5.090547
# mean max of probabilities: 0.39777058 - temperature 5.076575
# mean max of probabilities: 0.39845434 - temperature 5.0626025
# mean max of probabilities: 0.39904988 - temperature 5.04863
# mean max of probabilities: 0.39955464 - temperature 5.034658
# mean max of probabilities: 0.3999849 - temperature 5.0206857
# mean max of probabilities: 0.40041095 - temperature 5.0067134
# mean max of probabilities: 0.40102154 - temperature 4.992741
# mean max of probabilities: 0.40150625 - temperature 4.978769
# mean max of probabilities: 0.40197554 - temperature 4.9647965
# mean max of probabilities: 0.4025008 - temperature 4.9508243
# mean max of probabilities: 0.40308702 - temperature 4.936852
# mean max of probabilities: 0.40354866 - temperature 4.9228797
# mean max of probabilities: 0.40415317 - temperature 4.9089074
# mean max of probabilities: 0.4048942 - temperature 4.894935
# mean max of probabilities: 0.40549853 - temperature 4.880963
# mean max of probabilities: 0.4062086 - temperature 4.8669906
# mean max of probabilities: 0.40680817 - temperature 4.8530183
# mean max of probabilities: 0.40753457 - temperature 4.839046
# mean max of probabilities: 0.40826198 - temperature 4.8250737
# mean max of probabilities: 0.40922314 - temperature 4.8111014
# mean max of probabilities: 0.4100308 - temperature 4.797129
# mean max of probabilities: 0.41082755 - temperature 4.783157
# mean max of probabilities: 0.41187647 - temperature 4.7691846
# mean max of probabilities: 0.4125015 - temperature 4.755727
# mean max of probabilities: 0.4133515 - temperature 4.7428293
# mean max of probabilities: 0.41395533 - temperature 4.729932
# mean max of probabilities: 0.41465637 - temperature 4.7170343
# mean max of probabilities: 0.41558844 - temperature 4.704137
# mean max of probabilities: 0.41660008 - temperature 4.6912394
# mean max of probabilities: 0.41752765 - temperature 4.678342
# mean max of probabilities: 0.41828328 - temperature 4.6654444
# mean max of probabilities: 0.41908607 - temperature 4.652547
# mean max of probabilities: 0.41995567 - temperature 4.6396494
# mean max of probabilities: 0.4208614 - temperature 4.626752
# mean max of probabilities: 0.42171356 - temperature 4.6138544
# mean max of probabilities: 0.42238086 - temperature 4.600957
# mean max of probabilities: 0.42322245 - temperature 4.5880594
# mean max of probabilities: 0.4238334 - temperature 4.575162
# mean max of probabilities: 0.42455843 - temperature 4.5622644
# mean max of probabilities: 0.42522132 - temperature 4.549367
# mean max of probabilities: 0.42585206 - temperature 4.5364695
# mean max of probabilities: 0.4264514 - temperature 4.523572
# mean max of probabilities: 0.4273188 - temperature 4.5106745
# mean max of probabilities: 0.42797256 - temperature 4.497777
# mean max of probabilities: 0.42833897 - temperature 4.4848795
# mean max of probabilities: 0.429191 - temperature 4.471982
# mean max of probabilities: 0.4298896 - temperature 4.4590845
# mean max of probabilities: 0.43049386 - temperature 4.446187
# mean max of probabilities: 0.43095002 - temperature 4.4332895
# mean max of probabilities: 0.43154052 - temperature 4.420392
# mean max of probabilities: 0.43220165 - temperature 4.4074945
# mean max of probabilities: 0.43257177 - temperature 4.394597
# mean max of probabilities: 0.43315065 - temperature 4.3816996
# mean max of probabilities: 0.43397334 - temperature 4.3698144
# mean max of probabilities: 0.43466008 - temperature 4.3579917
# mean max of probabilities: 0.43541172 - temperature 4.346169
# mean max of probabilities: 0.43593532 - temperature 4.3343463
# mean max of probabilities: 0.43648595 - temperature 4.3225236
# mean max of probabilities: 0.43696558 - temperature 4.310701
# mean max of probabilities: 0.43758842 - temperature 4.298878
# mean max of probabilities: 0.43806913 - temperature 4.2870555
# mean max of probabilities: 0.43865815 - temperature 4.275233
# mean max of probabilities: 0.4391073 - temperature 4.26341
# mean max of probabilities: 0.43962866 - temperature 4.2515874
# mean max of probabilities: 0.43981037 - temperature 4.2397647
# mean max of probabilities: 0.44001764 - temperature 4.227942
# mean max of probabilities: 0.4403216 - temperature 4.2161193
# mean max of probabilities: 0.4406355 - temperature 4.2042966
# mean max of probabilities: 0.44074365 - temperature 4.192474
# mean max of probabilities: 0.44096935 - temperature 4.180651
# mean max of probabilities: 0.44114956 - temperature 4.1688285
# mean max of probabilities: 0.44138995 - temperature 4.157006
# mean max of probabilities: 0.44174883 - temperature 4.145183
# mean max of probabilities: 0.44218886 - temperature 4.1333604
# mean max of probabilities: 0.44215736 - temperature 4.1215377
# mean max of probabilities: 0.44230002 - temperature 4.109715
# mean max of probabilities: 0.44250622 - temperature 4.0978923
# mean max of probabilities: 0.44257966 - temperature 4.0860696
# mean max of probabilities: 0.4426953 - temperature 4.074247
# mean max of probabilities: 0.4429196 - temperature 4.062424
# mean max of probabilities: 0.44299036 - temperature 4.0506015
# mean max of probabilities: 0.4432101 - temperature 4.038779
# mean max of probabilities: 0.44327068 - temperature 4.026956
# mean max of probabilities: 0.4431176 - temperature 4.0151334
# mean max of probabilities: 0.4432232 - temperature 4.0033107
# mean max of probabilities: 0.44316238 - temperature 3.991875
# mean max of probabilities: 0.4431821 - temperature 3.9805896
# mean max of probabilities: 0.4431594 - temperature 3.9693043
# mean max of probabilities: 0.44284737 - temperature 3.958019
# mean max of probabilities: 0.44284284 - temperature 3.9467337
# mean max of probabilities: 0.44273236 - temperature 3.9354484
# mean max of probabilities: 0.4428225 - temperature 3.924163
# mean max of probabilities: 0.4428393 - temperature 3.9128778
# mean max of probabilities: 0.44285387 - temperature 3.9017434
# mean max of probabilities: 0.44320217 - temperature 3.8909955
# mean max of probabilities: 0.44337112 - temperature 3.8802476
# mean max of probabilities: 0.44367492 - temperature 3.8694997
# mean max of probabilities: 0.44406015 - temperature 3.8587518
# mean max of probabilities: 0.44416896 - temperature 3.8480039
# mean max of probabilities: 0.44423285 - temperature 3.837256
# mean max of probabilities: 0.44450995 - temperature 3.826508
# mean max of probabilities: 0.44428152 - temperature 3.8157601
# mean max of probabilities: 0.44433507 - temperature 3.8050122
# mean max of probabilities: 0.4442479 - temperature 3.7942643
# mean max of probabilities: 0.4441418 - temperature 3.7835164
# mean max of probabilities: 0.44424096 - temperature 3.7727685
# mean max of probabilities: 0.44405413 - temperature 3.7620206
# mean max of probabilities: 0.44407126 - temperature 3.7512727
# mean max of probabilities: 0.44402334 - temperature 3.7405248
# mean max of probabilities: 0.44391876 - temperature 3.7297769
# mean max of probabilities: 0.44392717 - temperature 3.719029
# mean max of probabilities: 0.4439296 - temperature 3.7085812
# mean max of probabilities: 0.44349054 - temperature 3.6983707
# mean max of probabilities: 0.4434628 - temperature 3.6881602
# mean max of probabilities: 0.44302082 - temperature 3.6779497
# mean max of probabilities: 0.44262132 - temperature 3.6677392
# mean max of probabilities: 0.44230732 - temperature 3.6575286
# mean max of probabilities: 0.44229934 - temperature 3.6473181
# mean max of probabilities: 0.44191304 - temperature 3.6371076
# mean max of probabilities: 0.4414922 - temperature 3.626897
# mean max of probabilities: 0.44137615 - temperature 3.6166866
# mean max of probabilities: 0.44112962 - temperature 3.606476
# mean max of probabilities: 0.44080934 - temperature 3.5962656
# mean max of probabilities: 0.44032258 - temperature 3.586055
# mean max of probabilities: 0.44001102 - temperature 3.5758445
# mean max of probabilities: 0.43981224 - temperature 3.565634
# mean max of probabilities: 0.4401687 - temperature 3.5554235
# mean max of probabilities: 0.4402788 - temperature 3.545213
# mean max of probabilities: 0.4401385 - temperature 3.5350025
# mean max of probabilities: 0.44013837 - temperature 3.524792
# mean max of probabilities: 0.43981782 - temperature 3.515067
# mean max of probabilities: 0.43974885 - temperature 3.505394
# mean max of probabilities: 0.43948933 - temperature 3.4957209
# mean max of probabilities: 0.43936378 - temperature 3.4860477
# mean max of probabilities: 0.43926427 - temperature 3.4763746
# mean max of probabilities: 0.43931955 - temperature 3.4667015
# mean max of probabilities: 0.439175 - temperature 3.4570284
# mean max of probabilities: 0.43912223 - temperature 3.4473553
# mean max of probabilities: 0.43901306 - temperature 3.4376822
# mean max of probabilities: 0.43925756 - temperature 3.428009
# mean max of probabilities: 0.43926024 - temperature 3.418336
# mean max of probabilities: 0.4391176 - temperature 3.4086628
# mean max of probabilities: 0.43889776 - temperature 3.3989897
# mean max of probabilities: 0.4387963 - temperature 3.3893166
# mean max of probabilities: 0.43870068 - temperature 3.3796434
# mean max of probabilities: 0.4384298 - temperature 3.3699703
# mean max of probabilities: 0.4382554 - temperature 3.3602972
# mean max of probabilities: 0.4382535 - temperature 3.350624
# mean max of probabilities: 0.43809763 - temperature 3.340951
# mean max of probabilities: 0.43776652 - temperature 3.3313918
# mean max of probabilities: 0.43738356 - temperature 3.322256
# mean max of probabilities: 0.43711424 - temperature 3.3131204
# mean max of probabilities: 0.436938 - temperature 3.3039846
# mean max of probabilities: 0.4367705 - temperature 3.294849
# mean max of probabilities: 0.4367249 - temperature 3.2857132
# mean max of probabilities: 0.43635553 - temperature 3.2765775
# mean max of probabilities: 0.43595865 - temperature 3.2674417
# mean max of probabilities: 0.43582147 - temperature 3.258306
# mean max of probabilities: 0.4356272 - temperature 3.2491703
# mean max of probabilities: 0.4350274 - temperature 3.2400346
# mean max of probabilities: 0.4348782 - temperature 3.2308989
# mean max of probabilities: 0.4349153 - temperature 3.2217631
# mean max of probabilities: 0.43470618 - temperature 3.2126274
# mean max of probabilities: 0.43473193 - temperature 3.2034917
# mean max of probabilities: 0.43460232 - temperature 3.194356
# mean max of probabilities: 0.43431377 - temperature 3.1852202
# mean max of probabilities: 0.43428326 - temperature 3.1760845
# mean max of probabilities: 0.4342148 - temperature 3.1669488
# mean max of probabilities: 0.43445766 - temperature 3.157813
# mean max of probabilities: 0.43456775 - temperature 3.1486773
# mean max of probabilities: 0.43399498 - temperature 3.1397367
# mean max of probabilities: 0.43383652 - temperature 3.1311383
# mean max of probabilities: 0.43380684 - temperature 3.12254
# mean max of probabilities: 0.433522 - temperature 3.1139417
# mean max of probabilities: 0.43393344 - temperature 3.1053433
# mean max of probabilities: 0.4342113 - temperature 3.096745
# mean max of probabilities: 0.43397528 - temperature 3.0881467
# mean max of probabilities: 0.4338585 - temperature 3.0795484
# mean max of probabilities: 0.43383324 - temperature 3.07095
# mean max of probabilities: 0.43379208 - temperature 3.0623517
# mean max of probabilities: 0.43356892 - temperature 3.0537534
# mean max of probabilities: 0.43331105 - temperature 3.045155
# mean max of probabilities: 0.4326905 - temperature 3.0365567
# mean max of probabilities: 0.4325672 - temperature 3.0279584
# mean max of probabilities: 0.43294367 - temperature 3.01936
# mean max of probabilities: 0.43321753 - temperature 3.0107617
# mean max of probabilities: 0.43357706 - temperature 3.0021634
# mean max of probabilities: 0.43370363 - temperature 2.993565
# mean max of probabilities: 0.43407926 - temperature 2.9849668
# mean max of probabilities: 0.43469885 - temperature 2.9763684
# mean max of probabilities: 0.43520537 - temperature 2.96777
# mean max of probabilities: 0.43553257 - temperature 2.9591718
# mean max of probabilities: 0.4359084 - temperature 2.9506862
# mean max of probabilities: 0.43651238 - temperature 2.9426253
# mean max of probabilities: 0.43680748 - temperature 2.9345644
# mean max of probabilities: 0.43710065 - temperature 2.9265034
# mean max of probabilities: 0.43728772 - temperature 2.9184425
# mean max of probabilities: 0.4375191 - temperature 2.9103816
# mean max of probabilities: 0.4380882 - temperature 2.9023206
# mean max of probabilities: 0.438484 - temperature 2.8942597
# mean max of probabilities: 0.438735 - temperature 2.8861988
# mean max of probabilities: 0.4391194 - temperature 2.8781378
# mean max of probabilities: 0.43930316 - temperature 2.870077
# mean max of probabilities: 0.43899843 - temperature 2.862016
# mean max of probabilities: 0.4391873 - temperature 2.853955
# mean max of probabilities: 0.4391633 - temperature 2.845894
# mean max of probabilities: 0.438712 - temperature 2.8378332
# mean max of probabilities: 0.4386516 - temperature 2.8297722
# mean max of probabilities: 0.438726 - temperature 2.8217113
# mean max of probabilities: 0.4385529 - temperature 2.8136504
# mean max of probabilities: 0.43888515 - temperature 2.8055894
# mean max of probabilities: 0.4387093 - temperature 2.7975285
# mean max of probabilities: 0.43862593 - temperature 2.7894676
# mean max of probabilities: 0.4386323 - temperature 2.7814066
# mean max of probabilities: 0.4390416 - temperature 2.7733457
# mean max of probabilities: 0.43916395 - temperature 2.7652848
# mean max of probabilities: 0.43923247 - temperature 2.7575357
# mean max of probabilities: 0.43939948 - temperature 2.7500122
# mean max of probabilities: 0.4394356 - temperature 2.7424886
# mean max of probabilities: 0.4395596 - temperature 2.734965
# mean max of probabilities: 0.4396988 - temperature 2.7274415
# mean max of probabilities: 0.43995228 - temperature 2.719918
# mean max of probabilities: 0.44025943 - temperature 2.7123945
# mean max of probabilities: 0.44025475 - temperature 2.704871
# mean max of probabilities: 0.44034168 - temperature 2.6973474
# mean max of probabilities: 0.44032636 - temperature 2.6898239
# mean max of probabilities: 0.44049245 - temperature 2.6823003
# mean max of probabilities: 0.44038445 - temperature 2.6747768
# mean max of probabilities: 0.44049358 - temperature 2.6672533
# mean max of probabilities: 0.44025704 - temperature 2.6597297
# mean max of probabilities: 0.44041276 - temperature 2.6522062
# mean max of probabilities: 0.4403082 - temperature 2.6446826
# mean max of probabilities: 0.44023257 - temperature 2.637159
# mean max of probabilities: 0.4399586 - temperature 2.6296356
# mean max of probabilities: 0.44003096 - temperature 2.622112
# mean max of probabilities: 0.44028702 - temperature 2.6145885
# mean max of probabilities: 0.4403577 - temperature 2.607065
# mean max of probabilities: 0.44069487 - temperature 2.5995414
# mean max of probabilities: 0.44080108 - temperature 2.592018
# mean max of probabilities: 0.4409801 - temperature 2.5844944
# mean max of probabilities: 0.44084498 - temperature 2.5769708
# mean max of probabilities: 0.44077113 - temperature 2.5695887
# mean max of probabilities: 0.44067505 - temperature 2.5626025
# mean max of probabilities: 0.44094926 - temperature 2.5556164
# mean max of probabilities: 0.4409036 - temperature 2.5486302
# mean max of probabilities: 0.44043842 - temperature 2.541644
# mean max of probabilities: 0.44051704 - temperature 2.534658
# mean max of probabilities: 0.4406388 - temperature 2.5276718
# mean max of probabilities: 0.44038305 - temperature 2.5206857
# mean max of probabilities: 0.44068265 - temperature 2.5136995
# mean max of probabilities: 0.44082206 - temperature 2.5067134
# mean max of probabilities: 0.44089562 - temperature 2.4997272
# mean max of probabilities: 0.44109258 - temperature 2.492741
# mean max of probabilities: 0.44116697 - temperature 2.485755
# mean max of probabilities: 0.44092277 - temperature 2.4787688
# mean max of probabilities: 0.44083965 - temperature 2.4717827
# mean max of probabilities: 0.4406464 - temperature 2.4647965
# mean max of probabilities: 0.4407176 - temperature 2.4578104
# mean max of probabilities: 0.44133124 - temperature 2.4508243
# mean max of probabilities: 0.4417666 - temperature 2.4438381
# mean max of probabilities: 0.44172573 - temperature 2.436852
# mean max of probabilities: 0.4422571 - temperature 2.4298658
# mean max of probabilities: 0.44262987 - temperature 2.4228797
# mean max of probabilities: 0.44294667 - temperature 2.4158936
# mean max of probabilities: 0.4432246 - temperature 2.4089074
# mean max of probabilities: 0.44307154 - temperature 2.4019213
# mean max of probabilities: 0.44321686 - temperature 2.3949351
# mean max of probabilities: 0.44345912 - temperature 2.387949
# mean max of probabilities: 0.44350705 - temperature 2.3809628
# mean max of probabilities: 0.44368708 - temperature 2.3745131
# mean max of probabilities: 0.44443744 - temperature 2.3680644
# mean max of probabilities: 0.4447493 - temperature 2.3616157
# mean max of probabilities: 0.44537306 - temperature 2.355167
# mean max of probabilities: 0.4456357 - temperature 2.3487182
# mean max of probabilities: 0.44562858 - temperature 2.3422694
# mean max of probabilities: 0.44630197 - temperature 2.3358207
# mean max of probabilities: 0.44632208 - temperature 2.329372
# mean max of probabilities: 0.44642156 - temperature 2.3229232
# mean max of probabilities: 0.44666126 - temperature 2.3164744
# mean max of probabilities: 0.4467763 - temperature 2.3100257
# mean max of probabilities: 0.44677487 - temperature 2.303577
# mean max of probabilities: 0.44706866 - temperature 2.2971282
# mean max of probabilities: 0.44739386 - temperature 2.2906795
# mean max of probabilities: 0.447761 - temperature 2.2842307
# mean max of probabilities: 0.44793332 - temperature 2.277782
# mean max of probabilities: 0.44845843 - temperature 2.2713332
# mean max of probabilities: 0.44861472 - temperature 2.2648845
# mean max of probabilities: 0.44875786 - temperature 2.2584357
# mean max of probabilities: 0.4489225 - temperature 2.251987
# mean max of probabilities: 0.4487647 - temperature 2.2455382
# mean max of probabilities: 0.44896993 - temperature 2.2390895
# mean max of probabilities: 0.449195 - temperature 2.2326407
# mean max of probabilities: 0.44951096 - temperature 2.226192
# mean max of probabilities: 0.4498782 - temperature 2.2197433
# mean max of probabilities: 0.45035776 - temperature 2.2132945
# mean max of probabilities: 0.45023948 - temperature 2.2068458
# mean max of probabilities: 0.45044306 - temperature 2.200397
# mean max of probabilities: 0.44990608 - temperature 2.1939483
# mean max of probabilities: 0.44987106 - temperature 2.1877475
# mean max of probabilities: 0.44963974 - temperature 2.1818361
# mean max of probabilities: 0.449571 - temperature 2.1759248
# mean max of probabilities: 0.44905397 - temperature 2.1700134
# mean max of probabilities: 0.4483281 - temperature 2.164102
# mean max of probabilities: 0.44775334 - temperature 2.1581907
# mean max of probabilities: 0.447503 - temperature 2.1522794
# mean max of probabilities: 0.44726348 - temperature 2.146368
# mean max of probabilities: 0.44709498 - temperature 2.1404567
# mean max of probabilities: 0.44713825 - temperature 2.1345453
# mean max of probabilities: 0.44737962 - temperature 2.128634
# mean max of probabilities: 0.44714794 - temperature 2.1227226
# mean max of probabilities: 0.4472846 - temperature 2.1168113
# mean max of probabilities: 0.44782558 - temperature 2.1109
# mean max of probabilities: 0.44791728 - temperature 2.1049886
# mean max of probabilities: 0.44820303 - temperature 2.0990772
# mean max of probabilities: 0.4479383 - temperature 2.0931659
# mean max of probabilities: 0.44804493 - temperature 2.0872545
# mean max of probabilities: 0.4480746 - temperature 2.0813432
# mean max of probabilities: 0.44808558 - temperature 2.0754318
# mean max of probabilities: 0.44817892 - temperature 2.0695205
# mean max of probabilities: 0.44820544 - temperature 2.0636091
# mean max of probabilities: 0.4488091 - temperature 2.0576978
# mean max of probabilities: 0.44899547 - temperature 2.0517864
# mean max of probabilities: 0.44869345 - temperature 2.045875
# mean max of probabilities: 0.4487784 - temperature 2.0399637
# mean max of probabilities: 0.44868812 - temperature 2.0340524
# mean max of probabilities: 0.44861403 - temperature 2.028141
# mean max of probabilities: 0.44835413 - temperature 2.0222297
# mean max of probabilities: 0.44803858 - temperature 2.0163183
# mean max of probabilities: 0.44710937 - temperature 2.010407
# mean max of probabilities: 0.44683522 - temperature 2.0044956
# mean max of probabilities: 0.44660935 - temperature 1.9986486
# mean max of probabilities: 0.44635785 - temperature 1.993006
# mean max of probabilities: 0.44632116 - temperature 1.9873633
# mean max of probabilities: 0.44631284 - temperature 1.9817207
# mean max of probabilities: 0.44653338 - temperature 1.976078
# mean max of probabilities: 0.4470691 - temperature 1.9704354
# mean max of probabilities: 0.44725835 - temperature 1.9647927
# mean max of probabilities: 0.447277 - temperature 1.9591501
# mean max of probabilities: 0.44749704 - temperature 1.9535074
# mean max of probabilities: 0.44769695 - temperature 1.9480798
# mean max of probabilities: 0.4476381 - temperature 1.9427059
# mean max of probabilities: 0.44770607 - temperature 1.9373319
# mean max of probabilities: 0.4476143 - temperature 1.931958
# mean max of probabilities: 0.44770896 - temperature 1.926584
# mean max of probabilities: 0.44824696 - temperature 1.92121
# mean max of probabilities: 0.4485307 - temperature 1.9158361
# mean max of probabilities: 0.44883567 - temperature 1.9104621
# mean max of probabilities: 0.44865307 - temperature 1.9050882
# mean max of probabilities: 0.44877794 - temperature 1.8997142
# mean max of probabilities: 0.44903973 - temperature 1.8943403
# mean max of probabilities: 0.4490946 - temperature 1.8889663
# mean max of probabilities: 0.44927728 - temperature 1.8835924
# mean max of probabilities: 0.44977254 - temperature 1.8782184
# mean max of probabilities: 0.44997168 - temperature 1.8728445
# mean max of probabilities: 0.44964534 - temperature 1.8674705
# mean max of probabilities: 0.4497333 - temperature 1.8620965
# mean max of probabilities: 0.45025432 - temperature 1.8567436
# mean max of probabilities: 0.45028266 - temperature 1.8516383
# mean max of probabilities: 0.45066503 - temperature 1.8465331
# mean max of probabilities: 0.45084614 - temperature 1.8414278
# mean max of probabilities: 0.450784 - temperature 1.8363225
# mean max of probabilities: 0.4507677 - temperature 1.8312173
# mean max of probabilities: 0.4513567 - temperature 1.826112
# mean max of probabilities: 0.45154735 - temperature 1.8210068
# mean max of probabilities: 0.4515141 - temperature 1.8159015
# mean max of probabilities: 0.45166436 - temperature 1.8107963
# mean max of probabilities: 0.45176256 - temperature 1.805691
# mean max of probabilities: 0.4519303 - temperature 1.8005857
# mean max of probabilities: 0.4517387 - temperature 1.7954805
# mean max of probabilities: 0.45147485 - temperature 1.7903752
# mean max of probabilities: 0.45147485 - temperature 1.78527
# mean max of probabilities: 0.4516937 - temperature 1.7801647
# mean max of probabilities: 0.45184267 - temperature 1.7750595
# mean max of probabilities: 0.45196855 - temperature 1.7699542
# mean max of probabilities: 0.45214316 - temperature 1.764849
# mean max of probabilities: 0.45232123 - temperature 1.7598574
# mean max of probabilities: 0.4526338 - temperature 1.7550209
# mean max of probabilities: 0.4528533 - temperature 1.7501843
# mean max of probabilities: 0.4534118 - temperature 1.7453477
# mean max of probabilities: 0.4536142 - temperature 1.7405112
# mean max of probabilities: 0.45392817 - temperature 1.7356746
# mean max of probabilities: 0.4542775 - temperature 1.7308381
# mean max of probabilities: 0.45455128 - temperature 1.7260015
# mean max of probabilities: 0.4547441 - temperature 1.721165
# mean max of probabilities: 0.45501712 - temperature 1.7163284
# mean max of probabilities: 0.45523283 - temperature 1.7114918
# mean max of probabilities: 0.45512804 - temperature 1.7066553
# mean max of probabilities: 0.45493096 - temperature 1.7018187
# mean max of probabilities: 0.45528907 - temperature 1.6969821
# mean max of probabilities: 0.45505303 - temperature 1.6921456
# mean max of probabilities: 0.4553709 - temperature 1.687309
# mean max of probabilities: 0.45574558 - temperature 1.6824725
# mean max of probabilities: 0.4557643 - temperature 1.6776359
# mean max of probabilities: 0.4556606 - temperature 1.6727993
# mean max of probabilities: 0.45590514 - temperature 1.6679628
# mean max of probabilities: 0.45587933 - temperature 1.6633228
# mean max of probabilities: 0.45612344 - temperature 1.658755
# mean max of probabilities: 0.45602372 - temperature 1.6541871
# mean max of probabilities: 0.45622885 - temperature 1.6496192
# mean max of probabilities: 0.45622456 - temperature 1.6450514
# mean max of probabilities: 0.45645666 - temperature 1.6404835
# mean max of probabilities: 0.45642772 - temperature 1.6359156
# mean max of probabilities: 0.45657587 - temperature 1.6313478
# mean max of probabilities: 0.45694202 - temperature 1.6267799
# mean max of probabilities: 0.4572367 - temperature 1.622212
# mean max of probabilities: 0.45751098 - temperature 1.6176442
# mean max of probabilities: 0.45745763 - temperature 1.6130763
# mean max of probabilities: 0.45770222 - temperature 1.6085085
# mean max of probabilities: 0.4578705 - temperature 1.6039406
# mean max of probabilities: 0.45803878 - temperature 1.5993727
# mean max of probabilities: 0.45851353 - temperature 1.5948049
# mean max of probabilities: 0.4589616 - temperature 1.590237
# mean max of probabilities: 0.4592552 - temperature 1.5856692
# mean max of probabilities: 0.45977354 - temperature 1.5811013
# mean max of probabilities: 0.45994788 - temperature 1.5765334
# mean max of probabilities: 0.46051753 - temperature 1.5719656
# mean max of probabilities: 0.46111545 - temperature 1.5676348
# mean max of probabilities: 0.46146742 - temperature 1.5633357
# mean max of probabilities: 0.461622 - temperature 1.5590365
# mean max of probabilities: 0.4623245 - temperature 1.5547373
# mean max of probabilities: 0.46327505 - temperature 1.5504382
# mean max of probabilities: 0.46403095 - temperature 1.546139
# mean max of probabilities: 0.46477076 - temperature 1.5418398
# mean max of probabilities: 0.46215484 - temperature 1.5375407
# mean max of probabilities: 0.4623145 - temperature 1.5332415
# mean max of probabilities: 0.46278664 - temperature 1.5289423
# mean max of probabilities: 0.463586 - temperature 1.5246432
# mean max of probabilities: 0.46476743 - temperature 1.520344
# mean max of probabilities: 0.46586934 - temperature 1.5160449
# mean max of probabilities: 0.46644711 - temperature 1.5117457
# mean max of probabilities: 0.46729293 - temperature 1.5074465
# mean max of probabilities: 0.4680439 - temperature 1.5031474
# mean max of probabilities: 0.4688433 - temperature 1.4988482
# mean max of probabilities: 0.469577 - temperature 1.494549
# mean max of probabilities: 0.47049317 - temperature 1.4902499
# mean max of probabilities: 0.4717045 - temperature 1.4859507
# mean max of probabilities: 0.4728016 - temperature 1.4816515
# mean max of probabilities: 0.47299927 - temperature 1.4773524
# mean max of probabilities: 0.47434288 - temperature 1.4732492
# mean max of probabilities: 0.47547144 - temperature 1.4692187
# mean max of probabilities: 0.4767436 - temperature 1.4651883
# mean max of probabilities: 0.47775397 - temperature 1.4611578
# mean max of probabilities: 0.47629127 - temperature 1.4571273
# mean max of probabilities: 0.47697607 - temperature 1.4530969
# mean max of probabilities: 0.4781703 - temperature 1.4490664
# mean max of probabilities: 0.4794316 - temperature 1.4450359
# mean max of probabilities: 0.4804934 - temperature 1.4410055
# mean max of probabilities: 0.48145443 - temperature 1.436975
# mean max of probabilities: 0.48242307 - temperature 1.4329445
# mean max of probabilities: 0.48323822 - temperature 1.4289141
# mean max of probabilities: 0.4842503 - temperature 1.4248836
# mean max of probabilities: 0.48344177 - temperature 1.4208531
# mean max of probabilities: 0.48351815 - temperature 1.4168227
# mean max of probabilities: 0.48406523 - temperature 1.4127922
# mean max of probabilities: 0.48486242 - temperature 1.4087617
# mean max of probabilities: 0.48610425 - temperature 1.4047313
# mean max of probabilities: 0.48749343 - temperature 1.4007008
# mean max of probabilities: 0.48860094 - temperature 1.3966703
# mean max of probabilities: 0.48972917 - temperature 1.3926399
# mean max of probabilities: 0.49109915 - temperature 1.3886094
# mean max of probabilities: 0.49234304 - temperature 1.384579
# mean max of probabilities: 0.49367285 - temperature 1.3805753
# mean max of probabilities: 0.49499294 - temperature 1.3768135
# mean max of probabilities: 0.4960436 - temperature 1.3730518
# mean max of probabilities: 0.49706402 - temperature 1.36929
# mean max of probabilities: 0.4980753 - temperature 1.3655282
# mean max of probabilities: 0.49910033 - temperature 1.3617665
# mean max of probabilities: 0.49991754 - temperature 1.3580047
# mean max of probabilities: 0.50101197 - temperature 1.3542429
# mean max of probabilities: 0.50176156 - temperature 1.3504812
# mean max of probabilities: 0.5028992 - temperature 1.3467194
# mean max of probabilities: 0.50359714 - temperature 1.3429576
# mean max of probabilities: 0.50444245 - temperature 1.3391958
# mean max of probabilities: 0.5051618 - temperature 1.3354341
# mean max of probabilities: 0.5059835 - temperature 1.3316723
# mean max of probabilities: 0.5068493 - temperature 1.3279105
# mean max of probabilities: 0.5076297 - temperature 1.3241488
# mean max of probabilities: 0.5087595 - temperature 1.320387
# mean max of probabilities: 0.50946796 - temperature 1.3166252
# mean max of probabilities: 0.51052046 - temperature 1.3128635
# mean max of probabilities: 0.5113192 - temperature 1.3091017
# mean max of probabilities: 0.5121879 - temperature 1.3053399
# mean max of probabilities: 0.513026 - temperature 1.3015782
# mean max of probabilities: 0.5140109 - temperature 1.2978164
# mean max of probabilities: 0.5148143 - temperature 1.2940546
# mean max of probabilities: 0.51553327 - temperature 1.2902929
# mean max of probabilities: 0.5165219 - temperature 1.2865311
# mean max of probabilities: 0.5173829 - temperature 1.2829796
# mean max of probabilities: 0.5183025 - temperature 1.2794865
# mean max of probabilities: 0.519146 - temperature 1.2759935
# mean max of probabilities: 0.52019733 - temperature 1.2725004
# mean max of probabilities: 0.5209492 - temperature 1.2690073
# mean max of probabilities: 0.5218245 - temperature 1.2655143
# mean max of probabilities: 0.52257985 - temperature 1.2620212
# mean max of probabilities: 0.5232297 - temperature 1.2585281
# mean max of probabilities: 0.5238823 - temperature 1.255035
# mean max of probabilities: 0.52463776 - temperature 1.251542
# mean max of probabilities: 0.5252449 - temperature 1.2480489
# mean max of probabilities: 0.52405345 - temperature 1.2445558
# mean max of probabilities: 0.5242557 - temperature 1.2410628
# mean max of probabilities: 0.5245712 - temperature 1.2375697
# mean max of probabilities: 0.5250533 - temperature 1.2340766
# mean max of probabilities: 0.52570736 - temperature 1.2305835
# mean max of probabilities: 0.52632964 - temperature 1.2270905
# mean max of probabilities: 0.5269896 - temperature 1.2235974
# mean max of probabilities: 0.52707833 - temperature 1.2201043
# mean max of probabilities: 0.5278283 - temperature 1.2166113
# mean max of probabilities: 0.5284541 - temperature 1.2131182
# mean max of probabilities: 0.5288568 - temperature 1.2096251
# ...
# mean max of probabilities: 0.99983144 - temperature 0.1
# mean max of probabilities: 0.9998317 - temperature 0.1
# mean max of probabilities: 0.99983156 - temperature 0.1
# mean max of probabilities: 0.99983186 - temperature 0.1
# mean max of probabilities: 0.99983203 - temperature 0.1
# mean max of probabilities: 0.9998325 - temperature 0.1
# mean max of probabilities: 0.9998329 - temperature 0.1
# mean max of probabilities: 0.9998331 - temperature 0.1
# mean max of probabilities: 0.99983335 - temperature 0.1
# mean max of probabilities: 0.9998338 - temperature 0.1
# mean max of probabilities: 0.9998337 - temperature 0.1
# mean max of probabilities: 0.9998338 - temperature 0.1
# mean max of probabilities: 0.99983394 - temperature 0.1
# mean max of probabilities: 0.99983406 - temperature 0.1
# mean max of probabilities: 0.9998343 - temperature 0.1
# mean max of probabilities: 0.9998345 - temperature 0.1
# mean max of probabilities: 0.9998352 - temperature 0.1
# mean max of probabilities: 0.9998354 - temperature 0.1
# mean max of probabilities: 0.99983525 - temperature 0.1
# mean max of probabilities: 0.9998354 - temperature 0.1
# mean max of probabilities: 0.9998354 - temperature 0.1
# mean max of probabilities: 0.99983543 - temperature 0.1
# mean max of probabilities: 0.9998355 - temperature 0.1
# mean max of probabilities: 0.999836 - temperature 0.1
# mean max of probabilities: 0.9998364 - temperature 0.1
# mean max of probabilities: 0.9998367 - temperature 0.1
# mean max of probabilities: 0.99983704 - temperature 0.1
# mean max of probabilities: 0.9998372 - temperature 0.1
# mean max of probabilities: 0.99983746 - temperature 0.1
# mean max of probabilities: 0.9998375 - temperature 0.1
# mean max of probabilities: 0.9998377 - temperature 0.1
# mean max of probabilities: 0.9998378 - temperature 0.1
# mean max of probabilities: 0.99983805 - temperature 0.1
# mean max of probabilities: 0.99983865 - temperature 0.1
# mean max of probabilities: 0.9998387 - temperature 0.1
# mean max of probabilities: 0.99983895 - temperature 0.1
# mean max of probabilities: 0.999839 - temperature 0.1
# mean max of probabilities: 0.99983907 - temperature 0.1
# mean max of probabilities: 0.9998392 - temperature 0.1
# mean max of probabilities: 0.9998393 - temperature 0.1
# mean max of probabilities: 0.9998395 - temperature 0.1
# mean max of probabilities: 0.9998391 - temperature 0.1
# mean max of probabilities: 0.99983925 - temperature 0.1
# mean max of probabilities: 0.99983925 - temperature 0.1
# mean max of probabilities: 0.99983954 - temperature 0.1
# mean max of probabilities: 0.99983966 - temperature 0.1
# mean max of probabilities: 0.99984 - temperature 0.1
# mean max of probabilities: 0.99984014 - temperature 0.1
# mean max of probabilities: 0.9998402 - temperature 0.1
# mean max of probabilities: 0.99984074 - temperature 0.1
# mean max of probabilities: 0.9998408 - temperature 0.1
# mean max of probabilities: 0.9998407 - temperature 0.1
# mean max of probabilities: 0.9998409 - temperature 0.1
# mean max of probabilities: 0.9998411 - temperature 0.1
# mean max of probabilities: 0.9998413 - temperature 0.1
# mean max of probabilities: 0.99984145 - temperature 0.1
# mean max of probabilities: 0.9998416 - temperature 0.1
# mean max of probabilities: 0.99984175 - temperature 0.1
# mean max of probabilities: 0.99984187 - temperature 0.1
# mean max of probabilities: 0.9998422 - temperature 0.1
# mean max of probabilities: 0.9998422 - temperature 0.1
# mean max of probabilities: 0.9998425 - temperature 0.1
# mean max of probabilities: 0.9998429 - temperature 0.1
# mean max of probabilities: 0.9998433 - temperature 0.1
# mean max of probabilities: 0.999844 - temperature 0.1
# mean max of probabilities: 0.999844 - temperature 0.1
# mean max of probabilities: 0.99984413 - temperature 0.1
# mean max of probabilities: 0.9998445 - temperature 0.1
# mean max of probabilities: 0.99984473 - temperature 0.1
# mean max of probabilities: 0.9998451 - temperature 0.1
# mean max of probabilities: 0.99984515 - temperature 0.1
# mean max of probabilities: 0.9998454 - temperature 0.1
# mean max of probabilities: 0.99984556 - temperature 0.1
# mean max of probabilities: 0.99984586 - temperature 0.1
# mean max of probabilities: 0.9998461 - temperature 0.1
# mean max of probabilities: 0.99984634 - temperature 0.1
# mean max of probabilities: 0.9998464 - temperature 0.1
# mean max of probabilities: 0.99984664 - temperature 0.1
# mean max of probabilities: 0.999847 - temperature 0.1
# mean max of probabilities: 0.99984705 - temperature 0.1
# mean max of probabilities: 0.9998472 - temperature 0.1
# mean max of probabilities: 0.9998474 - temperature 0.1
# mean max of probabilities: 0.99984765 - temperature 0.1
# mean max of probabilities: 0.9998478 - temperature 0.1
# mean max of probabilities: 0.99984807 - temperature 0.1
# mean max of probabilities: 0.9998482 - temperature 0.1
# mean max of probabilities: 0.9998481 - temperature 0.1
# mean max of probabilities: 0.99984825 - temperature 0.1
# mean max of probabilities: 0.9998482 - temperature 0.1
# mean max of probabilities: 0.9998482 - temperature 0.1
# mean max of probabilities: 0.9998483 - temperature 0.1
# mean max of probabilities: 0.99984825 - temperature 0.1
# mean max of probabilities: 0.9998484 - temperature 0.1
# mean max of probabilities: 0.9998488 - temperature 0.1
# mean max of probabilities: 0.999849 - temperature 0.1
# mean max of probabilities: 0.9998494 - temperature 0.1
# mean max of probabilities: 0.9998496 - temperature 0.1
# mean max of probabilities: 0.99984986 - temperature 0.1
# mean max of probabilities: 0.9998499 - temperature 0.1
# mean max of probabilities: 0.99985015 - temperature 0.1
# mean max of probabilities: 0.9998501 - temperature 0.1
# mean max of probabilities: 0.9998502 - temperature 0.1
# mean max of probabilities: 0.99985033 - temperature 0.1
# mean max of probabilities: 0.9998504 - temperature 0.1
# mean max of probabilities: 0.9998507 - temperature 0.1
# mean max of probabilities: 0.9998508 - temperature 0.1
# mean max of probabilities: 0.99985075 - temperature 0.1
# mean max of probabilities: 0.99985105 - temperature 0.1
# mean max of probabilities: 0.99985117 - temperature 0.1
# mean max of probabilities: 0.9998514 - temperature 0.1
# mean max of probabilities: 0.9998516 - temperature 0.1
# mean max of probabilities: 0.9998518 - temperature 0.1
# mean max of probabilities: 0.9998519 - temperature 0.1
# mean max of probabilities: 0.99985206 - temperature 0.1
# mean max of probabilities: 0.99985206 - temperature 0.1
# mean max of probabilities: 0.9998522 - temperature 0.1
# mean max of probabilities: 0.99985224 - temperature 0.1
# mean max of probabilities: 0.9998525 - temperature 0.1
# mean max of probabilities: 0.9998531 - temperature 0.1
# mean max of probabilities: 0.999853 - temperature 0.1
# mean max of probabilities: 0.9998529 - temperature 0.1
# mean max of probabilities: 0.9998534 - temperature 0.1
# mean max of probabilities: 0.9998535 - temperature 0.1
# mean max of probabilities: 0.99985373 - temperature 0.1
# mean max of probabilities: 0.9998537 - temperature 0.1
# mean max of probabilities: 0.999854 - temperature 0.1
# mean max of probabilities: 0.99985427 - temperature 0.1
# mean max of probabilities: 0.99985456 - temperature 0.1
# mean max of probabilities: 0.9998548 - temperature 0.1
# mean max of probabilities: 0.99985474 - temperature 0.1
# mean max of probabilities: 0.999855 - temperature 0.1
# mean max of probabilities: 0.9998553 - temperature 0.1
# mean max of probabilities: 0.9998557 - temperature 0.1
# mean max of probabilities: 0.9998557 - temperature 0.1
# mean max of probabilities: 0.9998559 - temperature 0.1
# mean max of probabilities: 0.9998561 - temperature 0.1
# mean max of probabilities: 0.9998565 - temperature 0.1
# mean max of probabilities: 0.9998565 - temperature 0.1
# mean max of probabilities: 0.9998565 - temperature 0.1
# mean max of probabilities: 0.9998569 - temperature 0.1
# mean max of probabilities: 0.99985725 - temperature 0.1
# mean max of probabilities: 0.99985725 - temperature 0.1
# mean max of probabilities: 0.9998575 - temperature 0.1
# mean max of probabilities: 0.99985754 - temperature 0.1
# mean max of probabilities: 0.9998577 - temperature 0.1
# mean max of probabilities: 0.99985796 - temperature 0.1
# mean max of probabilities: 0.9998581 - temperature 0.1
# mean max of probabilities: 0.9998585 - temperature 0.1
# mean max of probabilities: 0.9998587 - temperature 0.1
# mean max of probabilities: 0.999859 - temperature 0.1
# mean max of probabilities: 0.99985933 - temperature 0.1
# mean max of probabilities: 0.99985975 - temperature 0.1
# mean max of probabilities: 0.9998599 - temperature 0.1
# mean max of probabilities: 0.99986005 - temperature 0.1
# mean max of probabilities: 0.99985987 - temperature 0.1
# mean max of probabilities: 0.99986005 - temperature 0.1
# mean max of probabilities: 0.9998602 - temperature 0.1
# mean max of probabilities: 0.9998606 - temperature 0.1
# mean max of probabilities: 0.99986076 - temperature 0.1
# mean max of probabilities: 0.9998607 - temperature 0.1
# mean max of probabilities: 0.999861 - temperature 0.1
# mean max of probabilities: 0.99986106 - temperature 0.1
# mean max of probabilities: 0.9998615 - temperature 0.1
# mean max of probabilities: 0.9998617 - temperature 0.1
# mean max of probabilities: 0.9998616 - temperature 0.1
# mean max of probabilities: 0.9998616 - temperature 0.1
# mean max of probabilities: 0.99986154 - temperature 0.1
# mean max of probabilities: 0.99986166 - temperature 0.1
# mean max of probabilities: 0.9998618 - temperature 0.1
# mean max of probabilities: 0.99986196 - temperature 0.1
# mean max of probabilities: 0.99986225 - temperature 0.1
# mean max of probabilities: 0.99986225 - temperature 0.1
# mean max of probabilities: 0.99986243 - temperature 0.1
# mean max of probabilities: 0.99986255 - temperature 0.1
# mean max of probabilities: 0.9998628 - temperature 0.1
# mean max of probabilities: 0.9998628 - temperature 0.1
# mean max of probabilities: 0.99986297 - temperature 0.1
# mean max of probabilities: 0.9998632 - temperature 0.1
# mean max of probabilities: 0.9998633 - temperature 0.1
# mean max of probabilities: 0.9998637 - temperature 0.1
# mean max of probabilities: 0.99986386 - temperature 0.1
# mean max of probabilities: 0.99986386 - temperature 0.1
# mean max of probabilities: 0.999864 - temperature 0.1
# mean max of probabilities: 0.99986416 - temperature 0.1
# mean max of probabilities: 0.99986404 - temperature 0.1
# mean max of probabilities: 0.9998641 - temperature 0.1
# mean max of probabilities: 0.9998645 - temperature 0.1
# mean max of probabilities: 0.9998645 - temperature 0.1
# mean max of probabilities: 0.99986464 - temperature 0.1
# mean max of probabilities: 0.99986476 - temperature 0.1
# mean max of probabilities: 0.999865 - temperature 0.1
# mean max of probabilities: 0.99986523 - temperature 0.1
# mean max of probabilities: 0.99986535 - temperature 0.1
# mean max of probabilities: 0.99986535 - temperature 0.1
# mean max of probabilities: 0.9998655 - temperature 0.1
# mean max of probabilities: 0.9998655 - temperature 0.1
# mean max of probabilities: 0.99986565 - temperature 0.1
# mean max of probabilities: 0.99986583 - temperature 0.1
# mean max of probabilities: 0.999866 - temperature 0.1
# mean max of probabilities: 0.99986607 - temperature 0.1
# mean max of probabilities: 0.9998663 - temperature 0.1
# mean max of probabilities: 0.9998663 - temperature 0.1
# mean max of probabilities: 0.99986655 - temperature 0.1
# mean max of probabilities: 0.9998667 - temperature 0.1
# mean max of probabilities: 0.9998664 - temperature 0.1
# mean max of probabilities: 0.9998663 - temperature 0.1
# mean max of probabilities: 0.99986655 - temperature 0.1
# mean max of probabilities: 0.99986666 - temperature 0.1
# mean max of probabilities: 0.99986684 - temperature 0.1
# mean max of probabilities: 0.9998671 - temperature 0.1
# mean max of probabilities: 0.9998672 - temperature 0.1
# mean max of probabilities: 0.9998672 - temperature 0.1
# mean max of probabilities: 0.9998673 - temperature 0.1
# mean max of probabilities: 0.99986744 - temperature 0.1
# mean max of probabilities: 0.9998676 - temperature 0.1
# mean max of probabilities: 0.99986786 - temperature 0.1
# mean max of probabilities: 0.99986786 - temperature 0.1
# mean max of probabilities: 0.9998681 - temperature 0.1
# mean max of probabilities: 0.9998683 - temperature 0.1
# mean max of probabilities: 0.99986845 - temperature 0.1
# mean max of probabilities: 0.9998686 - temperature 0.1
# mean max of probabilities: 0.9998687 - temperature 0.1
# mean max of probabilities: 0.99986887 - temperature 0.1
# mean max of probabilities: 0.999869 - temperature 0.1
# mean max of probabilities: 0.99986917 - temperature 0.1
# mean max of probabilities: 0.999869 - temperature 0.1
# mean max of probabilities: 0.99986917 - temperature 0.1
# mean max of probabilities: 0.99986917 - temperature 0.1
# mean max of probabilities: 0.99986947 - temperature 0.1
# mean max of probabilities: 0.9998697 - temperature 0.1
# mean max of probabilities: 0.9998698 - temperature 0.1
# mean max of probabilities: 0.99986994 - temperature 0.1
# mean max of probabilities: 0.9998701 - temperature 0.1
# mean max of probabilities: 0.9998701 - temperature 0.1
# mean max of probabilities: 0.9998703 - temperature 0.1
# mean max of probabilities: 0.99987036 - temperature 0.1
# mean max of probabilities: 0.9998705 - temperature 0.1
# mean max of probabilities: 0.9998708 - temperature 0.1
# mean max of probabilities: 0.9998711 - temperature 0.1
# mean max of probabilities: 0.99987125 - temperature 0.1
# mean max of probabilities: 0.99987143 - temperature 0.1
# mean max of probabilities: 0.9998715 - temperature 0.1
# mean max of probabilities: 0.9998715 - temperature 0.1
# mean max of probabilities: 0.9998717 - temperature 0.1
# mean max of probabilities: 0.9998719 - temperature 0.1
# mean max of probabilities: 0.9998717 - temperature 0.1
# mean max of probabilities: 0.99987185 - temperature 0.1
# mean max of probabilities: 0.99987173 - temperature 0.1
# mean max of probabilities: 0.9998719 - temperature 0.1
# mean max of probabilities: 0.99987185 - temperature 0.1
# mean max of probabilities: 0.9998721 - temperature 0.1
# mean max of probabilities: 0.99987215 - temperature 0.1
# mean max of probabilities: 0.99987227 - temperature 0.1
# mean max of probabilities: 0.99987245 - temperature 0.1
# mean max of probabilities: 0.9998726 - temperature 0.1
# mean max of probabilities: 0.9998731 - temperature 0.1
# mean max of probabilities: 0.99987304 - temperature 0.1
# mean max of probabilities: 0.99987316 - temperature 0.1
# mean max of probabilities: 0.9998731 - temperature 0.1
# mean max of probabilities: 0.99987316 - temperature 0.1
# mean max of probabilities: 0.9998734 - temperature 0.1
# mean max of probabilities: 0.99987364 - temperature 0.1
# mean max of probabilities: 0.999874 - temperature 0.1
# mean max of probabilities: 0.9998742 - temperature 0.1
# mean max of probabilities: 0.9998743 - temperature 0.1
# mean max of probabilities: 0.9998745 - temperature 0.1
# mean max of probabilities: 0.9998746 - temperature 0.1
# mean max of probabilities: 0.99987465 - temperature 0.1
# mean max of probabilities: 0.9998746 - temperature 0.1
# mean max of probabilities: 0.99987465 - temperature 0.1
# mean max of probabilities: 0.9998747 - temperature 0.1
# mean max of probabilities: 0.999875 - temperature 0.1
# mean max of probabilities: 0.9998752 - temperature 0.1
# mean max of probabilities: 0.99987525 - temperature 0.1
# mean max of probabilities: 0.9998755 - temperature 0.1
# mean max of probabilities: 0.9998756 - temperature 0.1
# mean max of probabilities: 0.99987584 - temperature 0.1
# mean max of probabilities: 0.99987584 - temperature 0.1
# mean max of probabilities: 0.9998761 - temperature 0.1
# mean max of probabilities: 0.99987626 - temperature 0.1
# mean max of probabilities: 0.9998763 - temperature 0.1
# mean max of probabilities: 0.9998765 - temperature 0.1
# mean max of probabilities: 0.99987656 - temperature 0.1
# mean max of probabilities: 0.9998768 - temperature 0.1
# mean max of probabilities: 0.99987686 - temperature 0.1
# mean max of probabilities: 0.99987686 - temperature 0.1
# mean max of probabilities: 0.999877 - temperature 0.1
# mean max of probabilities: 0.99987715 - temperature 0.1
# mean max of probabilities: 0.9998774 - temperature 0.1

# %%
print(np.sort(selector.get_indices()))
np.savetxt('./MUDI/runs/textfiles/' + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.txt', np.array(selector.get_indices(), dtype=int), fmt='%d')
# Out:
# [   0    0    0    0    1    3    4   10   13   15   16   16   19   20
#    25   29   32   35   36   37   40   40   43   44   46   51   52   54
#    56   59   60   64   68   75   76   79   81   84   88   91   92   92
#    94   99  100  103  104  107  108  110  112  114  116  117  120  123
#   128  131  136  138  140  147  148  149  156  156  163  164  169  173
#   177  179  180  180  181  183  184  184  188  196  197  198  199  200
#   204  210  212  212  215  216  222  224  224  225  229  232  232  233
#   236  243  248  252  256  256  260  264  265  267  268  272  278  282
#   285  287  288  290  292  293  295  296  299  300  307  308  309  311
#   312  313  319  320  320  323  328  331  333  338  343  344  344  345
#   349  350  356  356  363  365  365  367  368  369  372  375  376  381
#   384  385  387  389  392  393  395  396  397  404  404  405  407  408
#   408  408  408  412  418  419  425  428  428  430  432  435  436  437
#   443  446  452  459  464  475  476  484  487  488  495  496  497  500
#   502  504  504  515  516  517  520  526  528  531  532  532  533  543
#   545  552  552  560  563  564  565  566  572  577  583  584  585  587
#   588  588  588  594  596  596  600  604  607  613  616  619  620  624
#   624  630  635  636  639  641  642  643  646  651  652  654  656  656
#   657  660  664  666  670  671  672  672  672  676  683  684  695  696
#   700  709  712  716  718  720  720  721  728  736  754  756  756  756
#   762  764  764  772  776  777  780  784  792  796  796  802  803  804
#   806  807  810  812  812  813  813  814  819  824  826  828  832  836
#   840  841  845  847  848  850  851  856  856  859  863  866  868  871
#   872  876  876  879  880  881  884  884  904  910  912  912  914  916
#   918  920  922  926  929  932  936  936  940  948  950  951  952  955
#   959  960  967  968  968  968  968  969  971  972  978  980 1000 1003
#  1007 1012 1013 1015 1020 1024 1024 1024 1028 1032 1036 1039 1044 1048
#  1052 1052 1052 1054 1059 1063 1064 1064 1064 1064 1072 1074 1075 1080
#  1080 1082 1088 1092 1092 1104 1104 1104 1104 1104 1105 1109 1110 1112
#  1114 1115 1120 1127 1128 1132 1136 1136 1137 1140 1144 1147 1148 1148
#  1148 1148 1149 1159 1160 1161 1162 1164 1166 1168 1170 1171 1172 1175
#  1176 1184 1186 1187 1188 1188 1193 1196 1199 1204 1204 1204 1204 1212
#  1212 1213 1220 1224 1230 1231 1232 1236 1244 1244 1244 1252 1259 1260
#  1260 1260 1260 1260 1260 1260 1260 1260 1269 1269 1271 1272 1273 1275
#  1286 1287 1288 1289 1290 1293 1300 1300 1301 1304 1308 1313 1315 1316
#  1316 1320 1323 1328 1330 1332 1336 1337 1340 1343]

# %%
testsubj = 12
testsubjstr = '12'

# %%
for run in RunBuilder.get_runs(params):
    logdir = "./MUDI/runs/scalars/" + datetime.now().strftime("%Y%m%d-%H%M%S") + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr

    tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)
    monitor_callback = keras.callbacks.ModelCheckpoint('./MUDI/runs/models/' + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '_runtime.h5', monitor='val_loss', verbose=0, save_weights_only=True)
    
    trainset = MRISelectorSubjDataset(root_dir='.', dataf='data_.hdf5', headerf ='header_.csv',
                                  subj_list=np.array([11, 13, 14, 15]), batch_size=run.batch_size)
    testset = MRISelectorSubjDataset(root_dir='.', dataf='data_.hdf5', headerf ='header_.csv',
                                  subj_list=np.array([12]), batch_size=run.batch_size)

    selector = ConcreteAutoencoderFeatureSelector(K=n_meas, output_function=dec, num_epochs=num_epochs, learning_rate=run.lr, start_temp=10.0, min_temp=0.1, 
                                                  tryout_limit=5, input_dim=1344, callback=[tensorboard_callback, monitor_callback])
    
    selector.fit(X=trainset, val_X=testset)
    
    model = selector.get_params()
    
    model.save_weights('./MUDI/runs/models/' + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.h5')
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 1344)]            0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 500)               672001
# _________________________________________________________________
# dense_9 (Dense)              (None, 800)               400800
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 800)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1000)              801000
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 1000)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1344)              1345344
# =================================================================
# Total params: 3,219,145
# Trainable params: 3,219,144
# Non-trainable params: 1
# _________________________________________________________________
# None
# [<keras.callbacks.tensorboard_v2.TensorBoard object at 0x7f59180c0a58>, <keras.callbacks.callbacks.ModelCheckpoint object at 0x7f5910555978>]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layers with arguments in `__init__` must override `get_config`.
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layers with arguments in `__init__` must override `get_config`.
# mean max of probabilities: 0.0008010759 - temperature 10.0
# mean max of probabilities: 0.00093506265 - temperature 9.972043
# mean max of probabilities: 0.0011882165 - temperature 9.944086
# mean max of probabilities: 0.0016214414 - temperature 9.916129
# mean max of probabilities: 0.0024916702 - temperature 9.888172
# mean max of probabilities: 0.0051362664 - temperature 9.860215
# mean max of probabilities: 0.006144052 - temperature 9.832258
# mean max of probabilities: 0.007169547 - temperature 9.804301
# mean max of probabilities: 0.007934147 - temperature 9.776344
# mean max of probabilities: 0.008699859 - temperature 9.748387
# mean max of probabilities: 0.009609975 - temperature 9.72043
# mean max of probabilities: 0.010395534 - temperature 9.692473
# mean max of probabilities: 0.011041949 - temperature 9.664516
# mean max of probabilities: 0.011768315 - temperature 9.6365595
# mean max of probabilities: 0.0122647965 - temperature 9.608603
# mean max of probabilities: 0.01263777 - temperature 9.580646
# mean max of probabilities: 0.013086747 - temperature 9.552689
# mean max of probabilities: 0.013533523 - temperature 9.524732
# mean max of probabilities: 0.013796488 - temperature 9.498854
# mean max of probabilities: 0.014241883 - temperature 9.473047
# mean max of probabilities: 0.014654605 - temperature 9.447241
# mean max of probabilities: 0.015116232 - temperature 9.421434
# mean max of probabilities: 0.015623205 - temperature 9.395628
# mean max of probabilities: 0.0162589 - temperature 9.369822
# mean max of probabilities: 0.016960246 - temperature 9.344015
# mean max of probabilities: 0.017753948 - temperature 9.318209
# mean max of probabilities: 0.018758766 - temperature 9.292402
# mean max of probabilities: 0.019912729 - temperature 9.266596
# mean max of probabilities: 0.021623021 - temperature 9.240789
# mean max of probabilities: 0.024283547 - temperature 9.214983
# mean max of probabilities: 0.02923726 - temperature 9.189177
# mean max of probabilities: 0.037025623 - temperature 9.16337
# mean max of probabilities: 0.04078327 - temperature 9.137564
# mean max of probabilities: 0.04410292 - temperature 9.111757
# mean max of probabilities: 0.047267362 - temperature 9.085951
# mean max of probabilities: 0.049750168 - temperature 9.060144
# mean max of probabilities: 0.052908536 - temperature 9.034338
# mean max of probabilities: 0.056307767 - temperature 9.008532
# mean max of probabilities: 0.059238434 - temperature 8.982725
# mean max of probabilities: 0.062185664 - temperature 8.956919
# mean max of probabilities: 0.06533604 - temperature 8.931112
# mean max of probabilities: 0.06868501 - temperature 8.905306
# mean max of probabilities: 0.07216104 - temperature 8.879499
# mean max of probabilities: 0.07539883 - temperature 8.853693
# mean max of probabilities: 0.07868995 - temperature 8.827887
# mean max of probabilities: 0.082107425 - temperature 8.80208
# mean max of probabilities: 0.084123686 - temperature 8.776274
# mean max of probabilities: 0.08731505 - temperature 8.75142
# mean max of probabilities: 0.09088425 - temperature 8.727764
# mean max of probabilities: 0.09447716 - temperature 8.704108
# mean max of probabilities: 0.0978019 - temperature 8.680452
# mean max of probabilities: 0.101099476 - temperature 8.656796
# mean max of probabilities: 0.10436374 - temperature 8.633141
# mean max of probabilities: 0.107828885 - temperature 8.609485
# mean max of probabilities: 0.11133142 - temperature 8.585829
# mean max of probabilities: 0.11476408 - temperature 8.562173
# mean max of probabilities: 0.11808139 - temperature 8.538517
# mean max of probabilities: 0.121461056 - temperature 8.514861
# mean max of probabilities: 0.120682366 - temperature 8.491205
# mean max of probabilities: 0.12410031 - temperature 8.467549
# mean max of probabilities: 0.12780277 - temperature 8.443893
# mean max of probabilities: 0.13135013 - temperature 8.420238
# mean max of probabilities: 0.13498023 - temperature 8.396582
# mean max of probabilities: 0.13857958 - temperature 8.372926
# mean max of probabilities: 0.14232346 - temperature 8.34927
# mean max of probabilities: 0.14598091 - temperature 8.325614
# mean max of probabilities: 0.14971246 - temperature 8.301958
# mean max of probabilities: 0.1536092 - temperature 8.278302
# mean max of probabilities: 0.1574051 - temperature 8.254646
# mean max of probabilities: 0.16104999 - temperature 8.23099
# mean max of probabilities: 0.16433437 - temperature 8.2073345
# mean max of probabilities: 0.16726731 - temperature 8.183679
# mean max of probabilities: 0.16994357 - temperature 8.160023
# mean max of probabilities: 0.17265064 - temperature 8.136367
# mean max of probabilities: 0.17504822 - temperature 8.112711
# mean max of probabilities: 0.17745107 - temperature 8.089055
# mean max of probabilities: 0.1795025 - temperature 8.065399
# mean max of probabilities: 0.18167049 - temperature 8.041743
# mean max of probabilities: 0.1823526 - temperature 8.018087
# mean max of probabilities: 0.18501037 - temperature 7.9946847
# mean max of probabilities: 0.18721174 - temperature 7.972104
# mean max of probabilities: 0.18920147 - temperature 7.9495234
# mean max of probabilities: 0.19100995 - temperature 7.926943
# mean max of probabilities: 0.19283572 - temperature 7.904362
# mean max of probabilities: 0.1948378 - temperature 7.8817816
# mean max of probabilities: 0.19656439 - temperature 7.859201
# mean max of probabilities: 0.19842778 - temperature 7.8366203
# mean max of probabilities: 0.20047045 - temperature 7.8140397
# mean max of probabilities: 0.20244941 - temperature 7.7923193
# mean max of probabilities: 0.20443638 - temperature 7.770814
# mean max of probabilities: 0.20635341 - temperature 7.7493086
# mean max of probabilities: 0.20825702 - temperature 7.727803
# mean max of probabilities: 0.21016157 - temperature 7.706298
# mean max of probabilities: 0.21218587 - temperature 7.6847925
# mean max of probabilities: 0.2143999 - temperature 7.663287
# mean max of probabilities: 0.21709105 - temperature 7.641782
# mean max of probabilities: 0.21960907 - temperature 7.6202765
# mean max of probabilities: 0.22224748 - temperature 7.598771
# mean max of probabilities: 0.22462443 - temperature 7.5772657
# mean max of probabilities: 0.22720279 - temperature 7.5557604
# mean max of probabilities: 0.22995326 - temperature 7.534255
# mean max of probabilities: 0.23259808 - temperature 7.5127497
# mean max of probabilities: 0.2353684 - temperature 7.4912443
# mean max of probabilities: 0.23821338 - temperature 7.469739
# mean max of probabilities: 0.24075651 - temperature 7.4482336
# mean max of probabilities: 0.24335761 - temperature 7.4268203
# mean max of probabilities: 0.24575086 - temperature 7.40639
# mean max of probabilities: 0.24831487 - temperature 7.38596
# mean max of probabilities: 0.250594 - temperature 7.36553
# mean max of probabilities: 0.25271517 - temperature 7.3451
# mean max of probabilities: 0.2549462 - temperature 7.32467
# mean max of probabilities: 0.25692183 - temperature 7.3042397
# mean max of probabilities: 0.25903356 - temperature 7.2838097
# mean max of probabilities: 0.26094308 - temperature 7.2633796
# mean max of probabilities: 0.26260507 - temperature 7.2429495
# mean max of probabilities: 0.26435202 - temperature 7.2225194
# mean max of probabilities: 0.26588324 - temperature 7.2020893
# mean max of probabilities: 0.2677217 - temperature 7.181659
# mean max of probabilities: 0.2693559 - temperature 7.161229
# mean max of probabilities: 0.27086553 - temperature 7.140799
# mean max of probabilities: 0.27232203 - temperature 7.120369
# mean max of probabilities: 0.27394786 - temperature 7.099939
# mean max of probabilities: 0.27564737 - temperature 7.079509
# mean max of probabilities: 0.2770189 - temperature 7.0590787
# mean max of probabilities: 0.27853382 - temperature 7.0391207
# mean max of probabilities: 0.2802632 - temperature 7.019766
# mean max of probabilities: 0.28194427 - temperature 7.000411
# mean max of probabilities: 0.28369242 - temperature 6.981056
# mean max of probabilities: 0.285519 - temperature 6.9617014
# mean max of probabilities: 0.2874698 - temperature 6.9423466
# mean max of probabilities: 0.28977436 - temperature 6.9229918
# mean max of probabilities: 0.29226032 - temperature 6.903637
# mean max of probabilities: 0.29487765 - temperature 6.884282
# mean max of probabilities: 0.29750696 - temperature 6.8649273
# mean max of probabilities: 0.29999983 - temperature 6.8455725
# mean max of probabilities: 0.30260265 - temperature 6.8262177
# mean max of probabilities: 0.30495512 - temperature 6.806863
# mean max of probabilities: 0.30730012 - temperature 6.787508
# mean max of probabilities: 0.30996197 - temperature 6.768153
# mean max of probabilities: 0.3122781 - temperature 6.7487984
# mean max of probabilities: 0.31459463 - temperature 6.7294436
# mean max of probabilities: 0.3165472 - temperature 6.7100887
# mean max of probabilities: 0.3183839 - temperature 6.690734
# mean max of probabilities: 0.32016444 - temperature 6.671379
# mean max of probabilities: 0.32163745 - temperature 6.6528373
# mean max of probabilities: 0.323123 - temperature 6.6345577
# mean max of probabilities: 0.3245969 - temperature 6.616278
# mean max of probabilities: 0.32589772 - temperature 6.5979986
# mean max of probabilities: 0.32718912 - temperature 6.579719
# mean max of probabilities: 0.328274 - temperature 6.5614395
# mean max of probabilities: 0.32919815 - temperature 6.54316
# mean max of probabilities: 0.33023074 - temperature 6.5248804
# mean max of probabilities: 0.33130047 - temperature 6.506601
# mean max of probabilities: 0.3323289 - temperature 6.4883213
# mean max of probabilities: 0.33335337 - temperature 6.4700418
# mean max of probabilities: 0.33426827 - temperature 6.451762
# mean max of probabilities: 0.33527088 - temperature 6.4334826
# mean max of probabilities: 0.33612764 - temperature 6.415203
# mean max of probabilities: 0.33682925 - temperature 6.3969235
# mean max of probabilities: 0.33746758 - temperature 6.378644
# mean max of probabilities: 0.33783597 - temperature 6.3603644
# mean max of probabilities: 0.33798304 - temperature 6.342085
# mean max of probabilities: 0.338398 - temperature 6.3238053
# mean max of probabilities: 0.3385362 - temperature 6.305526
# mean max of probabilities: 0.33899748 - temperature 6.287246
# mean max of probabilities: 0.3396392 - temperature 6.269952
# mean max of probabilities: 0.34007987 - temperature 6.2527475
# mean max of probabilities: 0.34050727 - temperature 6.2355433
# mean max of probabilities: 0.34091672 - temperature 6.218339
# mean max of probabilities: 0.34135666 - temperature 6.2011347
# mean max of probabilities: 0.34167585 - temperature 6.1839304
# mean max of probabilities: 0.34202984 - temperature 6.166726
# mean max of probabilities: 0.34234288 - temperature 6.149522
# mean max of probabilities: 0.34283525 - temperature 6.1323175
# mean max of probabilities: 0.34335083 - temperature 6.1151133
# mean max of probabilities: 0.34404457 - temperature 6.097909
# mean max of probabilities: 0.34468314 - temperature 6.0807047
# mean max of probabilities: 0.34526417 - temperature 6.0635004
# mean max of probabilities: 0.34574038 - temperature 6.046296
# mean max of probabilities: 0.34625575 - temperature 6.029092
# mean max of probabilities: 0.34662753 - temperature 6.0118876
# mean max of probabilities: 0.34696382 - temperature 5.9946833
# mean max of probabilities: 0.34722605 - temperature 5.977479
# mean max of probabilities: 0.3475753 - temperature 5.9602747
# mean max of probabilities: 0.34780636 - temperature 5.9430704
# mean max of probabilities: 0.34801847 - temperature 5.925866
# mean max of probabilities: 0.34824613 - temperature 5.908662
# mean max of probabilities: 0.348311 - temperature 5.8922887
# mean max of probabilities: 0.34848106 - temperature 5.8761597
# mean max of probabilities: 0.3488203 - temperature 5.8600307
# mean max of probabilities: 0.34906456 - temperature 5.8439016
# mean max of probabilities: 0.34935954 - temperature 5.8277726
# mean max of probabilities: 0.34955743 - temperature 5.8116436
# mean max of probabilities: 0.3498932 - temperature 5.7955146
# mean max of probabilities: 0.35024774 - temperature 5.7793856
# mean max of probabilities: 0.35057965 - temperature 5.7632565
# mean max of probabilities: 0.35094273 - temperature 5.7471275
# mean max of probabilities: 0.35125387 - temperature 5.7309985
# mean max of probabilities: 0.351616 - temperature 5.7148695
# mean max of probabilities: 0.35194072 - temperature 5.6987405
# mean max of probabilities: 0.3522891 - temperature 5.6826115
# mean max of probabilities: 0.35268745 - temperature 5.6664824
# mean max of probabilities: 0.35299268 - temperature 5.6503534
# mean max of probabilities: 0.3534984 - temperature 5.6342244
# mean max of probabilities: 0.35372105 - temperature 5.6180954
# mean max of probabilities: 0.3538594 - temperature 5.6019664
# mean max of probabilities: 0.35424265 - temperature 5.5858374
# mean max of probabilities: 0.35441926 - temperature 5.5697083
# mean max of probabilities: 0.3546558 - temperature 5.5535793
# mean max of probabilities: 0.35474136 - temperature 5.5374503
# mean max of probabilities: 0.35495007 - temperature 5.5214868
# mean max of probabilities: 0.35522145 - temperature 5.506433
# mean max of probabilities: 0.35549274 - temperature 5.4913793
# mean max of probabilities: 0.3556389 - temperature 5.4763255
# mean max of probabilities: 0.3559539 - temperature 5.461272
# mean max of probabilities: 0.3566333 - temperature 5.446218
# mean max of probabilities: 0.35730505 - temperature 5.4311643
# mean max of probabilities: 0.35786843 - temperature 5.4161105
# mean max of probabilities: 0.35862222 - temperature 5.401057
# mean max of probabilities: 0.3594093 - temperature 5.386003
# mean max of probabilities: 0.36008713 - temperature 5.3709493
# mean max of probabilities: 0.36082882 - temperature 5.3558955
# mean max of probabilities: 0.36161673 - temperature 5.340842
# mean max of probabilities: 0.36219406 - temperature 5.325788
# mean max of probabilities: 0.3626375 - temperature 5.3107343
# mean max of probabilities: 0.3633753 - temperature 5.2956805
# mean max of probabilities: 0.36382917 - temperature 5.280627
# mean max of probabilities: 0.36447975 - temperature 5.265573
# mean max of probabilities: 0.36488655 - temperature 5.2505193
# mean max of probabilities: 0.36551976 - temperature 5.2354655
# mean max of probabilities: 0.36590928 - temperature 5.220412
# mean max of probabilities: 0.3662649 - temperature 5.205358
# mean max of probabilities: 0.36682555 - temperature 5.1903043
# mean max of probabilities: 0.36745846 - temperature 5.1752505
# mean max of probabilities: 0.36804932 - temperature 5.160197
# mean max of probabilities: 0.3686068 - temperature 5.145143
# mean max of probabilities: 0.36929557 - temperature 5.131001
# mean max of probabilities: 0.3698986 - temperature 5.1170225
# mean max of probabilities: 0.37052098 - temperature 5.103044
# mean max of probabilities: 0.3710613 - temperature 5.0890656
# mean max of probabilities: 0.3717227 - temperature 5.075087
# mean max of probabilities: 0.37240967 - temperature 5.0611086
# mean max of probabilities: 0.37316316 - temperature 5.04713
# mean max of probabilities: 0.37393764 - temperature 5.0331516
# mean max of probabilities: 0.37503523 - temperature 5.019173
# mean max of probabilities: 0.37628585 - temperature 5.0051947
# mean max of probabilities: 0.37769237 - temperature 4.991216
# mean max of probabilities: 0.37885827 - temperature 4.9772377
# mean max of probabilities: 0.38027713 - temperature 4.963259
# mean max of probabilities: 0.38174546 - temperature 4.9492807
# mean max of probabilities: 0.38321307 - temperature 4.9353023
# mean max of probabilities: 0.38471362 - temperature 4.921324
# mean max of probabilities: 0.38608405 - temperature 4.9073453
# mean max of probabilities: 0.3873901 - temperature 4.893367
# mean max of probabilities: 0.38892493 - temperature 4.8793883
# mean max of probabilities: 0.39027318 - temperature 4.86541
# mean max of probabilities: 0.3916263 - temperature 4.8514314
# mean max of probabilities: 0.3929185 - temperature 4.837453
# mean max of probabilities: 0.39437103 - temperature 4.8234744
# mean max of probabilities: 0.39568087 - temperature 4.809496
# mean max of probabilities: 0.39704573 - temperature 4.7955174
# mean max of probabilities: 0.39810362 - temperature 4.781539
# mean max of probabilities: 0.39915946 - temperature 4.7675605
# mean max of probabilities: 0.4002454 - temperature 4.754222
# mean max of probabilities: 0.40121776 - temperature 4.7413187
# mean max of probabilities: 0.40231243 - temperature 4.7284155
# mean max of probabilities: 0.40308988 - temperature 4.7155123
# mean max of probabilities: 0.40367508 - temperature 4.702609
# mean max of probabilities: 0.4043025 - temperature 4.689706
# mean max of probabilities: 0.40516832 - temperature 4.6768026
# mean max of probabilities: 0.40571734 - temperature 4.6638994
# mean max of probabilities: 0.40654194 - temperature 4.650996
# mean max of probabilities: 0.40761617 - temperature 4.638093
# mean max of probabilities: 0.40852496 - temperature 4.62519
# mean max of probabilities: 0.40944624 - temperature 4.6122866
# mean max of probabilities: 0.41036448 - temperature 4.5993834
# mean max of probabilities: 0.4111324 - temperature 4.58648
# mean max of probabilities: 0.41191623 - temperature 4.573577
# mean max of probabilities: 0.41270435 - temperature 4.5606737
# mean max of probabilities: 0.41363004 - temperature 4.5477705
# mean max of probabilities: 0.41438705 - temperature 4.5348673
# mean max of probabilities: 0.4151073 - temperature 4.521964
# mean max of probabilities: 0.41554692 - temperature 4.509061
# mean max of probabilities: 0.41626027 - temperature 4.4961576
# mean max of probabilities: 0.4168864 - temperature 4.4832544
# mean max of probabilities: 0.41751984 - temperature 4.470351
# mean max of probabilities: 0.41799852 - temperature 4.457448
# mean max of probabilities: 0.41836622 - temperature 4.444545
# mean max of probabilities: 0.4190258 - temperature 4.4316416
# mean max of probabilities: 0.4195885 - temperature 4.4187384
# mean max of probabilities: 0.42018437 - temperature 4.405835
# mean max of probabilities: 0.42064422 - temperature 4.392932
# mean max of probabilities: 0.42102095 - temperature 4.3801055
# mean max of probabilities: 0.421713 - temperature 4.3682775
# mean max of probabilities: 0.42213556 - temperature 4.3564496
# mean max of probabilities: 0.4226935 - temperature 4.3446217
# mean max of probabilities: 0.4230363 - temperature 4.3327937
# mean max of probabilities: 0.42326334 - temperature 4.320966
# mean max of probabilities: 0.4236019 - temperature 4.309138
# mean max of probabilities: 0.42357752 - temperature 4.29731
# mean max of probabilities: 0.42396486 - temperature 4.285482
# mean max of probabilities: 0.42412117 - temperature 4.273654
# mean max of probabilities: 0.42428863 - temperature 4.261826
# mean max of probabilities: 0.4245711 - temperature 4.249998
# mean max of probabilities: 0.4247254 - temperature 4.23817
# mean max of probabilities: 0.42485777 - temperature 4.226342
# mean max of probabilities: 0.42484137 - temperature 4.2145143
# mean max of probabilities: 0.42474523 - temperature 4.2026863
# mean max of probabilities: 0.4247839 - temperature 4.1908584
# mean max of probabilities: 0.42491382 - temperature 4.1790304
# mean max of probabilities: 0.424852 - temperature 4.1672025
# mean max of probabilities: 0.42489302 - temperature 4.1553745
# mean max of probabilities: 0.42491218 - temperature 4.1435466
# mean max of probabilities: 0.4250429 - temperature 4.1317186
# mean max of probabilities: 0.42514253 - temperature 4.1198907
# mean max of probabilities: 0.42550412 - temperature 4.1080627
# mean max of probabilities: 0.4258527 - temperature 4.096235
# mean max of probabilities: 0.42625397 - temperature 4.084407
# mean max of probabilities: 0.42672175 - temperature 4.072579
# mean max of probabilities: 0.42690244 - temperature 4.060751
# mean max of probabilities: 0.42715806 - temperature 4.048923
# mean max of probabilities: 0.4273786 - temperature 4.037095
# mean max of probabilities: 0.42756575 - temperature 4.025267
# mean max of probabilities: 0.4276464 - temperature 4.013439
# mean max of probabilities: 0.42776796 - temperature 4.001611
# mean max of probabilities: 0.42791563 - temperature 3.9902477
# mean max of probabilities: 0.4281567 - temperature 3.9789574
# mean max of probabilities: 0.4282378 - temperature 3.967667
# mean max of probabilities: 0.4282522 - temperature 3.9563768
# mean max of probabilities: 0.4282652 - temperature 3.9450865
# mean max of probabilities: 0.42804322 - temperature 3.9337962
# mean max of probabilities: 0.4280561 - temperature 3.9225059
# mean max of probabilities: 0.42775914 - temperature 3.9112155
# mean max of probabilities: 0.4275532 - temperature 3.9001555
# mean max of probabilities: 0.42740604 - temperature 3.8894029
# mean max of probabilities: 0.42735025 - temperature 3.8786502
# mean max of probabilities: 0.42722172 - temperature 3.8678975
# mean max of probabilities: 0.4268521 - temperature 3.8571448
# mean max of probabilities: 0.4263036 - temperature 3.8463922
# mean max of probabilities: 0.42591617 - temperature 3.8356395
# mean max of probabilities: 0.425387 - temperature 3.8248868
# mean max of probabilities: 0.4250491 - temperature 3.8141341
# mean max of probabilities: 0.42460248 - temperature 3.8033814
# mean max of probabilities: 0.42434815 - temperature 3.7926288
# mean max of probabilities: 0.4238922 - temperature 3.781876
# mean max of probabilities: 0.42326894 - temperature 3.7711234
# mean max of probabilities: 0.42298397 - temperature 3.7603707
# mean max of probabilities: 0.42251444 - temperature 3.749618
# mean max of probabilities: 0.42194828 - temperature 3.7388654
# mean max of probabilities: 0.4215044 - temperature 3.7281127
# mean max of probabilities: 0.42132494 - temperature 3.71736
# mean max of probabilities: 0.42130306 - temperature 3.7069912
# mean max of probabilities: 0.4210466 - temperature 3.6967762
# mean max of probabilities: 0.42080307 - temperature 3.686561
# mean max of probabilities: 0.42054072 - temperature 3.676346
# mean max of probabilities: 0.42025912 - temperature 3.666131
# mean max of probabilities: 0.41998157 - temperature 3.655916
# mean max of probabilities: 0.4195798 - temperature 3.645701
# mean max of probabilities: 0.41938287 - temperature 3.635486
# mean max of probabilities: 0.41896006 - temperature 3.6252708
# mean max of probabilities: 0.41886246 - temperature 3.6150558
# mean max of probabilities: 0.4185701 - temperature 3.6048408
# mean max of probabilities: 0.4182926 - temperature 3.5946257
# mean max of probabilities: 0.4180918 - temperature 3.5844107
# mean max of probabilities: 0.4181795 - temperature 3.5741956
# mean max of probabilities: 0.41807818 - temperature 3.5639806
# mean max of probabilities: 0.41784492 - temperature 3.5537655
# mean max of probabilities: 0.41792446 - temperature 3.5435505
# mean max of probabilities: 0.41763344 - temperature 3.5333354
# mean max of probabilities: 0.4173753 - temperature 3.5231566
# mean max of probabilities: 0.4172756 - temperature 3.5134792
# mean max of probabilities: 0.41710994 - temperature 3.5038018
# mean max of probabilities: 0.41705507 - temperature 3.4941244
# mean max of probabilities: 0.4167761 - temperature 3.484447
# mean max of probabilities: 0.41651502 - temperature 3.4747696
# mean max of probabilities: 0.41667846 - temperature 3.4650922
# mean max of probabilities: 0.41665518 - temperature 3.4554148
# mean max of probabilities: 0.41673118 - temperature 3.4457374
# mean max of probabilities: 0.41650227 - temperature 3.43606
# mean max of probabilities: 0.41614148 - temperature 3.4263825
# mean max of probabilities: 0.4158451 - temperature 3.4167051
# mean max of probabilities: 0.41577017 - temperature 3.4070277
# mean max of probabilities: 0.41556585 - temperature 3.3973503
# mean max of probabilities: 0.4155967 - temperature 3.387673
# mean max of probabilities: 0.41569856 - temperature 3.3779955
# mean max of probabilities: 0.4157363 - temperature 3.368318
# mean max of probabilities: 0.4156766 - temperature 3.3586407
# mean max of probabilities: 0.41540167 - temperature 3.3489633
# mean max of probabilities: 0.41495624 - temperature 3.3392859
# mean max of probabilities: 0.41429994 - temperature 3.3298151
# mean max of probabilities: 0.41402948 - temperature 3.3206754
# mean max of probabilities: 0.41389167 - temperature 3.3115356
# mean max of probabilities: 0.41360074 - temperature 3.3023958
# mean max of probabilities: 0.41351303 - temperature 3.293256
# mean max of probabilities: 0.41320604 - temperature 3.2841163
# mean max of probabilities: 0.4132994 - temperature 3.2749765
# mean max of probabilities: 0.41309696 - temperature 3.2658367
# mean max of probabilities: 0.4131483 - temperature 3.256697
# mean max of probabilities: 0.41286936 - temperature 3.2475572
# mean max of probabilities: 0.41305196 - temperature 3.2384174
# mean max of probabilities: 0.41282266 - temperature 3.2292776
# mean max of probabilities: 0.41285455 - temperature 3.2201378
# mean max of probabilities: 0.41252553 - temperature 3.210998
# mean max of probabilities: 0.41232213 - temperature 3.2018583
# mean max of probabilities: 0.41214088 - temperature 3.1927185
# mean max of probabilities: 0.412052 - temperature 3.1835787
# mean max of probabilities: 0.4122032 - temperature 3.174439
# mean max of probabilities: 0.41199425 - temperature 3.1652992
# mean max of probabilities: 0.41203225 - temperature 3.1561594
# mean max of probabilities: 0.41190743 - temperature 3.1470196
# mean max of probabilities: 0.4120114 - temperature 3.1381726
# mean max of probabilities: 0.41185287 - temperature 3.1295705
# mean max of probabilities: 0.4118687 - temperature 3.1209683
# mean max of probabilities: 0.41201624 - temperature 3.1123662
# mean max of probabilities: 0.4120135 - temperature 3.103764
# mean max of probabilities: 0.41186726 - temperature 3.095162
# mean max of probabilities: 0.41214603 - temperature 3.0865598
# mean max of probabilities: 0.41190323 - temperature 3.0779576
# mean max of probabilities: 0.41185063 - temperature 3.0693555
# mean max of probabilities: 0.4119681 - temperature 3.0607533
# mean max of probabilities: 0.41185006 - temperature 3.0521512
# mean max of probabilities: 0.41185918 - temperature 3.043549
# mean max of probabilities: 0.41178447 - temperature 3.034947
# mean max of probabilities: 0.41208187 - temperature 3.0263448
# mean max of probabilities: 0.4123313 - temperature 3.0177426
# mean max of probabilities: 0.41222724 - temperature 3.0091405
# mean max of probabilities: 0.41203293 - temperature 3.0005383
# mean max of probabilities: 0.4120432 - temperature 2.9919362
# mean max of probabilities: 0.412285 - temperature 2.983334
# mean max of probabilities: 0.41216943 - temperature 2.974732
# mean max of probabilities: 0.41196516 - temperature 2.9661298
# mean max of probabilities: 0.41179678 - temperature 2.9575276
# mean max of probabilities: 0.411927 - temperature 2.9491413
# mean max of probabilities: 0.4118562 - temperature 2.9410768
# mean max of probabilities: 0.41219816 - temperature 2.9330122
# mean max of probabilities: 0.41272044 - temperature 2.9249477
# mean max of probabilities: 0.41317818 - temperature 2.9168832
# mean max of probabilities: 0.41353148 - temperature 2.9088187
# mean max of probabilities: 0.41356832 - temperature 2.9007542
# mean max of probabilities: 0.41386765 - temperature 2.8926897
# mean max of probabilities: 0.41400272 - temperature 2.8846252
# mean max of probabilities: 0.4141105 - temperature 2.8765607
# mean max of probabilities: 0.4137664 - temperature 2.8684962
# mean max of probabilities: 0.41403913 - temperature 2.8604317
# mean max of probabilities: 0.41441578 - temperature 2.8523672
# mean max of probabilities: 0.41465387 - temperature 2.8443027
# mean max of probabilities: 0.4146856 - temperature 2.8362381
# mean max of probabilities: 0.4150663 - temperature 2.8281736
# mean max of probabilities: 0.41562065 - temperature 2.8201091
# mean max of probabilities: 0.41578117 - temperature 2.8120446
# mean max of probabilities: 0.4161364 - temperature 2.80398
# mean max of probabilities: 0.4162996 - temperature 2.7959156
# mean max of probabilities: 0.41662243 - temperature 2.787851
# mean max of probabilities: 0.41653076 - temperature 2.7797866
# mean max of probabilities: 0.4167571 - temperature 2.771722
# mean max of probabilities: 0.41708788 - temperature 2.7636576
# mean max of probabilities: 0.41711348 - temperature 2.7560136
# mean max of probabilities: 0.4171805 - temperature 2.7484868
# mean max of probabilities: 0.41746068 - temperature 2.74096
# mean max of probabilities: 0.41759992 - temperature 2.733433
# mean max of probabilities: 0.41757104 - temperature 2.7259061
# mean max of probabilities: 0.41774696 - temperature 2.7183793
# mean max of probabilities: 0.4178646 - temperature 2.7108524
# mean max of probabilities: 0.4178249 - temperature 2.7033255
# mean max of probabilities: 0.41808796 - temperature 2.6957986
# mean max of probabilities: 0.41841942 - temperature 2.6882718
# mean max of probabilities: 0.4185522 - temperature 2.680745
# mean max of probabilities: 0.4187393 - temperature 2.673218
# mean max of probabilities: 0.41869453 - temperature 2.6656911
# mean max of probabilities: 0.41881508 - temperature 2.6581643
# mean max of probabilities: 0.41868675 - temperature 2.6506374
# mean max of probabilities: 0.41845915 - temperature 2.6431105
# mean max of probabilities: 0.41881037 - temperature 2.6355836
# mean max of probabilities: 0.41897094 - temperature 2.6280568
# mean max of probabilities: 0.41922006 - temperature 2.62053
# mean max of probabilities: 0.41896027 - temperature 2.613003
# mean max of probabilities: 0.41912568 - temperature 2.6054761
# mean max of probabilities: 0.419078 - temperature 2.5979493
# mean max of probabilities: 0.4194782 - temperature 2.5904224
# mean max of probabilities: 0.41968995 - temperature 2.5828955
# mean max of probabilities: 0.41947314 - temperature 2.5753686
# mean max of probabilities: 0.41912052 - temperature 2.5680978
# mean max of probabilities: 0.41909313 - temperature 2.5611086
# mean max of probabilities: 0.4191408 - temperature 2.5541193
# mean max of probabilities: 0.41909423 - temperature 2.54713
# mean max of probabilities: 0.41872755 - temperature 2.5401409
# mean max of probabilities: 0.41843212 - temperature 2.5331516
# mean max of probabilities: 0.41821378 - temperature 2.5261624
# mean max of probabilities: 0.41850185 - temperature 2.5191731
# mean max of probabilities: 0.41800565 - temperature 2.512184
# mean max of probabilities: 0.41799054 - temperature 2.5051947
# mean max of probabilities: 0.41805553 - temperature 2.4982054
# mean max of probabilities: 0.4178441 - temperature 2.4912162
# mean max of probabilities: 0.4178781 - temperature 2.484227
# mean max of probabilities: 0.41763172 - temperature 2.4772377
# mean max of probabilities: 0.41746092 - temperature 2.4702485
# mean max of probabilities: 0.41748855 - temperature 2.4632592
# mean max of probabilities: 0.4171031 - temperature 2.45627
# mean max of probabilities: 0.41716954 - temperature 2.4492807
# mean max of probabilities: 0.41687927 - temperature 2.4422915
# mean max of probabilities: 0.4168128 - temperature 2.4353023
# mean max of probabilities: 0.41635424 - temperature 2.428313
# mean max of probabilities: 0.41587335 - temperature 2.4213238
# mean max of probabilities: 0.41581613 - temperature 2.4143345
# mean max of probabilities: 0.41544127 - temperature 2.4073453
# mean max of probabilities: 0.41503364 - temperature 2.400356
# mean max of probabilities: 0.41481677 - temperature 2.3933668
# mean max of probabilities: 0.41470572 - temperature 2.3863776
# mean max of probabilities: 0.41420785 - temperature 2.3795085
# mean max of probabilities: 0.41376695 - temperature 2.373057
# mean max of probabilities: 0.41351417 - temperature 2.3666053
# mean max of probabilities: 0.41327107 - temperature 2.3601537
# mean max of probabilities: 0.41259667 - temperature 2.353702
# mean max of probabilities: 0.41226548 - temperature 2.3472505
# mean max of probabilities: 0.4118582 - temperature 2.3407989
# mean max of probabilities: 0.4113341 - temperature 2.3343472
# mean max of probabilities: 0.41133088 - temperature 2.3278956
# mean max of probabilities: 0.41094306 - temperature 2.321444
# mean max of probabilities: 0.41076908 - temperature 2.3149924
# mean max of probabilities: 0.41044396 - temperature 2.3085408
# mean max of probabilities: 0.4099676 - temperature 2.3020892
# mean max of probabilities: 0.40996915 - temperature 2.2956376
# mean max of probabilities: 0.41009006 - temperature 2.289186
# mean max of probabilities: 0.41010404 - temperature 2.2827344
# mean max of probabilities: 0.4103365 - temperature 2.2762828
# mean max of probabilities: 0.41070363 - temperature 2.2698312
# mean max of probabilities: 0.41087213 - temperature 2.2633796
# mean max of probabilities: 0.4106909 - temperature 2.256928
# mean max of probabilities: 0.41054723 - temperature 2.2504764
# mean max of probabilities: 0.41044122 - temperature 2.2440248
# mean max of probabilities: 0.41055995 - temperature 2.2375731
# mean max of probabilities: 0.4104652 - temperature 2.2311215
# mean max of probabilities: 0.4108043 - temperature 2.22467
# mean max of probabilities: 0.4105658 - temperature 2.2182183
# mean max of probabilities: 0.41083732 - temperature 2.2117667
# mean max of probabilities: 0.41051146 - temperature 2.205315
# mean max of probabilities: 0.41104597 - temperature 2.1988635
# mean max of probabilities: 0.4114109 - temperature 2.192412
# mean max of probabilities: 0.41177562 - temperature 2.1863365
# mean max of probabilities: 0.41213194 - temperature 2.1804225
# mean max of probabilities: 0.41217482 - temperature 2.1745086
# mean max of probabilities: 0.41243723 - temperature 2.1685946
# mean max of probabilities: 0.41275924 - temperature 2.1626806
# mean max of probabilities: 0.41312358 - temperature 2.1567667
# mean max of probabilities: 0.4134682 - temperature 2.1508527
# mean max of probabilities: 0.41381702 - temperature 2.1449387
# mean max of probabilities: 0.41414478 - temperature 2.1390247
# mean max of probabilities: 0.41485682 - temperature 2.1331108
# mean max of probabilities: 0.41542324 - temperature 2.1271968
# mean max of probabilities: 0.4158834 - temperature 2.1212828
# mean max of probabilities: 0.4162751 - temperature 2.1153688
# mean max of probabilities: 0.41617417 - temperature 2.1094549
# mean max of probabilities: 0.41629693 - temperature 2.103541
# mean max of probabilities: 0.41708463 - temperature 2.097627
# mean max of probabilities: 0.4175464 - temperature 2.091713
# mean max of probabilities: 0.41738278 - temperature 2.085799
# mean max of probabilities: 0.4176807 - temperature 2.079885
# mean max of probabilities: 0.41858038 - temperature 2.073971
# mean max of probabilities: 0.4184978 - temperature 2.068057
# mean max of probabilities: 0.41884008 - temperature 2.062143
# mean max of probabilities: 0.4189153 - temperature 2.056229
# mean max of probabilities: 0.4190099 - temperature 2.0503151
# mean max of probabilities: 0.4192086 - temperature 2.0444012
# mean max of probabilities: 0.41934925 - temperature 2.0384872
# mean max of probabilities: 0.41982046 - temperature 2.0325732
# mean max of probabilities: 0.41987154 - temperature 2.0266593
# mean max of probabilities: 0.41979048 - temperature 2.0207453
# mean max of probabilities: 0.4198895 - temperature 2.0148313
# mean max of probabilities: 0.41965234 - temperature 2.0089173
# mean max of probabilities: 0.41988418 - temperature 2.0030034
# mean max of probabilities: 0.41973487 - temperature 1.9972217
# mean max of probabilities: 0.41960913 - temperature 1.9915766
# mean max of probabilities: 0.41968644 - temperature 1.9859314
# mean max of probabilities: 0.41939828 - temperature 1.9802862
# mean max of probabilities: 0.41949555 - temperature 1.9746411
# mean max of probabilities: 0.41998786 - temperature 1.9689959
# mean max of probabilities: 0.4198263 - temperature 1.9633508
# mean max of probabilities: 0.41965288 - temperature 1.9577056
# mean max of probabilities: 0.42011964 - temperature 1.9520757
# mean max of probabilities: 0.42037123 - temperature 1.9466994
# mean max of probabilities: 0.4203603 - temperature 1.941323
# mean max of probabilities: 0.42081255 - temperature 1.9359467
# mean max of probabilities: 0.4211735 - temperature 1.9305704
# mean max of probabilities: 0.4213442 - temperature 1.925194
# mean max of probabilities: 0.42196253 - temperature 1.9198177
# mean max of probabilities: 0.4224358 - temperature 1.9144413
# mean max of probabilities: 0.4222753 - temperature 1.909065
# mean max of probabilities: 0.42258325 - temperature 1.9036887
# mean max of probabilities: 0.4228514 - temperature 1.8983123
# mean max of probabilities: 0.4229349 - temperature 1.892936
# mean max of probabilities: 0.42292276 - temperature 1.8875597
# mean max of probabilities: 0.4231392 - temperature 1.8821833
# mean max of probabilities: 0.42324993 - temperature 1.876807
# mean max of probabilities: 0.4229264 - temperature 1.8714306
# mean max of probabilities: 0.42297456 - temperature 1.8660543
# mean max of probabilities: 0.42319363 - temperature 1.860678
# mean max of probabilities: 0.42284986 - temperature 1.8553936
# mean max of probabilities: 0.42292038 - temperature 1.8502861
# mean max of probabilities: 0.41869786 - temperature 1.8451786
# mean max of probabilities: 0.4186401 - temperature 1.8400711
# mean max of probabilities: 0.4186603 - temperature 1.8349636
# mean max of probabilities: 0.41884398 - temperature 1.829856
# mean max of probabilities: 0.41906303 - temperature 1.8247485
# mean max of probabilities: 0.4195552 - temperature 1.819641
# mean max of probabilities: 0.41967344 - temperature 1.8145335
# mean max of probabilities: 0.41970104 - temperature 1.809426
# mean max of probabilities: 0.41988117 - temperature 1.8043184
# mean max of probabilities: 0.41957814 - temperature 1.7992109
# mean max of probabilities: 0.41984707 - temperature 1.7941034
# mean max of probabilities: 0.4195285 - temperature 1.7889959
# mean max of probabilities: 0.41965398 - temperature 1.7838883
# mean max of probabilities: 0.4199184 - temperature 1.7787808
# mean max of probabilities: 0.42012373 - temperature 1.7736733
# mean max of probabilities: 0.4203355 - temperature 1.7685658
# mean max of probabilities: 0.4207218 - temperature 1.7634583
# mean max of probabilities: 0.42093676 - temperature 1.7585378
# mean max of probabilities: 0.42090407 - temperature 1.7536991
# mean max of probabilities: 0.42117655 - temperature 1.7488604
# mean max of probabilities: 0.4214001 - temperature 1.7440217
# mean max of probabilities: 0.42166442 - temperature 1.739183
# mean max of probabilities: 0.42194837 - temperature 1.7343442
# mean max of probabilities: 0.42222583 - temperature 1.7295055
# mean max of probabilities: 0.42255285 - temperature 1.7246668
# mean max of probabilities: 0.42290425 - temperature 1.7198281
# mean max of probabilities: 0.42294016 - temperature 1.7149894
# mean max of probabilities: 0.42340717 - temperature 1.7101507
# mean max of probabilities: 0.4236081 - temperature 1.705312
# mean max of probabilities: 0.42417035 - temperature 1.7004733
# mean max of probabilities: 0.42455205 - temperature 1.6956346
# mean max of probabilities: 0.42446655 - temperature 1.6907959
# mean max of probabilities: 0.4245509 - temperature 1.6859572
# mean max of probabilities: 0.42463225 - temperature 1.6811185
# mean max of probabilities: 0.42481408 - temperature 1.6762798
# mean max of probabilities: 0.42511526 - temperature 1.6714411
# mean max of probabilities: 0.4259815 - temperature 1.6666058
# mean max of probabilities: 0.42677534 - temperature 1.662036
# mean max of probabilities: 0.42702955 - temperature 1.657466
# mean max of probabilities: 0.4272428 - temperature 1.6528962
# mean max of probabilities: 0.42746934 - temperature 1.6483263
# mean max of probabilities: 0.42770183 - temperature 1.6437564
# mean max of probabilities: 0.4281157 - temperature 1.6391865
# mean max of probabilities: 0.42870492 - temperature 1.6346166
# mean max of probabilities: 0.42853802 - temperature 1.6300467
# mean max of probabilities: 0.42926356 - temperature 1.6254768
# mean max of probabilities: 0.42985263 - temperature 1.620907
# mean max of probabilities: 0.43031022 - temperature 1.6163371
# mean max of probabilities: 0.43046236 - temperature 1.6117672
# mean max of probabilities: 0.43074456 - temperature 1.6071973
# mean max of probabilities: 0.43108433 - temperature 1.6026274
# mean max of probabilities: 0.43151632 - temperature 1.5980575
# mean max of probabilities: 0.4316264 - temperature 1.5934876
# mean max of probabilities: 0.43214247 - temperature 1.5889177
# mean max of probabilities: 0.43244806 - temperature 1.5843478
# mean max of probabilities: 0.43321812 - temperature 1.579778
# mean max of probabilities: 0.43370965 - temperature 1.5752081
# mean max of probabilities: 0.4340533 - temperature 1.5706847
# mean max of probabilities: 0.43491352 - temperature 1.5663836
# mean max of probabilities: 0.43562365 - temperature 1.5620825
# mean max of probabilities: 0.43622282 - temperature 1.5577815
# mean max of probabilities: 0.43684483 - temperature 1.5534804
# mean max of probabilities: 0.43757355 - temperature 1.5491793
# mean max of probabilities: 0.43843395 - temperature 1.5448782
# mean max of probabilities: 0.43929332 - temperature 1.5405772
# mean max of probabilities: 0.44022775 - temperature 1.5362761
# mean max of probabilities: 0.44089928 - temperature 1.531975
# mean max of probabilities: 0.4416162 - temperature 1.527674
# mean max of probabilities: 0.44239375 - temperature 1.5233729
# mean max of probabilities: 0.4431706 - temperature 1.5190718
# mean max of probabilities: 0.44412547 - temperature 1.5147707
# mean max of probabilities: 0.44517463 - temperature 1.5104697
# mean max of probabilities: 0.44599727 - temperature 1.5061686
# mean max of probabilities: 0.4468678 - temperature 1.5018675
# mean max of probabilities: 0.44772965 - temperature 1.4975665
# mean max of probabilities: 0.44839048 - temperature 1.4932654
# mean max of probabilities: 0.44933262 - temperature 1.4889643
# mean max of probabilities: 0.4503632 - temperature 1.4846632
# mean max of probabilities: 0.4512799 - temperature 1.4803622
# mean max of probabilities: 0.45212758 - temperature 1.4760691
# mean max of probabilities: 0.45312145 - temperature 1.4720368
# mean max of probabilities: 0.45400685 - temperature 1.4680046
# mean max of probabilities: 0.45477307 - temperature 1.4639723
# mean max of probabilities: 0.45534748 - temperature 1.4599401
# mean max of probabilities: 0.45592555 - temperature 1.4559078
# mean max of probabilities: 0.4564387 - temperature 1.4518756
# mean max of probabilities: 0.4572361 - temperature 1.4478433
# mean max of probabilities: 0.45816046 - temperature 1.443811
# mean max of probabilities: 0.45829114 - temperature 1.4397788
# mean max of probabilities: 0.45947254 - temperature 1.4357466
# mean max of probabilities: 0.46008423 - temperature 1.4317143
# mean max of probabilities: 0.46084595 - temperature 1.427682
# mean max of probabilities: 0.46172202 - temperature 1.4236498
# mean max of probabilities: 0.46257502 - temperature 1.4196175
# mean max of probabilities: 0.46321052 - temperature 1.4155853
# mean max of probabilities: 0.46386024 - temperature 1.411553
# mean max of probabilities: 0.46454772 - temperature 1.4075208
# mean max of probabilities: 0.46527913 - temperature 1.4034885
# mean max of probabilities: 0.46607023 - temperature 1.3994563
# mean max of probabilities: 0.4668158 - temperature 1.395424
# mean max of probabilities: 0.46806479 - temperature 1.3913918
# mean max of probabilities: 0.46910617 - temperature 1.3873595
# mean max of probabilities: 0.46992186 - temperature 1.3833272
# mean max of probabilities: 0.47090963 - temperature 1.3794054
# mean max of probabilities: 0.47183052 - temperature 1.375642
# mean max of probabilities: 0.47301105 - temperature 1.3718785
# mean max of probabilities: 0.47408727 - temperature 1.3681151
# mean max of probabilities: 0.47492456 - temperature 1.3643516
# mean max of probabilities: 0.47574416 - temperature 1.3605882
# mean max of probabilities: 0.4767784 - temperature 1.3568248
# mean max of probabilities: 0.477656 - temperature 1.3530613
# mean max of probabilities: 0.4788683 - temperature 1.3492979
# mean max of probabilities: 0.47980052 - temperature 1.3455344
# mean max of probabilities: 0.4807818 - temperature 1.341771
# mean max of probabilities: 0.4817076 - temperature 1.3380076
# mean max of probabilities: 0.4825688 - temperature 1.3342441
# mean max of probabilities: 0.4832776 - temperature 1.3304807
# mean max of probabilities: 0.48422185 - temperature 1.3267173
# mean max of probabilities: 0.48516417 - temperature 1.3229538
# mean max of probabilities: 0.48619837 - temperature 1.3191904
# mean max of probabilities: 0.4871346 - temperature 1.315427
# mean max of probabilities: 0.48815677 - temperature 1.3116635
# mean max of probabilities: 0.4874814 - temperature 1.3079001
# mean max of probabilities: 0.48790723 - temperature 1.3041366
# mean max of probabilities: 0.48851964 - temperature 1.3003732
# mean max of probabilities: 0.4893365 - temperature 1.2966098
# mean max of probabilities: 0.4905628 - temperature 1.2928463
# mean max of probabilities: 0.49153745 - temperature 1.2890829
# mean max of probabilities: 0.49271652 - temperature 1.2853476
# mean max of probabilities: 0.49392092 - temperature 1.281853
# mean max of probabilities: 0.4950182 - temperature 1.2783583
# mean max of probabilities: 0.4961225 - temperature 1.2748637
# mean max of probabilities: 0.49740827 - temperature 1.2713691
# mean max of probabilities: 0.49865925 - temperature 1.2678745
# mean max of probabilities: 0.4999181 - temperature 1.2643799
# mean max of probabilities: 0.5011629 - temperature 1.2608852
# mean max of probabilities: 0.50237197 - temperature 1.2573906
# mean max of probabilities: 0.5035156 - temperature 1.253896
# mean max of probabilities: 0.5046271 - temperature 1.2504014
# mean max of probabilities: 0.50574684 - temperature 1.2469068
# mean max of probabilities: 0.5068027 - temperature 1.2434121
# mean max of probabilities: 0.50782305 - temperature 1.2399175
# mean max of probabilities: 0.5087956 - temperature 1.2364229
# mean max of probabilities: 0.50974435 - temperature 1.2329283
# mean max of probabilities: 0.51062244 - temperature 1.2294337
# mean max of probabilities: 0.5117842 - temperature 1.225939
# mean max of probabilities: 0.51286733 - temperature 1.2224444
# mean max of probabilities: 0.51388353 - temperature 1.2189498
# mean max of probabilities: 0.5147539 - temperature 1.2154552
# mean max of probabilities: 0.5158197 - temperature 1.2119606
# mean max of probabilities: 0.51679265 - temperature 1.2084659
# ...
# mean max of probabilities: 0.99983203 - temperature 0.1
# mean max of probabilities: 0.99983215 - temperature 0.1
# mean max of probabilities: 0.9998322 - temperature 0.1
# mean max of probabilities: 0.9998324 - temperature 0.1
# mean max of probabilities: 0.99983263 - temperature 0.1
# mean max of probabilities: 0.99983275 - temperature 0.1
# mean max of probabilities: 0.9998335 - temperature 0.1
# mean max of probabilities: 0.9998339 - temperature 0.1
# mean max of probabilities: 0.999834 - temperature 0.1
# mean max of probabilities: 0.9998341 - temperature 0.1
# mean max of probabilities: 0.9998345 - temperature 0.1
# mean max of probabilities: 0.9998348 - temperature 0.1
# mean max of probabilities: 0.9998348 - temperature 0.1
# mean max of probabilities: 0.9998351 - temperature 0.1
# mean max of probabilities: 0.99983567 - temperature 0.1
# mean max of probabilities: 0.99983567 - temperature 0.1
# mean max of probabilities: 0.999836 - temperature 0.1
# mean max of probabilities: 0.999836 - temperature 0.1
# mean max of probabilities: 0.9998361 - temperature 0.1
# mean max of probabilities: 0.9998362 - temperature 0.1
# mean max of probabilities: 0.99983644 - temperature 0.1
# mean max of probabilities: 0.9998368 - temperature 0.1
# mean max of probabilities: 0.99983704 - temperature 0.1
# mean max of probabilities: 0.9998371 - temperature 0.1
# mean max of probabilities: 0.99983734 - temperature 0.1
# mean max of probabilities: 0.99983746 - temperature 0.1
# mean max of probabilities: 0.9998377 - temperature 0.1
# mean max of probabilities: 0.99983776 - temperature 0.1
# mean max of probabilities: 0.99983805 - temperature 0.1
# mean max of probabilities: 0.99983835 - temperature 0.1
# mean max of probabilities: 0.9998384 - temperature 0.1
# mean max of probabilities: 0.99983865 - temperature 0.1
# mean max of probabilities: 0.9998388 - temperature 0.1
# mean max of probabilities: 0.9998392 - temperature 0.1
# mean max of probabilities: 0.99983925 - temperature 0.1
# mean max of probabilities: 0.99983954 - temperature 0.1
# mean max of probabilities: 0.9998398 - temperature 0.1
# mean max of probabilities: 0.9998401 - temperature 0.1
# mean max of probabilities: 0.9998405 - temperature 0.1
# mean max of probabilities: 0.99984074 - temperature 0.1
# mean max of probabilities: 0.9998409 - temperature 0.1
# mean max of probabilities: 0.99984145 - temperature 0.1
# mean max of probabilities: 0.9998416 - temperature 0.1
# mean max of probabilities: 0.99984163 - temperature 0.1
# mean max of probabilities: 0.99984175 - temperature 0.1
# mean max of probabilities: 0.9998419 - temperature 0.1
# mean max of probabilities: 0.99984217 - temperature 0.1
# mean max of probabilities: 0.9998425 - temperature 0.1
# mean max of probabilities: 0.9998428 - temperature 0.1
# mean max of probabilities: 0.9998428 - temperature 0.1
# mean max of probabilities: 0.9998428 - temperature 0.1
# mean max of probabilities: 0.9998429 - temperature 0.1
# mean max of probabilities: 0.9998432 - temperature 0.1
# mean max of probabilities: 0.99984336 - temperature 0.1
# mean max of probabilities: 0.99984324 - temperature 0.1
# mean max of probabilities: 0.99984324 - temperature 0.1
# mean max of probabilities: 0.99984336 - temperature 0.1
# mean max of probabilities: 0.99984366 - temperature 0.1
# mean max of probabilities: 0.9998435 - temperature 0.1
# mean max of probabilities: 0.99984366 - temperature 0.1
# mean max of probabilities: 0.99984384 - temperature 0.1
# mean max of probabilities: 0.9998438 - temperature 0.1
# mean max of probabilities: 0.9998439 - temperature 0.1
# mean max of probabilities: 0.9998442 - temperature 0.1
# mean max of probabilities: 0.9998443 - temperature 0.1
# mean max of probabilities: 0.9998446 - temperature 0.1
# mean max of probabilities: 0.99984497 - temperature 0.1
# mean max of probabilities: 0.99984527 - temperature 0.1
# mean max of probabilities: 0.9998454 - temperature 0.1
# mean max of probabilities: 0.9998453 - temperature 0.1
# mean max of probabilities: 0.99984545 - temperature 0.1
# mean max of probabilities: 0.9998457 - temperature 0.1
# mean max of probabilities: 0.9998459 - temperature 0.1
# mean max of probabilities: 0.9998459 - temperature 0.1
# mean max of probabilities: 0.99984634 - temperature 0.1
# mean max of probabilities: 0.99984664 - temperature 0.1
# mean max of probabilities: 0.99984646 - temperature 0.1
# mean max of probabilities: 0.9998465 - temperature 0.1
# mean max of probabilities: 0.9998469 - temperature 0.1
# mean max of probabilities: 0.99984705 - temperature 0.1
# mean max of probabilities: 0.99984753 - temperature 0.1
# mean max of probabilities: 0.9998479 - temperature 0.1
# mean max of probabilities: 0.99984825 - temperature 0.1
# mean max of probabilities: 0.99984854 - temperature 0.1
# mean max of probabilities: 0.99984884 - temperature 0.1
# mean max of probabilities: 0.99984884 - temperature 0.1
# mean max of probabilities: 0.999849 - temperature 0.1
# mean max of probabilities: 0.999849 - temperature 0.1
# mean max of probabilities: 0.9998491 - temperature 0.1
# mean max of probabilities: 0.9998496 - temperature 0.1
# mean max of probabilities: 0.9998499 - temperature 0.1
# mean max of probabilities: 0.9998504 - temperature 0.1
# mean max of probabilities: 0.99985063 - temperature 0.1
# mean max of probabilities: 0.9998508 - temperature 0.1
# mean max of probabilities: 0.99985105 - temperature 0.1
# mean max of probabilities: 0.99985147 - temperature 0.1
# mean max of probabilities: 0.9998517 - temperature 0.1
# mean max of probabilities: 0.9998518 - temperature 0.1
# mean max of probabilities: 0.999852 - temperature 0.1
# mean max of probabilities: 0.9998522 - temperature 0.1
# mean max of probabilities: 0.9998523 - temperature 0.1
# mean max of probabilities: 0.99985254 - temperature 0.1
# mean max of probabilities: 0.9998526 - temperature 0.1
# mean max of probabilities: 0.9998527 - temperature 0.1
# mean max of probabilities: 0.99985266 - temperature 0.1
# mean max of probabilities: 0.9998528 - temperature 0.1
# mean max of probabilities: 0.9998529 - temperature 0.1
# mean max of probabilities: 0.9998532 - temperature 0.1
# mean max of probabilities: 0.9998535 - temperature 0.1
# mean max of probabilities: 0.9998539 - temperature 0.1
# mean max of probabilities: 0.99985427 - temperature 0.1
# mean max of probabilities: 0.9998544 - temperature 0.1
# mean max of probabilities: 0.9998542 - temperature 0.1
# mean max of probabilities: 0.9998544 - temperature 0.1
# mean max of probabilities: 0.9998547 - temperature 0.1
# mean max of probabilities: 0.9998548 - temperature 0.1
# mean max of probabilities: 0.9998548 - temperature 0.1
# mean max of probabilities: 0.9998551 - temperature 0.1
# mean max of probabilities: 0.9998554 - temperature 0.1
# mean max of probabilities: 0.9998555 - temperature 0.1
# mean max of probabilities: 0.9998557 - temperature 0.1
# mean max of probabilities: 0.9998561 - temperature 0.1
# mean max of probabilities: 0.9998562 - temperature 0.1
# mean max of probabilities: 0.9998565 - temperature 0.1
# mean max of probabilities: 0.99985653 - temperature 0.1
# mean max of probabilities: 0.9998567 - temperature 0.1
# mean max of probabilities: 0.9998569 - temperature 0.1
# mean max of probabilities: 0.999857 - temperature 0.1
# mean max of probabilities: 0.99985725 - temperature 0.1
# mean max of probabilities: 0.99985725 - temperature 0.1
# mean max of probabilities: 0.99985766 - temperature 0.1
# mean max of probabilities: 0.9998578 - temperature 0.1
# mean max of probabilities: 0.9998579 - temperature 0.1
# mean max of probabilities: 0.99985814 - temperature 0.1
# mean max of probabilities: 0.9998584 - temperature 0.1
# mean max of probabilities: 0.9998585 - temperature 0.1
# mean max of probabilities: 0.99985856 - temperature 0.1
# mean max of probabilities: 0.99985874 - temperature 0.1
# mean max of probabilities: 0.99985904 - temperature 0.1
# mean max of probabilities: 0.9998593 - temperature 0.1
# mean max of probabilities: 0.9998595 - temperature 0.1
# mean max of probabilities: 0.9998598 - temperature 0.1
# mean max of probabilities: 0.99985987 - temperature 0.1
# mean max of probabilities: 0.9998601 - temperature 0.1
# mean max of probabilities: 0.99986047 - temperature 0.1
# mean max of probabilities: 0.99986047 - temperature 0.1
# mean max of probabilities: 0.9998607 - temperature 0.1
# mean max of probabilities: 0.9998608 - temperature 0.1
# mean max of probabilities: 0.9998608 - temperature 0.1
# mean max of probabilities: 0.9998612 - temperature 0.1
# mean max of probabilities: 0.9998613 - temperature 0.1
# mean max of probabilities: 0.99986154 - temperature 0.1
# mean max of probabilities: 0.99986166 - temperature 0.1
# mean max of probabilities: 0.99986196 - temperature 0.1
# mean max of probabilities: 0.9998621 - temperature 0.1
# mean max of probabilities: 0.99986225 - temperature 0.1
# mean max of probabilities: 0.9998624 - temperature 0.1
# mean max of probabilities: 0.99986255 - temperature 0.1
# mean max of probabilities: 0.9998626 - temperature 0.1
# mean max of probabilities: 0.9998628 - temperature 0.1
# mean max of probabilities: 0.99986285 - temperature 0.1
# mean max of probabilities: 0.999863 - temperature 0.1
# mean max of probabilities: 0.99986315 - temperature 0.1
# mean max of probabilities: 0.9998634 - temperature 0.1
# mean max of probabilities: 0.9998634 - temperature 0.1
# mean max of probabilities: 0.99986374 - temperature 0.1
# mean max of probabilities: 0.99986386 - temperature 0.1
# mean max of probabilities: 0.999864 - temperature 0.1
# mean max of probabilities: 0.9998641 - temperature 0.1
# mean max of probabilities: 0.9998643 - temperature 0.1
# mean max of probabilities: 0.99986464 - temperature 0.1
# mean max of probabilities: 0.9998647 - temperature 0.1
# mean max of probabilities: 0.9998649 - temperature 0.1
# mean max of probabilities: 0.999865 - temperature 0.1
# mean max of probabilities: 0.999865 - temperature 0.1
# mean max of probabilities: 0.99986506 - temperature 0.1
# mean max of probabilities: 0.9998653 - temperature 0.1
# mean max of probabilities: 0.9998654 - temperature 0.1
# mean max of probabilities: 0.99986553 - temperature 0.1
# mean max of probabilities: 0.99986583 - temperature 0.1
# mean max of probabilities: 0.99986595 - temperature 0.1
# mean max of probabilities: 0.99986625 - temperature 0.1
# mean max of probabilities: 0.9998664 - temperature 0.1
# mean max of probabilities: 0.9998666 - temperature 0.1
# mean max of probabilities: 0.9998667 - temperature 0.1
# mean max of probabilities: 0.9998667 - temperature 0.1
# mean max of probabilities: 0.99986684 - temperature 0.1
# mean max of probabilities: 0.99986696 - temperature 0.1
# mean max of probabilities: 0.99986726 - temperature 0.1
# mean max of probabilities: 0.9998674 - temperature 0.1
# mean max of probabilities: 0.9998677 - temperature 0.1
# mean max of probabilities: 0.9998678 - temperature 0.1
# mean max of probabilities: 0.9998679 - temperature 0.1
# mean max of probabilities: 0.9998679 - temperature 0.1
# mean max of probabilities: 0.999868 - temperature 0.1
# mean max of probabilities: 0.99986804 - temperature 0.1
# mean max of probabilities: 0.99986804 - temperature 0.1
# mean max of probabilities: 0.9998683 - temperature 0.1
# mean max of probabilities: 0.99986833 - temperature 0.1
# mean max of probabilities: 0.99986845 - temperature 0.1
# mean max of probabilities: 0.99986863 - temperature 0.1
# mean max of probabilities: 0.9998689 - temperature 0.1
# mean max of probabilities: 0.99986917 - temperature 0.1
# mean max of probabilities: 0.9998692 - temperature 0.1
# mean max of probabilities: 0.9998691 - temperature 0.1
# mean max of probabilities: 0.9998692 - temperature 0.1
# mean max of probabilities: 0.9998692 - temperature 0.1
# mean max of probabilities: 0.9998693 - temperature 0.1
# mean max of probabilities: 0.9998695 - temperature 0.1
# mean max of probabilities: 0.99986964 - temperature 0.1
# mean max of probabilities: 0.99986976 - temperature 0.1
# mean max of probabilities: 0.99986976 - temperature 0.1
# mean max of probabilities: 0.9998699 - temperature 0.1
# mean max of probabilities: 0.99987 - temperature 0.1
# mean max of probabilities: 0.99987024 - temperature 0.1
# mean max of probabilities: 0.9998706 - temperature 0.1
# mean max of probabilities: 0.99987066 - temperature 0.1
# mean max of probabilities: 0.9998707 - temperature 0.1
# mean max of probabilities: 0.99987096 - temperature 0.1
# mean max of probabilities: 0.9998712 - temperature 0.1
# mean max of probabilities: 0.99987125 - temperature 0.1
# mean max of probabilities: 0.9998713 - temperature 0.1
# mean max of probabilities: 0.99987143 - temperature 0.1
# mean max of probabilities: 0.99987173 - temperature 0.1
# mean max of probabilities: 0.999872 - temperature 0.1
# mean max of probabilities: 0.9998721 - temperature 0.1
# mean max of probabilities: 0.9998723 - temperature 0.1
# mean max of probabilities: 0.9998724 - temperature 0.1
# mean max of probabilities: 0.99987245 - temperature 0.1
# mean max of probabilities: 0.99987257 - temperature 0.1
# mean max of probabilities: 0.9998728 - temperature 0.1
# mean max of probabilities: 0.9998729 - temperature 0.1
# mean max of probabilities: 0.99987304 - temperature 0.1
# mean max of probabilities: 0.999873 - temperature 0.1
# mean max of probabilities: 0.99987316 - temperature 0.1
# mean max of probabilities: 0.9998732 - temperature 0.1
# mean max of probabilities: 0.9998735 - temperature 0.1
# mean max of probabilities: 0.9998735 - temperature 0.1
# mean max of probabilities: 0.99987364 - temperature 0.1
# mean max of probabilities: 0.9998738 - temperature 0.1
# mean max of probabilities: 0.99987394 - temperature 0.1
# mean max of probabilities: 0.999874 - temperature 0.1
# mean max of probabilities: 0.999874 - temperature 0.1
# mean max of probabilities: 0.9998739 - temperature 0.1
# mean max of probabilities: 0.99987406 - temperature 0.1
# mean max of probabilities: 0.99987423 - temperature 0.1
# mean max of probabilities: 0.9998744 - temperature 0.1
# mean max of probabilities: 0.99987483 - temperature 0.1
# mean max of probabilities: 0.99987507 - temperature 0.1
# mean max of probabilities: 0.99987525 - temperature 0.1
# mean max of probabilities: 0.9998753 - temperature 0.1
# mean max of probabilities: 0.9998755 - temperature 0.1
# mean max of probabilities: 0.9998756 - temperature 0.1
# mean max of probabilities: 0.9998758 - temperature 0.1
# mean max of probabilities: 0.9998758 - temperature 0.1
# mean max of probabilities: 0.999876 - temperature 0.1
# mean max of probabilities: 0.9998761 - temperature 0.1
# mean max of probabilities: 0.9998763 - temperature 0.1
# mean max of probabilities: 0.9998763 - temperature 0.1
# mean max of probabilities: 0.9998766 - temperature 0.1
# mean max of probabilities: 0.99987656 - temperature 0.1
# mean max of probabilities: 0.99987686 - temperature 0.1
# mean max of probabilities: 0.9998769 - temperature 0.1
# mean max of probabilities: 0.9998771 - temperature 0.1
# mean max of probabilities: 0.9998772 - temperature 0.1
# mean max of probabilities: 0.99987733 - temperature 0.1
# mean max of probabilities: 0.9998774 - temperature 0.1
# mean max of probabilities: 0.9998776 - temperature 0.1
# mean max of probabilities: 0.99987763 - temperature 0.1
# mean max of probabilities: 0.99987775 - temperature 0.1
# mean max of probabilities: 0.999878 - temperature 0.1
# mean max of probabilities: 0.9998782 - temperature 0.1
# mean max of probabilities: 0.99987835 - temperature 0.1
# mean max of probabilities: 0.9998784 - temperature 0.1
# mean max of probabilities: 0.99987847 - temperature 0.1
# mean max of probabilities: 0.99987864 - temperature 0.1
# mean max of probabilities: 0.99987876 - temperature 0.1
# mean max of probabilities: 0.99987876 - temperature 0.1
# mean max of probabilities: 0.9998789 - temperature 0.1
# mean max of probabilities: 0.99987894 - temperature 0.1
# mean max of probabilities: 0.9998789 - temperature 0.1
# mean max of probabilities: 0.99987906 - temperature 0.1
# mean max of probabilities: 0.9998794 - temperature 0.1
# mean max of probabilities: 0.9998794 - temperature 0.1
# mean max of probabilities: 0.9998795 - temperature 0.1
# mean max of probabilities: 0.9998797 - temperature 0.1
# mean max of probabilities: 0.9998798 - temperature 0.1
# mean max of probabilities: 0.9998799 - temperature 0.1
# mean max of probabilities: 0.99987996 - temperature 0.1

# %%
print(np.sort(selector.get_indices()))
np.savetxt('./MUDI/runs/textfiles/' + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.txt', np.array(selector.get_indices(), dtype=int), fmt='%d')
# Out:
# [   0    0    0    0    0    0    0    0    3    9   10   15   16   16
#    20   25   36   39   40   43   44   47   48   51   52   54   59   60
#    64   65   67   68   68   72   72   75   77   82   83   84   91   92
#    95   96   97  100  104  104  108  115  116  117  118  119  123  129
#   131  135  136  141  147  148  154  156  160  160  161  163  164  168
#   171  173  176  177  178  180  183  184  184  184  188  188  190  199
#   200  204  211  215  216  219  221  222  223  224  224  225  229  230
#   232  239  240  240  240  241  244  248  252  252  253  254  256  259
#   260  264  264  266  268  271  275  278  281  283  287  288  290  293
#   296  296  299  303  305  311  314  316  317  319  320  320  324  328
#   328  331  332  332  336  340  343  344  348  350  351  363  367  368
#   371  373  376  380  383  384  385  387  388  392  396  397  398  400
#   404  404  408  408  408  408  412  415  418  419  421  424  425  428
#   429  431  432  432  438  440  446  448  448  448  450  452  461  462
#   464  464  467  468  474  476  483  484  484  485  486  487  494  496
#   498  500  502  504  516  521  527  532  532  532  533  537  538  540
#   548  548  550  551  557  559  560  564  568  575  578  580  581  584
#   587  588  588  588  593  596  600  600  601  603  613  616  616  624
#   624  628  630  635  639  641  643  652  652  655  656  664  672  672
#   672  675  683  684  691  692  700  700  700  701  711  712  712  715
#   716  718  720  721  728  736  755  756  756  761  764  776  780  781
#   785  785  787  792  793  795  803  804  807  809  812  812  823  824
#   825  826  828  828  829  840  841  844  851  852  852  856  856  857
#   860  864  867  868  871  872  878  880  883  885  890  896  904  908
#   913  916  918  920  920  923  924  924  936  936  937  940  944  948
#   949  950  951  952  955  960  964  967  968  975  979  980  981  984
#   992  995  996 1000 1003 1008 1009 1012 1015 1020 1023 1024 1024 1025
#  1035 1036 1038 1044 1045 1046 1052 1052 1052 1055 1056 1056 1057 1059
#  1070 1072 1074 1076 1076 1077 1079 1081 1088 1089 1092 1101 1103 1104
#  1104 1104 1104 1104 1108 1108 1112 1114 1115 1119 1120 1135 1136 1136
#  1146 1160 1160 1160 1164 1166 1168 1170 1178 1184 1185 1186 1187 1188
#  1188 1188 1188 1192 1192 1193 1193 1194 1195 1199 1200 1204 1204 1204
#  1206 1212 1212 1213 1220 1224 1227 1230 1231 1232 1235 1236 1244 1244
#  1244 1245 1252 1252 1256 1259 1260 1260 1263 1270 1272 1275 1276 1282
#  1284 1287 1288 1289 1291 1296 1300 1302 1304 1307 1308 1309 1312 1312
#  1312 1316 1320 1323 1328 1330 1334 1335 1336 1343]

# %%
testsubj = 11
testsubjstr = '11'

# %%
for run in RunBuilder.get_runs(params):
    logdir = "./MUDI/runs/scalars/" + datetime.now().strftime("%Y%m%d-%H%M%S") + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr

    tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)
    monitor_callback = keras.callbacks.ModelCheckpoint('./MUDI/runs/models/' + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '_runtime.h5', monitor='val_loss', verbose=0, save_weights_only=True)
    
    trainset = MRISelectorSubjDataset(root_dir='.', dataf='data_.hdf5', headerf ='header_.csv',
                                  subj_list=np.array([12, 13, 14, 15]), batch_size=run.batch_size)
    testset = MRISelectorSubjDataset(root_dir='.', dataf='data_.hdf5', headerf ='header_.csv',
                                  subj_list=np.array([11]), batch_size=run.batch_size)

    selector = ConcreteAutoencoderFeatureSelector(K=n_meas, output_function=dec, num_epochs=num_epochs, learning_rate=run.lr, start_temp=10.0, min_temp=0.1, 
                                                  tryout_limit=5, input_dim=1344, callback=[tensorboard_callback, monitor_callback])
    
    selector.fit(X=trainset, val_X=testset)
    
    model = selector.get_params()
    
    model.save_weights('./MUDI/runs/models/' + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.h5')
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 1344)]            0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 500)               672001
# _________________________________________________________________
# dense_12 (Dense)             (None, 800)               400800
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 800)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1000)              801000
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 1000)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1344)              1345344
# =================================================================
# Total params: 3,219,145
# Trainable params: 3,219,144
# Non-trainable params: 1
# _________________________________________________________________
# None
# [<keras.callbacks.tensorboard_v2.TensorBoard object at 0x7f5910325f28>, <keras.callbacks.callbacks.ModelCheckpoint object at 0x7f591072aa20>]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layers with arguments in `__init__` must override `get_config`.
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layers with arguments in `__init__` must override `get_config`.
# mean max of probabilities: 0.0008010714 - temperature 10.0
# mean max of probabilities: 0.0009660879 - temperature 9.972043
# mean max of probabilities: 0.0013015328 - temperature 9.944086
# mean max of probabilities: 0.00219251 - temperature 9.916129
# mean max of probabilities: 0.0044949637 - temperature 9.888172
# mean max of probabilities: 0.0053036814 - temperature 9.860215
# mean max of probabilities: 0.0061397897 - temperature 9.832258
# mean max of probabilities: 0.0068393294 - temperature 9.804301
# mean max of probabilities: 0.0074459594 - temperature 9.776344
# mean max of probabilities: 0.008147312 - temperature 9.748387
# mean max of probabilities: 0.008731729 - temperature 9.72043
# mean max of probabilities: 0.009264303 - temperature 9.692473
# mean max of probabilities: 0.00973906 - temperature 9.664516
# mean max of probabilities: 0.010348361 - temperature 9.6365595
# mean max of probabilities: 0.010740311 - temperature 9.608603
# mean max of probabilities: 0.011011288 - temperature 9.580646
# mean max of probabilities: 0.011425548 - temperature 9.552689
# mean max of probabilities: 0.011773429 - temperature 9.524732
# mean max of probabilities: 0.0121344235 - temperature 9.498854
# mean max of probabilities: 0.012574632 - temperature 9.473047
# mean max of probabilities: 0.012995467 - temperature 9.447241
# mean max of probabilities: 0.013417788 - temperature 9.421434
# mean max of probabilities: 0.014087282 - temperature 9.395628
# mean max of probabilities: 0.014720001 - temperature 9.369822
# mean max of probabilities: 0.015349253 - temperature 9.344015
# mean max of probabilities: 0.016127419 - temperature 9.318209
# mean max of probabilities: 0.017099902 - temperature 9.292402
# mean max of probabilities: 0.01832187 - temperature 9.266596
# mean max of probabilities: 0.019980067 - temperature 9.240789
# mean max of probabilities: 0.022290321 - temperature 9.214983
# mean max of probabilities: 0.026062269 - temperature 9.189177
# mean max of probabilities: 0.033618636 - temperature 9.16337
# mean max of probabilities: 0.03923073 - temperature 9.137564
# mean max of probabilities: 0.042476874 - temperature 9.111757
# mean max of probabilities: 0.045205608 - temperature 9.085951
# mean max of probabilities: 0.047953073 - temperature 9.060144
# mean max of probabilities: 0.050682608 - temperature 9.034338
# mean max of probabilities: 0.05330202 - temperature 9.008532
# mean max of probabilities: 0.056034945 - temperature 8.982725
# mean max of probabilities: 0.05865783 - temperature 8.956919
# mean max of probabilities: 0.061284956 - temperature 8.931112
# mean max of probabilities: 0.06403361 - temperature 8.905306
# mean max of probabilities: 0.06668423 - temperature 8.879499
# mean max of probabilities: 0.06935935 - temperature 8.853693
# mean max of probabilities: 0.072272696 - temperature 8.827887
# mean max of probabilities: 0.07514297 - temperature 8.80208
# mean max of probabilities: 0.0780114 - temperature 8.776274
# mean max of probabilities: 0.08094086 - temperature 8.75142
# mean max of probabilities: 0.08375046 - temperature 8.727764
# mean max of probabilities: 0.08676364 - temperature 8.704108
# mean max of probabilities: 0.089527346 - temperature 8.680452
# mean max of probabilities: 0.09249934 - temperature 8.656796
# mean max of probabilities: 0.095487155 - temperature 8.633141
# mean max of probabilities: 0.09854594 - temperature 8.609485
# mean max of probabilities: 0.10146523 - temperature 8.585829
# mean max of probabilities: 0.10454025 - temperature 8.562173
# mean max of probabilities: 0.107653394 - temperature 8.538517
# mean max of probabilities: 0.110780746 - temperature 8.514861
# mean max of probabilities: 0.113878 - temperature 8.491205
# mean max of probabilities: 0.11731471 - temperature 8.467549
# mean max of probabilities: 0.120527215 - temperature 8.443893
# mean max of probabilities: 0.123787016 - temperature 8.420238
# mean max of probabilities: 0.12716447 - temperature 8.396582
# mean max of probabilities: 0.13050324 - temperature 8.372926
# mean max of probabilities: 0.13386975 - temperature 8.34927
# mean max of probabilities: 0.13709792 - temperature 8.325614
# mean max of probabilities: 0.14054494 - temperature 8.301958
# mean max of probabilities: 0.14392954 - temperature 8.278302
# mean max of probabilities: 0.14766176 - temperature 8.254646
# mean max of probabilities: 0.15128662 - temperature 8.23099
# mean max of probabilities: 0.15484811 - temperature 8.2073345
# mean max of probabilities: 0.15841997 - temperature 8.183679
# mean max of probabilities: 0.16191013 - temperature 8.160023
# mean max of probabilities: 0.16506228 - temperature 8.136367
# mean max of probabilities: 0.16818489 - temperature 8.112711
# mean max of probabilities: 0.17155816 - temperature 8.089055
# mean max of probabilities: 0.17468585 - temperature 8.065399
# mean max of probabilities: 0.17763762 - temperature 8.041743
# mean max of probabilities: 0.18062325 - temperature 8.018087
# mean max of probabilities: 0.1834065 - temperature 7.9946847
# mean max of probabilities: 0.18606195 - temperature 7.972104
# mean max of probabilities: 0.18881221 - temperature 7.9495234
# mean max of probabilities: 0.1887737 - temperature 7.926943
# mean max of probabilities: 0.19174479 - temperature 7.904362
# mean max of probabilities: 0.19510576 - temperature 7.8817816
# mean max of probabilities: 0.19809814 - temperature 7.859201
# mean max of probabilities: 0.20104285 - temperature 7.8366203
# mean max of probabilities: 0.20392029 - temperature 7.8140397
# mean max of probabilities: 0.2068194 - temperature 7.7923193
# mean max of probabilities: 0.20974399 - temperature 7.770814
# mean max of probabilities: 0.21251649 - temperature 7.7493086
# mean max of probabilities: 0.2153706 - temperature 7.727803
# mean max of probabilities: 0.21826324 - temperature 7.706298
# mean max of probabilities: 0.22097787 - temperature 7.6847925
# mean max of probabilities: 0.2235849 - temperature 7.663287
# mean max of probabilities: 0.22630985 - temperature 7.641782
# mean max of probabilities: 0.229019 - temperature 7.6202765
# mean max of probabilities: 0.23151836 - temperature 7.598771
# mean max of probabilities: 0.23398364 - temperature 7.5772657
# mean max of probabilities: 0.23657192 - temperature 7.5557604
# mean max of probabilities: 0.23875707 - temperature 7.534255
# mean max of probabilities: 0.24119891 - temperature 7.5127497
# mean max of probabilities: 0.24369486 - temperature 7.4912443
# mean max of probabilities: 0.24614629 - temperature 7.469739
# mean max of probabilities: 0.24870063 - temperature 7.4482336
# mean max of probabilities: 0.2509822 - temperature 7.4268203
# mean max of probabilities: 0.25358212 - temperature 7.40639
# mean max of probabilities: 0.2557578 - temperature 7.38596
# mean max of probabilities: 0.25802195 - temperature 7.36553
# mean max of probabilities: 0.26047394 - temperature 7.3451
# mean max of probabilities: 0.26262745 - temperature 7.32467
# mean max of probabilities: 0.26495576 - temperature 7.3042397
# mean max of probabilities: 0.26738197 - temperature 7.2838097
# mean max of probabilities: 0.26988527 - temperature 7.2633796
# mean max of probabilities: 0.2723415 - temperature 7.2429495
# mean max of probabilities: 0.27502418 - temperature 7.2225194
# mean max of probabilities: 0.27760324 - temperature 7.2020893
# mean max of probabilities: 0.28041586 - temperature 7.181659
# mean max of probabilities: 0.2832295 - temperature 7.161229
# mean max of probabilities: 0.28622532 - temperature 7.140799
# mean max of probabilities: 0.2895089 - temperature 7.120369
# mean max of probabilities: 0.2927898 - temperature 7.099939
# mean max of probabilities: 0.2961341 - temperature 7.079509
# mean max of probabilities: 0.29967904 - temperature 7.0590787
# mean max of probabilities: 0.3030028 - temperature 7.0391207
# mean max of probabilities: 0.30649352 - temperature 7.019766
# mean max of probabilities: 0.3097554 - temperature 7.000411
# mean max of probabilities: 0.31278557 - temperature 6.981056
# mean max of probabilities: 0.3157104 - temperature 6.9617014
# mean max of probabilities: 0.31824833 - temperature 6.9423466
# mean max of probabilities: 0.32071793 - temperature 6.9229918
# mean max of probabilities: 0.32324046 - temperature 6.903637
# mean max of probabilities: 0.3256849 - temperature 6.884282
# mean max of probabilities: 0.3278423 - temperature 6.8649273
# mean max of probabilities: 0.33007082 - temperature 6.8455725
# mean max of probabilities: 0.3320142 - temperature 6.8262177
# mean max of probabilities: 0.33383238 - temperature 6.806863
# mean max of probabilities: 0.33556908 - temperature 6.787508
# mean max of probabilities: 0.33722344 - temperature 6.768153
# mean max of probabilities: 0.33855706 - temperature 6.7487984
# mean max of probabilities: 0.33972242 - temperature 6.7294436
# mean max of probabilities: 0.3408772 - temperature 6.7100887
# mean max of probabilities: 0.3416963 - temperature 6.690734
# mean max of probabilities: 0.34225866 - temperature 6.671379
# mean max of probabilities: 0.34272522 - temperature 6.6528373
# mean max of probabilities: 0.3429704 - temperature 6.6345577
# mean max of probabilities: 0.342969 - temperature 6.616278
# mean max of probabilities: 0.34297177 - temperature 6.5979986
# mean max of probabilities: 0.34307122 - temperature 6.579719
# mean max of probabilities: 0.3430343 - temperature 6.5614395
# mean max of probabilities: 0.343106 - temperature 6.54316
# mean max of probabilities: 0.34290284 - temperature 6.5248804
# mean max of probabilities: 0.3427991 - temperature 6.506601
# mean max of probabilities: 0.34266332 - temperature 6.4883213
# mean max of probabilities: 0.342236 - temperature 6.4700418
# mean max of probabilities: 0.3419446 - temperature 6.451762
# mean max of probabilities: 0.34144548 - temperature 6.4334826
# mean max of probabilities: 0.34093952 - temperature 6.415203
# mean max of probabilities: 0.34031406 - temperature 6.3969235
# mean max of probabilities: 0.33954266 - temperature 6.378644
# mean max of probabilities: 0.3390082 - temperature 6.3603644
# mean max of probabilities: 0.33826467 - temperature 6.342085
# mean max of probabilities: 0.3375006 - temperature 6.3238053
# mean max of probabilities: 0.3367291 - temperature 6.305526
# mean max of probabilities: 0.3361629 - temperature 6.287246
# mean max of probabilities: 0.33554894 - temperature 6.269952
# mean max of probabilities: 0.3349208 - temperature 6.2527475
# mean max of probabilities: 0.33425745 - temperature 6.2355433
# mean max of probabilities: 0.3336004 - temperature 6.218339
# mean max of probabilities: 0.33294284 - temperature 6.2011347
# mean max of probabilities: 0.33257285 - temperature 6.1839304
# mean max of probabilities: 0.33236477 - temperature 6.166726
# mean max of probabilities: 0.33228692 - temperature 6.149522
# mean max of probabilities: 0.33239362 - temperature 6.1323175
# mean max of probabilities: 0.3325484 - temperature 6.1151133
# mean max of probabilities: 0.33279204 - temperature 6.097909
# mean max of probabilities: 0.3332391 - temperature 6.0807047
# mean max of probabilities: 0.33362204 - temperature 6.0635004
# mean max of probabilities: 0.33415997 - temperature 6.046296
# mean max of probabilities: 0.33287117 - temperature 6.029092
# mean max of probabilities: 0.3333657 - temperature 6.0118876
# mean max of probabilities: 0.33421323 - temperature 5.9946833
# mean max of probabilities: 0.33499262 - temperature 5.977479
# mean max of probabilities: 0.33581957 - temperature 5.9602747
# mean max of probabilities: 0.33662558 - temperature 5.9430704
# mean max of probabilities: 0.33730423 - temperature 5.925866
# mean max of probabilities: 0.33815226 - temperature 5.908662
# mean max of probabilities: 0.3391215 - temperature 5.8922887
# mean max of probabilities: 0.34011516 - temperature 5.8761597
# mean max of probabilities: 0.34108573 - temperature 5.8600307
# mean max of probabilities: 0.342027 - temperature 5.8439016
# mean max of probabilities: 0.34332576 - temperature 5.8277726
# mean max of probabilities: 0.34446585 - temperature 5.8116436
# mean max of probabilities: 0.34553358 - temperature 5.7955146
# mean max of probabilities: 0.34671184 - temperature 5.7793856
# mean max of probabilities: 0.34793273 - temperature 5.7632565
# mean max of probabilities: 0.3489802 - temperature 5.7471275
# mean max of probabilities: 0.34988916 - temperature 5.7309985
# mean max of probabilities: 0.35081777 - temperature 5.7148695
# mean max of probabilities: 0.35185927 - temperature 5.6987405
# mean max of probabilities: 0.35278127 - temperature 5.6826115
# mean max of probabilities: 0.3534588 - temperature 5.6664824
# mean max of probabilities: 0.3545969 - temperature 5.6503534
# mean max of probabilities: 0.3556912 - temperature 5.6342244
# mean max of probabilities: 0.35660675 - temperature 5.6180954
# mean max of probabilities: 0.35755107 - temperature 5.6019664
# mean max of probabilities: 0.3584183 - temperature 5.5858374
# mean max of probabilities: 0.35929814 - temperature 5.5697083
# mean max of probabilities: 0.36014733 - temperature 5.5535793
# mean max of probabilities: 0.36096805 - temperature 5.5374503
# mean max of probabilities: 0.36189324 - temperature 5.5214868
# mean max of probabilities: 0.3625863 - temperature 5.506433
# mean max of probabilities: 0.3633768 - temperature 5.4913793
# mean max of probabilities: 0.36398223 - temperature 5.4763255
# mean max of probabilities: 0.36475217 - temperature 5.461272
# mean max of probabilities: 0.36542925 - temperature 5.446218
# mean max of probabilities: 0.3660457 - temperature 5.4311643
# mean max of probabilities: 0.36679748 - temperature 5.4161105
# mean max of probabilities: 0.36730227 - temperature 5.401057
# mean max of probabilities: 0.3677522 - temperature 5.386003
# mean max of probabilities: 0.3683061 - temperature 5.3709493
# mean max of probabilities: 0.3690673 - temperature 5.3558955
# mean max of probabilities: 0.36995193 - temperature 5.340842
# mean max of probabilities: 0.37073633 - temperature 5.325788
# mean max of probabilities: 0.3715864 - temperature 5.3107343
# mean max of probabilities: 0.37242556 - temperature 5.2956805
# mean max of probabilities: 0.3732449 - temperature 5.280627
# mean max of probabilities: 0.3739069 - temperature 5.265573
# mean max of probabilities: 0.3745392 - temperature 5.2505193
# mean max of probabilities: 0.37541366 - temperature 5.2354655
# mean max of probabilities: 0.37604088 - temperature 5.220412
# mean max of probabilities: 0.37687457 - temperature 5.205358
# mean max of probabilities: 0.37775066 - temperature 5.1903043
# mean max of probabilities: 0.37849712 - temperature 5.1752505
# mean max of probabilities: 0.3793659 - temperature 5.160197
# mean max of probabilities: 0.38017073 - temperature 5.145143
# mean max of probabilities: 0.38069743 - temperature 5.131001
# mean max of probabilities: 0.38142633 - temperature 5.1170225
# mean max of probabilities: 0.38215178 - temperature 5.103044
# mean max of probabilities: 0.38267377 - temperature 5.0890656
# mean max of probabilities: 0.38324377 - temperature 5.075087
# mean max of probabilities: 0.38382018 - temperature 5.0611086
# mean max of probabilities: 0.3847207 - temperature 5.04713
# mean max of probabilities: 0.3854636 - temperature 5.0331516
# mean max of probabilities: 0.38638884 - temperature 5.019173
# mean max of probabilities: 0.38713202 - temperature 5.0051947
# mean max of probabilities: 0.38803804 - temperature 4.991216
# mean max of probabilities: 0.38870567 - temperature 4.9772377
# mean max of probabilities: 0.3895296 - temperature 4.963259
# mean max of probabilities: 0.39030156 - temperature 4.9492807
# mean max of probabilities: 0.39097995 - temperature 4.9353023
# mean max of probabilities: 0.39184412 - temperature 4.921324
# mean max of probabilities: 0.39276993 - temperature 4.9073453
# mean max of probabilities: 0.39365125 - temperature 4.893367
# mean max of probabilities: 0.39465487 - temperature 4.8793883
# mean max of probabilities: 0.39565045 - temperature 4.86541
# mean max of probabilities: 0.3965169 - temperature 4.8514314
# mean max of probabilities: 0.39737496 - temperature 4.837453
# mean max of probabilities: 0.3982574 - temperature 4.8234744
# mean max of probabilities: 0.39923313 - temperature 4.809496
# mean max of probabilities: 0.40037045 - temperature 4.7955174
# mean max of probabilities: 0.40115052 - temperature 4.781539
# mean max of probabilities: 0.40237048 - temperature 4.7675605
# mean max of probabilities: 0.40313533 - temperature 4.754222
# mean max of probabilities: 0.40417776 - temperature 4.7413187
# mean max of probabilities: 0.4051875 - temperature 4.7284155
# mean max of probabilities: 0.4063101 - temperature 4.7155123
# mean max of probabilities: 0.40709388 - temperature 4.702609
# mean max of probabilities: 0.4079861 - temperature 4.689706
# mean max of probabilities: 0.40889147 - temperature 4.6768026
# mean max of probabilities: 0.40979853 - temperature 4.6638994
# mean max of probabilities: 0.41060564 - temperature 4.650996
# mean max of probabilities: 0.41169432 - temperature 4.638093
# mean max of probabilities: 0.41288745 - temperature 4.62519
# mean max of probabilities: 0.41398102 - temperature 4.6122866
# mean max of probabilities: 0.4152301 - temperature 4.5993834
# mean max of probabilities: 0.41623735 - temperature 4.58648
# mean max of probabilities: 0.41711524 - temperature 4.573577
# mean max of probabilities: 0.41786724 - temperature 4.5606737
# mean max of probabilities: 0.41873482 - temperature 4.5477705
# mean max of probabilities: 0.41971734 - temperature 4.5348673
# mean max of probabilities: 0.42048532 - temperature 4.521964
# mean max of probabilities: 0.42127374 - temperature 4.509061
# mean max of probabilities: 0.42192295 - temperature 4.4961576
# mean max of probabilities: 0.42298594 - temperature 4.4832544
# mean max of probabilities: 0.4237963 - temperature 4.470351
# mean max of probabilities: 0.42456293 - temperature 4.457448
# mean max of probabilities: 0.42527115 - temperature 4.444545
# mean max of probabilities: 0.4259666 - temperature 4.4316416
# mean max of probabilities: 0.42659083 - temperature 4.4187384
# mean max of probabilities: 0.4272065 - temperature 4.405835
# mean max of probabilities: 0.4279359 - temperature 4.392932
# mean max of probabilities: 0.42872468 - temperature 4.3801055
# mean max of probabilities: 0.42940253 - temperature 4.3682775
# mean max of probabilities: 0.42984307 - temperature 4.3564496
# mean max of probabilities: 0.43057066 - temperature 4.3446217
# mean max of probabilities: 0.43105355 - temperature 4.3327937
# mean max of probabilities: 0.431943 - temperature 4.320966
# mean max of probabilities: 0.43272227 - temperature 4.309138
# mean max of probabilities: 0.43323186 - temperature 4.29731
# mean max of probabilities: 0.4338238 - temperature 4.285482
# mean max of probabilities: 0.43442348 - temperature 4.273654
# mean max of probabilities: 0.43519443 - temperature 4.261826
# mean max of probabilities: 0.43576568 - temperature 4.249998
# mean max of probabilities: 0.43661073 - temperature 4.23817
# mean max of probabilities: 0.4371515 - temperature 4.226342
# mean max of probabilities: 0.43757543 - temperature 4.2145143
# mean max of probabilities: 0.43802577 - temperature 4.2026863
# mean max of probabilities: 0.43844378 - temperature 4.1908584
# mean max of probabilities: 0.4391541 - temperature 4.1790304
# mean max of probabilities: 0.43961594 - temperature 4.1672025
# mean max of probabilities: 0.44014266 - temperature 4.1553745
# mean max of probabilities: 0.4406211 - temperature 4.1435466
# mean max of probabilities: 0.44123426 - temperature 4.1317186
# mean max of probabilities: 0.44153976 - temperature 4.1198907
# mean max of probabilities: 0.44177338 - temperature 4.1080627
# mean max of probabilities: 0.44204834 - temperature 4.096235
# mean max of probabilities: 0.4425588 - temperature 4.084407
# mean max of probabilities: 0.44284728 - temperature 4.072579
# mean max of probabilities: 0.44296724 - temperature 4.060751
# mean max of probabilities: 0.44323784 - temperature 4.048923
# mean max of probabilities: 0.44363132 - temperature 4.037095
# mean max of probabilities: 0.4437699 - temperature 4.025267
# mean max of probabilities: 0.4443096 - temperature 4.013439
# mean max of probabilities: 0.44473907 - temperature 4.001611
# mean max of probabilities: 0.44517156 - temperature 3.9902477
# mean max of probabilities: 0.44566342 - temperature 3.9789574
# mean max of probabilities: 0.4459729 - temperature 3.967667
# mean max of probabilities: 0.44648498 - temperature 3.9563768
# mean max of probabilities: 0.44679308 - temperature 3.9450865
# mean max of probabilities: 0.44686586 - temperature 3.9337962
# mean max of probabilities: 0.44708923 - temperature 3.9225059
# mean max of probabilities: 0.44733673 - temperature 3.9112155
# mean max of probabilities: 0.44768232 - temperature 3.9001555
# mean max of probabilities: 0.44773737 - temperature 3.8894029
# mean max of probabilities: 0.44772065 - temperature 3.8786502
# mean max of probabilities: 0.44794592 - temperature 3.8678975
# mean max of probabilities: 0.4482142 - temperature 3.8571448
# mean max of probabilities: 0.44829676 - temperature 3.8463922
# mean max of probabilities: 0.4485504 - temperature 3.8356395
# mean max of probabilities: 0.44847584 - temperature 3.8248868
# mean max of probabilities: 0.4485488 - temperature 3.8141341
# mean max of probabilities: 0.44881973 - temperature 3.8033814
# mean max of probabilities: 0.44900334 - temperature 3.7926288
# mean max of probabilities: 0.44901678 - temperature 3.781876
# mean max of probabilities: 0.4492873 - temperature 3.7711234
# mean max of probabilities: 0.44967827 - temperature 3.7603707
# mean max of probabilities: 0.44949096 - temperature 3.749618
# mean max of probabilities: 0.44978878 - temperature 3.7388654
# mean max of probabilities: 0.44991416 - temperature 3.7281127
# mean max of probabilities: 0.4500013 - temperature 3.71736
# mean max of probabilities: 0.4500612 - temperature 3.7069912
# mean max of probabilities: 0.44999254 - temperature 3.6967762
# mean max of probabilities: 0.45036247 - temperature 3.686561
# mean max of probabilities: 0.45062223 - temperature 3.676346
# mean max of probabilities: 0.4509245 - temperature 3.666131
# mean max of probabilities: 0.45159358 - temperature 3.655916
# mean max of probabilities: 0.45169643 - temperature 3.645701
# mean max of probabilities: 0.45191187 - temperature 3.635486
# mean max of probabilities: 0.45195052 - temperature 3.6252708
# mean max of probabilities: 0.45223486 - temperature 3.6150558
# mean max of probabilities: 0.4521597 - temperature 3.6048408
# mean max of probabilities: 0.45234075 - temperature 3.5946257
# mean max of probabilities: 0.45244494 - temperature 3.5844107
# mean max of probabilities: 0.4523663 - temperature 3.5741956
# mean max of probabilities: 0.45230168 - temperature 3.5639806
# mean max of probabilities: 0.45238703 - temperature 3.5537655
# mean max of probabilities: 0.45253578 - temperature 3.5435505
# mean max of probabilities: 0.45245653 - temperature 3.5333354
# mean max of probabilities: 0.452377 - temperature 3.5231566
# mean max of probabilities: 0.4522209 - temperature 3.5134792
# mean max of probabilities: 0.4523477 - temperature 3.5038018
# mean max of probabilities: 0.45233178 - temperature 3.4941244
# mean max of probabilities: 0.4524277 - temperature 3.484447
# mean max of probabilities: 0.45242888 - temperature 3.4747696
# mean max of probabilities: 0.4525963 - temperature 3.4650922
# mean max of probabilities: 0.45234966 - temperature 3.4554148
# mean max of probabilities: 0.45226878 - temperature 3.4457374
# mean max of probabilities: 0.4521121 - temperature 3.43606
# mean max of probabilities: 0.45180824 - temperature 3.4263825
# mean max of probabilities: 0.45155475 - temperature 3.4167051
# mean max of probabilities: 0.45119083 - temperature 3.4070277
# mean max of probabilities: 0.4508586 - temperature 3.3973503
# mean max of probabilities: 0.4503953 - temperature 3.387673
# mean max of probabilities: 0.45030695 - temperature 3.3779955
# mean max of probabilities: 0.44988576 - temperature 3.368318
# mean max of probabilities: 0.44958046 - temperature 3.3586407
# mean max of probabilities: 0.44924006 - temperature 3.3489633
# mean max of probabilities: 0.44904897 - temperature 3.3392859
# mean max of probabilities: 0.4485406 - temperature 3.3298151
# mean max of probabilities: 0.44797802 - temperature 3.3206754
# mean max of probabilities: 0.44750673 - temperature 3.3115356
# mean max of probabilities: 0.44677603 - temperature 3.3023958
# mean max of probabilities: 0.4461797 - temperature 3.293256
# mean max of probabilities: 0.4458461 - temperature 3.2841163
# mean max of probabilities: 0.4453573 - temperature 3.2749765
# mean max of probabilities: 0.44516364 - temperature 3.2658367
# mean max of probabilities: 0.44504824 - temperature 3.256697
# mean max of probabilities: 0.4449964 - temperature 3.2475572
# mean max of probabilities: 0.44476303 - temperature 3.2384174
# mean max of probabilities: 0.44445792 - temperature 3.2292776
# mean max of probabilities: 0.44404376 - temperature 3.2201378
# mean max of probabilities: 0.4438366 - temperature 3.210998
# mean max of probabilities: 0.4435395 - temperature 3.2018583
# mean max of probabilities: 0.44314232 - temperature 3.1927185
# mean max of probabilities: 0.44265497 - temperature 3.1835787
# mean max of probabilities: 0.4420761 - temperature 3.174439
# mean max of probabilities: 0.4419623 - temperature 3.1652992
# mean max of probabilities: 0.44166687 - temperature 3.1561594
# mean max of probabilities: 0.44136038 - temperature 3.1470196
# mean max of probabilities: 0.44091937 - temperature 3.1381726
# mean max of probabilities: 0.4407574 - temperature 3.1295705
# mean max of probabilities: 0.44068098 - temperature 3.1209683
# mean max of probabilities: 0.43979394 - temperature 3.1123662
# mean max of probabilities: 0.43910024 - temperature 3.103764
# mean max of probabilities: 0.43897986 - temperature 3.095162
# mean max of probabilities: 0.43889022 - temperature 3.0865598
# mean max of probabilities: 0.43873996 - temperature 3.0779576
# mean max of probabilities: 0.43849877 - temperature 3.0693555
# mean max of probabilities: 0.43832976 - temperature 3.0607533
# mean max of probabilities: 0.43777177 - temperature 3.0521512
# mean max of probabilities: 0.43726546 - temperature 3.043549
# mean max of probabilities: 0.43709412 - temperature 3.034947
# mean max of probabilities: 0.43685186 - temperature 3.0263448
# mean max of probabilities: 0.43645674 - temperature 3.0177426
# mean max of probabilities: 0.4361518 - temperature 3.0091405
# mean max of probabilities: 0.43586588 - temperature 3.0005383
# mean max of probabilities: 0.43574384 - temperature 2.9919362
# mean max of probabilities: 0.4355709 - temperature 2.983334
# mean max of probabilities: 0.4354286 - temperature 2.974732
# mean max of probabilities: 0.4350596 - temperature 2.9661298
# mean max of probabilities: 0.4345199 - temperature 2.9575276
# mean max of probabilities: 0.43395498 - temperature 2.9491413
# mean max of probabilities: 0.43368208 - temperature 2.9410768
# mean max of probabilities: 0.4333766 - temperature 2.9330122
# mean max of probabilities: 0.43315485 - temperature 2.9249477
# mean max of probabilities: 0.4330383 - temperature 2.9168832
# mean max of probabilities: 0.4327822 - temperature 2.9088187
# mean max of probabilities: 0.4329156 - temperature 2.9007542
# mean max of probabilities: 0.4327561 - temperature 2.8926897
# mean max of probabilities: 0.43301505 - temperature 2.8846252
# mean max of probabilities: 0.43293613 - temperature 2.8765607
# mean max of probabilities: 0.4331157 - temperature 2.8684962
# mean max of probabilities: 0.43279096 - temperature 2.8604317
# mean max of probabilities: 0.43268928 - temperature 2.8523672
# mean max of probabilities: 0.43268642 - temperature 2.8443027
# mean max of probabilities: 0.43295893 - temperature 2.8362381
# mean max of probabilities: 0.4328788 - temperature 2.8281736
# mean max of probabilities: 0.4326786 - temperature 2.8201091
# mean max of probabilities: 0.4328383 - temperature 2.8120446
# mean max of probabilities: 0.43262208 - temperature 2.80398
# mean max of probabilities: 0.4328948 - temperature 2.7959156
# mean max of probabilities: 0.43295488 - temperature 2.787851
# mean max of probabilities: 0.43318892 - temperature 2.7797866
# mean max of probabilities: 0.4333747 - temperature 2.771722
# mean max of probabilities: 0.4334222 - temperature 2.7636576
# mean max of probabilities: 0.43357906 - temperature 2.7560136
# mean max of probabilities: 0.43359223 - temperature 2.7484868
# mean max of probabilities: 0.4340503 - temperature 2.74096
# mean max of probabilities: 0.43416885 - temperature 2.733433
# mean max of probabilities: 0.4340363 - temperature 2.7259061
# mean max of probabilities: 0.43393365 - temperature 2.7183793
# mean max of probabilities: 0.43397918 - temperature 2.7108524
# mean max of probabilities: 0.43454388 - temperature 2.7033255
# mean max of probabilities: 0.4345978 - temperature 2.6957986
# mean max of probabilities: 0.4346118 - temperature 2.6882718
# mean max of probabilities: 0.43467572 - temperature 2.680745
# mean max of probabilities: 0.43449366 - temperature 2.673218
# mean max of probabilities: 0.43452883 - temperature 2.6656911
# mean max of probabilities: 0.43470433 - temperature 2.6581643
# mean max of probabilities: 0.43459055 - temperature 2.6506374
# mean max of probabilities: 0.43487388 - temperature 2.6431105
# mean max of probabilities: 0.43497854 - temperature 2.6355836
# mean max of probabilities: 0.43502504 - temperature 2.6280568
# mean max of probabilities: 0.4348498 - temperature 2.62053
# mean max of probabilities: 0.43468723 - temperature 2.613003
# mean max of probabilities: 0.4346639 - temperature 2.6054761
# mean max of probabilities: 0.43481767 - temperature 2.5979493
# mean max of probabilities: 0.43472937 - temperature 2.5904224
# mean max of probabilities: 0.43457842 - temperature 2.5828955
# mean max of probabilities: 0.43444133 - temperature 2.5753686
# mean max of probabilities: 0.43422917 - temperature 2.5680978
# mean max of probabilities: 0.4339311 - temperature 2.5611086
# mean max of probabilities: 0.4339123 - temperature 2.5541193
# mean max of probabilities: 0.43375686 - temperature 2.54713
# mean max of probabilities: 0.43346563 - temperature 2.5401409
# mean max of probabilities: 0.43324286 - temperature 2.5331516
# mean max of probabilities: 0.43308485 - temperature 2.5261624
# mean max of probabilities: 0.43281317 - temperature 2.5191731
# mean max of probabilities: 0.43261743 - temperature 2.512184
# mean max of probabilities: 0.4323968 - temperature 2.5051947
# mean max of probabilities: 0.43224725 - temperature 2.4982054
# mean max of probabilities: 0.43203765 - temperature 2.4912162
# mean max of probabilities: 0.43178672 - temperature 2.484227
# mean max of probabilities: 0.43158928 - temperature 2.4772377
# mean max of probabilities: 0.4312607 - temperature 2.4702485
# mean max of probabilities: 0.43136194 - temperature 2.4632592
# mean max of probabilities: 0.43134895 - temperature 2.45627
# mean max of probabilities: 0.43089306 - temperature 2.4492807
# mean max of probabilities: 0.43089572 - temperature 2.4422915
# mean max of probabilities: 0.4310013 - temperature 2.4353023
# mean max of probabilities: 0.43107244 - temperature 2.428313
# mean max of probabilities: 0.43067765 - temperature 2.4213238
# mean max of probabilities: 0.43019557 - temperature 2.4143345
# mean max of probabilities: 0.43009713 - temperature 2.4073453
# mean max of probabilities: 0.42998505 - temperature 2.400356
# mean max of probabilities: 0.43021175 - temperature 2.3933668
# mean max of probabilities: 0.43038172 - temperature 2.3863776
# mean max of probabilities: 0.43035105 - temperature 2.3795085
# mean max of probabilities: 0.43057787 - temperature 2.373057
# mean max of probabilities: 0.4308018 - temperature 2.3666053
# mean max of probabilities: 0.43083972 - temperature 2.3601537
# mean max of probabilities: 0.43083158 - temperature 2.353702
# mean max of probabilities: 0.4309863 - temperature 2.3472505
# mean max of probabilities: 0.4309903 - temperature 2.3407989
# mean max of probabilities: 0.43125635 - temperature 2.3343472
# mean max of probabilities: 0.43163356 - temperature 2.3278956
# mean max of probabilities: 0.43186408 - temperature 2.321444
# mean max of probabilities: 0.43186268 - temperature 2.3149924
# mean max of probabilities: 0.4327318 - temperature 2.3085408
# mean max of probabilities: 0.43314862 - temperature 2.3020892
# mean max of probabilities: 0.43353805 - temperature 2.2956376
# mean max of probabilities: 0.43381247 - temperature 2.289186
# mean max of probabilities: 0.43443212 - temperature 2.2827344
# mean max of probabilities: 0.43473193 - temperature 2.2762828
# mean max of probabilities: 0.4349961 - temperature 2.2698312
# mean max of probabilities: 0.43522304 - temperature 2.2633796
# mean max of probabilities: 0.43550092 - temperature 2.256928
# mean max of probabilities: 0.43545958 - temperature 2.2504764
# mean max of probabilities: 0.43564233 - temperature 2.2440248
# mean max of probabilities: 0.43605074 - temperature 2.2375731
# mean max of probabilities: 0.43614933 - temperature 2.2311215
# mean max of probabilities: 0.43635896 - temperature 2.22467
# mean max of probabilities: 0.4366966 - temperature 2.2182183
# mean max of probabilities: 0.43652046 - temperature 2.2117667
# mean max of probabilities: 0.43690753 - temperature 2.205315
# mean max of probabilities: 0.43683878 - temperature 2.1988635
# mean max of probabilities: 0.4370231 - temperature 2.192412
# mean max of probabilities: 0.43728432 - temperature 2.1863365
# mean max of probabilities: 0.43743426 - temperature 2.1804225
# mean max of probabilities: 0.43755895 - temperature 2.1745086
# mean max of probabilities: 0.43783203 - temperature 2.1685946
# mean max of probabilities: 0.43794525 - temperature 2.1626806
# mean max of probabilities: 0.437542 - temperature 2.1567667
# mean max of probabilities: 0.43753743 - temperature 2.1508527
# mean max of probabilities: 0.43713516 - temperature 2.1449387
# mean max of probabilities: 0.43660963 - temperature 2.1390247
# mean max of probabilities: 0.43648764 - temperature 2.1331108
# mean max of probabilities: 0.43636444 - temperature 2.1271968
# mean max of probabilities: 0.4361741 - temperature 2.1212828
# mean max of probabilities: 0.43565166 - temperature 2.1153688
# mean max of probabilities: 0.43520594 - temperature 2.1094549
# mean max of probabilities: 0.43454367 - temperature 2.103541
# mean max of probabilities: 0.43427372 - temperature 2.097627
# mean max of probabilities: 0.4340228 - temperature 2.091713
# mean max of probabilities: 0.43407246 - temperature 2.085799
# mean max of probabilities: 0.43355897 - temperature 2.079885
# mean max of probabilities: 0.4332429 - temperature 2.073971
# mean max of probabilities: 0.43322963 - temperature 2.068057
# mean max of probabilities: 0.42824298 - temperature 2.062143
# mean max of probabilities: 0.4281095 - temperature 2.056229
# mean max of probabilities: 0.42806742 - temperature 2.0503151
# mean max of probabilities: 0.42811754 - temperature 2.0444012
# mean max of probabilities: 0.4287196 - temperature 2.0384872
# mean max of probabilities: 0.4287326 - temperature 2.0325732
# mean max of probabilities: 0.42867607 - temperature 2.0266593
# mean max of probabilities: 0.42820412 - temperature 2.0207453
# mean max of probabilities: 0.42792353 - temperature 2.0148313
# mean max of probabilities: 0.42792085 - temperature 2.0089173
# mean max of probabilities: 0.42743608 - temperature 2.0030034
# mean max of probabilities: 0.4273202 - temperature 1.9972217
# mean max of probabilities: 0.42706946 - temperature 1.9915766
# mean max of probabilities: 0.42700848 - temperature 1.9859314
# mean max of probabilities: 0.42702073 - temperature 1.9802862
# mean max of probabilities: 0.42718655 - temperature 1.9746411
# mean max of probabilities: 0.4273003 - temperature 1.9689959
# mean max of probabilities: 0.42720947 - temperature 1.9633508
# mean max of probabilities: 0.42711645 - temperature 1.9577056
# mean max of probabilities: 0.4268674 - temperature 1.9520757
# mean max of probabilities: 0.4269413 - temperature 1.9466994
# mean max of probabilities: 0.42687654 - temperature 1.941323
# mean max of probabilities: 0.42680928 - temperature 1.9359467
# mean max of probabilities: 0.42681926 - temperature 1.9305704
# mean max of probabilities: 0.4267631 - temperature 1.925194
# mean max of probabilities: 0.42656305 - temperature 1.9198177
# mean max of probabilities: 0.42682797 - temperature 1.9144413
# mean max of probabilities: 0.42701814 - temperature 1.909065
# mean max of probabilities: 0.42732477 - temperature 1.9036887
# mean max of probabilities: 0.42751473 - temperature 1.8983123
# mean max of probabilities: 0.42785743 - temperature 1.892936
# mean max of probabilities: 0.42798132 - temperature 1.8875597
# mean max of probabilities: 0.42853296 - temperature 1.8821833
# mean max of probabilities: 0.42860523 - temperature 1.876807
# mean max of probabilities: 0.42898628 - temperature 1.8714306
# mean max of probabilities: 0.42981598 - temperature 1.8660543
# mean max of probabilities: 0.43013102 - temperature 1.860678
# mean max of probabilities: 0.4308758 - temperature 1.8553936
# mean max of probabilities: 0.4313587 - temperature 1.8502861
# mean max of probabilities: 0.43212074 - temperature 1.8451786
# mean max of probabilities: 0.4327271 - temperature 1.8400711
# mean max of probabilities: 0.43339962 - temperature 1.8349636
# mean max of probabilities: 0.4337589 - temperature 1.829856
# mean max of probabilities: 0.4346481 - temperature 1.8247485
# mean max of probabilities: 0.43506864 - temperature 1.819641
# mean max of probabilities: 0.43583453 - temperature 1.8145335
# mean max of probabilities: 0.43631026 - temperature 1.809426
# mean max of probabilities: 0.4369461 - temperature 1.8043184
# mean max of probabilities: 0.4378468 - temperature 1.7992109
# mean max of probabilities: 0.4381985 - temperature 1.7941034
# mean max of probabilities: 0.43858075 - temperature 1.7889959
# mean max of probabilities: 0.4389381 - temperature 1.7838883
# mean max of probabilities: 0.43931141 - temperature 1.7787808
# mean max of probabilities: 0.43933484 - temperature 1.7736733
# mean max of probabilities: 0.4396791 - temperature 1.7685658
# mean max of probabilities: 0.4404006 - temperature 1.7634583
# mean max of probabilities: 0.44081837 - temperature 1.7585378
# mean max of probabilities: 0.4409442 - temperature 1.7536991
# mean max of probabilities: 0.43596756 - temperature 1.7488604
# mean max of probabilities: 0.43626997 - temperature 1.7440217
# mean max of probabilities: 0.4370682 - temperature 1.739183
# mean max of probabilities: 0.43803793 - temperature 1.7343442
# mean max of probabilities: 0.43878084 - temperature 1.7295055
# mean max of probabilities: 0.43882883 - temperature 1.7246668
# mean max of probabilities: 0.4390425 - temperature 1.7198281
# mean max of probabilities: 0.4394986 - temperature 1.7149894
# mean max of probabilities: 0.4397944 - temperature 1.7101507
# mean max of probabilities: 0.4403808 - temperature 1.705312
# mean max of probabilities: 0.4404805 - temperature 1.7004733
# mean max of probabilities: 0.44136187 - temperature 1.6956346
# mean max of probabilities: 0.4419216 - temperature 1.6907959
# mean max of probabilities: 0.44244552 - temperature 1.6859572
# mean max of probabilities: 0.4424682 - temperature 1.6811185
# mean max of probabilities: 0.442629 - temperature 1.6762798
# mean max of probabilities: 0.44286257 - temperature 1.6714411
# mean max of probabilities: 0.44348943 - temperature 1.6666058
# mean max of probabilities: 0.44396317 - temperature 1.662036
# mean max of probabilities: 0.44438168 - temperature 1.657466
# mean max of probabilities: 0.44470888 - temperature 1.6528962
# mean max of probabilities: 0.44516912 - temperature 1.6483263
# mean max of probabilities: 0.44518864 - temperature 1.6437564
# mean max of probabilities: 0.4455349 - temperature 1.6391865
# mean max of probabilities: 0.44565946 - temperature 1.6346166
# mean max of probabilities: 0.44591498 - temperature 1.6300467
# mean max of probabilities: 0.44598132 - temperature 1.6254768
# mean max of probabilities: 0.44651988 - temperature 1.620907
# mean max of probabilities: 0.44716036 - temperature 1.6163371
# mean max of probabilities: 0.44778302 - temperature 1.6117672
# mean max of probabilities: 0.44825852 - temperature 1.6071973
# mean max of probabilities: 0.4487817 - temperature 1.6026274
# mean max of probabilities: 0.44968647 - temperature 1.5980575
# mean max of probabilities: 0.45076486 - temperature 1.5934876
# mean max of probabilities: 0.4510389 - temperature 1.5889177
# mean max of probabilities: 0.4514197 - temperature 1.5843478
# mean max of probabilities: 0.45218244 - temperature 1.579778
# mean max of probabilities: 0.45281982 - temperature 1.5752081
# mean max of probabilities: 0.45356038 - temperature 1.5706847
# mean max of probabilities: 0.45438105 - temperature 1.5663836
# mean max of probabilities: 0.4549256 - temperature 1.5620825
# mean max of probabilities: 0.45573166 - temperature 1.5577815
# mean max of probabilities: 0.4566402 - temperature 1.5534804
# mean max of probabilities: 0.45752567 - temperature 1.5491793
# mean max of probabilities: 0.45847094 - temperature 1.5448782
# mean max of probabilities: 0.4592172 - temperature 1.5405772
# mean max of probabilities: 0.4601458 - temperature 1.5362761
# mean max of probabilities: 0.46082747 - temperature 1.531975
# mean max of probabilities: 0.46177563 - temperature 1.527674
# mean max of probabilities: 0.4626283 - temperature 1.5233729
# mean max of probabilities: 0.4630636 - temperature 1.5190718
# mean max of probabilities: 0.46394697 - temperature 1.5147707
# mean max of probabilities: 0.46463993 - temperature 1.5104697
# mean max of probabilities: 0.46541378 - temperature 1.5061686
# mean max of probabilities: 0.46595162 - temperature 1.5018675
# mean max of probabilities: 0.46669272 - temperature 1.4975665
# mean max of probabilities: 0.4676644 - temperature 1.4932654
# mean max of probabilities: 0.46825 - temperature 1.4889643
# mean max of probabilities: 0.46896517 - temperature 1.4846632
# mean max of probabilities: 0.46954846 - temperature 1.4803622
# mean max of probabilities: 0.47020426 - temperature 1.4760691
# mean max of probabilities: 0.47078326 - temperature 1.4720368
# mean max of probabilities: 0.47128892 - temperature 1.4680046
# mean max of probabilities: 0.47174004 - temperature 1.4639723
# mean max of probabilities: 0.47253606 - temperature 1.4599401
# mean max of probabilities: 0.4734767 - temperature 1.4559078
# mean max of probabilities: 0.4742614 - temperature 1.4518756
# mean max of probabilities: 0.47540033 - temperature 1.4478433
# mean max of probabilities: 0.47623697 - temperature 1.443811
# mean max of probabilities: 0.47716454 - temperature 1.4397788
# mean max of probabilities: 0.47810957 - temperature 1.4357466
# mean max of probabilities: 0.47876388 - temperature 1.4317143
# mean max of probabilities: 0.4797392 - temperature 1.427682
# mean max of probabilities: 0.48030907 - temperature 1.4236498
# mean max of probabilities: 0.48132354 - temperature 1.4196175
# mean max of probabilities: 0.48201555 - temperature 1.4155853
# mean max of probabilities: 0.48250696 - temperature 1.411553
# mean max of probabilities: 0.48302227 - temperature 1.4075208
# mean max of probabilities: 0.4832557 - temperature 1.4034885
# mean max of probabilities: 0.4836435 - temperature 1.3994563
# mean max of probabilities: 0.48401904 - temperature 1.395424
# mean max of probabilities: 0.48425156 - temperature 1.3913918
# mean max of probabilities: 0.48444116 - temperature 1.3873595
# mean max of probabilities: 0.4845881 - temperature 1.3833272
# mean max of probabilities: 0.4846867 - temperature 1.3794054
# mean max of probabilities: 0.48485914 - temperature 1.375642
# mean max of probabilities: 0.4850204 - temperature 1.3718785
# mean max of probabilities: 0.4852837 - temperature 1.3681151
# mean max of probabilities: 0.48564655 - temperature 1.3643516
# mean max of probabilities: 0.48610303 - temperature 1.3605882
# mean max of probabilities: 0.48429736 - temperature 1.3568248
# mean max of probabilities: 0.48477072 - temperature 1.3530613
# mean max of probabilities: 0.48564026 - temperature 1.3492979
# mean max of probabilities: 0.48629865 - temperature 1.3455344
# mean max of probabilities: 0.4869422 - temperature 1.341771
# mean max of probabilities: 0.4876267 - temperature 1.3380076
# mean max of probabilities: 0.48846817 - temperature 1.3342441
# mean max of probabilities: 0.4892522 - temperature 1.3304807
# mean max of probabilities: 0.4898957 - temperature 1.3267173
# mean max of probabilities: 0.49047476 - temperature 1.3229538
# mean max of probabilities: 0.4913582 - temperature 1.3191904
# mean max of probabilities: 0.49195212 - temperature 1.315427
# mean max of probabilities: 0.492743 - temperature 1.3116635
# mean max of probabilities: 0.49362108 - temperature 1.3079001
# mean max of probabilities: 0.4942814 - temperature 1.3041366
# mean max of probabilities: 0.49502262 - temperature 1.3003732
# mean max of probabilities: 0.49572796 - temperature 1.2966098
# mean max of probabilities: 0.49639562 - temperature 1.2928463
# mean max of probabilities: 0.49720466 - temperature 1.2890829
# mean max of probabilities: 0.49821332 - temperature 1.2853476
# mean max of probabilities: 0.4990177 - temperature 1.281853
# mean max of probabilities: 0.49983665 - temperature 1.2783583
# mean max of probabilities: 0.50055325 - temperature 1.2748637
# mean max of probabilities: 0.50131935 - temperature 1.2713691
# mean max of probabilities: 0.5020385 - temperature 1.2678745
# mean max of probabilities: 0.5027021 - temperature 1.2643799
# mean max of probabilities: 0.50343287 - temperature 1.2608852
# mean max of probabilities: 0.50392723 - temperature 1.2573906
# mean max of probabilities: 0.5032928 - temperature 1.253896
# mean max of probabilities: 0.5035408 - temperature 1.2504014
# mean max of probabilities: 0.5040826 - temperature 1.2469068
# mean max of probabilities: 0.5048826 - temperature 1.2434121
# mean max of probabilities: 0.5045234 - temperature 1.2399175
# mean max of probabilities: 0.5047761 - temperature 1.2364229
# mean max of probabilities: 0.5052991 - temperature 1.2329283
# mean max of probabilities: 0.50610816 - temperature 1.2294337
# mean max of probabilities: 0.50697577 - temperature 1.225939
# mean max of probabilities: 0.50784576 - temperature 1.2224444
# mean max of probabilities: 0.5085972 - temperature 1.2189498
# mean max of probabilities: 0.50934565 - temperature 1.2154552
# mean max of probabilities: 0.50995547 - temperature 1.2119606
# mean max of probabilities: 0.5107034 - temperature 1.2084659
# ...
# mean max of probabilities: 0.99967897 - temperature 0.1
# mean max of probabilities: 0.99968 - temperature 0.1
# mean max of probabilities: 0.9996789 - temperature 0.1
# mean max of probabilities: 0.99967146 - temperature 0.1
# mean max of probabilities: 0.99966353 - temperature 0.1
# mean max of probabilities: 0.99966633 - temperature 0.1
# mean max of probabilities: 0.9996592 - temperature 0.1
# mean max of probabilities: 0.9996604 - temperature 0.1
# mean max of probabilities: 0.9996627 - temperature 0.1
# mean max of probabilities: 0.9996584 - temperature 0.1
# mean max of probabilities: 0.9996652 - temperature 0.1
# mean max of probabilities: 0.9996677 - temperature 0.1
# mean max of probabilities: 0.9996648 - temperature 0.1
# mean max of probabilities: 0.9996642 - temperature 0.1
# mean max of probabilities: 0.9996675 - temperature 0.1
# mean max of probabilities: 0.9996734 - temperature 0.1
# mean max of probabilities: 0.9996698 - temperature 0.1
# mean max of probabilities: 0.99966824 - temperature 0.1
# mean max of probabilities: 0.99965984 - temperature 0.1
# mean max of probabilities: 0.999653 - temperature 0.1
# mean max of probabilities: 0.99964106 - temperature 0.1
# mean max of probabilities: 0.99964976 - temperature 0.1
# mean max of probabilities: 0.99965245 - temperature 0.1
# mean max of probabilities: 0.9996523 - temperature 0.1
# mean max of probabilities: 0.9996459 - temperature 0.1
# mean max of probabilities: 0.99965143 - temperature 0.1
# mean max of probabilities: 0.9996533 - temperature 0.1
# mean max of probabilities: 0.9996501 - temperature 0.1
# mean max of probabilities: 0.9996518 - temperature 0.1
# mean max of probabilities: 0.99964094 - temperature 0.1
# mean max of probabilities: 0.99963295 - temperature 0.1
# mean max of probabilities: 0.999636 - temperature 0.1
# mean max of probabilities: 0.99964637 - temperature 0.1
# mean max of probabilities: 0.99965024 - temperature 0.1
# mean max of probabilities: 0.9996609 - temperature 0.1
# mean max of probabilities: 0.9996672 - temperature 0.1
# mean max of probabilities: 0.99967104 - temperature 0.1
# mean max of probabilities: 0.9996828 - temperature 0.1
# mean max of probabilities: 0.99967515 - temperature 0.1
# mean max of probabilities: 0.9996752 - temperature 0.1
# mean max of probabilities: 0.9996812 - temperature 0.1
# mean max of probabilities: 0.9996684 - temperature 0.1
# mean max of probabilities: 0.9996544 - temperature 0.1
# mean max of probabilities: 0.999648 - temperature 0.1
# mean max of probabilities: 0.999651 - temperature 0.1
# mean max of probabilities: 0.9996475 - temperature 0.1
# mean max of probabilities: 0.99964345 - temperature 0.1
# mean max of probabilities: 0.9996359 - temperature 0.1
# mean max of probabilities: 0.99962366 - temperature 0.1
# mean max of probabilities: 0.99961317 - temperature 0.1
# mean max of probabilities: 0.9996254 - temperature 0.1
# mean max of probabilities: 0.99961966 - temperature 0.1
# mean max of probabilities: 0.99959385 - temperature 0.1
# mean max of probabilities: 0.99959385 - temperature 0.1
# mean max of probabilities: 0.9995928 - temperature 0.1
# mean max of probabilities: 0.99958885 - temperature 0.1
# mean max of probabilities: 0.9995865 - temperature 0.1
# mean max of probabilities: 0.99958605 - temperature 0.1
# mean max of probabilities: 0.9995844 - temperature 0.1
# mean max of probabilities: 0.99958843 - temperature 0.1
# mean max of probabilities: 0.99956596 - temperature 0.1
# mean max of probabilities: 0.99956596 - temperature 0.1
# mean max of probabilities: 0.9995678 - temperature 0.1
# mean max of probabilities: 0.9995736 - temperature 0.1
# mean max of probabilities: 0.9995641 - temperature 0.1
# mean max of probabilities: 0.99957407 - temperature 0.1
# mean max of probabilities: 0.9995846 - temperature 0.1
# mean max of probabilities: 0.99957377 - temperature 0.1
# mean max of probabilities: 0.99956053 - temperature 0.1
# mean max of probabilities: 0.9995542 - temperature 0.1
# mean max of probabilities: 0.9995432 - temperature 0.1
# mean max of probabilities: 0.999547 - temperature 0.1
# mean max of probabilities: 0.9995501 - temperature 0.1
# mean max of probabilities: 0.9995444 - temperature 0.1
# mean max of probabilities: 0.9995418 - temperature 0.1
# mean max of probabilities: 0.99952567 - temperature 0.1
# mean max of probabilities: 0.9995205 - temperature 0.1
# mean max of probabilities: 0.99949116 - temperature 0.1
# mean max of probabilities: 0.9994885 - temperature 0.1
# mean max of probabilities: 0.99947214 - temperature 0.1
# mean max of probabilities: 0.999488 - temperature 0.1
# mean max of probabilities: 0.99948496 - temperature 0.1
# mean max of probabilities: 0.99948543 - temperature 0.1
# mean max of probabilities: 0.99952394 - temperature 0.1
# mean max of probabilities: 0.99951 - temperature 0.1
# mean max of probabilities: 0.99949795 - temperature 0.1
# mean max of probabilities: 0.99948865 - temperature 0.1
# mean max of probabilities: 0.9994869 - temperature 0.1
# mean max of probabilities: 0.99948096 - temperature 0.1
# mean max of probabilities: 0.9994619 - temperature 0.1
# mean max of probabilities: 0.99943346 - temperature 0.1
# mean max of probabilities: 0.9994225 - temperature 0.1
# mean max of probabilities: 0.99943054 - temperature 0.1
# mean max of probabilities: 0.99943703 - temperature 0.1
# mean max of probabilities: 0.999419 - temperature 0.1
# mean max of probabilities: 0.9993776 - temperature 0.1
# mean max of probabilities: 0.99938965 - temperature 0.1
# mean max of probabilities: 0.9993738 - temperature 0.1
# mean max of probabilities: 0.9993824 - temperature 0.1
# mean max of probabilities: 0.9993742 - temperature 0.1
# mean max of probabilities: 0.99936575 - temperature 0.1
# mean max of probabilities: 0.99937254 - temperature 0.1
# mean max of probabilities: 0.9993541 - temperature 0.1
# mean max of probabilities: 0.9993406 - temperature 0.1
# mean max of probabilities: 0.9993173 - temperature 0.1
# mean max of probabilities: 0.9992898 - temperature 0.1
# mean max of probabilities: 0.9992549 - temperature 0.1
# mean max of probabilities: 0.99922466 - temperature 0.1
# mean max of probabilities: 0.99922943 - temperature 0.1
# mean max of probabilities: 0.9992067 - temperature 0.1
# mean max of probabilities: 0.999178 - temperature 0.1
# mean max of probabilities: 0.9991549 - temperature 0.1
# mean max of probabilities: 0.9991644 - temperature 0.1
# mean max of probabilities: 0.99912405 - temperature 0.1
# mean max of probabilities: 0.9991174 - temperature 0.1
# mean max of probabilities: 0.99911076 - temperature 0.1
# mean max of probabilities: 0.9991011 - temperature 0.1
# mean max of probabilities: 0.9990813 - temperature 0.1
# mean max of probabilities: 0.9990772 - temperature 0.1
# mean max of probabilities: 0.9990796 - temperature 0.1
# mean max of probabilities: 0.9990672 - temperature 0.1
# mean max of probabilities: 0.99905074 - temperature 0.1
# mean max of probabilities: 0.99902487 - temperature 0.1
# mean max of probabilities: 0.999025 - temperature 0.1
# mean max of probabilities: 0.9990374 - temperature 0.1
# mean max of probabilities: 0.9990171 - temperature 0.1
# mean max of probabilities: 0.9990132 - temperature 0.1
# mean max of probabilities: 0.99899906 - temperature 0.1
# mean max of probabilities: 0.9989463 - temperature 0.1
# mean max of probabilities: 0.99886847 - temperature 0.1
# mean max of probabilities: 0.9988535 - temperature 0.1
# mean max of probabilities: 0.9988902 - temperature 0.1
# mean max of probabilities: 0.9989246 - temperature 0.1
# mean max of probabilities: 0.99894714 - temperature 0.1
# mean max of probabilities: 0.9989796 - temperature 0.1
# mean max of probabilities: 0.9989874 - temperature 0.1
# mean max of probabilities: 0.99901986 - temperature 0.1
# mean max of probabilities: 0.9990292 - temperature 0.1
# mean max of probabilities: 0.99904406 - temperature 0.1
# mean max of probabilities: 0.999068 - temperature 0.1
# mean max of probabilities: 0.99910605 - temperature 0.1
# mean max of probabilities: 0.9991421 - temperature 0.1
# mean max of probabilities: 0.9991786 - temperature 0.1
# mean max of probabilities: 0.9992067 - temperature 0.1
# mean max of probabilities: 0.99923086 - temperature 0.1
# mean max of probabilities: 0.99927074 - temperature 0.1
# mean max of probabilities: 0.9993088 - temperature 0.1
# mean max of probabilities: 0.9993294 - temperature 0.1
# mean max of probabilities: 0.9993131 - temperature 0.1
# mean max of probabilities: 0.99933904 - temperature 0.1
# mean max of probabilities: 0.9993626 - temperature 0.1
# mean max of probabilities: 0.9993949 - temperature 0.1
# mean max of probabilities: 0.99941427 - temperature 0.1
# mean max of probabilities: 0.9994469 - temperature 0.1
# mean max of probabilities: 0.9994956 - temperature 0.1
# mean max of probabilities: 0.99950826 - temperature 0.1
# mean max of probabilities: 0.9995119 - temperature 0.1
# mean max of probabilities: 0.9995192 - temperature 0.1
# mean max of probabilities: 0.99953985 - temperature 0.1
# mean max of probabilities: 0.99955374 - temperature 0.1
# mean max of probabilities: 0.9995547 - temperature 0.1
# mean max of probabilities: 0.9995732 - temperature 0.1
# mean max of probabilities: 0.9995702 - temperature 0.1
# mean max of probabilities: 0.9995801 - temperature 0.1
# mean max of probabilities: 0.9995866 - temperature 0.1
# mean max of probabilities: 0.99959385 - temperature 0.1
# mean max of probabilities: 0.99959177 - temperature 0.1
# mean max of probabilities: 0.9996043 - temperature 0.1
# mean max of probabilities: 0.99963546 - temperature 0.1
# mean max of probabilities: 0.9996438 - temperature 0.1
# mean max of probabilities: 0.9996499 - temperature 0.1
# mean max of probabilities: 0.9996729 - temperature 0.1
# mean max of probabilities: 0.9996784 - temperature 0.1
# mean max of probabilities: 0.9996803 - temperature 0.1
# mean max of probabilities: 0.9996997 - temperature 0.1
# mean max of probabilities: 0.999715 - temperature 0.1
# mean max of probabilities: 0.9997201 - temperature 0.1
# mean max of probabilities: 0.9997221 - temperature 0.1
# mean max of probabilities: 0.9997259 - temperature 0.1
# mean max of probabilities: 0.9997334 - temperature 0.1
# mean max of probabilities: 0.99973977 - temperature 0.1
# mean max of probabilities: 0.9997399 - temperature 0.1
# mean max of probabilities: 0.9997376 - temperature 0.1
# mean max of probabilities: 0.99973685 - temperature 0.1
# mean max of probabilities: 0.99974626 - temperature 0.1
# mean max of probabilities: 0.99975425 - temperature 0.1
# mean max of probabilities: 0.9997513 - temperature 0.1
# mean max of probabilities: 0.9997573 - temperature 0.1
# mean max of probabilities: 0.9997518 - temperature 0.1
# mean max of probabilities: 0.9997549 - temperature 0.1
# mean max of probabilities: 0.9997585 - temperature 0.1
# mean max of probabilities: 0.9997638 - temperature 0.1
# mean max of probabilities: 0.9997639 - temperature 0.1
# mean max of probabilities: 0.9997703 - temperature 0.1
# mean max of probabilities: 0.9997732 - temperature 0.1
# mean max of probabilities: 0.9997702 - temperature 0.1
# mean max of probabilities: 0.99977297 - temperature 0.1
# mean max of probabilities: 0.9997743 - temperature 0.1
# mean max of probabilities: 0.9997746 - temperature 0.1
# mean max of probabilities: 0.99977696 - temperature 0.1
# mean max of probabilities: 0.9997667 - temperature 0.1
# mean max of probabilities: 0.99977297 - temperature 0.1
# mean max of probabilities: 0.9997745 - temperature 0.1
# mean max of probabilities: 0.9997722 - temperature 0.1
# mean max of probabilities: 0.9997774 - temperature 0.1
# mean max of probabilities: 0.9997801 - temperature 0.1
# mean max of probabilities: 0.99978423 - temperature 0.1
# mean max of probabilities: 0.9997874 - temperature 0.1
# mean max of probabilities: 0.9997912 - temperature 0.1
# mean max of probabilities: 0.9997957 - temperature 0.1
# mean max of probabilities: 0.99979806 - temperature 0.1
# mean max of probabilities: 0.99980295 - temperature 0.1
# mean max of probabilities: 0.9998039 - temperature 0.1
# mean max of probabilities: 0.9998052 - temperature 0.1
# mean max of probabilities: 0.99980813 - temperature 0.1
# mean max of probabilities: 0.99980825 - temperature 0.1
# mean max of probabilities: 0.9998086 - temperature 0.1
# mean max of probabilities: 0.99980927 - temperature 0.1
# mean max of probabilities: 0.9998081 - temperature 0.1
# mean max of probabilities: 0.9998095 - temperature 0.1
# mean max of probabilities: 0.9998106 - temperature 0.1
# mean max of probabilities: 0.99981135 - temperature 0.1
# mean max of probabilities: 0.99981123 - temperature 0.1
# mean max of probabilities: 0.9998156 - temperature 0.1
# mean max of probabilities: 0.9998155 - temperature 0.1
# mean max of probabilities: 0.99981576 - temperature 0.1
# mean max of probabilities: 0.999817 - temperature 0.1
# mean max of probabilities: 0.9998188 - temperature 0.1
# mean max of probabilities: 0.99981844 - temperature 0.1
# mean max of probabilities: 0.9998203 - temperature 0.1
# mean max of probabilities: 0.9998208 - temperature 0.1
# mean max of probabilities: 0.99982053 - temperature 0.1
# mean max of probabilities: 0.99982095 - temperature 0.1
# mean max of probabilities: 0.99982244 - temperature 0.1
# mean max of probabilities: 0.99982363 - temperature 0.1
# mean max of probabilities: 0.99982494 - temperature 0.1
# mean max of probabilities: 0.99982303 - temperature 0.1
# mean max of probabilities: 0.99982476 - temperature 0.1
# mean max of probabilities: 0.99982524 - temperature 0.1
# mean max of probabilities: 0.9998252 - temperature 0.1
# mean max of probabilities: 0.999826 - temperature 0.1
# mean max of probabilities: 0.9998281 - temperature 0.1
# mean max of probabilities: 0.99982995 - temperature 0.1
# mean max of probabilities: 0.99983144 - temperature 0.1
# mean max of probabilities: 0.9998338 - temperature 0.1
# mean max of probabilities: 0.9998337 - temperature 0.1
# mean max of probabilities: 0.9998332 - temperature 0.1
# mean max of probabilities: 0.9998353 - temperature 0.1
# mean max of probabilities: 0.9998345 - temperature 0.1
# mean max of probabilities: 0.99983394 - temperature 0.1
# mean max of probabilities: 0.9998353 - temperature 0.1
# mean max of probabilities: 0.999837 - temperature 0.1
# mean max of probabilities: 0.99983764 - temperature 0.1
# mean max of probabilities: 0.99983937 - temperature 0.1
# mean max of probabilities: 0.9998398 - temperature 0.1
# mean max of probabilities: 0.999839 - temperature 0.1
# mean max of probabilities: 0.999839 - temperature 0.1
# mean max of probabilities: 0.99983776 - temperature 0.1
# mean max of probabilities: 0.9998388 - temperature 0.1
# mean max of probabilities: 0.9998399 - temperature 0.1
# mean max of probabilities: 0.999841 - temperature 0.1
# mean max of probabilities: 0.99984145 - temperature 0.1
# mean max of probabilities: 0.9998425 - temperature 0.1
# mean max of probabilities: 0.99984396 - temperature 0.1
# mean max of probabilities: 0.9998445 - temperature 0.1
# mean max of probabilities: 0.9998444 - temperature 0.1
# mean max of probabilities: 0.99984384 - temperature 0.1
# mean max of probabilities: 0.9998448 - temperature 0.1
# mean max of probabilities: 0.9998452 - temperature 0.1
# mean max of probabilities: 0.9998454 - temperature 0.1
# mean max of probabilities: 0.99984556 - temperature 0.1
# mean max of probabilities: 0.99984676 - temperature 0.1
# mean max of probabilities: 0.9998463 - temperature 0.1
# mean max of probabilities: 0.9998466 - temperature 0.1
# mean max of probabilities: 0.9998479 - temperature 0.1
# mean max of probabilities: 0.9998486 - temperature 0.1
# mean max of probabilities: 0.99984914 - temperature 0.1
# mean max of probabilities: 0.99984944 - temperature 0.1
# mean max of probabilities: 0.9998504 - temperature 0.1
# mean max of probabilities: 0.9998501 - temperature 0.1
# mean max of probabilities: 0.99985063 - temperature 0.1
# mean max of probabilities: 0.9998508 - temperature 0.1
# mean max of probabilities: 0.99985105 - temperature 0.1
# mean max of probabilities: 0.9998514 - temperature 0.1
# mean max of probabilities: 0.9998516 - temperature 0.1
# mean max of probabilities: 0.9998514 - temperature 0.1
# mean max of probabilities: 0.99985194 - temperature 0.1
# mean max of probabilities: 0.9998526 - temperature 0.1
# mean max of probabilities: 0.9998532 - temperature 0.1

# %%
print(np.sort(selector.get_indices()))
np.savetxt('./MUDI/runs/textfiles/' + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.txt', np.array(selector.get_indices(), dtype=int), fmt='%d')
# Out:
# [   0    0    0    3    4    8    8   12   13   15   16   20   26   36
#    41   43   44   44   44   48   48   50   51   52   56   57   60   65
#    68   68   72   73   80   83   84   91   92   93   96  100  103  104
#   105  108  112  113  115  116  117  120  120  122  131  133  136  139
#   143  146  148  156  156  159  161  163  164  169  171  177  178  180
#   180  180  183  184  185  188  199  203  204  208  209  212  213  216
#   218  220  221  222  224  225  229  231  232  233  236  243  248  252
#   254  256  257  258  260  267  268  276  278  282  285  287  288  292
#   293  299  304  307  308  309  313  314  316  319  320  320  324  327
#   328  329  332  333  336  336  340  344  344  350  351  357  361  364
#   365  367  368  371  372  373  375  376  378  384  384  384  387  388
#   392  393  394  399  400  400  404  405  406  407  408  408  408  408
#   412  412  415  416  417  424  428  428  430  431  432  439  440  443
#   446  448  452  456  458  459  460  460  460  462  463  467  475  476
#   479  483  487  488  495  496  501  502  504  504  512  516  520  520
#   523  527  530  531  532  532  533  543  548  552  555  558  559  560
#   564  565  571  572  577  586  588  588  588  588  595  596  602  604
#   608  610  613  616  618  620  621  625  627  628  632  635  636  636
#   639  641  643  644  652  653  656  656  658  660  663  664  666  669
#   671  672  672  672  673  678  681  687  692  695  700  700  708  711
#   713  716  718  720  720  723  725  736  738  740  744  744  744  746
#   752  754  755  756  756  756  758  764  768  768  768  776  776  779
#   785  788  791  792  796  796  802  807  808  811  812  812  812  817
#   820  821  823  824  825  828  828  828  828  831  840  843  848  850
#   852  856  856  856  856  867  868  871  872  873  884  885  897  904
#   908  912  912  916  918  920  924  936  936  936  940  940  943  948
#   951  955  959  960  967  968  969  977  980  981  992  995 1000 1004
#  1004 1005 1008 1010 1012 1015 1020 1020 1020 1024 1024 1033 1035 1036
#  1044 1048 1048 1048 1050 1051 1052 1054 1059 1064 1064 1064 1072 1073
#  1092 1092 1092 1092 1098 1100 1104 1108 1112 1114 1115 1116 1119 1121
#  1125 1125 1125 1131 1136 1136 1137 1140 1146 1148 1148 1148 1155 1158
#  1164 1166 1169 1176 1176 1183 1184 1187 1188 1188 1199 1200 1200 1200
#  1204 1204 1204 1204 1204 1212 1212 1213 1224 1230 1231 1232 1232 1232
#  1235 1239 1243 1244 1247 1251 1256 1256 1260 1260 1272 1274 1275 1276
#  1276 1287 1289 1290 1296 1299 1300 1300 1300 1300 1302 1304 1307 1308
#  1316 1316 1320 1322 1328 1330 1331 1332 1337 1343]

# %%
for run in RunBuilder.get_runs(params):
    for trial in range(3):
        logdir = "./MUDI/runs/scalars/" + datetime.now().strftime("%Y%m%d-%H%M%S") + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_testnone_dec' + decstr + '_trial' + str(trial)

        tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)
        monitor_callback = keras.callbacks.ModelCheckpoint('./MUDI/runs/models/' + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_testnone_dec' + decstr + '_runtime'  + '_trial' + str(trial) + '.h5', monitor='val_loss', verbose=0, save_weights_only=True)

        trainset = MRISelectorSubjDataset(root_dir='.', dataf='data_.hdf5', headerf ='header_.csv',
                                      subj_list=np.array([11, 12, 13, 14, 15]), batch_size=run.batch_size)


        selector = ConcreteAutoencoderFeatureSelector(K=n_meas, output_function=dec, num_epochs=num_epochs, learning_rate=run.lr, start_temp=10.0, min_temp=0.1, 
                                                      tryout_limit=5, input_dim=1344, callback=[tensorboard_callback, monitor_callback])

        selector.fit(X=trainset)

        model = selector.get_params()

        model.save_weights('./MUDI/runs/models/' + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_testnone_dec' + decstr + '_trial' + str(trial) + '.h5')
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 1344)]            0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 500)               672001
# _________________________________________________________________
# dense_15 (Dense)             (None, 800)               400800
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 800)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1000)              801000
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 1000)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1344)              1345344
# =================================================================
# Total params: 3,219,145
# Trainable params: 3,219,144
# Non-trainable params: 1
# _________________________________________________________________
# None
# [<keras.callbacks.tensorboard_v2.TensorBoard object at 0x7f59103d4668>, <keras.callbacks.callbacks.ModelCheckpoint object at 0x7f59103d4518>]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layers with arguments in `__init__` must override `get_config`.
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layers with arguments in `__init__` must override `get_config`.
# mean max of probabilities: 0.0008010466 - temperature 10.0
# mean max of probabilities: 0.0010004895 - temperature 9.976355
# mean max of probabilities: 0.0014470762 - temperature 9.952709
# mean max of probabilities: 0.0034203383 - temperature 9.929064
# mean max of probabilities: 0.005246357 - temperature 9.905418
# mean max of probabilities: 0.0062826686 - temperature 9.881825
# mean max of probabilities: 0.007274154 - temperature 9.86033
# mean max of probabilities: 0.0079724025 - temperature 9.838834
# mean max of probabilities: 0.008679924 - temperature 9.817338
# mean max of probabilities: 0.009587731 - temperature 9.795842
# mean max of probabilities: 0.010143932 - temperature 9.774346
# mean max of probabilities: 0.010700223 - temperature 9.752851
# mean max of probabilities: 0.011316635 - temperature 9.731355
# mean max of probabilities: 0.011780981 - temperature 9.709859
# mean max of probabilities: 0.0123565085 - temperature 9.688363
# mean max of probabilities: 0.012912229 - temperature 9.666867
# mean max of probabilities: 0.013416147 - temperature 9.645371
# mean max of probabilities: 0.013996172 - temperature 9.623876
# mean max of probabilities: 0.014482799 - temperature 9.60238
# mean max of probabilities: 0.015055481 - temperature 9.580884
# mean max of probabilities: 0.01566685 - temperature 9.559388
# mean max of probabilities: 0.016490888 - temperature 9.537892
# mean max of probabilities: 0.017493991 - temperature 9.5163965
# mean max of probabilities: 0.018776022 - temperature 9.494901
# mean max of probabilities: 0.020434787 - temperature 9.473405
# mean max of probabilities: 0.023078246 - temperature 9.451909
# mean max of probabilities: 0.027601404 - temperature 9.430413
# mean max of probabilities: 0.036384262 - temperature 9.408917
# mean max of probabilities: 0.041035306 - temperature 9.387422
# mean max of probabilities: 0.044817276 - temperature 9.365926
# mean max of probabilities: 0.048555218 - temperature 9.34443
# mean max of probabilities: 0.051987488 - temperature 9.322934
# mean max of probabilities: 0.05559496 - temperature 9.301438
# mean max of probabilities: 0.059308667 - temperature 9.2799425
# mean max of probabilities: 0.06282296 - temperature 9.258447
# mean max of probabilities: 0.066285126 - temperature 9.236951
# mean max of probabilities: 0.07000414 - temperature 9.215455
# mean max of probabilities: 0.07356292 - temperature 9.193959
# mean max of probabilities: 0.07706828 - temperature 9.172463
# mean max of probabilities: 0.08108101 - temperature 9.150968
# mean max of probabilities: 0.08478702 - temperature 9.129472
# mean max of probabilities: 0.08862658 - temperature 9.107976
# mean max of probabilities: 0.09254892 - temperature 9.08648
# mean max of probabilities: 0.096290335 - temperature 9.064984
# mean max of probabilities: 0.099983305 - temperature 9.0434885
# mean max of probabilities: 0.10388745 - temperature 9.021993
# mean max of probabilities: 0.10768717 - temperature 9.000497
# mean max of probabilities: 0.11181851 - temperature 8.979001
# mean max of probabilities: 0.1160361 - temperature 8.957505
# mean max of probabilities: 0.12035555 - temperature 8.936525
# mean max of probabilities: 0.12437876 - temperature 8.917179
# mean max of probabilities: 0.12869687 - temperature 8.897833
# mean max of probabilities: 0.13296917 - temperature 8.878487
# mean max of probabilities: 0.13730448 - temperature 8.85914
# mean max of probabilities: 0.14130048 - temperature 8.839794
# mean max of probabilities: 0.14529827 - temperature 8.820448
# mean max of probabilities: 0.14916056 - temperature 8.801102
# mean max of probabilities: 0.15313466 - temperature 8.781755
# mean max of probabilities: 0.15697876 - temperature 8.762409
# mean max of probabilities: 0.1610713 - temperature 8.743063
# mean max of probabilities: 0.16527392 - temperature 8.723717
# mean max of probabilities: 0.16907415 - temperature 8.7043705
# mean max of probabilities: 0.17271475 - temperature 8.685024
# mean max of probabilities: 0.17617111 - temperature 8.665678
# mean max of probabilities: 0.17945288 - temperature 8.646332
# mean max of probabilities: 0.18268262 - temperature 8.626986
# mean max of probabilities: 0.18595763 - temperature 8.607639
# mean max of probabilities: 0.1892396 - temperature 8.588293
# mean max of probabilities: 0.19267341 - temperature 8.568947
# mean max of probabilities: 0.19598815 - temperature 8.549601
# mean max of probabilities: 0.1990005 - temperature 8.530254
# mean max of probabilities: 0.20219895 - temperature 8.510908
# mean max of probabilities: 0.20538974 - temperature 8.491562
# mean max of probabilities: 0.20879862 - temperature 8.472216
# mean max of probabilities: 0.21206112 - temperature 8.452869
# mean max of probabilities: 0.21561655 - temperature 8.433523
# mean max of probabilities: 0.2191793 - temperature 8.414177
# mean max of probabilities: 0.22290859 - temperature 8.394831
# mean max of probabilities: 0.22687708 - temperature 8.375484
# mean max of probabilities: 0.23059347 - temperature 8.356138
# mean max of probabilities: 0.23410831 - temperature 8.336792
# mean max of probabilities: 0.23755494 - temperature 8.317446
# mean max of probabilities: 0.24092546 - temperature 8.2980995
# mean max of probabilities: 0.24407846 - temperature 8.278753
# mean max of probabilities: 0.2471611 - temperature 8.259407
# mean max of probabilities: 0.25022185 - temperature 8.240061
# mean max of probabilities: 0.25320357 - temperature 8.220715
# mean max of probabilities: 0.25582913 - temperature 8.201368
# mean max of probabilities: 0.25800648 - temperature 8.182022
# mean max of probabilities: 0.2603711 - temperature 8.162676
# mean max of probabilities: 0.2626638 - temperature 8.14333
# mean max of probabilities: 0.26462555 - temperature 8.123983
# mean max of probabilities: 0.26634935 - temperature 8.104637
# mean max of probabilities: 0.2676944 - temperature 8.085291
# mean max of probabilities: 0.26923952 - temperature 8.065945
# mean max of probabilities: 0.27058518 - temperature 8.046598
# mean max of probabilities: 0.2720513 - temperature 8.027252
# mean max of probabilities: 0.27337745 - temperature 8.007906
# mean max of probabilities: 0.27459192 - temperature 7.9891953
# mean max of probabilities: 0.27623373 - temperature 7.970924
# mean max of probabilities: 0.27789134 - temperature 7.9526525
# mean max of probabilities: 0.2796393 - temperature 7.934381
# mean max of probabilities: 0.28058764 - temperature 7.9161096
# mean max of probabilities: 0.28292954 - temperature 7.897838
# mean max of probabilities: 0.28473774 - temperature 7.8795667
# mean max of probabilities: 0.2864283 - temperature 7.861295
# mean max of probabilities: 0.28830948 - temperature 7.843024
# mean max of probabilities: 0.29028738 - temperature 7.8247523
# mean max of probabilities: 0.29250053 - temperature 7.806481
# mean max of probabilities: 0.29513156 - temperature 7.7882094
# mean max of probabilities: 0.29774126 - temperature 7.769938
# mean max of probabilities: 0.30073607 - temperature 7.7524333
# mean max of probabilities: 0.3037526 - temperature 7.7352366
# mean max of probabilities: 0.30700928 - temperature 7.71804
# mean max of probabilities: 0.3101749 - temperature 7.7008433
# mean max of probabilities: 0.31326786 - temperature 7.6836467
# mean max of probabilities: 0.31653178 - temperature 7.66645
# mean max of probabilities: 0.31958628 - temperature 7.6492534
# mean max of probabilities: 0.32247853 - temperature 7.6320567
# mean max of probabilities: 0.3251747 - temperature 7.61486
# mean max of probabilities: 0.32767943 - temperature 7.5976634
# mean max of probabilities: 0.3303247 - temperature 7.5804667
# mean max of probabilities: 0.3325823 - temperature 7.56327
# mean max of probabilities: 0.33480167 - temperature 7.5460734
# mean max of probabilities: 0.33685333 - temperature 7.528877
# mean max of probabilities: 0.33868426 - temperature 7.51168
# mean max of probabilities: 0.3403438 - temperature 7.4944835
# mean max of probabilities: 0.34175333 - temperature 7.477287
# mean max of probabilities: 0.34305307 - temperature 7.46009
# mean max of probabilities: 0.34430993 - temperature 7.4428935
# mean max of probabilities: 0.3453553 - temperature 7.425697
# mean max of probabilities: 0.34632072 - temperature 7.4085
# mean max of probabilities: 0.34723234 - temperature 7.3913035
# mean max of probabilities: 0.34785792 - temperature 7.374107
# mean max of probabilities: 0.34841686 - temperature 7.35691
# mean max of probabilities: 0.34877038 - temperature 7.3397136
# mean max of probabilities: 0.3490549 - temperature 7.322517
# mean max of probabilities: 0.3493825 - temperature 7.3053203
# mean max of probabilities: 0.34970206 - temperature 7.288498
# mean max of probabilities: 0.3497285 - temperature 7.272376
# mean max of probabilities: 0.34964135 - temperature 7.256254
# mean max of probabilities: 0.34941697 - temperature 7.2401323
# mean max of probabilities: 0.3493039 - temperature 7.2240105
# mean max of probabilities: 0.34912997 - temperature 7.2078886
# mean max of probabilities: 0.34894872 - temperature 7.1917667
# mean max of probabilities: 0.3485855 - temperature 7.175645
# mean max of probabilities: 0.34822905 - temperature 7.159523
# mean max of probabilities: 0.34777498 - temperature 7.143401
# mean max of probabilities: 0.3473897 - temperature 7.1272793
# mean max of probabilities: 0.3469757 - temperature 7.1111574
# mean max of probabilities: 0.34654236 - temperature 7.0950356
# mean max of probabilities: 0.34610772 - temperature 7.0789137
# mean max of probabilities: 0.34583715 - temperature 7.062792
# mean max of probabilities: 0.34560704 - temperature 7.04667
# mean max of probabilities: 0.34544367 - temperature 7.030548
# mean max of probabilities: 0.3452395 - temperature 7.014426
# mean max of probabilities: 0.34492156 - temperature 6.9983044
# mean max of probabilities: 0.34474015 - temperature 6.9821825
# mean max of probabilities: 0.34471503 - temperature 6.9660606
# mean max of probabilities: 0.34458104 - temperature 6.949939
# mean max of probabilities: 0.3447128 - temperature 6.933817
# mean max of probabilities: 0.34473535 - temperature 6.917695
# mean max of probabilities: 0.34511936 - temperature 6.901573
# mean max of probabilities: 0.34554908 - temperature 6.8854513
# mean max of probabilities: 0.34602946 - temperature 6.8693295
# mean max of probabilities: 0.3467303 - temperature 6.8532076
# mean max of probabilities: 0.34805146 - temperature 6.8370857
# mean max of probabilities: 0.34949836 - temperature 6.8211346
# mean max of probabilities: 0.35097837 - temperature 6.8060875
# mean max of probabilities: 0.35232124 - temperature 6.7910404
# mean max of probabilities: 0.35360944 - temperature 6.7759933
# mean max of probabilities: 0.35499397 - temperature 6.7609463
# mean max of probabilities: 0.35630232 - temperature 6.745899
# mean max of probabilities: 0.35765785 - temperature 6.730852
# mean max of probabilities: 0.35895836 - temperature 6.715805
# mean max of probabilities: 0.36017114 - temperature 6.700758
# mean max of probabilities: 0.36136213 - temperature 6.685711
# mean max of probabilities: 0.3625556 - temperature 6.670664
# mean max of probabilities: 0.3635562 - temperature 6.6556168
# mean max of probabilities: 0.36470273 - temperature 6.6405697
# mean max of probabilities: 0.36584505 - temperature 6.6255226
# mean max of probabilities: 0.3672159 - temperature 6.6104755
# mean max of probabilities: 0.36857265 - temperature 6.5954285
# mean max of probabilities: 0.3699076 - temperature 6.5803814
# mean max of probabilities: 0.37131262 - temperature 6.5653343
# mean max of probabilities: 0.37274048 - temperature 6.5502872
# mean max of probabilities: 0.37426534 - temperature 6.53524
# mean max of probabilities: 0.3757195 - temperature 6.520193
# mean max of probabilities: 0.37710673 - temperature 6.505146
# mean max of probabilities: 0.37889147 - temperature 6.490099
# mean max of probabilities: 0.3807503 - temperature 6.475052
# mean max of probabilities: 0.38252032 - temperature 6.460005
# mean max of probabilities: 0.38444048 - temperature 6.4449577
# mean max of probabilities: 0.3861521 - temperature 6.4299107
# mean max of probabilities: 0.3878715 - temperature 6.4148636
# mean max of probabilities: 0.38962054 - temperature 6.3998165
# mean max of probabilities: 0.39133343 - temperature 6.3847694
# mean max of probabilities: 0.3929177 - temperature 6.3697224
# mean max of probabilities: 0.3944527 - temperature 6.3546753
# mean max of probabilities: 0.39606002 - temperature 6.340579
# mean max of probabilities: 0.39740735 - temperature 6.3266068
# mean max of probabilities: 0.39884582 - temperature 6.3126345
# mean max of probabilities: 0.40017918 - temperature 6.298662
# mean max of probabilities: 0.40139753 - temperature 6.28469
# mean max of probabilities: 0.40258443 - temperature 6.2707176
# mean max of probabilities: 0.40381756 - temperature 6.2567453
# mean max of probabilities: 0.40475228 - temperature 6.242773
# mean max of probabilities: 0.4058384 - temperature 6.228801
# mean max of probabilities: 0.40668893 - temperature 6.2148285
# mean max of probabilities: 0.4076787 - temperature 6.200856
# mean max of probabilities: 0.4084952 - temperature 6.186884
# mean max of probabilities: 0.40933523 - temperature 6.1729116
# mean max of probabilities: 0.41003093 - temperature 6.1589394
# mean max of probabilities: 0.41067505 - temperature 6.144967
# mean max of probabilities: 0.41134498 - temperature 6.130995
# mean max of probabilities: 0.41205806 - temperature 6.1170225
# mean max of probabilities: 0.41290107 - temperature 6.10305
# mean max of probabilities: 0.41366595 - temperature 6.089078
# mean max of probabilities: 0.41436467 - temperature 6.0751057
# mean max of probabilities: 0.41523606 - temperature 6.0611334
# mean max of probabilities: 0.41583318 - temperature 6.047161
# mean max of probabilities: 0.41650856 - temperature 6.033189
# mean max of probabilities: 0.41710204 - temperature 6.0192165
# mean max of probabilities: 0.41779777 - temperature 6.0052443
# mean max of probabilities: 0.41834584 - temperature 5.991272
# mean max of probabilities: 0.41915628 - temperature 5.9772997
# mean max of probabilities: 0.4200038 - temperature 5.9633274
# mean max of probabilities: 0.42091683 - temperature 5.949355
# mean max of probabilities: 0.42191952 - temperature 5.935383
# mean max of probabilities: 0.42302614 - temperature 5.9214106
# mean max of probabilities: 0.42428133 - temperature 5.9074383
# mean max of probabilities: 0.42570186 - temperature 5.893466
# mean max of probabilities: 0.4270518 - temperature 5.8797135
# mean max of probabilities: 0.42833793 - temperature 5.866816
# mean max of probabilities: 0.42726356 - temperature 5.8539186
# mean max of probabilities: 0.42797935 - temperature 5.841021
# mean max of probabilities: 0.42935216 - temperature 5.8281236
# mean max of probabilities: 0.43076435 - temperature 5.815226
# mean max of probabilities: 0.43194276 - temperature 5.8023286
# mean max of probabilities: 0.43325117 - temperature 5.789431
# mean max of probabilities: 0.43436328 - temperature 5.7765336
# mean max of probabilities: 0.4354955 - temperature 5.763636
# mean max of probabilities: 0.43642047 - temperature 5.7507386
# mean max of probabilities: 0.4374004 - temperature 5.737841
# mean max of probabilities: 0.43832067 - temperature 5.7249436
# mean max of probabilities: 0.43925723 - temperature 5.712046
# mean max of probabilities: 0.4403621 - temperature 5.6991487
# mean max of probabilities: 0.44138083 - temperature 5.686251
# mean max of probabilities: 0.4423687 - temperature 5.6733537
# mean max of probabilities: 0.44331285 - temperature 5.660456
# mean max of probabilities: 0.444189 - temperature 5.6475587
# mean max of probabilities: 0.44514325 - temperature 5.634661
# mean max of probabilities: 0.4460932 - temperature 5.6217637
# mean max of probabilities: 0.44697782 - temperature 5.608866
# mean max of probabilities: 0.44795796 - temperature 5.5959687
# mean max of probabilities: 0.44899 - temperature 5.583071
# mean max of probabilities: 0.45003077 - temperature 5.5701737
# mean max of probabilities: 0.4511 - temperature 5.5572762
# mean max of probabilities: 0.45227125 - temperature 5.5443788
# mean max of probabilities: 0.45351902 - temperature 5.5314813
# mean max of probabilities: 0.45482042 - temperature 5.518584
# mean max of probabilities: 0.45597905 - temperature 5.5056863
# mean max of probabilities: 0.45722938 - temperature 5.492789
# mean max of probabilities: 0.45827362 - temperature 5.4798913
# mean max of probabilities: 0.45946765 - temperature 5.466994
# mean max of probabilities: 0.46060166 - temperature 5.4540963
# mean max of probabilities: 0.4617401 - temperature 5.441199
# mean max of probabilities: 0.46273145 - temperature 5.4283013
# mean max of probabilities: 0.46401122 - temperature 5.415404
# mean max of probabilities: 0.4649369 - temperature 5.403278
# mean max of probabilities: 0.46598324 - temperature 5.391455
# mean max of probabilities: 0.46689022 - temperature 5.3796325
# mean max of probabilities: 0.46791163 - temperature 5.36781
# mean max of probabilities: 0.4688348 - temperature 5.355987
# mean max of probabilities: 0.46980572 - temperature 5.3441644
# mean max of probabilities: 0.47067374 - temperature 5.3323417
# mean max of probabilities: 0.47156444 - temperature 5.320519
# mean max of probabilities: 0.47244012 - temperature 5.3086963
# mean max of probabilities: 0.47332925 - temperature 5.2968736
# mean max of probabilities: 0.47401643 - temperature 5.285051
# mean max of probabilities: 0.47483203 - temperature 5.273228
# mean max of probabilities: 0.475706 - temperature 5.2614055
# mean max of probabilities: 0.47657454 - temperature 5.249583
# mean max of probabilities: 0.477422 - temperature 5.23776
# mean max of probabilities: 0.4782859 - temperature 5.2259374
# mean max of probabilities: 0.4789696 - temperature 5.2141147
# mean max of probabilities: 0.4796098 - temperature 5.202292
# mean max of probabilities: 0.4803907 - temperature 5.1904693
# mean max of probabilities: 0.48096478 - temperature 5.1786466
# mean max of probabilities: 0.48140433 - temperature 5.166824
# mean max of probabilities: 0.48185807 - temperature 5.155001
# mean max of probabilities: 0.48239005 - temperature 5.1431785
# mean max of probabilities: 0.48295626 - temperature 5.131356
# mean max of probabilities: 0.48346487 - temperature 5.119533
# mean max of probabilities: 0.483943 - temperature 5.1077104
# mean max of probabilities: 0.48453435 - temperature 5.0958877
# mean max of probabilities: 0.48494878 - temperature 5.084065
# mean max of probabilities: 0.48518914 - temperature 5.0722423
# mean max of probabilities: 0.48555475 - temperature 5.0604196
# mean max of probabilities: 0.4858508 - temperature 5.048597
# mean max of probabilities: 0.48620617 - temperature 5.036774
# mean max of probabilities: 0.48656255 - temperature 5.0249515
# mean max of probabilities: 0.48677602 - temperature 5.0131288
# mean max of probabilities: 0.48720184 - temperature 5.001306
# mean max of probabilities: 0.48789048 - temperature 4.9894834
# mean max of probabilities: 0.488564 - temperature 4.9776607
# mean max of probabilities: 0.48914716 - temperature 4.965838
# mean max of probabilities: 0.48958853 - temperature 4.9540153
# mean max of probabilities: 0.4902084 - temperature 4.9421926
# mean max of probabilities: 0.49066746 - temperature 4.931352
# mean max of probabilities: 0.49119213 - temperature 4.920604
# mean max of probabilities: 0.4917547 - temperature 4.9098563
# mean max of probabilities: 0.49236977 - temperature 4.8991084
# mean max of probabilities: 0.4927276 - temperature 4.8883605
# mean max of probabilities: 0.49335426 - temperature 4.8776126
# mean max of probabilities: 0.49381015 - temperature 4.8668647
# mean max of probabilities: 0.49421084 - temperature 4.856117
# mean max of probabilities: 0.4947212 - temperature 4.845369
# mean max of probabilities: 0.4951414 - temperature 4.834621
# mean max of probabilities: 0.4955592 - temperature 4.823873
# mean max of probabilities: 0.49597383 - temperature 4.813125
# mean max of probabilities: 0.4964366 - temperature 4.802377
# mean max of probabilities: 0.49666828 - temperature 4.7916293
# mean max of probabilities: 0.4969825 - temperature 4.7808814
# mean max of probabilities: 0.49711138 - temperature 4.7701335
# mean max of probabilities: 0.497355 - temperature 4.7593856
# mean max of probabilities: 0.49787483 - temperature 4.7486377
# mean max of probabilities: 0.49825898 - temperature 4.73789
# mean max of probabilities: 0.49839827 - temperature 4.727142
# mean max of probabilities: 0.49865273 - temperature 4.716394
# mean max of probabilities: 0.49863353 - temperature 4.705646
# mean max of probabilities: 0.49881786 - temperature 4.694898
# mean max of probabilities: 0.49889195 - temperature 4.68415
# mean max of probabilities: 0.499052 - temperature 4.6734023
# mean max of probabilities: 0.49923572 - temperature 4.6626544
# mean max of probabilities: 0.49940717 - temperature 4.6519065
# mean max of probabilities: 0.49962327 - temperature 4.6411586
# mean max of probabilities: 0.49979067 - temperature 4.6304107
# mean max of probabilities: 0.4998362 - temperature 4.619663
# mean max of probabilities: 0.4999973 - temperature 4.608915
# mean max of probabilities: 0.50017416 - temperature 4.598167
# mean max of probabilities: 0.50054383 - temperature 4.587419
# mean max of probabilities: 0.5007284 - temperature 4.576671
# mean max of probabilities: 0.50095594 - temperature 4.565923
# mean max of probabilities: 0.5009533 - temperature 4.5551753
# mean max of probabilities: 0.50105333 - temperature 4.5444274
# mean max of probabilities: 0.5012856 - temperature 4.5336795
# mean max of probabilities: 0.50131977 - temperature 4.5229316
# mean max of probabilities: 0.5012354 - temperature 4.5121837
# mean max of probabilities: 0.5011485 - temperature 4.5014358
# mean max of probabilities: 0.50122935 - temperature 4.490688
# mean max of probabilities: 0.5013658 - temperature 4.47994
# mean max of probabilities: 0.50154907 - temperature 4.4693313
# mean max of probabilities: 0.5017231 - temperature 4.459658
# mean max of probabilities: 0.5017845 - temperature 4.449985
# mean max of probabilities: 0.5019622 - temperature 4.440312
# mean max of probabilities: 0.50214314 - temperature 4.430639
# mean max of probabilities: 0.5021089 - temperature 4.4209657
# mean max of probabilities: 0.50195044 - temperature 4.4112926
# mean max of probabilities: 0.5017747 - temperature 4.4016194
# mean max of probabilities: 0.50175107 - temperature 4.3919463
# mean max of probabilities: 0.50163794 - temperature 4.382273
# mean max of probabilities: 0.5014738 - temperature 4.3726
# mean max of probabilities: 0.5011954 - temperature 4.362927
# mean max of probabilities: 0.50093675 - temperature 4.353254
# mean max of probabilities: 0.5007687 - temperature 4.3435807
# mean max of probabilities: 0.5005758 - temperature 4.3339076
# mean max of probabilities: 0.5004331 - temperature 4.3242345
# mean max of probabilities: 0.50030154 - temperature 4.3145614
# mean max of probabilities: 0.5003008 - temperature 4.3048882
# mean max of probabilities: 0.50024045 - temperature 4.295215
# mean max of probabilities: 0.5001984 - temperature 4.285542
# mean max of probabilities: 0.5000894 - temperature 4.275869
# mean max of probabilities: 0.49994037 - temperature 4.266196
# mean max of probabilities: 0.499964 - temperature 4.2565227
# mean max of probabilities: 0.49979898 - temperature 4.2468495
# mean max of probabilities: 0.49931946 - temperature 4.2371764
# mean max of probabilities: 0.49911577 - temperature 4.2275033
# mean max of probabilities: 0.4989867 - temperature 4.21783
# mean max of probabilities: 0.4987639 - temperature 4.208157
# mean max of probabilities: 0.4988206 - temperature 4.198484
# mean max of probabilities: 0.49870056 - temperature 4.188811
# mean max of probabilities: 0.4990502 - temperature 4.1791377
# mean max of probabilities: 0.49917677 - temperature 4.1694646
# mean max of probabilities: 0.49944597 - temperature 4.1597915
# mean max of probabilities: 0.49962533 - temperature 4.1501184
# mean max of probabilities: 0.49974582 - temperature 4.140445
# mean max of probabilities: 0.4998074 - temperature 4.130772
# mean max of probabilities: 0.49988452 - temperature 4.121099
# mean max of probabilities: 0.50021064 - temperature 4.111426
# mean max of probabilities: 0.5002399 - temperature 4.1017528
# mean max of probabilities: 0.5003309 - temperature 4.0920796
# mean max of probabilities: 0.50013006 - temperature 4.0824065
# mean max of probabilities: 0.5003286 - temperature 4.0727334
# mean max of probabilities: 0.50046206 - temperature 4.0630603
# mean max of probabilities: 0.5004601 - temperature 4.053387
# mean max of probabilities: 0.50051415 - temperature 4.043714
# mean max of probabilities: 0.5007573 - temperature 4.034041
# mean max of probabilities: 0.50069255 - temperature 4.024368
# mean max of probabilities: 0.500796 - temperature 4.0146947
# mean max of probabilities: 0.50092775 - temperature 4.0050216
# mean max of probabilities: 0.5007352 - temperature 3.995607
# mean max of probabilities: 0.5009945 - temperature 3.9864712
# mean max of probabilities: 0.5009395 - temperature 3.9773355
# mean max of probabilities: 0.5011038 - temperature 3.9681997
# mean max of probabilities: 0.50094694 - temperature 3.959064
# mean max of probabilities: 0.5010943 - temperature 3.9499283
# mean max of probabilities: 0.5008191 - temperature 3.9407926
# mean max of probabilities: 0.5007022 - temperature 3.9316568
# mean max of probabilities: 0.50094527 - temperature 3.922521
# mean max of probabilities: 0.50073653 - temperature 3.9133854
# mean max of probabilities: 0.5009555 - temperature 3.9042497
# mean max of probabilities: 0.50102353 - temperature 3.895114
# mean max of probabilities: 0.50107545 - temperature 3.8859782
# mean max of probabilities: 0.5010674 - temperature 3.8771665
# mean max of probabilities: 0.5011765 - temperature 3.8685682
# mean max of probabilities: 0.5013269 - temperature 3.8599699
# mean max of probabilities: 0.501508 - temperature 3.8513715
# mean max of probabilities: 0.5013748 - temperature 3.8427732
# mean max of probabilities: 0.5010266 - temperature 3.8341749
# mean max of probabilities: 0.5005741 - temperature 3.8255765
# mean max of probabilities: 0.5002618 - temperature 3.8169782
# mean max of probabilities: 0.5001203 - temperature 3.80838
# mean max of probabilities: 0.49972096 - temperature 3.7997816
# mean max of probabilities: 0.49961656 - temperature 3.7911832
# mean max of probabilities: 0.49950364 - temperature 3.782585
# mean max of probabilities: 0.4992485 - temperature 3.7739866
# mean max of probabilities: 0.49879357 - temperature 3.7653883
# mean max of probabilities: 0.49818438 - temperature 3.75679
# mean max of probabilities: 0.49781898 - temperature 3.7481916
# mean max of probabilities: 0.4977116 - temperature 3.7395933
# mean max of probabilities: 0.4978498 - temperature 3.730995
# mean max of probabilities: 0.4978996 - temperature 3.7223966
# mean max of probabilities: 0.49821106 - temperature 3.7137983
# mean max of probabilities: 0.49843705 - temperature 3.7052
# mean max of probabilities: 0.49854377 - temperature 3.6966016
# mean max of probabilities: 0.49855164 - temperature 3.6880033
# mean max of probabilities: 0.49896514 - temperature 3.679405
# mean max of probabilities: 0.49910286 - temperature 3.6708066
# mean max of probabilities: 0.49939743 - temperature 3.6622083
# mean max of probabilities: 0.4997027 - temperature 3.65361
# mean max of probabilities: 0.50006855 - temperature 3.6451395
# mean max of probabilities: 0.5002685 - temperature 3.6370785
# mean max of probabilities: 0.50049436 - temperature 3.6290176
# mean max of probabilities: 0.5003526 - temperature 3.6209567
# mean max of probabilities: 0.5005924 - temperature 3.6128957
# mean max of probabilities: 0.5005876 - temperature 3.6048348
# mean max of probabilities: 0.50019825 - temperature 3.5967739
# mean max of probabilities: 0.50017136 - temperature 3.588713
# mean max of probabilities: 0.5002592 - temperature 3.580652
# mean max of probabilities: 0.5002572 - temperature 3.572591
# mean max of probabilities: 0.5001732 - temperature 3.5645301
# mean max of probabilities: 0.50038826 - temperature 3.5564692
# mean max of probabilities: 0.5003581 - temperature 3.5484083
# mean max of probabilities: 0.50055796 - temperature 3.5403473
# mean max of probabilities: 0.50066125 - temperature 3.5322864
# mean max of probabilities: 0.5010841 - temperature 3.5242255
# mean max of probabilities: 0.50150996 - temperature 3.5161645
# mean max of probabilities: 0.5019522 - temperature 3.5081036
# mean max of probabilities: 0.5022418 - temperature 3.5000427
# mean max of probabilities: 0.50224715 - temperature 3.4919817
# mean max of probabilities: 0.5020786 - temperature 3.4839208
# mean max of probabilities: 0.5026604 - temperature 3.4758599
# mean max of probabilities: 0.50294906 - temperature 3.467799
# mean max of probabilities: 0.50294334 - temperature 3.459738
# mean max of probabilities: 0.50295067 - temperature 3.451677
# mean max of probabilities: 0.5027859 - temperature 3.4436162
# mean max of probabilities: 0.50262386 - temperature 3.4355552
# mean max of probabilities: 0.5026292 - temperature 3.4274943
# mean max of probabilities: 0.5026196 - temperature 3.4194334
# mean max of probabilities: 0.50193423 - temperature 3.4113984
# mean max of probabilities: 0.5020044 - temperature 3.4038749
# mean max of probabilities: 0.5015817 - temperature 3.3963513
# mean max of probabilities: 0.50174886 - temperature 3.3888278
# mean max of probabilities: 0.5014071 - temperature 3.3813043
# mean max of probabilities: 0.50139004 - temperature 3.3737807
# mean max of probabilities: 0.50162005 - temperature 3.3662572
# mean max of probabilities: 0.50189245 - temperature 3.3587337
# mean max of probabilities: 0.50192565 - temperature 3.35121
# mean max of probabilities: 0.5019158 - temperature 3.3436866
# mean max of probabilities: 0.5026702 - temperature 3.336163
# mean max of probabilities: 0.5026487 - temperature 3.3286395
# mean max of probabilities: 0.5029428 - temperature 3.321116
# mean max of probabilities: 0.50330263 - temperature 3.3135924
# mean max of probabilities: 0.5032749 - temperature 3.306069
# mean max of probabilities: 0.5035844 - temperature 3.2985454
# mean max of probabilities: 0.5037678 - temperature 3.2910218
# mean max of probabilities: 0.5037042 - temperature 3.2834983
# mean max of probabilities: 0.5038589 - temperature 3.2759748
# mean max of probabilities: 0.5037955 - temperature 3.2684512
# mean max of probabilities: 0.5039455 - temperature 3.2609277
# mean max of probabilities: 0.50397426 - temperature 3.2534041
# mean max of probabilities: 0.5041673 - temperature 3.2458806
# mean max of probabilities: 0.50448453 - temperature 3.238357
# mean max of probabilities: 0.5046786 - temperature 3.2308335
# mean max of probabilities: 0.50487494 - temperature 3.22331
# mean max of probabilities: 0.50554013 - temperature 3.2157865
# mean max of probabilities: 0.5057089 - temperature 3.208263
# mean max of probabilities: 0.5059161 - temperature 3.2007394
# mean max of probabilities: 0.5061325 - temperature 3.1932158
# mean max of probabilities: 0.50637794 - temperature 3.1856923
# mean max of probabilities: 0.50679374 - temperature 3.1781688
# mean max of probabilities: 0.5071999 - temperature 3.1710613
# mean max of probabilities: 0.5077921 - temperature 3.1640751
# mean max of probabilities: 0.5078093 - temperature 3.157089
# mean max of probabilities: 0.5080667 - temperature 3.1501029
# mean max of probabilities: 0.5078741 - temperature 3.1431167
# mean max of probabilities: 0.507912 - temperature 3.1361306
# mean max of probabilities: 0.50818986 - temperature 3.1291444
# mean max of probabilities: 0.5080536 - temperature 3.1221583
# mean max of probabilities: 0.5084012 - temperature 3.1151721
# mean max of probabilities: 0.50894433 - temperature 3.108186
# mean max of probabilities: 0.5089498 - temperature 3.1011999
# mean max of probabilities: 0.50906616 - temperature 3.0942137
# mean max of probabilities: 0.5088164 - temperature 3.0872276
# mean max of probabilities: 0.5086909 - temperature 3.0802414
# mean max of probabilities: 0.50858957 - temperature 3.0732553
# mean max of probabilities: 0.50850135 - temperature 3.0662692
# mean max of probabilities: 0.5084435 - temperature 3.059283
# mean max of probabilities: 0.5085503 - temperature 3.0522969
# mean max of probabilities: 0.5080127 - temperature 3.0453107
# mean max of probabilities: 0.5076956 - temperature 3.0383246
# mean max of probabilities: 0.5075611 - temperature 3.0313385
# mean max of probabilities: 0.5071665 - temperature 3.0243523
# mean max of probabilities: 0.50717455 - temperature 3.0173662
# mean max of probabilities: 0.5068256 - temperature 3.01038
# mean max of probabilities: 0.50667626 - temperature 3.003394
# mean max of probabilities: 0.50641644 - temperature 2.9964077
# mean max of probabilities: 0.50607145 - temperature 2.9894216
# mean max of probabilities: 0.50573874 - temperature 2.9824355
# mean max of probabilities: 0.5055322 - temperature 2.9754493
# mean max of probabilities: 0.50535 - temperature 2.9684632
# mean max of probabilities: 0.5052669 - temperature 2.961477
# mean max of probabilities: 0.50466627 - temperature 2.954491
# mean max of probabilities: 0.50450623 - temperature 2.9475048
# mean max of probabilities: 0.5042643 - temperature 2.9405692
# mean max of probabilities: 0.504236 - temperature 2.9341204
# mean max of probabilities: 0.50398105 - temperature 2.9276717
# mean max of probabilities: 0.5038626 - temperature 2.921223
# mean max of probabilities: 0.50382173 - temperature 2.9147742
# mean max of probabilities: 0.5029904 - temperature 2.9083254
# mean max of probabilities: 0.5029695 - temperature 2.9018767
# mean max of probabilities: 0.5024364 - temperature 2.895428
# mean max of probabilities: 0.50176483 - temperature 2.8889792
# mean max of probabilities: 0.5011068 - temperature 2.8825305
# mean max of probabilities: 0.5006796 - temperature 2.8760817
# mean max of probabilities: 0.5008306 - temperature 2.869633
# mean max of probabilities: 0.50056785 - temperature 2.8631842
# mean max of probabilities: 0.500288 - temperature 2.8567355
# mean max of probabilities: 0.50009054 - temperature 2.8502867
# mean max of probabilities: 0.49985307 - temperature 2.843838
# mean max of probabilities: 0.49969336 - temperature 2.8373892
# mean max of probabilities: 0.4994664 - temperature 2.8309405
# mean max of probabilities: 0.4987881 - temperature 2.8244917
# mean max of probabilities: 0.4982112 - temperature 2.818043
# mean max of probabilities: 0.49756137 - temperature 2.8115942
# mean max of probabilities: 0.49704784 - temperature 2.8051455
# mean max of probabilities: 0.49656385 - temperature 2.7986968
# mean max of probabilities: 0.4957988 - temperature 2.792248
# mean max of probabilities: 0.4951979 - temperature 2.7857993
# mean max of probabilities: 0.49419755 - temperature 2.7793505
# mean max of probabilities: 0.49308723 - temperature 2.7729018
# mean max of probabilities: 0.4922435 - temperature 2.766453
# mean max of probabilities: 0.49135864 - temperature 2.7600043
# mean max of probabilities: 0.4909721 - temperature 2.7535555
# mean max of probabilities: 0.4905804 - temperature 2.7471068
# mean max of probabilities: 0.49016273 - temperature 2.740658
# mean max of probabilities: 0.48947465 - temperature 2.7342093
# mean max of probabilities: 0.4888317 - temperature 2.7277606
# mean max of probabilities: 0.48816139 - temperature 2.7213118
# mean max of probabilities: 0.48772836 - temperature 2.714863
# mean max of probabilities: 0.48762175 - temperature 2.7084143
# mean max of probabilities: 0.48674473 - temperature 2.702292
# mean max of probabilities: 0.4859348 - temperature 2.6963806
# mean max of probabilities: 0.48519897 - temperature 2.6904693
# mean max of probabilities: 0.48464546 - temperature 2.684558
# mean max of probabilities: 0.4842079 - temperature 2.6786466
# mean max of probabilities: 0.48363054 - temperature 2.6727352
# mean max of probabilities: 0.4829209 - temperature 2.6668239
# mean max of probabilities: 0.48199192 - temperature 2.6609125
# mean max of probabilities: 0.48144665 - temperature 2.6550012
# mean max of probabilities: 0.48124838 - temperature 2.6490898
# mean max of probabilities: 0.4804489 - temperature 2.6431785
# mean max of probabilities: 0.47965616 - temperature 2.637267
# mean max of probabilities: 0.47912318 - temperature 2.6313558
# mean max of probabilities: 0.47837844 - temperature 2.6254444
# mean max of probabilities: 0.4780237 - temperature 2.619533
# mean max of probabilities: 0.4773759 - temperature 2.6136217
# mean max of probabilities: 0.47687387 - temperature 2.6077104
# mean max of probabilities: 0.47671717 - temperature 2.601799
# mean max of probabilities: 0.47625947 - temperature 2.5958877
# mean max of probabilities: 0.47589263 - temperature 2.5899763
# mean max of probabilities: 0.4752252 - temperature 2.584065
# mean max of probabilities: 0.47475109 - temperature 2.5781536
# mean max of probabilities: 0.47390002 - temperature 2.5722423
# mean max of probabilities: 0.47354412 - temperature 2.566331
# mean max of probabilities: 0.47332814 - temperature 2.5604196
# mean max of probabilities: 0.47281206 - temperature 2.5545082
# mean max of probabilities: 0.47234157 - temperature 2.5485969
# mean max of probabilities: 0.4721374 - temperature 2.5426855
# mean max of probabilities: 0.4716356 - temperature 2.5367742
# mean max of probabilities: 0.47104824 - temperature 2.5308628
# mean max of probabilities: 0.4707271 - temperature 2.5249515
# mean max of probabilities: 0.47012615 - temperature 2.51904
# mean max of probabilities: 0.46978325 - temperature 2.5131288
# mean max of probabilities: 0.4694095 - temperature 2.5072174
# mean max of probabilities: 0.46902233 - temperature 2.501306
# mean max of probabilities: 0.46857938 - temperature 2.4953947
# mean max of probabilities: 0.46819046 - temperature 2.4894834
# mean max of probabilities: 0.46744496 - temperature 2.483572
# mean max of probabilities: 0.4669837 - temperature 2.4776607
# mean max of probabilities: 0.4660874 - temperature 2.4717493
# mean max of probabilities: 0.46585158 - temperature 2.4662697
# mean max of probabilities: 0.4652617 - temperature 2.4608958
# mean max of probabilities: 0.4648069 - temperature 2.4555218
# mean max of probabilities: 0.46425173 - temperature 2.4501479
# mean max of probabilities: 0.46374443 - temperature 2.444774
# mean max of probabilities: 0.46297866 - temperature 2.4394
# mean max of probabilities: 0.46307755 - temperature 2.434026
# mean max of probabilities: 0.46305037 - temperature 2.428652
# mean max of probabilities: 0.4626693 - temperature 2.423278
# mean max of probabilities: 0.4624731 - temperature 2.4179041
# mean max of probabilities: 0.46221632 - temperature 2.4125302
# mean max of probabilities: 0.46176413 - temperature 2.4071562
# mean max of probabilities: 0.46158838 - temperature 2.4017823
# mean max of probabilities: 0.46120977 - temperature 2.3964083
# mean max of probabilities: 0.46059856 - temperature 2.3910344
# mean max of probabilities: 0.45996162 - temperature 2.3856604
# mean max of probabilities: 0.45966622 - temperature 2.3802865
# mean max of probabilities: 0.45913038 - temperature 2.3749125
# mean max of probabilities: 0.4593595 - temperature 2.3695385
# mean max of probabilities: 0.4589964 - temperature 2.3641646
# mean max of probabilities: 0.45933038 - temperature 2.3587906
# mean max of probabilities: 0.4596 - temperature 2.3534167
# mean max of probabilities: 0.46006662 - temperature 2.3480427
# mean max of probabilities: 0.45981652 - temperature 2.3426688
# mean max of probabilities: 0.45995897 - temperature 2.3372948
# mean max of probabilities: 0.46035418 - temperature 2.3319209
# mean max of probabilities: 0.4603808 - temperature 2.326547
# mean max of probabilities: 0.4606216 - temperature 2.321173
# mean max of probabilities: 0.46100086 - temperature 2.315799
# mean max of probabilities: 0.461423 - temperature 2.310425
# mean max of probabilities: 0.46113762 - temperature 2.305051
# mean max of probabilities: 0.4611843 - temperature 2.2996771
# mean max of probabilities: 0.46107632 - temperature 2.2943032
# mean max of probabilities: 0.46102864 - temperature 2.2889292
# mean max of probabilities: 0.46100214 - temperature 2.2835553
# mean max of probabilities: 0.4610745 - temperature 2.2781813
# mean max of probabilities: 0.46145815 - temperature 2.2728074
# mean max of probabilities: 0.46156526 - temperature 2.2674334
# mean max of probabilities: 0.45823672 - temperature 2.2620595
# mean max of probabilities: 0.45839775 - temperature 2.2566855
# mean max of probabilities: 0.4588695 - temperature 2.2513115
# mean max of probabilities: 0.4596525 - temperature 2.2459376
# mean max of probabilities: 0.4603997 - temperature 2.2405636
# mean max of probabilities: 0.46140623 - temperature 2.2352
# mean max of probabilities: 0.4618705 - temperature 2.2303634
# mean max of probabilities: 0.46207973 - temperature 2.2255268
# mean max of probabilities: 0.46232098 - temperature 2.2206903
# mean max of probabilities: 0.46254423 - temperature 2.2158537
# mean max of probabilities: 0.46232942 - temperature 2.2110171
# mean max of probabilities: 0.4628859 - temperature 2.2061806
# mean max of probabilities: 0.46294403 - temperature 2.201344
# mean max of probabilities: 0.46316153 - temperature 2.1965075
# mean max of probabilities: 0.4634344 - temperature 2.191671
# mean max of probabilities: 0.46328864 - temperature 2.1868343
# mean max of probabilities: 0.46359912 - temperature 2.1819978
# mean max of probabilities: 0.4640452 - temperature 2.1771612
# mean max of probabilities: 0.4643427 - temperature 2.1723247
# mean max of probabilities: 0.464905 - temperature 2.167488
# mean max of probabilities: 0.46525627 - temperature 2.1626515
# mean max of probabilities: 0.46561563 - temperature 2.157815
# mean max of probabilities: 0.4658203 - temperature 2.1529784
# mean max of probabilities: 0.46617964 - temperature 2.1481419
# mean max of probabilities: 0.4666177 - temperature 2.1433053
# mean max of probabilities: 0.4667351 - temperature 2.1384687
# mean max of probabilities: 0.4670245 - temperature 2.1336322
# mean max of probabilities: 0.46776992 - temperature 2.1287956
# mean max of probabilities: 0.46822986 - temperature 2.123959
# mean max of probabilities: 0.46844977 - temperature 2.1191225
# mean max of probabilities: 0.4680941 - temperature 2.114286
# mean max of probabilities: 0.46822453 - temperature 2.1094494
# mean max of probabilities: 0.46900558 - temperature 2.1046128
# mean max of probabilities: 0.46917984 - temperature 2.0997763
# mean max of probabilities: 0.46872896 - temperature 2.0949397
# mean max of probabilities: 0.4688145 - temperature 2.0901031
# mean max of probabilities: 0.46928918 - temperature 2.0852666
# mean max of probabilities: 0.46932903 - temperature 2.08043
# mean max of probabilities: 0.46937138 - temperature 2.0755935
# mean max of probabilities: 0.46952188 - temperature 2.070757
# mean max of probabilities: 0.46968654 - temperature 2.0659204
# mean max of probabilities: 0.47042713 - temperature 2.0610838
# mean max of probabilities: 0.47070333 - temperature 2.0562472
# mean max of probabilities: 0.4660454 - temperature 2.0514107
# mean max of probabilities: 0.46646973 - temperature 2.046574
# mean max of probabilities: 0.46773905 - temperature 2.0417376
# mean max of probabilities: 0.4688444 - temperature 2.036901
# mean max of probabilities: 0.46943596 - temperature 2.0320644
# mean max of probabilities: 0.46954358 - temperature 2.0272279
# mean max of probabilities: 0.47011036 - temperature 2.0223913
# mean max of probabilities: 0.4701609 - temperature 2.0175548
# mean max of probabilities: 0.4700885 - temperature 2.0127182
# mean max of probabilities: 0.4705592 - temperature 2.0078816
# mean max of probabilities: 0.4705968 - temperature 2.003045
# mean max of probabilities: 0.4711203 - temperature 1.9983081
# mean max of probabilities: 0.471593 - temperature 1.9937402
# mean max of probabilities: 0.47156563 - temperature 1.9891723
# mean max of probabilities: 0.4712951 - temperature 1.9846045
# mean max of probabilities: 0.47120315 - temperature 1.9800366
# mean max of probabilities: 0.4709012 - temperature 1.9754688
# mean max of probabilities: 0.47083429 - temperature 1.9709009
# mean max of probabilities: 0.470576 - temperature 1.966333
# mean max of probabilities: 0.47057295 - temperature 1.9617652
# mean max of probabilities: 0.47045612 - temperature 1.9571973
# mean max of probabilities: 0.4704244 - temperature 1.9526294
# mean max of probabilities: 0.47065958 - temperature 1.9480616
# mean max of probabilities: 0.47068256 - temperature 1.9434937
# mean max of probabilities: 0.4709076 - temperature 1.9390582
# mean max of probabilities: 0.47089714 - temperature 1.934759
# mean max of probabilities: 0.47077626 - temperature 1.9304599
# mean max of probabilities: 0.47082812 - temperature 1.9261607
# mean max of probabilities: 0.4712445 - temperature 1.9218615
# mean max of probabilities: 0.47123012 - temperature 1.9175624
# mean max of probabilities: 0.47091034 - temperature 1.9132632
# mean max of probabilities: 0.4709635 - temperature 1.908964
# mean max of probabilities: 0.47067973 - temperature 1.9046649
# mean max of probabilities: 0.4709844 - temperature 1.9003657
# mean max of probabilities: 0.47073323 - temperature 1.8960665
# mean max of probabilities: 0.47081235 - temperature 1.8917674
# mean max of probabilities: 0.47104686 - temperature 1.8874682
# mean max of probabilities: 0.47145113 - temperature 1.883169
# mean max of probabilities: 0.4718255 - temperature 1.8788699
# mean max of probabilities: 0.4719643 - temperature 1.8745707
# mean max of probabilities: 0.47223517 - temperature 1.8702716
# mean max of probabilities: 0.47220552 - temperature 1.8659724
# mean max of probabilities: 0.47257784 - temperature 1.8616732
# mean max of probabilities: 0.47292727 - temperature 1.8573741
# mean max of probabilities: 0.47322565 - temperature 1.8530749
# mean max of probabilities: 0.47375396 - temperature 1.8487757
# mean max of probabilities: 0.47388193 - temperature 1.8444766
# mean max of probabilities: 0.4740974 - temperature 1.8401774
# mean max of probabilities: 0.47451288 - temperature 1.8358783
# mean max of probabilities: 0.4750102 - temperature 1.8315791
# mean max of probabilities: 0.47537774 - temperature 1.8272799
# mean max of probabilities: 0.47614166 - temperature 1.823015
# mean max of probabilities: 0.47606984 - temperature 1.8189845
# mean max of probabilities: 0.4765278 - temperature 1.814954
# mean max of probabilities: 0.47346118 - temperature 1.8109236
# mean max of probabilities: 0.47380915 - temperature 1.8068931
# mean max of probabilities: 0.47424904 - temperature 1.8028626
# mean max of probabilities: 0.47507074 - temperature 1.7988322
# mean max of probabilities: 0.47553647 - temperature 1.7948017
# mean max of probabilities: 0.475911 - temperature 1.7907712
# mean max of probabilities: 0.4760149 - temperature 1.7867408
# ...
# mean max of probabilities: 0.99980646 - temperature 0.18528526
# mean max of probabilities: 0.999807 - temperature 0.18484862
# mean max of probabilities: 0.99980706 - temperature 0.18441199
# mean max of probabilities: 0.9998075 - temperature 0.18397535
# mean max of probabilities: 0.99980867 - temperature 0.18356062
# mean max of probabilities: 0.99980885 - temperature 0.18315758
# mean max of probabilities: 0.9998097 - temperature 0.18275453
# mean max of probabilities: 0.99981076 - temperature 0.18235148
# mean max of probabilities: 0.99981177 - temperature 0.18194844
# mean max of probabilities: 0.99981207 - temperature 0.18154539
# mean max of probabilities: 0.99981266 - temperature 0.18114235
# mean max of probabilities: 0.9998141 - temperature 0.1807393
# mean max of probabilities: 0.99981385 - temperature 0.18033625
# mean max of probabilities: 0.9998147 - temperature 0.1799332
# mean max of probabilities: 0.9998155 - temperature 0.17953016
# mean max of probabilities: 0.9998158 - temperature 0.17912711
# mean max of probabilities: 0.9998155 - temperature 0.17872407
# mean max of probabilities: 0.9998159 - temperature 0.17832102
# mean max of probabilities: 0.99981636 - temperature 0.17791797
# mean max of probabilities: 0.999819 - temperature 0.17751493
# mean max of probabilities: 0.999819 - temperature 0.17711188
# mean max of probabilities: 0.9998195 - temperature 0.17670883
# mean max of probabilities: 0.99982 - temperature 0.17630579
# mean max of probabilities: 0.9998202 - temperature 0.17590274
# mean max of probabilities: 0.9998214 - temperature 0.1754997
# mean max of probabilities: 0.9998213 - temperature 0.17509665
# mean max of probabilities: 0.99982166 - temperature 0.1746936
# mean max of probabilities: 0.99982166 - temperature 0.17429055
# mean max of probabilities: 0.9998224 - temperature 0.1738875
# mean max of probabilities: 0.9998219 - temperature 0.17348446
# mean max of probabilities: 0.99982166 - temperature 0.17308141
# mean max of probabilities: 0.999822 - temperature 0.17267837
# mean max of probabilities: 0.9998225 - temperature 0.17227532
# mean max of probabilities: 0.99982285 - temperature 0.17187227
# mean max of probabilities: 0.9998228 - temperature 0.17146923
# mean max of probabilities: 0.9998224 - temperature 0.17106618
# mean max of probabilities: 0.9998229 - temperature 0.17066313
# mean max of probabilities: 0.9998234 - temperature 0.17026009
# mean max of probabilities: 0.9998232 - temperature 0.16985704
# mean max of probabilities: 0.99982375 - temperature 0.169454
# mean max of probabilities: 0.9998236 - temperature 0.1690565
# mean max of probabilities: 0.999824 - temperature 0.16868705
# mean max of probabilities: 0.99982476 - temperature 0.16831759
# mean max of probabilities: 0.9998247 - temperature 0.16794813
# mean max of probabilities: 0.9998248 - temperature 0.16757867
# mean max of probabilities: 0.99982554 - temperature 0.16720921
# mean max of probabilities: 0.99982506 - temperature 0.16683975
# mean max of probabilities: 0.999826 - temperature 0.16647029
# mean max of probabilities: 0.9998252 - temperature 0.16610083
# mean max of probabilities: 0.99982476 - temperature 0.16573137
# mean max of probabilities: 0.9998244 - temperature 0.16536191
# mean max of probabilities: 0.99982464 - temperature 0.16499245
# mean max of probabilities: 0.99982476 - temperature 0.16462299
# mean max of probabilities: 0.99982375 - temperature 0.16425353
# mean max of probabilities: 0.9998246 - temperature 0.16388407
# mean max of probabilities: 0.99982667 - temperature 0.16351461
# mean max of probabilities: 0.99982727 - temperature 0.16314515
# mean max of probabilities: 0.9998273 - temperature 0.1627757
# mean max of probabilities: 0.99982804 - temperature 0.16240624
# mean max of probabilities: 0.9998282 - temperature 0.16203678
# mean max of probabilities: 0.9998291 - temperature 0.16166732
# mean max of probabilities: 0.9998297 - temperature 0.16129786
# mean max of probabilities: 0.99983007 - temperature 0.1609284
# mean max of probabilities: 0.9998298 - temperature 0.16055894
# mean max of probabilities: 0.9998311 - temperature 0.16018948
# mean max of probabilities: 0.9998319 - temperature 0.15982002
# mean max of probabilities: 0.9998317 - temperature 0.15945056
# mean max of probabilities: 0.9998317 - temperature 0.1590811
# mean max of probabilities: 0.999832 - temperature 0.15871164
# mean max of probabilities: 0.9998325 - temperature 0.15834218
# mean max of probabilities: 0.9998328 - temperature 0.15797272
# mean max of probabilities: 0.9998329 - temperature 0.15760326
# mean max of probabilities: 0.99983263 - temperature 0.1572338
# mean max of probabilities: 0.9998326 - temperature 0.15686435
# mean max of probabilities: 0.9998331 - temperature 0.15649489
# mean max of probabilities: 0.99983287 - temperature 0.15612543
# mean max of probabilities: 0.99983376 - temperature 0.15575597
# mean max of probabilities: 0.9998333 - temperature 0.15538651
# mean max of probabilities: 0.9998329 - temperature 0.15501705
# mean max of probabilities: 0.99983406 - temperature 0.15464759
# mean max of probabilities: 0.99983364 - temperature 0.15429027
# mean max of probabilities: 0.99983376 - temperature 0.1539544
# mean max of probabilities: 0.99983275 - temperature 0.15361853
# mean max of probabilities: 0.99983305 - temperature 0.15328266
# mean max of probabilities: 0.99983376 - temperature 0.15294679
# mean max of probabilities: 0.9998342 - temperature 0.15261091
# mean max of probabilities: 0.9998343 - temperature 0.15227504
# mean max of probabilities: 0.9998343 - temperature 0.15193917
# mean max of probabilities: 0.9998347 - temperature 0.1516033
# mean max of probabilities: 0.99983436 - temperature 0.15126742
# mean max of probabilities: 0.99983484 - temperature 0.15093155
# mean max of probabilities: 0.9998348 - temperature 0.15059568
# mean max of probabilities: 0.9998343 - temperature 0.15025981
# mean max of probabilities: 0.9998338 - temperature 0.14992394
# mean max of probabilities: 0.9998346 - temperature 0.14958806
# mean max of probabilities: 0.9998351 - temperature 0.14925219
# mean max of probabilities: 0.9998344 - temperature 0.14891632
# mean max of probabilities: 0.99983495 - temperature 0.14858045
# mean max of probabilities: 0.99983585 - temperature 0.14824457
# mean max of probabilities: 0.99983615 - temperature 0.1479087
# mean max of probabilities: 0.9998367 - temperature 0.14757283
# mean max of probabilities: 0.9998377 - temperature 0.14723696
# mean max of probabilities: 0.9998374 - temperature 0.14690109
# mean max of probabilities: 0.99983734 - temperature 0.14656521
# mean max of probabilities: 0.99983793 - temperature 0.14622934
# mean max of probabilities: 0.999839 - temperature 0.14589347
# mean max of probabilities: 0.9998393 - temperature 0.1455576
# mean max of probabilities: 0.9998403 - temperature 0.14522173
# mean max of probabilities: 0.9998411 - temperature 0.14488585
# mean max of probabilities: 0.99984163 - temperature 0.14454998
# mean max of probabilities: 0.99984175 - temperature 0.14421411
# mean max of probabilities: 0.99984145 - temperature 0.14387824
# mean max of probabilities: 0.9998419 - temperature 0.14354236
# mean max of probabilities: 0.9998422 - temperature 0.14320649
# mean max of probabilities: 0.9998432 - temperature 0.14287062
# mean max of probabilities: 0.9998448 - temperature 0.14253475
# mean max of probabilities: 0.9998453 - temperature 0.14219888
# mean max of probabilities: 0.99984485 - temperature 0.141863
# mean max of probabilities: 0.9998449 - temperature 0.14152713
# mean max of probabilities: 0.99984527 - temperature 0.14119126
# mean max of probabilities: 0.9998456 - temperature 0.14085539
# mean max of probabilities: 0.99984586 - temperature 0.14051951
# mean max of probabilities: 0.99984586 - temperature 0.14018364
# mean max of probabilities: 0.9998461 - temperature 0.13984777
# mean max of probabilities: 0.99984574 - temperature 0.13953128
# mean max of probabilities: 0.9998466 - temperature 0.139229
# mean max of probabilities: 0.99984705 - temperature 0.13892671
# mean max of probabilities: 0.9998472 - temperature 0.13862443
# mean max of probabilities: 0.9998472 - temperature 0.13832214
# mean max of probabilities: 0.9998464 - temperature 0.13801986
# mean max of probabilities: 0.9998466 - temperature 0.13771757
# mean max of probabilities: 0.99984646 - temperature 0.13741529
# mean max of probabilities: 0.999847 - temperature 0.137113
# mean max of probabilities: 0.9998471 - temperature 0.13681072
# mean max of probabilities: 0.99984753 - temperature 0.13650844
# mean max of probabilities: 0.99984825 - temperature 0.13620615
# mean max of probabilities: 0.99984854 - temperature 0.13590387
# mean max of probabilities: 0.9998486 - temperature 0.13560158
# mean max of probabilities: 0.9998481 - temperature 0.1352993
# mean max of probabilities: 0.99984837 - temperature 0.13499701
# mean max of probabilities: 0.999849 - temperature 0.13469473
# mean max of probabilities: 0.9998498 - temperature 0.13439244
# mean max of probabilities: 0.99985087 - temperature 0.13409016
# mean max of probabilities: 0.9998506 - temperature 0.13378787
# mean max of probabilities: 0.9998506 - temperature 0.13348559
# mean max of probabilities: 0.9998504 - temperature 0.1331833
# mean max of probabilities: 0.99985063 - temperature 0.13288102
# mean max of probabilities: 0.99985063 - temperature 0.13257873
# mean max of probabilities: 0.99985105 - temperature 0.13227645
# mean max of probabilities: 0.9998514 - temperature 0.13197416
# mean max of probabilities: 0.99985296 - temperature 0.13167188
# mean max of probabilities: 0.9998519 - temperature 0.13136959
# mean max of probabilities: 0.9998517 - temperature 0.1310673
# mean max of probabilities: 0.99985194 - temperature 0.13076502
# mean max of probabilities: 0.99985206 - temperature 0.13046274
# mean max of probabilities: 0.9998523 - temperature 0.13016045
# mean max of probabilities: 0.9998523 - temperature 0.12985817
# mean max of probabilities: 0.99985164 - temperature 0.12955588
# mean max of probabilities: 0.9998515 - temperature 0.1292536
# mean max of probabilities: 0.99985147 - temperature 0.12895131
# mean max of probabilities: 0.9998517 - temperature 0.12864903
# mean max of probabilities: 0.9998515 - temperature 0.12834674
# mean max of probabilities: 0.9998525 - temperature 0.12804446
# mean max of probabilities: 0.99985313 - temperature 0.12774217
# mean max of probabilities: 0.99985397 - temperature 0.12743989
# mean max of probabilities: 0.99985427 - temperature 0.1271376
# mean max of probabilities: 0.99985456 - temperature 0.12683532
# mean max of probabilities: 0.9998547 - temperature 0.12653303
# mean max of probabilities: 0.999855 - temperature 0.12623075
# mean max of probabilities: 0.9998557 - temperature 0.12592846
# mean max of probabilities: 0.9998557 - temperature 0.12562618
# mean max of probabilities: 0.9998559 - temperature 0.12532389
# mean max of probabilities: 0.9998557 - temperature 0.1250216
# mean max of probabilities: 0.9998555 - temperature 0.124734916
# mean max of probabilities: 0.99985594 - temperature 0.124449424
# mean max of probabilities: 0.9998564 - temperature 0.12416393
# mean max of probabilities: 0.9998569 - temperature 0.12387844
# mean max of probabilities: 0.9998571 - temperature 0.12359295
# mean max of probabilities: 0.99985635 - temperature 0.12330746
# mean max of probabilities: 0.9998574 - temperature 0.12302197
# mean max of probabilities: 0.99985635 - temperature 0.12273648
# mean max of probabilities: 0.9998566 - temperature 0.122450985
# mean max of probabilities: 0.9998569 - temperature 0.12216549
# mean max of probabilities: 0.9998573 - temperature 0.12188
# mean max of probabilities: 0.99985653 - temperature 0.12159451
# mean max of probabilities: 0.99985725 - temperature 0.12130987
# mean max of probabilities: 0.99985826 - temperature 0.12104117
# mean max of probabilities: 0.9998593 - temperature 0.12077247
# mean max of probabilities: 0.9998602 - temperature 0.120503776
# mean max of probabilities: 0.9998606 - temperature 0.12023508
# mean max of probabilities: 0.99986047 - temperature 0.11996638
# mean max of probabilities: 0.99986064 - temperature 0.11969768
# mean max of probabilities: 0.99986124 - temperature 0.119428985
# mean max of probabilities: 0.9998616 - temperature 0.11916029
# mean max of probabilities: 0.9998622 - temperature 0.11889159
# mean max of probabilities: 0.99986243 - temperature 0.11862289
# mean max of probabilities: 0.99986196 - temperature 0.118354194
# mean max of probabilities: 0.99986213 - temperature 0.118085496
# mean max of probabilities: 0.99986225 - temperature 0.1178168
# mean max of probabilities: 0.99986243 - temperature 0.1175481
# mean max of probabilities: 0.9998629 - temperature 0.1172794
# mean max of probabilities: 0.99986315 - temperature 0.117010705
# mean max of probabilities: 0.9998631 - temperature 0.11674201
# mean max of probabilities: 0.9998636 - temperature 0.11647331
# mean max of probabilities: 0.99986386 - temperature 0.11620461
# mean max of probabilities: 0.9998648 - temperature 0.115935914
# mean max of probabilities: 0.99986464 - temperature 0.11566722
# mean max of probabilities: 0.9998649 - temperature 0.11539852
# mean max of probabilities: 0.99986506 - temperature 0.11512982
# mean max of probabilities: 0.99986553 - temperature 0.11486112
# mean max of probabilities: 0.99986535 - temperature 0.114592426
# mean max of probabilities: 0.9998659 - temperature 0.11432373
# mean max of probabilities: 0.9998661 - temperature 0.11405503
# mean max of probabilities: 0.99986625 - temperature 0.11379784
# mean max of probabilities: 0.99986625 - temperature 0.11354594
# mean max of probabilities: 0.9998666 - temperature 0.113294035
# mean max of probabilities: 0.9998671 - temperature 0.11304213
# mean max of probabilities: 0.9998677 - temperature 0.11279023
# mean max of probabilities: 0.99986774 - temperature 0.11253832
# mean max of probabilities: 0.9998683 - temperature 0.11228642
# mean max of probabilities: 0.9998685 - temperature 0.112034515
# mean max of probabilities: 0.99986863 - temperature 0.11178261
# mean max of probabilities: 0.99986863 - temperature 0.11153071
# mean max of probabilities: 0.9998696 - temperature 0.1112788
# mean max of probabilities: 0.99986935 - temperature 0.1110269
# mean max of probabilities: 0.9998703 - temperature 0.110774994
# mean max of probabilities: 0.99987024 - temperature 0.11052309
# mean max of probabilities: 0.99987036 - temperature 0.110271186
# mean max of probabilities: 0.9998708 - temperature 0.11001928
# mean max of probabilities: 0.99987066 - temperature 0.10976738
# mean max of probabilities: 0.9998706 - temperature 0.10951547
# mean max of probabilities: 0.99987084 - temperature 0.10926357
# mean max of probabilities: 0.9998708 - temperature 0.109011665
# mean max of probabilities: 0.9998706 - temperature 0.10875976
# mean max of probabilities: 0.9998709 - temperature 0.10850786
# mean max of probabilities: 0.99987084 - temperature 0.10825595
# mean max of probabilities: 0.9998707 - temperature 0.10800405
# mean max of probabilities: 0.9998703 - temperature 0.107752144
# mean max of probabilities: 0.9998706 - temperature 0.10750024
# mean max of probabilities: 0.99987084 - temperature 0.107248336
# mean max of probabilities: 0.99987084 - temperature 0.10699643
# mean max of probabilities: 0.9998707 - temperature 0.10674453
# mean max of probabilities: 0.99987066 - temperature 0.10650095
# mean max of probabilities: 0.9998707 - temperature 0.10626584
# mean max of probabilities: 0.9998709 - temperature 0.10603073
# mean max of probabilities: 0.99987084 - temperature 0.10579562
# mean max of probabilities: 0.99987066 - temperature 0.10556051
# mean max of probabilities: 0.9998708 - temperature 0.1053254
# mean max of probabilities: 0.9998711 - temperature 0.10509029
# mean max of probabilities: 0.9998709 - temperature 0.10485518
# mean max of probabilities: 0.9998715 - temperature 0.10462007
# mean max of probabilities: 0.9998718 - temperature 0.10438496
# mean max of probabilities: 0.9998727 - temperature 0.10414985
# mean max of probabilities: 0.9998729 - temperature 0.10391474
# mean max of probabilities: 0.99987316 - temperature 0.10367963
# mean max of probabilities: 0.99987316 - temperature 0.10344452
