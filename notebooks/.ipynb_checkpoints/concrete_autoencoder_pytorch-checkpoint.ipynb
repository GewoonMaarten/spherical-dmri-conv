# %%
from pathlib import Path
# From keras we "translate" the code to Pytorch
#from tensorflow.keras.layers import Dense, LeakyReLU
import torch
from torch import nn
from torch import Tensor
from torch import reshape as tshape
from torch import matmul as tmat
import numpy as np

# %%
torch.__version__
# Out:
# '1.8.1'

# %%
ROOT_PATH = './data'

# %%
print("Current device: ",torch.cuda.current_device())
print("Device count: ",torch.cuda.device_count())
print("Is the GPU available? ",torch.cuda.is_available())

# use gpu if available, else cpu
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', torch.cuda.get_device_properties(device))
# Out:
# Current device:  0
# Device count:  1
# Is the GPU available?  True
# Using device: _CudaDeviceProperties(name='GeForce GTX 1080', major=6, minor=1, total_memory=8118MB, multi_processor_count=20)

# %% [markdown]
# # MUDI data

# %%
# packages related to data reading
import pandas as pd
import os
import h5py

# pytorch
from torch.utils.data import Dataset, DataLoader
import torchvision

# %%
class MRISelectorSubjDataset(Dataset):
    """MRI dataset to select features from."""
    
    # pytorch
    def __init__(self, root_dir, dataf, headerf, subj_list):
        """
        Args:
            root_dir (string): Directory with the .csv files
            data (string): Data .csv file
            header (string): Header .csv file
            subj_list (list): list of all the subjects to include
            
            batch_size & shuffle are defined with 'DataLoader' in pytorch 
        """
        
        self.root_dir = root_dir
        self.dataf = dataf
        self.headerf = headerf
        self.subj_list = subj_list
        
        # load the header
        subj = self.subj_list[0]
        self.header = pd.read_csv(os.path.join(self.root_dir,
                                             self.headerf), index_col=0).to_numpy()
        self.ind = self.header[np.isin(self.header[:,1],self.subj_list),0]
#         print(self.ind)
        
        self.indexes = np.arange(len(self.ind))
        
    def __len__(self):
        'Denotes the total number of samples'
        return len(self.ind)
    
    def __getitem__(self, index):
        'Generates one sample of data'
        indexes = self.indexes[index]
        
        # Find list of IDs
        #list_IDs_temp = [self.ind[k] for k in indexes]
        list_IDs_temp = self.ind[indexes]
        
        h5f = h5py.File(os.path.join(self.root_dir, self.dataf), 'r')
        X = h5f.get('data1')
        X = X[list_IDs_temp,:]
        
        return X

# %%
import math
#import random
import pickle as pk
import torch.nn.functional as F
from pytorch_lightning.callbacks.base import Callback
from pytorch_lightning.callbacks import EarlyStopping
from torch.utils.tensorboard import SummaryWriter
from pytorch_lightning.callbacks import ModelCheckpoint
from torch.autograd import Variable

class ConcreteSelect(nn.Module):
    
    def __init__(self, output_dim, input_shape, n_features = 500, start_temp = 10.0, min_temp = 0.1, alpha = 0.99999, **kwargs):
        super(ConcreteSelect, self).__init__(**kwargs)
        # encoder
        self.output_dim = output_dim
        self.input_shape = input_shape # the input layer has output (None,N_params_in). In this case, probably equal to input_dim
        self.start_temp = start_temp
        #self.min_temp = K.constant(min_temp)
        self.min_temp = nn.init.constant_(Tensor(np.zeros(1)),min_temp).to(device)
        #self.alpha = K.constant(alpha)
        self.alpha = nn.init.constant_(Tensor(np.zeros(1)),alpha).to(device)
        #self.name = name
              
        # equivalent to build in Keras
        self.temp = Variable(Tensor([self.start_temp]), requires_grad = False).to(device)
        tensor_logits = nn.init.xavier_normal_(torch.empty(self.output_dim,self.input_shape)).to(device)
        self.logits = nn.Parameter(tensor_logits, requires_grad = True).to(device)

        # for the decoder, we define three different Linear/dense layers and the activation function
        self.dense800 = nn.Linear(n_features,800)
        #self.dense800 = nn.Linear(500,800) # the example for the standard 500 features value
        self.dense1000 = nn.Linear(800,1000)
        self.dense1344 = nn.Linear(1000,1344)
        self.act = nn.LeakyReLU(0.2)
        
    # equivalent to call in Keras -> encoder, the concrete layer itself   
    def encoder(self, X, training = None):
        
        uniform = torch.rand(self.logits.size()).to(device)
        gumbel = -torch.log(-torch.log(uniform)).to(device)
        self.temp = torch.maximum(self.min_temp, self.temp * self.alpha).to(device)
        #print('temperature {}'.format(self.temp))
        #noisy_logits = (self.logits + gumbel.to(device)) / self.temp
        noisy_logits = ((self.logits + gumbel) / self.temp).to(device)
        samples = F.softmax(noisy_logits, dim = 1)
                
        #numClasses = self.logits.size()[1]
        dim_argmax = len(self.logits.size())-1
        discrete_logits = F.one_hot(torch.argmax(self.logits.to(device),dim_argmax),num_classes = self.logits.size()[1])
        
        # probably unnecessary
        if training is None:
            training = self.training
        
        if self.training:
            self.selections = samples
        else:
            self.selections = discrete_logits
        
        #Y = torch.dot(X,torch.transpose(self.selections, 0, 1)) 
        # dot is not exactly equal to a dot product, it could be a matrix product in keras 
        Y = torch.matmul(X,torch.transpose(self.selections.float(), 0, 1))
        return Y
    
    # decoder: we suppose the two-layers scheme. In keras this is defined outside
    def decoder(self,x):
        #x.to("cpu")
        x = self.act(self.dense800(x))
        x = self.act(self.dense1000(x))
        x = self.dense1344(x)
        
        return x
    
    def forward(self, X, training = None):
        y = self.encoder(X) # selected features
        x = self.decoder(y) # reconstructed signals

        return x, y
    
class StopperCallback(EarlyStopping):
    
    def __init__(self, mean_max_target = 0.998):#, writer=None):
        self.mean_max_target = mean_max_target
        #self.writer = writer
        #super(StopperCallback, self).__init__(monitor = '', patience = float('inf'), verbose = 1, mode = 'max')#, baseline = self.mean_max_target)
        super(StopperCallback, self).__init__(monitor = '', patience = float('inf'), verbose = True, mode = 'max')
    

class ConcreteAutoencoderFeatureSelector():
    
    #def __init__(self, K, output_function, num_epochs = 100, learning_rate = 0.001, start_temp = 10.0, min_temp = 0.1, tryout_limit = 5, input_dim = 1344, callback=None, writer=None): #batch_size = None, 
    def __init__(self, K, num_features = 500, num_epochs = 100, learning_rate = 0.001, start_temp = 10.0, min_temp = 0.1, tryout_limit = 5, input_dim = 1344, checkpt=True, callback=None, writer=None, path = ''):#, losstrain=None, lossval=None): #batch_size = None, 
        self.K = K # equivalent to output_dim
        # self.output_function = output_function # this function is now included in the ConcreteSelect class
        # but now we have to define the number of features to be extracted from the encoder
        self.num_features = num_features
        self.num_epochs = num_epochs
#         self.batch_size = batch_size
        self.learning_rate = learning_rate
        self.start_temp = start_temp
        self.min_temp = min_temp
        self.tryout_limit = tryout_limit
        self.input_dim = input_dim
        self.checkpt = checkpt
        self.callback = callback
        self.writer = writer
        self.path = path #str(Path(ROOT_PATH, 'runs', 'models'))
        #self.losstrain = losstrain
        #self.lossval = lossval
        
    def fit(self, X, val_X=None):
#         if self.batch_size is None:
#             self.batch_size = max(len(X) // 256, 16)
        
        num_epochs = self.num_epochs
        steps_per_epoch = X.__len__()#(len(X) + self.batch_size - 1) // self.batch_size
        print("steps per epoch: ",steps_per_epoch)
        writer = self.writer
        #losses,losses_val=[],[]
        
        for i in range(self.tryout_limit):
            
            alpha = math.exp(math.log(self.min_temp / self.start_temp) / (num_epochs * steps_per_epoch))
            
            # we apply the model
            self.model = ConcreteSelect(self.K, self.input_dim, self.num_features, self.start_temp, self.min_temp, alpha).to(device)
            
            # we define the loss and the optimizer functions
            criterion = nn.MSELoss()
            optimizer = torch.optim.Adam(self.model.parameters(),lr=self.learning_rate)
            
            
            
            if self.checkpt==True:
                checkpoint = torch.load(self.path)
                self.model.load_state_dict(checkpoint['model_state_dict'])
                optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
                epoch_check = checkpoint['epoch']
                loss = checkpoint['loss']
            self.model.train()
            
            stopper_callback = StopperCallback()#writer=self.writer)

            print(self.callback)
            
            for epoch in range(num_epochs):
                if self.checkpt==True:
                    if epoch < epoch_check:
                        continue
                
                value_stop = torch.mean(torch.max(F.softmax(self.model.logits, dim = 1),1).values)
                print('mean max of probabilities:', value_stop, '- temperature', self.model.temp)
                
                if value_stop >= stopper_callback.mean_max_target:
                    break
                
                self.model.train()
                for j, signals in enumerate(X):
                    signals = signals.to(device)
                    # just to check how it's going, the next two lines can be commented or removed
                    if(j%500 == 0):
                        print("iteration: ",j)
                        
                    # steps in pytorch:
                    # 1. Initialise gradients at the start of each batch
                    # 2. Run the forward and then the backwards pass
                    # 3. Compute the loss and update the weights
                    
                    # Initialise gradients
                    optimizer.zero_grad()

                    outputs, selected_features = self.model(signals)
                    loss = criterion(outputs, signals) # like criterion(yhat,target) -> the target in the autoencoder is the input
                    
                    writer.add_scalar(str(Path(ROOT_PATH, 'runs', 'scalars')), loss, epoch)
                    
                    #print('Epoch {}: Loss = {}'.format(epoch+1, loss.item())) # just to check how it's going
                    
                    # Backward pass
                    loss.backward()

                    # Compute the loss and update the weights
                    optimizer.step()
                
                if val_X is not None:
                    # Evaluate the model
                    self.model.eval()
                    
                    #steps_per_epoch_val = val_X.__len__()
                    for j, signals in enumerate(val_X):
                        signals = signals.to(device)
                        outputs_pred, selected_features_pred = self.model(signals)

                        loss = criterion(outputs_pred,signals)
                
                # save for checkpoint
                torch.save({'epoch': epoch,
                        'model_state_dict': self.model.state_dict(),
                        'optimizer_state_dict': optimizer.state_dict(),
                        'loss': loss.item(),
                        }, self.path)
                
            num_epochs *= 2
        
        self.probabilities = F.softmax(self.model.logits, dim = 1)
        self.indices = torch.argmax(self.model.logits, 1)
        
        return self
    
    def get_indices(self):
        val = torch.argmax(self.model.logits, 1)
        return val
        #return K.get_value(K.argmax(self.model.get_layer('concrete_select').logits))
    
    def get_mask(self):
        #nn.functional.one_hot(torch.argmax(self.logits),list(self.logits.size())[1], dim = )
        dim_argmax = len(self.model.logits.size())-1
        val = torch.sum(nn.functional.one_hot(torch.argmax(self.model.logits,dim_argmax),self.model.logits.size()[1]))
        return val
        #return K.get_value(K.sum(K.one_hot(K.argmax(self.model.get_layer('concrete_select').logits), self.model.get_layer('concrete_select').logits.shape[1]), axis = 0))
    

    def get_support(self, indices = False):
        return self.get_indices() if indices else self.get_mask()
    
    def get_params(self):
        return self.model
        #return self.output_function(self.concrete_select)

# %%
# import modules to build RunBuilder and RunManager helper classes
from collections  import OrderedDict
from collections import namedtuple
from itertools import product

# Read in the hyper-parameters and return a Run namedtuple containing all the 
# combinations of hyper-parameters
class RunBuilder():
  @staticmethod
  def get_runs(params):

    Run = namedtuple('Run', params.keys())

    runs = []
    for v in product(*params.values()):
      runs.append(Run(*v))
    
    return runs

# %%
# put all hyper params into a OrderedDict, easily expandable
params = OrderedDict(
    lr = [.001],
    batch_size = [256]
#     batch_size = [64]
)

# %%
from datetime import datetime

# %% [markdown]
# ## Experiment 3: 2 layers

# %%
n_means = 500
num_epochs = 2000
#dec = decoder_2l
#dec = mudi_net(n_meas)
decstr = 'l2'

# %%
testsubj = 15
testsubjstr = '15'

# %%
from torch.utils.tensorboard import SummaryWriter
from pytorch_lightning.callbacks import ModelCheckpoint
from torch.nn.utils.rnn import pad_sequence
writer = SummaryWriter()

torch.manual_seed(14)

for run in RunBuilder.get_runs(params):
    model_info_template_str = f'{run}_K={n_means}_epoch={num_epochs}_test={testsubjstr}_dec={decstr}'

    checkpoint_path = str(Path(ROOT_PATH, 'runs', 'models', f'{model_info_template_str}_runtime.h5'))
    monitor_callback = ModelCheckpoint(checkpoint_path, monitor='val_loss', verbose=True)
    
    root_dir = './data' # change depending on the directory where data are located
    dataf = 'data_.hdf5'
    headerf = 'header_.csv'
    subj_list_train = np.array([11, 12, 13, 14])
    subj_list_valid = np.array([15])
    
    train_set = MRISelectorSubjDataset(ROOT_PATH,dataf,headerf,subj_list_train)
    train_gen = DataLoader(train_set, batch_size = run.batch_size, shuffle = True, num_workers = 15, pin_memory=False, drop_last=True)
    
    # for the validation dataset
    valid_set = MRISelectorSubjDataset(ROOT_PATH,dataf,headerf,subj_list_valid)
    valid_gen = DataLoader(valid_set, batch_size = run.batch_size, shuffle = False, num_workers = 15, pin_memory=False, drop_last=True)

    path = str(Path(ROOT_PATH, 'runs', 'models', 'check15', 'model.pt'))
    # 1st time
    checkpt = False
    # Continue training
    # checkpt = True
    # temp = Tensor([10]) # check last value if necessary
    
    selector = ConcreteAutoencoderFeatureSelector(K=n_means, num_features=n_means, num_epochs=num_epochs, learning_rate=run.lr, start_temp=10, min_temp=0.1, 
                                                  tryout_limit=5, input_dim=1344, checkpt = checkpt, callback=monitor_callback, writer=writer, path = path)#,losstrain=losstrain,lossval=lossval)    
    
    selector.fit(X=train_gen, val_X=valid_gen)
    
    model = selector.get_params()
    
    #model.save('./runs/models/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.h5')
    torch.save(model, Path(ROOT_PATH, 'runs', 'models', f'{model_info_template_str}.pt'))
    # save only parameters
    torch.save(model.state_dict(), Path(ROOT_PATH, 'runs', 'models', f'{model_info_template_str}_params.pt'))
    
    print(np.sort(selector.get_indices()))
    np.savetxt(Path(ROOT_PATH, 'runs', 'models', f'{model_info_template_str}.txt'), np.array(selector.get_indices(), dtype=int), fmt='%d')
    
    #model.save('./runs/models/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.h5')
    #torch.save(model, './runs/models/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.h5')

torch.save(model.state_dict(), Path(ROOT_PATH, 'runs', 'models', f'epoch={num_epochs}_net.pth'))
model_file = open(Path(ROOT_PATH, 'runs', 'models', f'epoch={num_epochs}_net.bin'),'wb')
pk.dump(model,model_file,pk.HIGHEST_PROTOCOL)      
model_file.close()
# Out:
# steps per epoch:  1830
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f00e80d5e50>
# mean max of probabilities: tensor(0.0008, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([10.], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.0026, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.9773], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.0035, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.9546], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.0045, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.9319], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.0059, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.9092], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.0090, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.8866], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.0112, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.8639], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.0137, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.8412], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.0165, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.8185], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.0198, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.7958], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.0232, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.7731], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.0270, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.7504], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.0316, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.7277], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.0381, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.7051], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.0465, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.6824], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.0550, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.6597], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.0610, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.6370], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.0673, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.6143], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.0727, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.5916], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.0784, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.5689], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.0846, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.5462], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.0911, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.5236], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.0991, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.5026], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.1084, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.4817], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.1196, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.4607], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.1310, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.4398], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.1422, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.4189], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.1535, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.3979], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.1656, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.3770], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.1785, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.3560], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.1918, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.3351], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.2046, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.3141], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.2168, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.2932], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.2295, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.2723], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.2421, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.2513], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.2549, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.2304], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.2680, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.2094], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.2813, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.1885], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.2939, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.1675], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.3061, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.1466], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.3183, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.1257], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.3298, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.1047], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.3412, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.0838], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.3518, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.0628], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.3625, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.0419], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.3729, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.0209], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.3830, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([9.0000], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.3927, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.9791], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.4017, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.9581], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.4104, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.9372], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.4185, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.9162], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.4268, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.8953], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.4348, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.8743], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.4426, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.8534], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.4502, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.8325], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.4580, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.8115], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.4655, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.7906], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.4733, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.7696], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.4809, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.7498], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.4877, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.7306], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.4940, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.7114], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5004, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.6922], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5065, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.6730], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5125, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.6538], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5184, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.6346], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5242, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.6154], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5297, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.5962], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5350, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.5770], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5401, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.5578], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5449, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.5386], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5494, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.5194], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5540, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.5002], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5584, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.4810], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5626, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.4618], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5668, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.4426], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5706, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.4234], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5740, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.4042], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5773, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.3850], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5802, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.3658], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5834, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.3466], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5865, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.3274], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5894, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.3083], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5927, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.2891], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5957, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.2699], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.5987, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.2507], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6020, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.2315], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6054, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.2123], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6090, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.1931], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6129, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.1739], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6163, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.1547], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6194, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.1355], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6220, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.1163], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6247, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.0971], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6280, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.0779], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6313, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.0587], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6347, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.0395], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6383, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.0203], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6421, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([8.0011], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6455, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.9827], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6488, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.9644], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6520, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.9461], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6550, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.9277], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6580, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.9094], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6609, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.8911], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6636, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.8728], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6660, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.8544], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6691, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.8361], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6720, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.8178], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6747, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.7999], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6775, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.7825], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6801, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.7650], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6824, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.7476], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6844, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.7301], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6863, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.7127], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6881, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.6952], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6900, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.6778], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6921, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.6603], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6939, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.6429], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6957, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.6254], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6978, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.6080], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.6996, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.5905], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7015, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.5731], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7033, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.5556], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7052, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.5382], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7069, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.5207], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7086, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.5033], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7101, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.4858], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7117, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.4684], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7129, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.4509], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7144, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.4335], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7159, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.4166], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7178, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.4000], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7194, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.3835], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7211, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.3669], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7228, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.3503], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7243, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.3337], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7257, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.3172], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7269, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.3006], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7280, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.2840], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7299, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.2674], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7315, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.2508], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7330, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.2343], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7343, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.2177], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7356, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.2011], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7365, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.1845], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7375, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.1679], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7383, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.1514], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500
# mean max of probabilities: tensor(0.7389, device='cuda:0', grad_fn=<MeanBackward0>) - temperature tensor([7.1348], device='cuda:0')
# iteration:  0
# iteration:  500
# iteration:  1000
# iteration:  1500

# %%
print(np.sort(selector.get_indices()))
np.savetxt('./runs/textfiles/' + f'{run}' + 'K=' + str(n_meas) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.txt', np.array(selector.get_indices(), dtype=int), fmt='%d')

# %%
a = np.loadtxt('./runs/textfiles/Run(lr=0.001, batch_size=256)K=500_epoch=2000_test15_decl2.txt')
a = np.sort(a.astype(int))
print(a)

# %%
testsubj = 14
testsubjstr = '14'

# %%
from torch.utils.tensorboard import SummaryWriter
from pytorch_lightning.callbacks import ModelCheckpoint
from torch.nn.utils.rnn import pad_sequence
writer = SummaryWriter()

"""def pad_collate(batch):
    xx = list(zip(*batch))
    xx_pad = pad_sequence(torch.as_tensor(xx), batch_first=True, padding_value=0)
    return xx_pad #, xlens"""

#torch.manual_seed(14)

for run in RunBuilder.get_runs(params):
    monitor_callback = ModelCheckpoint('./runs/models/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '_runtime.h5', monitor='val_loss', verbose=True)
    
    root_dir = './MUDI/data'
    dataf = 'data_.hdf5'
    headerf = 'header_.csv'
    subj_list_train = np.array([11, 12, 13, 15])
    subj_list_valid = np.array([14])
    
    train_set = MRISelectorSubjDataset(root_dir,dataf,headerf,subj_list_train)
    train_gen = DataLoader(train_set, batch_size = run.batch_size, shuffle = True, pin_memory=False, drop_last=True)
    #train_gen = DataLoader(train_set, batch_size = run.batch_size, shuffle = True, num_workers = 4, pin_memory=False, collate_fn = pad_collate)
    #train_gen = DataLoader(train_set, batch_size = run.batch_size, shuffle = True, num_workers = 0, pin_memory=False)#, collate_fn = pad_collate)
    # for the validation dataset
    valid_set = MRISelectorSubjDataset(root_dir,dataf,headerf,subj_list_valid)
    valid_gen = DataLoader(valid_set, batch_size = run.batch_size, shuffle = False, pin_memory=False, drop_last=True)
    
    """### Allocate memory for losses
    n_batch=0   # Count how many mini-batches of size mbatch we created
    for j,signals in enumerate(train_gen):
        n_batch = n_batch+1
        signals = signals[:,:,ind_MUDI]
        print(signals.size())
    losstrain = np.zeros((num_epochs,n_batch)) + np.nan
    
    n_batch=0   # Count how many mini-batches of size mbatch we created
    for j,signals in enumerate(valid_gen):
        n_batch = n_batch+1
    lossval = np.zeros((num_epochs,n_batch)) + np.nan"""
    
    path = './runs/models/check14/model.pt'
    # 1st time
    checkpt = False
    # Continue training
    checkpt = False
    
    selector = ConcreteAutoencoderFeatureSelector(K=n_means, num_features=n_means, num_epochs=num_epochs, learning_rate=run.lr, start_temp=10.0, min_temp=0.1, 
                                                  tryout_limit=5, input_dim=1344, checkpt = checkpt, callback=monitor_callback, writer=writer, path = path)#,losstrain=losstrain,lossval=lossval)    

    #selector.fit(X=train_gen, val_X=valid_gen)
    selector.fit(X=train_gen, val_X=valid_gen)
    
    model = selector.get_params()
    
    print(np.sort(selector.get_indices()))
    np.savetxt('./runs/textfiles/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.txt', np.array(selector.get_indices(), dtype=int), fmt='%d')
    
    #model.save('./runs/models/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.h5')
    torch.save(model, './runs/models/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.pt')
    # save only parameters
    torch.save(model.state_dict(),'./runs/models/params_' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.pt')
    
    torch.save(model.state_dict(), os.path.join('./runs/models/','epoch{}_net.pth'.format(num_epochs)) )
    model_file = open(os.path.join('./runs/models/','epoch{}_net.bin'.format(num_epochs)),'wb')
    pk.dump(model,model_file,pk.HIGHEST_PROTOCOL)      
    model_file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-110-a2b574cb154c> in <module>
#      20     subj_list_valid = np.array([14])
#      21
# ---> 22     train_set = MRISelectorSubjDataset(root_dir,dataf,headerf,subj_list_train)
#      23     train_gen = DataLoader(train_set, batch_size = run.batch_size, shuffle = True, pin_memory=False, drop_last=True)
#      24     #train_gen = DataLoader(train_set, batch_size = run.batch_size, shuffle = True, num_workers = 4, pin_memory=False, collate_fn = pad_collate)
#
# <ipython-input-69-728e63155617> in __init__(self, root_dir, dataf, headerf, subj_list)
#      21         # load the header
#      22         subj = self.subj_list[0]
# ---> 23         self.header = pd.read_csv(os.path.join(self.root_dir,
#      24                                              self.headerf), index_col=0).to_numpy()
#      25         self.ind = self.header[np.isin(self.header[:,1],self.subj_list),0]
#
# ~/miniconda3/envs/mudi/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~/miniconda3/envs/mudi/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~/miniconda3/envs/mudi/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~/miniconda3/envs/mudi/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~/miniconda3/envs/mudi/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~/miniconda3/envs/mudi/lib/python3.8/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# ~/miniconda3/envs/mudi/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/sapap9/PythonCode/MUDI/data/header_.csv'

# %%
model.save_weights('./runs/models/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.h5')

# %%
print(np.sort(selector.get_indices()))
np.savetxt('./runs/textfiles/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.txt', np.array(selector.get_indices(), dtype=int), fmt='%d')
# Out:
# [   2    6   12   19   23   27   28   31   31   32   33   34   41   44
#    45   49   51   54   54   54   57   63   69   70   71   72   73   77
#    77   80   87   88   94   96   98  100  100  107  108  108  111  114
#   116  118  125  136  137  140  143  146  147  148  153  154  155  158
#   159  161  169  169  173  175  176  180  180  183  187  191  192  194
#   196  196  198  201  202  205  207  214  218  219  226  226  227  231
#   236  238  241  243  245  245  248  249  254  255  255  256  269  271
#   271  271  272  272  273  275  279  289  291  291  292  301  302  306
#   310  310  314  318  319  324  329  330  335  335  337  350  352  353
#   358  360  365  372  374  375  382  382  387  390  393  395  398  400
#   412  414  415  416  416  418  419  425  429  429  430  431  433  433
#   444  450  454  456  459  461  462  463  464  468  469  471  472  478
#   481  482  485  486  487  489  490  494  498  503  509  513  514  521
#   521  524  538  538  539  540  540  546  552  554  558  558  560  563
#   568  572  572  574  575  585  586  587  588  589  594  600  602  613
#   615  617  620  621  621  622  625  626  632  633  636  638  646  646
#   650  651  658  658  659  664  667  672  674  674  675  678  678  682
#   683  686  688  694  699  699  700  701  708  709  710  711  712  716
#   718  719  721  722  726  728  737  738  741  742  747  753  754  757
#   758  758  760  760  767  770  773  775  775  775  778  781  786  786
#   786  789  790  794  796  799  801  807  810  814  817  822  823  826
#   827  832  835  837  841  842  843  851  851  854  857  861  865  875
#   880  885  886  890  891  894  894  895  896  898  902  902  906  908
#   910  919  920  927  929  934  937  938  942  944  948  958  958  959
#   961  963  967  968  968  968  969  971  972  973  977  981  981  982
#   983  984  987  989  992  997  997  999 1000 1003 1005 1006 1012 1017
#  1017 1018 1020 1023 1024 1039 1044 1045 1046 1056 1058 1060 1064 1072
#  1079 1086 1087 1087 1089 1089 1091 1091 1091 1093 1094 1094 1095 1099
#  1099 1101 1103 1104 1105 1106 1108 1113 1115 1116 1117 1117 1120 1121
#  1126 1128 1133 1134 1134 1137 1137 1143 1149 1151 1152 1156 1159 1160
#  1161 1162 1163 1163 1164 1169 1171 1172 1173 1181 1188 1191 1191 1192
#  1197 1200 1201 1204 1206 1206 1210 1211 1212 1212 1213 1215 1216 1220
#  1224 1225 1228 1233 1233 1233 1233 1233 1238 1239 1239 1241 1244 1245
#  1246 1247 1248 1249 1251 1251 1253 1255 1264 1267 1269 1272 1279 1279
#  1281 1284 1286 1287 1291 1295 1299 1300 1301 1305 1305 1305 1310 1312
#  1315 1318 1319 1323 1325 1330 1331 1332 1336 1339]

# %%
testsubj = 13
testsubjstr = '13'

# %%
from torch.utils.tensorboard import SummaryWriter
from pytorch_lightning.callbacks import ModelCheckpoint
from torch.nn.utils.rnn import pad_sequence
writer = SummaryWriter()

for run in RunBuilder.get_runs(params):
    monitor_callback = ModelCheckpoint('./runs/models/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '_runtime.h5', monitor='val_loss', verbose=True)

    root_dir = './data'
    dataf = 'data_.hdf5'
    headerf = 'header_.csv'
    subj_list_train = np.array([11, 12, 14, 15])
    subj_list_valid = np.array([13])
    
    train_set = MRISelectorSubjDataset(root_dir,dataf,headerf,subj_list_train)
    train_gen = DataLoader(train_set, batch_size = run.batch_size, shuffle = True, pin_memory=False, drop_last=True)
    #train_gen = DataLoader(train_set, batch_size = run.batch_size, shuffle = True, num_workers = 4, pin_memory=False, collate_fn = pad_collate)
    #train_gen = DataLoader(train_set, batch_size = run.batch_size, shuffle = True, num_workers = 0, pin_memory=False)#, collate_fn = pad_collate)
    # for the validation dataset
    valid_set = MRISelectorSubjDataset(root_dir,dataf,headerf,subj_list_valid)
    valid_gen = DataLoader(valid_set, batch_size = run.batch_size, shuffle = False, pin_memory=False, drop_last=True)
    
    path = './runs/models/check13/model.pt'
    # 1st time
    checkpt = False
    # Continue training
    checkpt = True
    
    selector = ConcreteAutoencoderFeatureSelector(K=n_means, num_features=n_means, num_epochs=num_epochs, learning_rate=run.lr, start_temp=10.0, min_temp=0.1, 
                                                  tryout_limit=5, input_dim=1344, checkpt = checkpt, callback=monitor_callback, writer=writer, path = path)#,losstrain=losstrain,lossval=lossval)    
    
    selector.fit(X=train_gen, val_X=valid_gen)
    
    model = selector.get_params()
    
    print(np.sort(selector.get_indices()))
    np.savetxt('./runs/textfiles/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.txt', np.array(selector.get_indices(), dtype=int), fmt='%d')
    
    #model.save_weights('./runs/models/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.h5')
    torch.save(model, './runs/models/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.pt')
    # save only parameters
    #torch.save(model.state_dict(),'./runs/models/params_' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.pt')
    
torch.save(model.state_dict(), os.path.join('./runs/models/','epoch{}_net.pth'.format(num_epochs)) )
model_file = open(os.path.join('./runs/models/','epoch{}_net.bin'.format(num_epochs)),'wb')
pk.dump(model,model_file,pk.HIGHEST_PROTOCOL)      
model_file.close()
# Out:
# Epoch 1: Loss = 0.24961930513381958
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 0
# Epoch 1: Loss = 0.1942870020866394
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 1
# Epoch 1: Loss = 0.1328582912683487
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 2
# Epoch 1: Loss = 0.13640634715557098
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 3
# Epoch 1: Loss = 0.05716152489185333
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 4
# Epoch 1: Loss = 0.05666468292474747
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 5
# Epoch 1: Loss = 0.06451275199651718
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 6
# Epoch 1: Loss = 0.05805479362607002
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.043584775
# Value stop: 0.0008638574508950114
# Epoch 2: Loss = 0.04955551028251648
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 0
# Epoch 2: Loss = 0.043346792459487915
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 1
# Epoch 2: Loss = 0.039297495037317276
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 2
# Epoch 2: Loss = 0.03703223913908005
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 3
# Epoch 2: Loss = 0.03862280026078224
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 4
# Epoch 2: Loss = 0.03369792178273201
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 5
# Epoch 2: Loss = 0.03084200620651245
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 6
# Epoch 2: Loss = 0.033352069556713104
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.024806548
# Value stop: 0.0008638757863081992
# Epoch 3: Loss = 0.030851690098643303
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 0
# Epoch 3: Loss = 0.02854783833026886
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 1
# Epoch 3: Loss = 0.028558140620589256
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 2
# Epoch 3: Loss = 0.024748966097831726
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 3
# Epoch 3: Loss = 0.027669591829180717
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 4
# Epoch 3: Loss = 0.02346932142972946
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 5
# Epoch 3: Loss = 0.021618032827973366
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 6
# Epoch 3: Loss = 0.02034393697977066
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.015295539
# Value stop: 0.000863881316035986
# Epoch 4: Loss = 0.01868322864174843
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 0
# Epoch 4: Loss = 0.018285024911165237
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 1
# Epoch 4: Loss = 0.015542109496891499
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 2
# Epoch 4: Loss = 0.01468572486191988
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 3
# Epoch 4: Loss = 0.015818694606423378
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 4
# Epoch 4: Loss = 0.01467257458716631
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 5
# Epoch 4: Loss = 0.014800531789660454
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 6
# Epoch 4: Loss = 0.014119870960712433
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.011145558
# Value stop: 0.0008638832368887961
# Epoch 5: Loss = 0.013370092026889324
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 0
# Epoch 5: Loss = 0.014636102132499218
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 1
# Epoch 5: Loss = 0.01336421724408865
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 2
# Epoch 5: Loss = 0.013159002177417278
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 3
# Epoch 5: Loss = 0.0123127531260252
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 4
# Epoch 5: Loss = 0.01302529126405716
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 5
# Epoch 5: Loss = 0.011985095217823982
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 6
# Epoch 5: Loss = 0.012313321232795715
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.009792808
# Value stop: 0.0008638838771730661
# Epoch 6: Loss = 0.012514276430010796
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 0
# Epoch 6: Loss = 0.012090461328625679
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 1
# Epoch 6: Loss = 0.011547509580850601
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 2
# Epoch 6: Loss = 0.011054654605686665
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 3
# Epoch 6: Loss = 0.010317203588783741
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 4
# Epoch 6: Loss = 0.011189048178493977
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 5
# Epoch 6: Loss = 0.010880433954298496
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 6
# Epoch 6: Loss = 0.011256151832640171
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.008342732
# Value stop: 0.0008638842264190316
# Epoch 7: Loss = 0.01080725621432066
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 0
# Epoch 7: Loss = 0.009536425583064556
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 1
# Epoch 7: Loss = 0.010311901569366455
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 2
# Epoch 7: Loss = 0.010473169386386871
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 3
# Epoch 7: Loss = 0.010021473281085491
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 4
# Epoch 7: Loss = 0.009205881506204605
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 5
# Epoch 7: Loss = 0.009288865141570568
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 6
# Epoch 7: Loss = 0.009839086793363094
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.0075773215
# Value stop: 0.0008638844010420144
# Epoch 8: Loss = 0.00986381247639656
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 0
# Epoch 8: Loss = 0.009587553329765797
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 1
# Epoch 8: Loss = 0.009317498654127121
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 2
# Epoch 8: Loss = 0.009294390678405762
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 3
# Epoch 8: Loss = 0.009093373082578182
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 4
# Epoch 8: Loss = 0.009542460553348064
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 5
# Epoch 8: Loss = 0.008848913945257664
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 6
# Epoch 8: Loss = 0.00929115992039442
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.0070671886
# Value stop: 0.0008638844010420144
# Epoch 9: Loss = 0.00891317892819643
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 0
# Epoch 9: Loss = 0.008256659843027592
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 1
# Epoch 9: Loss = 0.00972411036491394
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 2
# Epoch 9: Loss = 0.008188789710402489
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 3
# Epoch 9: Loss = 0.008571245707571507
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 4
# Epoch 9: Loss = 0.008684876374900341
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 5
# Epoch 9: Loss = 0.008940125815570354
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 6
# Epoch 9: Loss = 0.007983651012182236
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.0066597336
# Value stop: 0.0008638844010420144
# Epoch 10: Loss = 0.009127876721322536
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 0
# Epoch 10: Loss = 0.008379883132874966
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 1
# Epoch 10: Loss = 0.008788924664258957
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 2
# Epoch 10: Loss = 0.008082528598606586
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 3
# Epoch 10: Loss = 0.008103742264211178
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 4
# Epoch 10: Loss = 0.007564660161733627
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 5
# Epoch 10: Loss = 0.008026712574064732
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 6
# Epoch 10: Loss = 0.0073943184688687325
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.006432181
# Value stop: 0.0008638845174573362
# Epoch 11: Loss = 0.007977035827934742
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 0
# Epoch 11: Loss = 0.007820598781108856
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 1
# Epoch 11: Loss = 0.008330383338034153
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 2
# Epoch 11: Loss = 0.008055165410041809
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train =
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 3
# Epoch 93: Loss = 0.0034775498788803816
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 4
# Epoch 93: Loss = 0.003199865110218525
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 5
# Epoch 93: Loss = 0.0035809192340821028
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 6
# Epoch 93: Loss = 0.0031949353870004416
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.0008638845174573362
# Epoch 94: Loss = 0.0034124241210520267
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 0
# Epoch 94: Loss = 0.003214907366782427
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 1
# Epoch 94: Loss = 0.003168088383972645
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 2
# Epoch 94: Loss = 0.0037466504145413637
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 3
# Epoch 94: Loss = 0.003317599417641759
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 4
# Epoch 94: Loss = 0.003248557448387146
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 5
# Epoch 94: Loss = 0.0034485142678022385
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 6
# Epoch 94: Loss = 0.0032101385295391083
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.0008638845174573362
# Epoch 95: Loss = 0.003553838934749365
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 0
# Epoch 95: Loss = 0.0034268361050635576
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 1
# Epoch 95: Loss = 0.003309383988380432
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 2
# Epoch 95: Loss = 0.0033212737180292606
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 3
# Epoch 95: Loss = 0.003423270769417286
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 4
# Epoch 95: Loss = 0.003322986885905266
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 5
# Epoch 95: Loss = 0.0032123953569680452
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 6
# Epoch 95: Loss = 0.0029805044177919626
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.0008638845174573362
# Epoch 96: Loss = 0.003335152054205537
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 0
# Epoch 96: Loss = 0.0032338681630790234
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 1
# Epoch 96: Loss = 0.003723681904375553
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 2
# Epoch 96: Loss = 0.0032148566097021103
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 3
# Epoch 96: Loss = 0.0031861583702266216
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 4
# Epoch 96: Loss = 0.003230354283004999
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 5
# Epoch 96: Loss = 0.0034444432239979506
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 6
# Epoch 96: Loss = 0.0033859354443848133
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.0008638845174573362
# Epoch 97: Loss = 0.0032848555129021406
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 0
# Epoch 97: Loss = 0.0032854240853339434
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 1
# Epoch 97: Loss = 0.003591241082176566
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 2
# Epoch 97: Loss = 0.003755484940484166
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 3
# Epoch 97: Loss = 0.00346982479095459
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 4
# Epoch 97: Loss = 0.0036526673939079046
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 5
# Epoch 97: Loss = 0.003386798780411482
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 6
# Epoch 97: Loss = 0.0030529038049280643
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.0025572863
# Value stop: 0.0008638845174573362
# Epoch 98: Loss = 0.0034114886075258255
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 0
# Epoch 98: Loss = 0.003214985830709338
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 1
# Epoch 98: Loss = 0.0032487064599990845
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 2
# Epoch 98: Loss = 0.003568006679415703
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 3
# Epoch 98: Loss = 0.00340047269128263
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 4
# Epoch 98: Loss = 0.003297841642051935
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 5
# Epoch 98: Loss = 0.0032993133645504713
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 6
# Epoch 98: Loss = 0.003210710594430566
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.0008638845174573362
# Epoch 99: Loss = 0.0033658083993941545
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 0
# Epoch 99: Loss = 0.0034591318108141422
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 1
# Epoch 99: Loss = 0.004079713951796293
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 2
# Epoch 99: Loss = 0.003842961974442005
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 3
# Epoch 99: Loss = 0.004084999207407236
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 4
# Epoch 99: Loss = 0.004011886660009623
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train = 5
# Epoch 99: Loss = 0.0036627035588026047
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f4240daf880>
# j train =
# %%
torch.save(model.state_dict(),'./runs/models/params_' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.pt')
    
torch.save(model.state_dict(), os.path.join('./runs/models/','epoch{}_net.pth'.format(num_epochs)) )
model_file = open(os.path.join('./runs/models/','epoch{}_net.bin'.format(num_epochs)),'wb')
pk.dump(model,model_file,pk.HIGHEST_PROTOCOL)      
model_file.close()

# %%
print(np.sort(selector.get_indices()))
np.savetxt('./runs/textfiles/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.txt', np.array(selector.get_indices(), dtype=int), fmt='%d')
# Out:
# [   0    0    0    0    1    3    4   10   13   15   16   16   19   20
#    25   29   32   35   36   37   40   40   43   44   46   51   52   54
#    56   59   60   64   68   75   76   79   81   84   88   91   92   92
#    94   99  100  103  104  107  108  110  112  114  116  117  120  123
#   128  131  136  138  140  147  148  149  156  156  163  164  169  173
#   177  179  180  180  181  183  184  184  188  196  197  198  199  200
#   204  210  212  212  215  216  222  224  224  225  229  232  232  233
#   236  243  248  252  256  256  260  264  265  267  268  272  278  282
#   285  287  288  290  292  293  295  296  299  300  307  308  309  311
#   312  313  319  320  320  323  328  331  333  338  343  344  344  345
#   349  350  356  356  363  365  365  367  368  369  372  375  376  381
#   384  385  387  389  392  393  395  396  397  404  404  405  407  408
#   408  408  408  412  418  419  425  428  428  430  432  435  436  437
#   443  446  452  459  464  475  476  484  487  488  495  496  497  500
#   502  504  504  515  516  517  520  526  528  531  532  532  533  543
#   545  552  552  560  563  564  565  566  572  577  583  584  585  587
#   588  588  588  594  596  596  600  604  607  613  616  619  620  624
#   624  630  635  636  639  641  642  643  646  651  652  654  656  656
#   657  660  664  666  670  671  672  672  672  676  683  684  695  696
#   700  709  712  716  718  720  720  721  728  736  754  756  756  756
#   762  764  764  772  776  777  780  784  792  796  796  802  803  804
#   806  807  810  812  812  813  813  814  819  824  826  828  832  836
#   840  841  845  847  848  850  851  856  856  859  863  866  868  871
#   872  876  876  879  880  881  884  884  904  910  912  912  914  916
#   918  920  922  926  929  932  936  936  940  948  950  951  952  955
#   959  960  967  968  968  968  968  969  971  972  978  980 1000 1003
#  1007 1012 1013 1015 1020 1024 1024 1024 1028 1032 1036 1039 1044 1048
#  1052 1052 1052 1054 1059 1063 1064 1064 1064 1064 1072 1074 1075 1080
#  1080 1082 1088 1092 1092 1104 1104 1104 1104 1104 1105 1109 1110 1112
#  1114 1115 1120 1127 1128 1132 1136 1136 1137 1140 1144 1147 1148 1148
#  1148 1148 1149 1159 1160 1161 1162 1164 1166 1168 1170 1171 1172 1175
#  1176 1184 1186 1187 1188 1188 1193 1196 1199 1204 1204 1204 1204 1212
#  1212 1213 1220 1224 1230 1231 1232 1236 1244 1244 1244 1252 1259 1260
#  1260 1260 1260 1260 1260 1260 1260 1260 1269 1269 1271 1272 1273 1275
#  1286 1287 1288 1289 1290 1293 1300 1300 1301 1304 1308 1313 1315 1316
#  1316 1320 1323 1328 1330 1332 1336 1337 1340 1343]

# %%
testsubj = 12
testsubjstr = '12'

# %%
from torch.utils.tensorboard import SummaryWriter
from pytorch_lightning.callbacks import ModelCheckpoint
from torch.nn.utils.rnn import pad_sequence
writer = SummaryWriter()

for run in RunBuilder.get_runs(params):
    monitor_callback = ModelCheckpoint('./runs/models/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '_runtime.h5', monitor='val_loss', verbose=True)
    
    root_dir = './data'
    dataf = 'data_.hdf5'
    headerf = 'header_.csv'
    subj_list_train = np.array([11, 13, 14, 15])
    subj_list_valid = np.array([12])
    
    train_set = MRISelectorSubjDataset(root_dir,dataf,headerf,subj_list_train)
    train_gen = DataLoader(train_set, batch_size = run.batch_size, shuffle = True, pin_memory=False, drop_last=True)
    #train_gen = DataLoader(train_set, batch_size = run.batch_size, shuffle = True, num_workers = 4, pin_memory=False, collate_fn = pad_collate)
    #train_gen = DataLoader(train_set, batch_size = run.batch_size, shuffle = True, num_workers = 0, pin_memory=False)#, collate_fn = pad_collate)
    # for the validation dataset
    valid_set = MRISelectorSubjDataset(root_dir,dataf,headerf,subj_list_valid)
    valid_gen = DataLoader(valid_set, batch_size = run.batch_size, shuffle = False, pin_memory=False, drop_last=True)
    
    path = './runs/models/check12/model.pt'
    # 1st time
    checkpt = False
    # Continue training
    checkpt = True
    
    selector = ConcreteAutoencoderFeatureSelector(K=n_means, num_features=n_means, num_epochs=num_epochs, learning_rate=run.lr, start_temp=10.0, min_temp=0.1, 
                                                  tryout_limit=5, input_dim=1344, checkpt = checkpt, callback=monitor_callback, writer=writer, path = path)#,losstrain=losstrain,lossval=lossval)    
    
    selector.fit(X=train_gen, val_X=valid_gen)
    
    model = selector.get_params()
    
    print(np.sort(selector.get_indices()))
    np.savetxt('./runs/textfiles/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.txt', np.array(selector.get_indices(), dtype=int), fmt='%d')
    
    #model.save('./runs/models/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.h5')
    torch.save(model, './runs/models/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.pt')
    # save only parameters
    torch.save(model.state_dict(),'./runs/models/params_' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.pt')
    
    torch.save(model.state_dict(), os.path.join('./runs/models/','epoch{}_net.pth'.format(num_epochs)) )
    model_file = open(os.path.join('./runs/models/','epoch{}_net.bin'.format(num_epochs)),'wb')
    pk.dump(model,model_file,pk.HIGHEST_PROTOCOL)      
    model_file.close()
# Out:
# Epoch 1: Loss = 0.24041230976581573
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 0
# Epoch 1: Loss = 0.19781215488910675
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 1
# Epoch 1: Loss = 0.13479676842689514
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 2
# Epoch 1: Loss = 0.12345556914806366
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 3
# Epoch 1: Loss = 0.059875719249248505
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 4
# Epoch 1: Loss = 0.05669020488858223
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 5
# Epoch 1: Loss = 0.06095398589968681
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 6
# Epoch 1: Loss = 0.05110770836472511
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.04706318
# Value stop: 0.0008609695942141116
# Epoch 2: Loss = 0.05001683905720711
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 0
# Epoch 2: Loss = 0.04447021707892418
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 1
# Epoch 2: Loss = 0.04013342037796974
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 2
# Epoch 2: Loss = 0.0413750596344471
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 3
# Epoch 2: Loss = 0.035456690937280655
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 4
# Epoch 2: Loss = 0.032507043331861496
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 5
# Epoch 2: Loss = 0.034361373633146286
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 6
# Epoch 2: Loss = 0.028036370873451233
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.030173933
# Value stop: 0.0008609509677626193
# Epoch 3: Loss = 0.034099627286195755
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 0
# Epoch 3: Loss = 0.030440835282206535
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 1
# Epoch 3: Loss = 0.02687148191034794
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 2
# Epoch 3: Loss = 0.027998842298984528
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 3
# Epoch 3: Loss = 0.027058085426688194
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 4
# Epoch 3: Loss = 0.026388738304376602
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 5
# Epoch 3: Loss = 0.02650494873523712
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 6
# Epoch 3: Loss = 0.027286864817142487
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.021581022
# Value stop: 0.0008609431097283959
# Epoch 4: Loss = 0.02259446308016777
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 0
# Epoch 4: Loss = 0.021012606099247932
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 1
# Epoch 4: Loss = 0.018321624025702477
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 2
# Epoch 4: Loss = 0.017973406240344048
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 3
# Epoch 4: Loss = 0.01696544885635376
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 4
# Epoch 4: Loss = 0.01594506949186325
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 5
# Epoch 4: Loss = 0.016474386677145958
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 6
# Epoch 4: Loss = 0.016895214095711708
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.01505523
# Value stop: 0.000860939733684063
# Epoch 5: Loss = 0.01604257896542549
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 0
# Epoch 5: Loss = 0.014301666058599949
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 1
# Epoch 5: Loss = 0.01457089651376009
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 2
# Epoch 5: Loss = 0.014165996573865414
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 3
# Epoch 5: Loss = 0.01357157714664936
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 4
# Epoch 5: Loss = 0.013431372120976448
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 5
# Epoch 5: Loss = 0.013508346863090992
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 6
# Epoch 5: Loss = 0.014340007677674294
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.012419617
# Value stop: 0.0008609382784925401
# Epoch 6: Loss = 0.01283701229840517
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 0
# Epoch 6: Loss = 0.012448938563466072
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 1
# Epoch 6: Loss = 0.012709986418485641
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 2
# Epoch 6: Loss = 0.012669115327298641
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 3
# Epoch 6: Loss = 0.012766970321536064
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 4
# Epoch 6: Loss = 0.011621309444308281
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 5
# Epoch 6: Loss = 0.011791537515819073
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 6
# Epoch 6: Loss = 0.011485444381833076
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.010675562
# Value stop: 0.0008609376382082701
# Epoch 7: Loss = 0.011451970785856247
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 0
# Epoch 7: Loss = 0.01057895552366972
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 1
# Epoch 7: Loss = 0.011142409406602383
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 2
# Epoch 7: Loss = 0.01148752961307764
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 3
# Epoch 7: Loss = 0.010195164009928703
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 4
# Epoch 7: Loss = 0.01079603098332882
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 5
# Epoch 7: Loss = 0.010061091743409634
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 6
# Epoch 7: Loss = 0.010165620595216751
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 1
# Epoch 90: Loss = 0.0034715619403868914
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 2
# Epoch 90: Loss = 0.003817253978922963
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 3
# Epoch 90: Loss = 0.003560356330126524
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 4
# Epoch 90: Loss = 0.003330795792862773
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 5
# Epoch 90: Loss = 0.003743581473827362
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 6
# Epoch 90: Loss = 0.0035150654148310423
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.0008609369397163391
# Epoch 91: Loss = 0.0032602970022708178
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 0
# Epoch 91: Loss = 0.0036738039925694466
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 1
# Epoch 91: Loss = 0.003411139827221632
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 2
# Epoch 91: Loss = 0.0034967376850545406
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 3
# Epoch 91: Loss = 0.003597893286496401
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 4
# Epoch 91: Loss = 0.003651547012850642
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 5
# Epoch 91: Loss = 0.0036221176851540804
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 6
# Epoch 91: Loss = 0.003343943040817976
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.0008609369397163391
# Epoch 92: Loss = 0.0036980286240577698
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 0
# Epoch 92: Loss = 0.0032361627090722322
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 1
# Epoch 92: Loss = 0.003235800890251994
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 2
# Epoch 92: Loss = 0.0035737152211368084
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 3
# Epoch 92: Loss = 0.003376986598595977
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 4
# Epoch 92: Loss = 0.0034450991079211235
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 5
# Epoch 92: Loss = 0.003673860337585211
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 6
# Epoch 92: Loss = 0.005055501125752926
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.0008609369397163391
# Epoch 93: Loss = 0.00338610727339983
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 0
# Epoch 93: Loss = 0.003677274100482464
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 1
# Epoch 93: Loss = 0.003285414772108197
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 2
# Epoch 93: Loss = 0.003776098368689418
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 3
# Epoch 93: Loss = 0.003424540162086487
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 4
# Epoch 93: Loss = 0.0034494136925786734
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 5
# Epoch 93: Loss = 0.003209928050637245
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 6
# Epoch 93: Loss = 0.004329525399953127
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.0008609369397163391
# Epoch 94: Loss = 0.003543869126588106
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 0
# Epoch 94: Loss = 0.003561687655746937
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 1
# Epoch 94: Loss = 0.003281618934124708
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 2
# Epoch 94: Loss = 0.0031718132086098194
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 3
# Epoch 94: Loss = 0.003852956462651491
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 4
# Epoch 94: Loss = 0.0035052504390478134
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 5
# Epoch 94: Loss = 0.00372137944214046
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 6
# Epoch 94: Loss = 0.0039975931867957115
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.0008609369397163391
# Epoch 95: Loss = 0.003269104054197669
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 0
# Epoch 95: Loss = 0.0033703793305903673
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 1
# Epoch 95: Loss = 0.0034943772479891777
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 2
# Epoch 95: Loss = 0.0034037691075354815
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 3
# Epoch 95: Loss = 0.0034069386310875416
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 4
# Epoch 95: Loss = 0.003393035614863038
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 5
# Epoch 95: Loss = 0.003752803662791848
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 6
# Epoch 95: Loss = 0.0032104633282870054
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.0008609369397163391
# Epoch 96: Loss = 0.0036200766917318106
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 0
# Epoch 96: Loss = 0.003870262298732996
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 1
# Epoch 96: Loss = 0.003761877538636327
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 2
# Epoch 96: Loss = 0.004284306894987822
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 3
# Epoch 96: Loss = 0.0041948785074055195
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 4
# Epoch 96: Loss = 0.004004290327429771
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 5
# Epoch 96: Loss = 0.003810904221609235
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 6
# Epoch 96: Loss = 0.0037631194572895765
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.0008609369397163391
# Epoch 97: Loss = 0.0036985143087804317
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 0
# Epoch 97: Loss = 0.003590987529605627
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 1
# Epoch 97: Loss = 0.004102516453713179
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 2
# Epoch 97: Loss = 0.003296506591141224
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 3
# Epoch 97: Loss = 0.0034035746939480305
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 4
# Epoch 97: Loss = 0.0037090242840349674
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 5
# Epoch 97: Loss = 0.003731652395799756
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 6
# Epoch 97: Loss = 0.004837413784116507
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.0008609369397163391
# Epoch 98: Loss = 0.004013384692370892
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 0
# Epoch 98: Loss = 0.004167965613305569
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 1
# Epoch 98: Loss = 0.0035985310096293688
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 2
# Epoch 98: Loss = 0.003452299628406763
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 3
# Epoch 98: Loss = 0.003342350944876671
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 4
# Epoch 98: Loss = 0.0037546937819570303
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 5
# Epoch 98: Loss = 0.0035392879508435726
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 6
# Epoch 98: Loss = 0.0030674217268824577
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.0008609369397163391
# Epoch 99: Loss = 0.0033425341825932264
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 0
# Epoch 99: Loss = 0.00382312573492527
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 1
# Epoch 99: Loss = 0.0033727700356394053
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 2
# Epoch 99: Loss = 0.0039581432938575745
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 3
# Epoch 99: Loss = 0.003537676064297557
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 4
# Epoch 99: Loss = 0.003496789140626788
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 5
# Epoch 99: Loss = 0.0033420086838304996
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 6
# Epoch 99: Loss = 0.002544939052313566
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.0033070953
# Value stop: 0.0008609369397163391
# Epoch 100: Loss = 0.0035746146459132433
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 0
# Epoch 100: Loss = 0.0036270872224122286
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 1
# Epoch 100: Loss = 0.0036033918149769306
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 2
# Epoch 100: Loss = 0.0033335324842482805
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 3
# Epoch 100: Loss = 0.0036107939667999744
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 4
# Epoch 100: Loss = 0.0031456095166504383
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 5
# Epoch 100: Loss = 0.003384547308087349
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 6
# Epoch 100: Loss = 0.002602782566100359
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4d2ea60>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.0032879398
# Value stop: 0.0008609369397163391
# [   0    2    6    7   12   24   27   28   28   30   32   34   34   35
#    35   38   38   42   45   48   50   51   54   57   58   58   59   62
#    66   66   66   66   69   69   70   71   73   73   78   79   86   89
#    93  101  103  103  105  109  113  115  115  123  128  128  130  131
#   132  132  139  142  144  145  146  146  148  156  160  161  163  172
#   177  182  182  184  191  191  192  196  203  204  209  210  212  212
#   213  214  214  215  215  220  229  230  231  233  235  236  240  247
#   250  256  257  264  266  270  275  277  280  281  285  285  292  295
#   302  306  306  308  315  315  315  317  319  324  324  325  331  333
#   333  347  349  349  351  355  359  368  372  373  374  374  378  380
#   380  381  382  382  386  387  389  391  396  398  400  402  403  403
#   405  407  407  407  407  410  412  415  418  420  422  425  430  433
#   436  438  439  447  449  451  451  452  452  453  458  464  469  470
#   473  485  487  487  488  493  497  498  504  506  507  510  515  515
#   516  517  518  518  519  525  525  525  526  538  541  542  543  543
#   829  830  834  837  837  838  840  843  845  845  848  851  851  855
#   855  861  862  864  864  866  870  876  879  879  879  879  882  887
#   888  895  906  908  912  919  923  925  928  930  930  931  932  932
#   934  935  947  947  948  952  953  956  962  965  965  969  969  970
#   970  982  986  988 1005 1009 1011 1013 1014 1014 1015 1020 1021 1024
#  1025 1026 1027 1029 1030 1031 1031 1032 1039 1039 1043 1045 1047 1052
#  1060 1062 1066 1069 1071 1076 1080 1083 1086 1087 1090 1094 1095 1095
#  1096 1098 1098 1099 1101 1103 1108 1109 1111 1114 1115 1117 1120 1123
#  1125 1125 1126 1128 1128 1128 1136 1151 1152 1155 1156 1157 1158 1158
#  1160 1162 1162 1163 1164 1167 1167 1178 1178 1179 1180 1184 1189 1192
#  1194 1195 1196 1206 1206 1209 1209 1210 1210 1215 1215 1221 1221 1226
#  1228 1230 1232 1232 1234 1236 1236 1238 1239 1246 1253 1253 1255 1257
#  1259 1264 1266 1267 1274 1278 1278 1282 1284 1284 1288 1289 1289 1291
#  1292 1294 1294 1299 1299 1303 1305 1305 1307 1309 1310 1311 1312 1316
#  1326 1329 1329 1329 1329 1332 1335 1339 1341 1342]

# %%
testsubj = 11
testsubjstr = '11'

# %%
from torch.utils.tensorboard import SummaryWriter
from pytorch_lightning.callbacks import ModelCheckpoint
from torch.nn.utils.rnn import pad_sequence
writer = SummaryWriter()

for run in RunBuilder.get_runs(params):
    monitor_callback = ModelCheckpoint('./runs/models/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '_runtime.h5', monitor='val_loss', verbose=True)
    
    root_dir = './data'
    dataf = 'data_.hdf5'
    headerf = 'header_.csv'
    subj_list_train = np.array([12, 13, 14, 15])
    subj_list_valid = np.array([11])
    
    train_set = MRISelectorSubjDataset(root_dir,dataf,headerf,subj_list_train)
    train_gen = DataLoader(train_set, batch_size = run.batch_size, shuffle = True, pin_memory=False, drop_last=True)
    #train_gen = DataLoader(train_set, batch_size = run.batch_size, shuffle = True, num_workers = 4, pin_memory=False, collate_fn = pad_collate)
    #train_gen = DataLoader(train_set, batch_size = run.batch_size, shuffle = True, num_workers = 0, pin_memory=False)#, collate_fn = pad_collate)
    # for the validation dataset
    valid_set = MRISelectorSubjDataset(root_dir,dataf,headerf,subj_list_valid)
    valid_gen = DataLoader(valid_set, batch_size = run.batch_size, shuffle = False, pin_memory=False, drop_last=True)  
    
    path = './runs/models/check11/model.pt'
    # 1st time
    checkpt = False
    # Continue training
    checkpt = True
    
    selector = ConcreteAutoencoderFeatureSelector(K=n_means, num_features=n_means, num_epochs=num_epochs, learning_rate=run.lr, start_temp=10.0, min_temp=0.1, 
                                                  tryout_limit=5, input_dim=1344, checkpt = checkpt, callback=monitor_callback, writer=writer, path = path)#,losstrain=losstrain,lossval=lossval)    
    
    selector.fit(X=train_gen, val_X=valid_gen)
    
    model = selector.get_params()
    
    print(np.sort(selector.get_indices()))
    np.savetxt('./runs/textfiles/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.txt', np.array(selector.get_indices(), dtype=int), fmt='%d')
    
    #model.save('./runs/models/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.h5')
    torch.save(model, './runs/models/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.pt')
    # save only parameters
    torch.save(model.state_dict(),'./runs/models/params_' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.pt')
    
    torch.save(model.state_dict(), os.path.join('./runs/models/','epoch{}_net.pth'.format(num_epochs)) )
    model_file = open(os.path.join('./runs/models/','epoch{}_net.bin'.format(num_epochs)),'wb')
    pk.dump(model,model_file,pk.HIGHEST_PROTOCOL)      
    model_file.close()
# Out:
# Epoch 1: Loss = 0.25644588470458984
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 1: Loss = 0.2039867341518402
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 1: Loss = 0.13457338511943817
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 1: Loss = 0.12008857727050781
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 1: Loss = 0.05704236030578613
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 1: Loss = 0.05602189525961876
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 1: Loss = 0.06095528602600098
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 1: Loss = 0.06257791817188263
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.037652474
# Value stop: 0.0008659674203954637
# Epoch 2: Loss = 0.0520944707095623
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 2: Loss = 0.041752878576517105
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 2: Loss = 0.03671441227197647
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 2: Loss = 0.040570903569459915
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 2: Loss = 0.033622290939092636
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 2: Loss = 0.035281263291835785
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 2: Loss = 0.03230012208223343
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 2: Loss = 0.028413468971848488
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.019214489
# Value stop: 0.0008666694047860801
# Epoch 3: Loss = 0.030587157234549522
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 3: Loss = 0.02933400869369507
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 3: Loss = 0.0270578321069479
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 3: Loss = 0.024028951302170753
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 3: Loss = 0.023762265220284462
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 3: Loss = 0.023475540801882744
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 3: Loss = 0.02172151952981949
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 3: Loss = 0.019339758902788162
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.012277028
# Value stop: 0.000866956717800349
# Epoch 4: Loss = 0.017106475308537483
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 4: Loss = 0.01684732548892498
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 4: Loss = 0.015687821432948112
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 4: Loss = 0.015819821506738663
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 4: Loss = 0.013947876170277596
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 4: Loss = 0.01439615897834301
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 4: Loss = 0.013528209179639816
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 4: Loss = 0.01481165923178196
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.009985852
# Value stop: 0.0008670830284245312
# Epoch 5: Loss = 0.013336651027202606
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 5: Loss = 0.013213940896093845
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 5: Loss = 0.012753372080624104
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 5: Loss = 0.012580866925418377
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 5: Loss = 0.012668384239077568
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 5: Loss = 0.012944324873387814
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 5: Loss = 0.012371267192065716
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 5: Loss = 0.011356071569025517
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.008990577
# Value stop: 0.0008671394316479564
# Epoch 6: Loss = 0.01205742172896862
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 6: Loss = 0.011881713755428791
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 6: Loss = 0.011145191267132759
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 6: Loss = 0.011041544377803802
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 6: Loss = 0.011072183027863503
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 6: Loss = 0.011014001443982124
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 6: Loss = 0.010412090457975864
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 6: Loss = 0.011546422727406025
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.0076167365
# Value stop: 0.0008671646355651319
# Epoch 7: Loss = 0.01005172822624445
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 7: Loss = 0.00974485743790865
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 7: Loss = 0.010254370048642159
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 7: Loss = 0.009777565486729145
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 7: Loss = 0.009312227368354797
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 7: Loss = 0.009152235463261604
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 7: Loss = 0.010637444444000721
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 7: Loss = 0.009758474305272102
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.006772127
# Value stop: 0.0008671758114360273
# Epoch 8: Loss = 0.010202486999332905
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 8: Loss = 0.009457393549382687
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 8: Loss = 0.008980227634310722
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 8: Loss = 0.00832919031381607
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 8: Loss = 0.009109685197472572
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 8: Loss = 0.009387746453285217
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 8: Loss = 0.008421368896961212
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 8: Loss = 0.007375718560069799
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.006313607
# Value stop: 0.0008671808755025268
# Epoch 9: Loss = 0.008457515388727188
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 9: Loss = 0.008469789288938046
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 9: Loss = 0.007733139209449291
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 9: Loss = 0.00887778215110302
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 9: Loss = 0.00899050384759903
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 9: Loss = 0.008228186517953873
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 9: Loss = 0.008608872070908546
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 9: Loss = 0.008488349616527557
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.005904801
# Value stop: 0.0008671830873936415
# Epoch 10: Loss = 0.008660187013447285
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 10: Loss = 0.007985402829945087
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 10: Loss = 0.007970193400979042
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 10: Loss = 0.00785112101584673
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 10: Loss = 0.007767638191580772
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 10: Loss = 0.008772418834269047
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 10: Loss = 0.0069617219269275665
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 10: Loss = 0.007905570790171623
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.0056135845
# Value stop: 0.000867184076923877
# Epoch 11: Loss = 0.007287369575351477
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 11: Loss = 0.007804290857166052
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 11: Loss = 0.007416591048240662
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 11: Loss = 0.008335424587130547
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 11: Loss = 0.007508430629968643
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 11: Loss = 0.0084710493683815
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 11: Loss = 0.009704996831715107
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 11: Loss = 0.008555627427995205
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.005431411
# Value stop: 0.0008671843679621816
# Epoch 12: Loss = 0.007181260734796524
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 12: Loss = 0.008590782061219215
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 12: Loss = 0.008770418353378773
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train =
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 19: Loss = 0.0048638926818966866
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 19: Loss = 0.004888006020337343
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 19: Loss = 0.004830904770642519
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 19: Loss = 0.005039597395807505
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 19: Loss = 0.005091592203825712
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 19: Loss = 0.004761453717947006
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 19: Loss = 0.004748656880110502
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.0032124333
# Value stop: 0.000867184717208147
# Epoch 20: Loss = 0.004840037319809198
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 20: Loss = 0.004624474793672562
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 20: Loss = 0.0046843551099300385
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 20: Loss = 0.0051016113720834255
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 20: Loss = 0.004634442273527384
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 20: Loss = 0.004692816641181707
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 20: Loss = 0.0044767288491129875
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 20: Loss = 0.00464269844815135
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.003106806
# Value stop: 0.000867184717208147
# Epoch 21: Loss = 0.005070390645414591
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 21: Loss = 0.0044001922942698
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 21: Loss = 0.0043016099371016026
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 21: Loss = 0.0047726756893098354
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 21: Loss = 0.004641968756914139
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 21: Loss = 0.004718571435660124
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 21: Loss = 0.005244219675660133
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 21: Loss = 0.005221688654273748
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.000867184717208147
# Epoch 22: Loss = 0.005339610856026411
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 22: Loss = 0.005359475966542959
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 22: Loss = 0.004799257963895798
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 22: Loss = 0.0049026417545974255
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 22: Loss = 0.0045848870649933815
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 22: Loss = 0.004916746634989977
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 22: Loss = 0.004369903821498156
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 22: Loss = 0.004135950934141874
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.0030405119
# Value stop: 0.000867184717208147
# Epoch 23: Loss = 0.004666292108595371
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 23: Loss = 0.004962154198437929
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 23: Loss = 0.004077889956533909
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 23: Loss = 0.0043168505653738976
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 23: Loss = 0.00471847876906395
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 23: Loss = 0.0045571234077215195
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 23: Loss = 0.0042905923910439014
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 23: Loss = 0.00424710800871253
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.0029709642
# Value stop: 0.000867184717208147
# Epoch 24: Loss = 0.004639632534235716
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 24: Loss = 0.004632347263395786
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 24: Loss = 0.004440938588231802
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 24: Loss = 0.004329837393015623
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 24: Loss = 0.004094400443136692
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 24: Loss = 0.0041612861678004265
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 24: Loss = 0.00433094147592783
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 24: Loss = 0.0034892673138529062
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.0028454477
# Value stop: 0.000867184717208147
# Epoch 25: Loss = 0.004054151009768248
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 25: Loss = 0.004336920566856861
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 25: Loss = 0.004221701063215733
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 25: Loss = 0.004078973550349474
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 25: Loss = 0.004441953729838133
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 25: Loss = 0.004391786642372608
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 25: Loss = 0.004421520978212357
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 25: Loss = 0.003888634731993079
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.002780237
# Value stop: 0.000867184717208147
# Epoch 26: Loss = 0.003819286823272705
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 26: Loss = 0.004077269695699215
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 26: Loss = 0.004257761407643557
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 26: Loss = 0.004305056296288967
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 26: Loss = 0.004278189968317747
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 26: Loss = 0.004144957289099693
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 26: Loss = 0.0043815807439386845
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 26: Loss = 0.0050928653217852116
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.0027587123
# Value stop: 0.000867184717208147
# Epoch 27: Loss = 0.004089574795216322
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 27: Loss = 0.004351045470684767
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 27: Loss = 0.00389575632289052
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 27: Loss = 0.0043635983020067215
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 27: Loss = 0.0040819537825882435
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 27: Loss = 0.003991216421127319
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 27: Loss = 0.004138792399317026
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 27: Loss = 0.004041330423206091
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.0027468863
# Value stop: 0.000867184717208147
# Epoch 28: Loss = 0.003975138068199158
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 28: Loss = 0.004092758521437645
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 28: Loss = 0.004137096926569939
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 28: Loss = 0.003928904887288809
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 28: Loss = 0.00386851467192173
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 28: Loss = 0.004240783397108316
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 28: Loss = 0.004267893265932798
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 28: Loss = 0.004319912753999233
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.000867184717208147
# Epoch 29: Loss = 0.004051724914461374
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 29: Loss = 0.0039450000040233135
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 29: Loss = 0.004633527249097824
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 29: Loss = 0.004419297911226749
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 29: Loss = 0.005168203730136156
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 29: Loss = 0.005581464618444443
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 29: Loss = 0.005664189346134663
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 29: Loss = 0.004501845687627792
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.000867184717208147
# Epoch 30: Loss = 0.004169339779764414
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 30: Loss = 0.00491020642220974
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 30: Loss = 0.0043614450842142105
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 30: Loss = 0.0045531862415373325
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 30: Loss = 0.004600103013217449
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 30: Loss = 0.004222120624035597
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 30: Loss = 0.003915602806955576
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 30: Loss = 0.004220077767968178
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.000867184717208147
# Epoch 31: Loss = 0.004067107103765011
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 31: Loss = 0.004107675515115261
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 31: Loss = 0.004671645816415548
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 31: Loss = 0.00397751247510314
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 31: Loss = 0.003985448740422726
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 31: Loss = 0.004080704413354397
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 31: Loss = 0.003784972708672285
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 31: Loss = 0.0034408431965857744
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.0027393233
# Value stop: 0.000867184717208147
# Epoch 32: Loss = 0.0040216767229139805
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train =
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 38: Loss = 0.0034056638833135366
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 38: Loss = 0.004157001152634621
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.0024968863
# Value stop: 0.000867184717208147
# Epoch 39: Loss = 0.003414296777918935
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 39: Loss = 0.003916285466402769
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 39: Loss = 0.003574254922568798
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 39: Loss = 0.003751408075913787
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 39: Loss = 0.003701057517901063
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 39: Loss = 0.003566517261788249
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 39: Loss = 0.0035984034184366465
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 39: Loss = 0.0038098280783742666
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.0024743588
# Value stop: 0.000867184717208147
# Epoch 40: Loss = 0.0035030569415539503
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 40: Loss = 0.0037330244667828083
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 40: Loss = 0.0037780364509671926
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# ...
# j train = 4
# Epoch 89: Loss = 0.002784137148410082
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 89: Loss = 0.002986124949529767
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 89: Loss = 0.0026799351908266544
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.0020782987
# Value stop: 0.000867184717208147
# Epoch 90: Loss = 0.0029319250024855137
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 90: Loss = 0.0027668518014252186
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 90: Loss = 0.0027765524573624134
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 90: Loss = 0.0030100427102297544
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 90: Loss = 0.002889583120122552
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 90: Loss = 0.0029317454900592566
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 90: Loss = 0.003252182388678193
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 90: Loss = 0.0026327944360673428
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.000867184717208147
# Epoch 91: Loss = 0.0027607802767306566
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 91: Loss = 0.002803509123623371
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 91: Loss = 0.0030262924265116453
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 91: Loss = 0.0028601691592484713
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 91: Loss = 0.0033922961447387934
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 91: Loss = 0.0027149098459631205
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 91: Loss = 0.003217628225684166
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 91: Loss = 0.0031553322914987803
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.000867184717208147
# Epoch 92: Loss = 0.003347827587276697
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 92: Loss = 0.00321519304998219
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 92: Loss = 0.0028725434094667435
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 92: Loss = 0.0030396354850381613
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 92: Loss = 0.002758472692221403
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 92: Loss = 0.0028334539383649826
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 92: Loss = 0.0029038568027317524
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 92: Loss = 0.0031886259093880653
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.000867184717208147
# Epoch 93: Loss = 0.0029388407710939646
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 93: Loss = 0.0029057941865175962
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 93: Loss = 0.0029310707468539476
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 93: Loss = 0.0028885435312986374
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 93: Loss = 0.0029478527139872313
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 93: Loss = 0.002761930227279663
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 93: Loss = 0.003019173862412572
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 93: Loss = 0.003016895381733775
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.000867184717208147
# Epoch 94: Loss = 0.002808450488373637
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 94: Loss = 0.0029553230851888657
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 94: Loss = 0.002984876511618495
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 94: Loss = 0.00279279169626534
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 94: Loss = 0.0030602230690419674
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 94: Loss = 0.0026271799579262733
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 94: Loss = 0.0028889630921185017
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 94: Loss = 0.0034601062070578337
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.000867184717208147
# Epoch 95: Loss = 0.0029834373854100704
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 95: Loss = 0.0029216203838586807
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 95: Loss = 0.003114467253908515
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 95: Loss = 0.0029618944972753525
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 95: Loss = 0.0030919278506189585
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 95: Loss = 0.00324268639087677
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 95: Loss = 0.0031811196822673082
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 95: Loss = 0.0037310405168682337
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.000867184717208147
# Epoch 96: Loss = 0.0031711559277027845
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 96: Loss = 0.0029151553753763437
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 96: Loss = 0.002666486194357276
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 96: Loss = 0.0029906367417424917
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 96: Loss = 0.002853508573025465
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 96: Loss = 0.0028490100521594286
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 96: Loss = 0.0028257579542696476
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 96: Loss = 0.0025412992108613253
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
#              ... validation loss has decreased. Saving model...
# 0.0020285868
# Value stop: 0.000867184717208147
# Epoch 97: Loss = 0.002827092306688428
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 97: Loss = 0.0026722776237875223
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 97: Loss = 0.002874594647437334
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 97: Loss = 0.0027764583937823772
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 97: Loss = 0.0029075713828206062
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 97: Loss = 0.002852973062545061
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 97: Loss = 0.003058008383959532
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 97: Loss = 0.0027408788446336985
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.000867184717208147
# Epoch 98: Loss = 0.002902576234191656
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 98: Loss = 0.0025803567841649055
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 98: Loss = 0.00299786776304245
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 98: Loss = 0.002742612035945058
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 98: Loss = 0.0027122669853270054
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 98: Loss = 0.0026453363243490458
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 98: Loss = 0.0032320006284862757
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 98: Loss = 0.0029994070064276457
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.000867184717208147
# Epoch 99: Loss = 0.002881425665691495
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 99: Loss = 0.0029891689773648977
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 99: Loss = 0.002955334261059761
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 99: Loss = 0.0027765976265072823
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 99: Loss = 0.002778605790808797
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 99: Loss = 0.0029423637315630913
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 99: Loss = 0.0028546431567519903
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 99: Loss = 0.0034693488851189613
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.000867184717208147
# Epoch 100: Loss = 0.002820925787091255
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 0
# Epoch 100: Loss = 0.002769872546195984
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 1
# Epoch 100: Loss = 0.00278778700158
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 2
# Epoch 100: Loss = 0.0030959106516093016
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 3
# Epoch 100: Loss = 0.0031771420035511255
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 4
# Epoch 100: Loss = 0.002756277332082391
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 5
# Epoch 100: Loss = 0.0027967689093202353
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 6
# Epoch 100: Loss = 0.002870074473321438
# <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f41f4ded7f0>
# j train = 7
# j val = 0
# j val = 1
# Value stop: 0.000867184717208147
# [   1    1    3    7    9   13   20   20   23   25   29   31   32   36
#    36   38   40   45   45   46   48   49   52   53   57   58   66   67
#    68   71   75   76   78   78   81   83   85   86   91   93   96   98
#   103  110  113  114  115  115  119  123  125  129  130  132  139  142
#   142  143  145  147  147  157  161  167  168  172  173  181  188  188
#   190  192  194  197  201  208  210  210  211  212  218  218  221  223
#   224  225  227  229  233  234  236  237  240  240  241  241  243  249
#   251  253  255  257  262  272  276  279  294  296  299  299  301  304
#   307  308  308  315  318  321  322  324  328  331  332  332  334  336
#   337  340  343  344  358  359  359  361  362  362  366  367  369  373
#   383  384  384  388  389  392  394  394  399  399  404  404  405  408
#   414  418  418  421  422  429  433  434  437  437  440  443  447  448
#   457  461  463  464  464  469  471  472  472  476  477  482  482  487
#   490  490  494  496  497  498  498  499  499  499  501  503  506  508
#   509  513  514  518  520  520  521  527  531  534  537  540  540  542
#   543  543  546  550  553  554  555  557  557  564  567  577  580  583
#   585  588  588  592  594  594  603  603  604  606  609  616  619  619
#   628  629  630  630  633  637  645  646  647  651  653  653  655  655
#   656  659  662  662  664  664  668  669  669  673  679  682  686  691
#   691  693  699  703  704  707  709  725  728  730  733  736  737  739
#   746  751  757  761  763  763  767  769  772  773  774  779  780  780
#   781  787  792  800  800  802  803  806  813  818  821  823  826  830
#   831  832  832  832  833  836  837  840  842  847  850  858  860  862
#   868  870  872  874  874  876  879  880  884  888  888  889  890  896
#   901  902  904  906  912  915  923  925  928  929  929  930  934  935
#   937  938  939  939  948  952  956  956  963  965  968  976  979  982
#   986  989  989 1000 1002 1003 1008 1008 1009 1009 1013 1014 1018 1020
#  1023 1032 1034 1040 1041 1042 1046 1047 1048 1059 1060 1062 1064 1065
#  1066 1070 1072 1072 1073 1073 1075 1076 1077 1077 1079 1079 1084 1086
#  1093 1097 1099 1101 1102 1104 1113 1117 1120 1122 1124 1128 1131 1132
#  1134 1140 1141 1142 1144 1150 1150 1155 1156 1156 1160 1161 1163 1164
#  1183 1185 1187 1192 1193 1196 1201 1206 1206 1209 1212 1214 1215 1218
#  1221 1222 1224 1225 1226 1250 1253 1255 1258 1271 1273 1275 1276 1276
#  1277 1279 1282 1283 1283 1284 1284 1290 1290 1291 1291 1292 1294 1297
#  1298 1298 1299 1302 1302 1303 1311 1312 1312 1314 1317 1318 1320 1324
#  1324 1327 1327 1328 1330 1332 1332 1333 1334 1337]

# %%
print(np.sort(selector.get_indices()))
np.savetxt('./runs/textfiles/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '.txt', np.array(selector.get_indices(), dtype=int), fmt='%d')
# Out:
# [   2    4    4    7    7    8    8   10   10   11   13   16   16   17
#    19   21   24   32   47   52   53   55   56   58   58   58   63   63
#    73   74   84   85   89   91   92  100  102  105  105  106  106  117
#   117  119  121  122  122  123  124  126  128  130  132  132  142  146
#   151  153  155  174  174  175  177  180  185  187  189  195  203  203
#   205  206  207  208  212  216  222  222  223  223  224  225  225  227
#   231  235  237  240  241  246  249  249  251  253  253  255  258  260
#   260  261  261  262  262  266  267  270  271  271  272  275  289  291
#   291  291  294  298  300  305  308  308  312  312  313  320  324  330
#   331  331  335  337  338  341  342  342  348  352  353  353  357  360
#   362  364  368  371  378  378  392  394  396  397  400  401  404  406
#   406  407  411  413  414  416  419  419  421  425  428  431  445  447
#   450  453  455  458  460  461  463  466  467  469  471  471  472  472
#   476  476  478  484  486  487  487  490  493  495  503  508  508  509
#   519  523  526  528  529  534  537  538  539  551  553  554  555  557
#   559  559  563  564  568  575  578  580  584  584  585  586  595  596
#   600  604  604  604  605  610  612  613  614  619  619  621  629  629
#   636  637  637  638  638  639  642  642  644  645  646  647  649  649
#   655  657  657  659  664  671  672  674  676  679  688  701  702  710
#   715  716  730  736  736  744  745  745  745  746  749  749  750  751
#   754  756  759  761  764  765  767  769  773  775  776  779  781  782
#   784  787  792  801  808  809  811  812  817  822  831  833  837  837
#   842  852  854  857  859  861  864  866  870  874  875  878  886  886
#   894  894  895  896  896  896  898  898  901  903  908  910  910  912
#   913  919  919  921  923  924  927  928  929  931  932  938  948  949
#   951  954  958  960  962  968  969  971  972  975  982  983  983  983
#   985  985  995  999 1002 1003 1004 1006 1007 1007 1012 1018 1023 1027
#  1033 1038 1041 1046 1046 1053 1053 1056 1059 1063 1066 1067 1070 1074
#  1075 1077 1078 1080 1083 1085 1085 1087 1088 1091 1091 1095 1101 1102
#  1104 1106 1110 1114 1116 1119 1119 1119 1122 1127 1128 1130 1135 1145
#  1148 1151 1152 1152 1159 1163 1165 1168 1170 1170 1170 1171 1172 1174
#  1175 1187 1187 1187 1188 1189 1196 1202 1202 1204 1205 1207 1209 1210
#  1210 1222 1226 1228 1233 1240 1241 1242 1245 1249 1251 1253 1254 1254
#  1255 1260 1261 1264 1265 1266 1267 1268 1269 1270 1270 1271 1271 1272
#  1279 1279 1283 1291 1292 1296 1300 1302 1303 1306 1311 1314 1320 1323
#  1326 1327 1329 1335 1336 1338 1338 1339 1340 1343]

# %%
for run in RunBuilder.get_runs(params):
    for trial in range(3):
        logdir = "./runs/scalars/" + datetime.now().strftime("%Y%m%d-%H%M%S") + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_testnone_dec' + decstr + '_trial' + str(trial)

        """tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)
        monitor_callback = keras.callbacks.ModelCheckpoint('./runs/models/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_testnone_dec' + decstr + '_runtime'  + '_trial' + str(trial) + '.h5', monitor='val_loss', verbose=0, save_weights_only=True)

        trainset = MRISelectorSubjDataset(root_dir='./data', dataf='data_.hdf5', headerf ='header_.csv',
                                      subj_list=np.array([11, 12, 13, 14, 15]), batch_size=run.batch_size)"""
        
        tensorboard_callback = torch.utils.tensorboard(log_dir=logdir)
        monitor_callback = pytorch_lightning.callbacks.ModelCheckpoint('./runs/models/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_test' + testsubjstr + '_dec' + decstr + '_runtime.h5', monitor='val_loss', verbose=True)

        root_dir = './data'
        dataf = 'data_.hdf5'
        headerf = 'header_.csv'
        subj_list = np.array([11, 12, 13, 14, 15])

        train_set = MRISelectorSubjDataset(root_dir,dataf,headerf,subj_list)
        train_gen = DataLoader(train_set, batch_size = run.batch_size, shuffle = True)
        # for the validation dataset
        #valid_set = MRISelectorSubjDataset(root_dir,dataf,headerf,subj_list)
        #valid_gen = DataLoader(valid_set, batch_size = run.batch_size, shuffle = False)
        
        selector = ConcreteAutoencoderFeatureSelector(K=n_means, output_function=dec, num_epochs=num_epochs, learning_rate=run.lr, start_temp=10.0, min_temp=0.1, 
                                                      tryout_limit=5, input_dim=1344, callback=[tensorboard_callback, monitor_callback])

        selector.fit(X=trainset)

        model = selector.get_params()

        model.save_weights('./runs/models/' + f'{run}' + 'K=' + str(n_means) + '_epoch=' + str(num_epochs) + '_testnone_dec' + decstr + '_trial' + str(trial) + '.h5')
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 1344)]            0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 500)               672001
# _________________________________________________________________
# dense_15 (Dense)             (None, 800)               400800
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 800)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1000)              801000
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 1000)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1344)              1345344
# =================================================================
# Total params: 3,219,145
# Trainable params: 3,219,144
# Non-trainable params: 1
# _________________________________________________________________
# None
# [<keras.callbacks.tensorboard_v2.TensorBoard object at 0x7f59103d4668>, <keras.callbacks.callbacks.ModelCheckpoint object at 0x7f59103d4518>]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layers with arguments in `__init__` must override `get_config`.
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layers with arguments in `__init__` must override `get_config`.
# mean max of probabilities: 0.0008010466 - temperature 10.0
# mean max of probabilities: 0.0010004895 - temperature 9.976355
# mean max of probabilities: 0.0014470762 - temperature 9.952709
# mean max of probabilities: 0.0034203383 - temperature 9.929064
# mean max of probabilities: 0.005246357 - temperature 9.905418
# mean max of probabilities: 0.0062826686 - temperature 9.881825
# mean max of probabilities: 0.007274154 - temperature 9.86033
# mean max of probabilities: 0.0079724025 - temperature 9.838834
# mean max of probabilities: 0.008679924 - temperature 9.817338
# mean max of probabilities: 0.009587731 - temperature 9.795842
# mean max of probabilities: 0.010143932 - temperature 9.774346
# mean max of probabilities: 0.010700223 - temperature 9.752851
# mean max of probabilities: 0.011316635 - temperature 9.731355
# mean max of probabilities: 0.011780981 - temperature 9.709859
# mean max of probabilities: 0.0123565085 - temperature 9.688363
# mean max of probabilities: 0.012912229 - temperature 9.666867
# mean max of probabilities: 0.013416147 - temperature 9.645371
# mean max of probabilities: 0.013996172 - temperature 9.623876
# mean max of probabilities: 0.014482799 - temperature 9.60238
# mean max of probabilities: 0.015055481 - temperature 9.580884
# mean max of probabilities: 0.01566685 - temperature 9.559388
# mean max of probabilities: 0.016490888 - temperature 9.537892
# mean max of probabilities: 0.017493991 - temperature 9.5163965
# mean max of probabilities: 0.018776022 - temperature 9.494901
# mean max of probabilities: 0.020434787 - temperature 9.473405
# mean max of probabilities: 0.023078246 - temperature 9.451909
# mean max of probabilities: 0.027601404 - temperature 9.430413
# mean max of probabilities: 0.036384262 - temperature 9.408917
# mean max of probabilities: 0.041035306 - temperature 9.387422
# mean max of probabilities: 0.044817276 - temperature 9.365926
# mean max of probabilities: 0.048555218 - temperature 9.34443
# mean max of probabilities: 0.051987488 - temperature 9.322934
# mean max of probabilities: 0.05559496 - temperature 9.301438
# mean max of probabilities: 0.059308667 - temperature 9.2799425
# mean max of probabilities: 0.06282296 - temperature 9.258447
# mean max of probabilities: 0.066285126 - temperature 9.236951
# mean max of probabilities: 0.07000414 - temperature 9.215455
# mean max of probabilities: 0.07356292 - temperature 9.193959
# mean max of probabilities: 0.07706828 - temperature 9.172463
# mean max of probabilities: 0.08108101 - temperature 9.150968
# mean max of probabilities: 0.08478702 - temperature 9.129472
# mean max of probabilities: 0.08862658 - temperature 9.107976
# mean max of probabilities: 0.09254892 - temperature 9.08648
# mean max of probabilities: 0.096290335 - temperature 9.064984
# mean max of probabilities: 0.099983305 - temperature 9.0434885
# mean max of probabilities: 0.10388745 - temperature 9.021993
# mean max of probabilities: 0.10768717 - temperature 9.000497
# mean max of probabilities: 0.11181851 - temperature 8.979001
# mean max of probabilities: 0.1160361 - temperature 8.957505
# mean max of probabilities: 0.12035555 - temperature 8.936525
# mean max of probabilities: 0.12437876 - temperature 8.917179
# mean max of probabilities: 0.12869687 - temperature 8.897833
# mean max of probabilities: 0.13296917 - temperature 8.878487
# mean max of probabilities: 0.13730448 - temperature 8.85914
# mean max of probabilities: 0.14130048 - temperature 8.839794
# mean max of probabilities: 0.14529827 - temperature 8.820448
# mean max of probabilities: 0.14916056 - temperature 8.801102
# mean max of probabilities: 0.15313466 - temperature 8.781755
# mean max of probabilities: 0.15697876 - temperature 8.762409
# mean max of probabilities: 0.1610713 - temperature 8.743063
# mean max of probabilities: 0.16527392 - temperature 8.723717
# mean max of probabilities: 0.16907415 - temperature 8.7043705
# mean max of probabilities: 0.17271475 - temperature 8.685024
# mean max of probabilities: 0.17617111 - temperature 8.665678
# mean max of probabilities: 0.17945288 - temperature 8.646332
# mean max of probabilities: 0.18268262 - temperature 8.626986
# mean max of probabilities: 0.18595763 - temperature 8.607639
# mean max of probabilities: 0.1892396 - temperature 8.588293
# mean max of probabilities: 0.19267341 - temperature 8.568947
# mean max of probabilities: 0.19598815 - temperature 8.549601
# mean max of probabilities: 0.1990005 - temperature 8.530254
# mean max of probabilities: 0.20219895 - temperature 8.510908
# mean max of probabilities: 0.20538974 - temperature 8.491562
# mean max of probabilities: 0.20879862 - temperature 8.472216
# mean max of probabilities: 0.21206112 - temperature 8.452869
# mean max of probabilities: 0.21561655 - temperature 8.433523
# mean max of probabilities: 0.2191793 - temperature 8.414177
# mean max of probabilities: 0.22290859 - temperature 8.394831
# mean max of probabilities: 0.22687708 - temperature 8.375484
# mean max of probabilities: 0.23059347 - temperature 8.356138
# mean max of probabilities: 0.23410831 - temperature 8.336792
# mean max of probabilities: 0.23755494 - temperature 8.317446
# mean max of probabilities: 0.24092546 - temperature 8.2980995
# mean max of probabilities: 0.24407846 - temperature 8.278753
# mean max of probabilities: 0.2471611 - temperature 8.259407
# mean max of probabilities: 0.25022185 - temperature 8.240061
# mean max of probabilities: 0.25320357 - temperature 8.220715
# mean max of probabilities: 0.25582913 - temperature 8.201368
# mean max of probabilities: 0.25800648 - temperature 8.182022
# mean max of probabilities: 0.2603711 - temperature 8.162676
# mean max of probabilities: 0.2626638 - temperature 8.14333
# mean max of probabilities: 0.26462555 - temperature 8.123983
# mean max of probabilities: 0.26634935 - temperature 8.104637
# mean max of probabilities: 0.2676944 - temperature 8.085291
# mean max of probabilities: 0.26923952 - temperature 8.065945
# mean max of probabilities: 0.27058518 - temperature 8.046598
# mean max of probabilities: 0.2720513 - temperature 8.027252
# mean max of probabilities: 0.27337745 - temperature 8.007906
# mean max of probabilities: 0.27459192 - temperature 7.9891953
# mean max of probabilities: 0.27623373 - temperature 7.970924
# mean max of probabilities: 0.27789134 - temperature 7.9526525
# mean max of probabilities: 0.2796393 - temperature 7.934381
# mean max of probabilities: 0.28058764 - temperature 7.9161096
# mean max of probabilities: 0.28292954 - temperature 7.897838
# mean max of probabilities: 0.28473774 - temperature 7.8795667
# mean max of probabilities: 0.2864283 - temperature 7.861295
# mean max of probabilities: 0.28830948 - temperature 7.843024
# mean max of probabilities: 0.29028738 - temperature 7.8247523
# mean max of probabilities: 0.29250053 - temperature 7.806481
# mean max of probabilities: 0.29513156 - temperature 7.7882094
# mean max of probabilities: 0.29774126 - temperature 7.769938
# mean max of probabilities: 0.30073607 - temperature 7.7524333
# mean max of probabilities: 0.3037526 - temperature 7.7352366
# mean max of probabilities: 0.30700928 - temperature 7.71804
# mean max of probabilities: 0.3101749 - temperature 7.7008433
# mean max of probabilities: 0.31326786 - temperature 7.6836467
# mean max of probabilities: 0.31653178 - temperature 7.66645
# mean max of probabilities: 0.31958628 - temperature 7.6492534
# mean max of probabilities: 0.32247853 - temperature 7.6320567
# mean max of probabilities: 0.3251747 - temperature 7.61486
# mean max of probabilities: 0.32767943 - temperature 7.5976634
# mean max of probabilities: 0.3303247 - temperature 7.5804667
# mean max of probabilities: 0.3325823 - temperature 7.56327
# mean max of probabilities: 0.33480167 - temperature 7.5460734
# mean max of probabilities: 0.33685333 - temperature 7.528877
# mean max of probabilities: 0.33868426 - temperature 7.51168
# mean max of probabilities: 0.3403438 - temperature 7.4944835
# mean max of probabilities: 0.34175333 - temperature 7.477287
# mean max of probabilities: 0.34305307 - temperature 7.46009
# mean max of probabilities: 0.34430993 - temperature 7.4428935
# mean max of probabilities: 0.3453553 - temperature 7.425697
# mean max of probabilities: 0.34632072 - temperature 7.4085
# mean max of probabilities: 0.34723234 - temperature 7.3913035
# mean max of probabilities: 0.34785792 - temperature 7.374107
# mean max of probabilities: 0.34841686 - temperature 7.35691
# mean max of probabilities: 0.34877038 - temperature 7.3397136
# mean max of probabilities: 0.3490549 - temperature 7.322517
# mean max of probabilities: 0.3493825 - temperature 7.3053203
# mean max of probabilities: 0.34970206 - temperature 7.288498
# mean max of probabilities: 0.3497285 - temperature 7.272376
# mean max of probabilities: 0.34964135 - temperature 7.256254
# mean max of probabilities: 0.34941697 - temperature 7.2401323
# mean max of probabilities: 0.3493039 - temperature 7.2240105
# mean max of probabilities: 0.34912997 - temperature 7.2078886
# mean max of probabilities: 0.34894872 - temperature 7.1917667
# mean max of probabilities: 0.3485855 - temperature 7.175645
# mean max of probabilities: 0.34822905 - temperature 7.159523
# mean max of probabilities: 0.34777498 - temperature 7.143401
# mean max of probabilities: 0.3473897 - temperature 7.1272793
# mean max of probabilities: 0.3469757 - temperature 7.1111574
# mean max of probabilities: 0.34654236 - temperature 7.0950356
# mean max of probabilities: 0.34610772 - temperature 7.0789137
# mean max of probabilities: 0.34583715 - temperature 7.062792
# mean max of probabilities: 0.34560704 - temperature 7.04667
# mean max of probabilities: 0.34544367 - temperature 7.030548
# mean max of probabilities: 0.3452395 - temperature 7.014426
# mean max of probabilities: 0.34492156 - temperature 6.9983044
# mean max of probabilities: 0.34474015 - temperature 6.9821825
# mean max of probabilities: 0.34471503 - temperature 6.9660606
# mean max of probabilities: 0.34458104 - temperature 6.949939
# mean max of probabilities: 0.3447128 - temperature 6.933817
# mean max of probabilities: 0.34473535 - temperature 6.917695
# mean max of probabilities: 0.34511936 - temperature 6.901573
# mean max of probabilities: 0.34554908 - temperature 6.8854513
# mean max of probabilities: 0.34602946 - temperature 6.8693295
# mean max of probabilities: 0.3467303 - temperature 6.8532076
# mean max of probabilities: 0.34805146 - temperature 6.8370857
# mean max of probabilities: 0.34949836 - temperature 6.8211346
# mean max of probabilities: 0.35097837 - temperature 6.8060875
# mean max of probabilities: 0.35232124 - temperature 6.7910404
# mean max of probabilities: 0.35360944 - temperature 6.7759933
# mean max of probabilities: 0.35499397 - temperature 6.7609463
# mean max of probabilities: 0.35630232 - temperature 6.745899
# mean max of probabilities: 0.35765785 - temperature 6.730852
# mean max of probabilities: 0.35895836 - temperature 6.715805
# mean max of probabilities: 0.36017114 - temperature 6.700758
# mean max of probabilities: 0.36136213 - temperature 6.685711
# mean max of probabilities: 0.3625556 - temperature 6.670664
# mean max of probabilities: 0.3635562 - temperature 6.6556168
# mean max of probabilities: 0.36470273 - temperature 6.6405697
# mean max of probabilities: 0.36584505 - temperature 6.6255226
# mean max of probabilities: 0.3672159 - temperature 6.6104755
# mean max of probabilities: 0.36857265 - temperature 6.5954285
# mean max of probabilities: 0.3699076 - temperature 6.5803814
# mean max of probabilities: 0.37131262 - temperature 6.5653343
# mean max of probabilities: 0.37274048 - temperature 6.5502872
# mean max of probabilities: 0.37426534 - temperature 6.53524
# mean max of probabilities: 0.3757195 - temperature 6.520193
# mean max of probabilities: 0.37710673 - temperature 6.505146
# mean max of probabilities: 0.37889147 - temperature 6.490099
# mean max of probabilities: 0.3807503 - temperature 6.475052
# mean max of probabilities: 0.38252032 - temperature 6.460005
# mean max of probabilities: 0.38444048 - temperature 6.4449577
# mean max of probabilities: 0.3861521 - temperature 6.4299107
# mean max of probabilities: 0.3878715 - temperature 6.4148636
# mean max of probabilities: 0.38962054 - temperature 6.3998165
# mean max of probabilities: 0.39133343 - temperature 6.3847694
# mean max of probabilities: 0.3929177 - temperature 6.3697224
# mean max of probabilities: 0.3944527 - temperature 6.3546753
# mean max of probabilities: 0.39606002 - temperature 6.340579
# mean max of probabilities: 0.39740735 - temperature 6.3266068
# mean max of probabilities: 0.39884582 - temperature 6.3126345
# mean max of probabilities: 0.40017918 - temperature 6.298662
# mean max of probabilities: 0.40139753 - temperature 6.28469
# mean max of probabilities: 0.40258443 - temperature 6.2707176
# mean max of probabilities: 0.40381756 - temperature 6.2567453
# mean max of probabilities: 0.40475228 - temperature 6.242773
# mean max of probabilities: 0.4058384 - temperature 6.228801
# mean max of probabilities: 0.40668893 - temperature 6.2148285
# mean max of probabilities: 0.4076787 - temperature 6.200856
# mean max of probabilities: 0.4084952 - temperature 6.186884
# mean max of probabilities: 0.40933523 - temperature 6.1729116
# mean max of probabilities: 0.41003093 - temperature 6.1589394
# mean max of probabilities: 0.41067505 - temperature 6.144967
# mean max of probabilities: 0.41134498 - temperature 6.130995
# mean max of probabilities: 0.41205806 - temperature 6.1170225
# mean max of probabilities: 0.41290107 - temperature 6.10305
# mean max of probabilities: 0.41366595 - temperature 6.089078
# mean max of probabilities: 0.41436467 - temperature 6.0751057
# mean max of probabilities: 0.41523606 - temperature 6.0611334
# mean max of probabilities: 0.41583318 - temperature 6.047161
# mean max of probabilities: 0.41650856 - temperature 6.033189
# mean max of probabilities: 0.41710204 - temperature 6.0192165
# mean max of probabilities: 0.41779777 - temperature 6.0052443
# mean max of probabilities: 0.41834584 - temperature 5.991272
# mean max of probabilities: 0.41915628 - temperature 5.9772997
# mean max of probabilities: 0.4200038 - temperature 5.9633274
# mean max of probabilities: 0.42091683 - temperature 5.949355
# mean max of probabilities: 0.42191952 - temperature 5.935383
# mean max of probabilities: 0.42302614 - temperature 5.9214106
# mean max of probabilities: 0.42428133 - temperature 5.9074383
# mean max of probabilities: 0.42570186 - temperature 5.893466
# mean max of probabilities: 0.4270518 - temperature 5.8797135
# mean max of probabilities: 0.42833793 - temperature 5.866816
# mean max of probabilities: 0.42726356 - temperature 5.8539186
# mean max of probabilities: 0.42797935 - temperature 5.841021
# mean max of probabilities: 0.42935216 - temperature 5.8281236
# mean max of probabilities: 0.43076435 - temperature 5.815226
# mean max of probabilities: 0.43194276 - temperature 5.8023286
# mean max of probabilities: 0.43325117 - temperature 5.789431
# mean max of probabilities: 0.43436328 - temperature 5.7765336
# mean max of probabilities: 0.4354955 - temperature 5.763636
# mean max of probabilities: 0.43642047 - temperature 5.7507386
# mean max of probabilities: 0.4374004 - temperature 5.737841
# mean max of probabilities: 0.43832067 - temperature 5.7249436
# mean max of probabilities: 0.43925723 - temperature 5.712046
# mean max of probabilities: 0.4403621 - temperature 5.6991487
# mean max of probabilities: 0.44138083 - temperature 5.686251
# mean max of probabilities: 0.4423687 - temperature 5.6733537
# mean max of probabilities: 0.44331285 - temperature 5.660456
# mean max of probabilities: 0.444189 - temperature 5.6475587
# mean max of probabilities: 0.44514325 - temperature 5.634661
# mean max of probabilities: 0.4460932 - temperature 5.6217637
# mean max of probabilities: 0.44697782 - temperature 5.608866
# mean max of probabilities: 0.44795796 - temperature 5.5959687
# mean max of probabilities: 0.44899 - temperature 5.583071
# mean max of probabilities: 0.45003077 - temperature 5.5701737
# mean max of probabilities: 0.4511 - temperature 5.5572762
# mean max of probabilities: 0.45227125 - temperature 5.5443788
# mean max of probabilities: 0.45351902 - temperature 5.5314813
# mean max of probabilities: 0.45482042 - temperature 5.518584
# mean max of probabilities: 0.45597905 - temperature 5.5056863
# mean max of probabilities: 0.45722938 - temperature 5.492789
# mean max of probabilities: 0.45827362 - temperature 5.4798913
# mean max of probabilities: 0.45946765 - temperature 5.466994
# mean max of probabilities: 0.46060166 - temperature 5.4540963
# mean max of probabilities: 0.4617401 - temperature 5.441199
# mean max of probabilities: 0.46273145 - temperature 5.4283013
# mean max of probabilities: 0.46401122 - temperature 5.415404
# mean max of probabilities: 0.4649369 - temperature 5.403278
# mean max of probabilities: 0.46598324 - temperature 5.391455
# mean max of probabilities: 0.46689022 - temperature 5.3796325
# mean max of probabilities: 0.46791163 - temperature 5.36781
# mean max of probabilities: 0.4688348 - temperature 5.355987
# mean max of probabilities: 0.46980572 - temperature 5.3441644
# mean max of probabilities: 0.47067374 - temperature 5.3323417
# mean max of probabilities: 0.47156444 - temperature 5.320519
# mean max of probabilities: 0.47244012 - temperature 5.3086963
# mean max of probabilities: 0.47332925 - temperature 5.2968736
# mean max of probabilities: 0.47401643 - temperature 5.285051
# mean max of probabilities: 0.47483203 - temperature 5.273228
# mean max of probabilities: 0.475706 - temperature 5.2614055
# mean max of probabilities: 0.47657454 - temperature 5.249583
# mean max of probabilities: 0.477422 - temperature 5.23776
# mean max of probabilities: 0.4782859 - temperature 5.2259374
# mean max of probabilities: 0.4789696 - temperature 5.2141147
# mean max of probabilities: 0.4796098 - temperature 5.202292
# mean max of probabilities: 0.4803907 - temperature 5.1904693
# mean max of probabilities: 0.48096478 - temperature 5.1786466
# mean max of probabilities: 0.48140433 - temperature 5.166824
# mean max of probabilities: 0.48185807 - temperature 5.155001
# mean max of probabilities: 0.48239005 - temperature 5.1431785
# mean max of probabilities: 0.48295626 - temperature 5.131356
# mean max of probabilities: 0.48346487 - temperature 5.119533
# mean max of probabilities: 0.483943 - temperature 5.1077104
# mean max of probabilities: 0.48453435 - temperature 5.0958877
# mean max of probabilities: 0.48494878 - temperature 5.084065
# mean max of probabilities: 0.48518914 - temperature 5.0722423
# mean max of probabilities: 0.48555475 - temperature 5.0604196
# mean max of probabilities: 0.4858508 - temperature 5.048597
# mean max of probabilities: 0.48620617 - temperature 5.036774
# mean max of probabilities: 0.48656255 - temperature 5.0249515
# mean max of probabilities: 0.48677602 - temperature 5.0131288
# mean max of probabilities: 0.48720184 - temperature 5.001306
# mean max of probabilities: 0.48789048 - temperature 4.9894834
# mean max of probabilities: 0.488564 - temperature 4.9776607
# mean max of probabilities: 0.48914716 - temperature 4.965838
# mean max of probabilities: 0.48958853 - temperature 4.9540153
# mean max of probabilities: 0.4902084 - temperature 4.9421926
# mean max of probabilities: 0.49066746 - temperature 4.931352
# mean max of probabilities: 0.49119213 - temperature 4.920604
# mean max of probabilities: 0.4917547 - temperature 4.9098563
# mean max of probabilities: 0.49236977 - temperature 4.8991084
# mean max of probabilities: 0.4927276 - temperature 4.8883605
# mean max of probabilities: 0.49335426 - temperature 4.8776126
# mean max of probabilities: 0.49381015 - temperature 4.8668647
# mean max of probabilities: 0.49421084 - temperature 4.856117
# mean max of probabilities: 0.4947212 - temperature 4.845369
# mean max of probabilities: 0.4951414 - temperature 4.834621
# mean max of probabilities: 0.4955592 - temperature 4.823873
# mean max of probabilities: 0.49597383 - temperature 4.813125
# mean max of probabilities: 0.4964366 - temperature 4.802377
# mean max of probabilities: 0.49666828 - temperature 4.7916293
# mean max of probabilities: 0.4969825 - temperature 4.7808814
# mean max of probabilities: 0.49711138 - temperature 4.7701335
# mean max of probabilities: 0.497355 - temperature 4.7593856
# mean max of probabilities: 0.49787483 - temperature 4.7486377
# mean max of probabilities: 0.49825898 - temperature 4.73789
# mean max of probabilities: 0.49839827 - temperature 4.727142
# mean max of probabilities: 0.49865273 - temperature 4.716394
# mean max of probabilities: 0.49863353 - temperature 4.705646
# mean max of probabilities: 0.49881786 - temperature 4.694898
# mean max of probabilities: 0.49889195 - temperature 4.68415
# mean max of probabilities: 0.499052 - temperature 4.6734023
# mean max of probabilities: 0.49923572 - temperature 4.6626544
# mean max of probabilities: 0.49940717 - temperature 4.6519065
# mean max of probabilities: 0.49962327 - temperature 4.6411586
# mean max of probabilities: 0.49979067 - temperature 4.6304107
# mean max of probabilities: 0.4998362 - temperature 4.619663
# mean max of probabilities: 0.4999973 - temperature 4.608915
# mean max of probabilities: 0.50017416 - temperature 4.598167
# mean max of probabilities: 0.50054383 - temperature 4.587419
# mean max of probabilities: 0.5007284 - temperature 4.576671
# mean max of probabilities: 0.50095594 - temperature 4.565923
# mean max of probabilities: 0.5009533 - temperature 4.5551753
# mean max of probabilities: 0.50105333 - temperature 4.5444274
# mean max of probabilities: 0.5012856 - temperature 4.5336795
# mean max of probabilities: 0.50131977 - temperature 4.5229316
# mean max of probabilities: 0.5012354 - temperature 4.5121837
# mean max of probabilities: 0.5011485 - temperature 4.5014358
# mean max of probabilities: 0.50122935 - temperature 4.490688
# mean max of probabilities: 0.5013658 - temperature 4.47994
# mean max of probabilities: 0.50154907 - temperature 4.4693313
# mean max of probabilities: 0.5017231 - temperature 4.459658
# mean max of probabilities: 0.5017845 - temperature 4.449985
# mean max of probabilities: 0.5019622 - temperature 4.440312
# mean max of probabilities: 0.50214314 - temperature 4.430639
# mean max of probabilities: 0.5021089 - temperature 4.4209657
# mean max of probabilities: 0.50195044 - temperature 4.4112926
# mean max of probabilities: 0.5017747 - temperature 4.4016194
# mean max of probabilities: 0.50175107 - temperature 4.3919463
# mean max of probabilities: 0.50163794 - temperature 4.382273
# mean max of probabilities: 0.5014738 - temperature 4.3726
# mean max of probabilities: 0.5011954 - temperature 4.362927
# mean max of probabilities: 0.50093675 - temperature 4.353254
# mean max of probabilities: 0.5007687 - temperature 4.3435807
# mean max of probabilities: 0.5005758 - temperature 4.3339076
# mean max of probabilities: 0.5004331 - temperature 4.3242345
# mean max of probabilities: 0.50030154 - temperature 4.3145614
# mean max of probabilities: 0.5003008 - temperature 4.3048882
# mean max of probabilities: 0.50024045 - temperature 4.295215
# mean max of probabilities: 0.5001984 - temperature 4.285542
# mean max of probabilities: 0.5000894 - temperature 4.275869
# mean max of probabilities: 0.49994037 - temperature 4.266196
# mean max of probabilities: 0.499964 - temperature 4.2565227
# mean max of probabilities: 0.49979898 - temperature 4.2468495
# mean max of probabilities: 0.49931946 - temperature 4.2371764
# mean max of probabilities: 0.49911577 - temperature 4.2275033
# mean max of probabilities: 0.4989867 - temperature 4.21783
# mean max of probabilities: 0.4987639 - temperature 4.208157
# mean max of probabilities: 0.4988206 - temperature 4.198484
# mean max of probabilities: 0.49870056 - temperature 4.188811
# mean max of probabilities: 0.4990502 - temperature 4.1791377
# mean max of probabilities: 0.49917677 - temperature 4.1694646
# mean max of probabilities: 0.49944597 - temperature 4.1597915
# mean max of probabilities: 0.49962533 - temperature 4.1501184
# mean max of probabilities: 0.49974582 - temperature 4.140445
# mean max of probabilities: 0.4998074 - temperature 4.130772
# mean max of probabilities: 0.49988452 - temperature 4.121099
# mean max of probabilities: 0.50021064 - temperature 4.111426
# mean max of probabilities: 0.5002399 - temperature 4.1017528
# mean max of probabilities: 0.5003309 - temperature 4.0920796
# mean max of probabilities: 0.50013006 - temperature 4.0824065
# mean max of probabilities: 0.5003286 - temperature 4.0727334
# mean max of probabilities: 0.50046206 - temperature 4.0630603
# mean max of probabilities: 0.5004601 - temperature 4.053387
# mean max of probabilities: 0.50051415 - temperature 4.043714
# mean max of probabilities: 0.5007573 - temperature 4.034041
# mean max of probabilities: 0.50069255 - temperature 4.024368
# mean max of probabilities: 0.500796 - temperature 4.0146947
# mean max of probabilities: 0.50092775 - temperature 4.0050216
# mean max of probabilities: 0.5007352 - temperature 3.995607
# mean max of probabilities: 0.5009945 - temperature 3.9864712
# mean max of probabilities: 0.5009395 - temperature 3.9773355
# mean max of probabilities: 0.5011038 - temperature 3.9681997
# mean max of probabilities: 0.50094694 - temperature 3.959064
# mean max of probabilities: 0.5010943 - temperature 3.9499283
# mean max of probabilities: 0.5008191 - temperature 3.9407926
# mean max of probabilities: 0.5007022 - temperature 3.9316568
# mean max of probabilities: 0.50094527 - temperature 3.922521
# mean max of probabilities: 0.50073653 - temperature 3.9133854
# mean max of probabilities: 0.5009555 - temperature 3.9042497
# mean max of probabilities: 0.50102353 - temperature 3.895114
# mean max of probabilities: 0.50107545 - temperature 3.8859782
# mean max of probabilities: 0.5010674 - temperature 3.8771665
# mean max of probabilities: 0.5011765 - temperature 3.8685682
# mean max of probabilities: 0.5013269 - temperature 3.8599699
# mean max of probabilities: 0.501508 - temperature 3.8513715
# mean max of probabilities: 0.5013748 - temperature 3.8427732
# mean max of probabilities: 0.5010266 - temperature 3.8341749
# mean max of probabilities: 0.5005741 - temperature 3.8255765
# mean max of probabilities: 0.5002618 - temperature 3.8169782
# mean max of probabilities: 0.5001203 - temperature 3.80838
# mean max of probabilities: 0.49972096 - temperature 3.7997816
# mean max of probabilities: 0.49961656 - temperature 3.7911832
# mean max of probabilities: 0.49950364 - temperature 3.782585
# mean max of probabilities: 0.4992485 - temperature 3.7739866
# mean max of probabilities: 0.49879357 - temperature 3.7653883
# mean max of probabilities: 0.49818438 - temperature 3.75679
# mean max of probabilities: 0.49781898 - temperature 3.7481916
# mean max of probabilities: 0.4977116 - temperature 3.7395933
# mean max of probabilities: 0.4978498 - temperature 3.730995
# mean max of probabilities: 0.4978996 - temperature 3.7223966
# mean max of probabilities: 0.49821106 - temperature 3.7137983
# mean max of probabilities: 0.49843705 - temperature 3.7052
# mean max of probabilities: 0.49854377 - temperature 3.6966016
# mean max of probabilities: 0.49855164 - temperature 3.6880033
# mean max of probabilities: 0.49896514 - temperature 3.679405
# mean max of probabilities: 0.49910286 - temperature 3.6708066
# mean max of probabilities: 0.49939743 - temperature 3.6622083
# mean max of probabilities: 0.4997027 - temperature 3.65361
# mean max of probabilities: 0.50006855 - temperature 3.6451395
# mean max of probabilities: 0.5002685 - temperature 3.6370785
# mean max of probabilities: 0.50049436 - temperature 3.6290176
# mean max of probabilities: 0.5003526 - temperature 3.6209567
# mean max of probabilities: 0.5005924 - temperature 3.6128957
# mean max of probabilities: 0.5005876 - temperature 3.6048348
# mean max of probabilities: 0.50019825 - temperature 3.5967739
# mean max of probabilities: 0.50017136 - temperature 3.588713
# mean max of probabilities: 0.5002592 - temperature 3.580652
# mean max of probabilities: 0.5002572 - temperature 3.572591
# mean max of probabilities: 0.5001732 - temperature 3.5645301
# mean max of probabilities: 0.50038826 - temperature 3.5564692
# mean max of probabilities: 0.5003581 - temperature 3.5484083
# mean max of probabilities: 0.50055796 - temperature 3.5403473
# mean max of probabilities: 0.50066125 - temperature 3.5322864
# mean max of probabilities: 0.5010841 - temperature 3.5242255
# mean max of probabilities: 0.50150996 - temperature 3.5161645
# mean max of probabilities: 0.5019522 - temperature 3.5081036
# mean max of probabilities: 0.5022418 - temperature 3.5000427
# mean max of probabilities: 0.50224715 - temperature 3.4919817
# mean max of probabilities: 0.5020786 - temperature 3.4839208
# mean max of probabilities: 0.5026604 - temperature 3.4758599
# mean max of probabilities: 0.50294906 - temperature 3.467799
# mean max of probabilities: 0.50294334 - temperature 3.459738
# mean max of probabilities: 0.50295067 - temperature 3.451677
# mean max of probabilities: 0.5027859 - temperature 3.4436162
# mean max of probabilities: 0.50262386 - temperature 3.4355552
# mean max of probabilities: 0.5026292 - temperature 3.4274943
# mean max of probabilities: 0.5026196 - temperature 3.4194334
# mean max of probabilities: 0.50193423 - temperature 3.4113984
# mean max of probabilities: 0.5020044 - temperature 3.4038749
# mean max of probabilities: 0.5015817 - temperature 3.3963513
# mean max of probabilities: 0.50174886 - temperature 3.3888278
# mean max of probabilities: 0.5014071 - temperature 3.3813043
# mean max of probabilities: 0.50139004 - temperature 3.3737807
# mean max of probabilities: 0.50162005 - temperature 3.3662572
# mean max of probabilities: 0.50189245 - temperature 3.3587337
# mean max of probabilities: 0.50192565 - temperature 3.35121
# mean max of probabilities: 0.5019158 - temperature 3.3436866
# mean max of probabilities: 0.5026702 - temperature 3.336163
# mean max of probabilities: 0.5026487 - temperature 3.3286395
# mean max of probabilities: 0.5029428 - temperature 3.321116
# mean max of probabilities: 0.50330263 - temperature 3.3135924
# mean max of probabilities: 0.5032749 - temperature 3.306069
# mean max of probabilities: 0.5035844 - temperature 3.2985454
# mean max of probabilities: 0.5037678 - temperature 3.2910218
# mean max of probabilities: 0.5037042 - temperature 3.2834983
# mean max of probabilities: 0.5038589 - temperature 3.2759748
# mean max of probabilities: 0.5037955 - temperature 3.2684512
# mean max of probabilities: 0.5039455 - temperature 3.2609277
# mean max of probabilities: 0.50397426 - temperature 3.2534041
# mean max of probabilities: 0.5041673 - temperature 3.2458806
# mean max of probabilities: 0.50448453 - temperature 3.238357
# mean max of probabilities: 0.5046786 - temperature 3.2308335
# mean max of probabilities: 0.50487494 - temperature 3.22331
# mean max of probabilities: 0.50554013 - temperature 3.2157865
# mean max of probabilities: 0.5057089 - temperature 3.208263
# mean max of probabilities: 0.5059161 - temperature 3.2007394
# mean max of probabilities: 0.5061325 - temperature 3.1932158
# mean max of probabilities: 0.50637794 - temperature 3.1856923
# mean max of probabilities: 0.50679374 - temperature 3.1781688
# mean max of probabilities: 0.5071999 - temperature 3.1710613
# mean max of probabilities: 0.5077921 - temperature 3.1640751
# mean max of probabilities: 0.5078093 - temperature 3.157089
# mean max of probabilities: 0.5080667 - temperature 3.1501029
# mean max of probabilities: 0.5078741 - temperature 3.1431167
# mean max of probabilities: 0.507912 - temperature 3.1361306
# mean max of probabilities: 0.50818986 - temperature 3.1291444
# mean max of probabilities: 0.5080536 - temperature 3.1221583
# mean max of probabilities: 0.5084012 - temperature 3.1151721
# mean max of probabilities: 0.50894433 - temperature 3.108186
# mean max of probabilities: 0.5089498 - temperature 3.1011999
# mean max of probabilities: 0.50906616 - temperature 3.0942137
# mean max of probabilities: 0.5088164 - temperature 3.0872276
# mean max of probabilities: 0.5086909 - temperature 3.0802414
# mean max of probabilities: 0.50858957 - temperature 3.0732553
# mean max of probabilities: 0.50850135 - temperature 3.0662692
# mean max of probabilities: 0.5084435 - temperature 3.059283
# mean max of probabilities: 0.5085503 - temperature 3.0522969
# mean max of probabilities: 0.5080127 - temperature 3.0453107
# mean max of probabilities: 0.5076956 - temperature 3.0383246
# mean max of probabilities: 0.5075611 - temperature 3.0313385
# mean max of probabilities: 0.5071665 - temperature 3.0243523
# mean max of probabilities: 0.50717455 - temperature 3.0173662
# mean max of probabilities: 0.5068256 - temperature 3.01038
# mean max of probabilities: 0.50667626 - temperature 3.003394
# mean max of probabilities: 0.50641644 - temperature 2.9964077
# mean max of probabilities: 0.50607145 - temperature 2.9894216
# mean max of probabilities: 0.50573874 - temperature 2.9824355
# mean max of probabilities: 0.5055322 - temperature 2.9754493
# mean max of probabilities: 0.50535 - temperature 2.9684632
# mean max of probabilities: 0.5052669 - temperature 2.961477
# mean max of probabilities: 0.50466627 - temperature 2.954491
# mean max of probabilities: 0.50450623 - temperature 2.9475048
# mean max of probabilities: 0.5042643 - temperature 2.9405692
# mean max of probabilities: 0.504236 - temperature 2.9341204
# mean max of probabilities: 0.50398105 - temperature 2.9276717
# mean max of probabilities: 0.5038626 - temperature 2.921223
# mean max of probabilities: 0.50382173 - temperature 2.9147742
# mean max of probabilities: 0.5029904 - temperature 2.9083254
# mean max of probabilities: 0.5029695 - temperature 2.9018767
# mean max of probabilities: 0.5024364 - temperature 2.895428
# mean max of probabilities: 0.50176483 - temperature 2.8889792
# mean max of probabilities: 0.5011068 - temperature 2.8825305
# mean max of probabilities: 0.5006796 - temperature 2.8760817
# mean max of probabilities: 0.5008306 - temperature 2.869633
# mean max of probabilities: 0.50056785 - temperature 2.8631842
# mean max of probabilities: 0.500288 - temperature 2.8567355
# mean max of probabilities: 0.50009054 - temperature 2.8502867
# mean max of probabilities: 0.49985307 - temperature 2.843838
# mean max of probabilities: 0.49969336 - temperature 2.8373892
# mean max of probabilities: 0.4994664 - temperature 2.8309405
# mean max of probabilities: 0.4987881 - temperature 2.8244917
# mean max of probabilities: 0.4982112 - temperature 2.818043
# mean max of probabilities: 0.49756137 - temperature 2.8115942
# mean max of probabilities: 0.49704784 - temperature 2.8051455
# mean max of probabilities: 0.49656385 - temperature 2.7986968
# mean max of probabilities: 0.4957988 - temperature 2.792248
# mean max of probabilities: 0.4951979 - temperature 2.7857993
# mean max of probabilities: 0.49419755 - temperature 2.7793505
# mean max of probabilities: 0.49308723 - temperature 2.7729018
# mean max of probabilities: 0.4922435 - temperature 2.766453
# mean max of probabilities: 0.49135864 - temperature 2.7600043
# mean max of probabilities: 0.4909721 - temperature 2.7535555
# mean max of probabilities: 0.4905804 - temperature 2.7471068
# mean max of probabilities: 0.49016273 - temperature 2.740658
# mean max of probabilities: 0.48947465 - temperature 2.7342093
# mean max of probabilities: 0.4888317 - temperature 2.7277606
# mean max of probabilities: 0.48816139 - temperature 2.7213118
# mean max of probabilities: 0.48772836 - temperature 2.714863
# mean max of probabilities: 0.48762175 - temperature 2.7084143
# mean max of probabilities: 0.48674473 - temperature 2.702292
# mean max of probabilities: 0.4859348 - temperature 2.6963806
# mean max of probabilities: 0.48519897 - temperature 2.6904693
# mean max of probabilities: 0.48464546 - temperature 2.684558
# mean max of probabilities: 0.4842079 - temperature 2.6786466
# mean max of probabilities: 0.48363054 - temperature 2.6727352
# mean max of probabilities: 0.4829209 - temperature 2.6668239
# mean max of probabilities: 0.48199192 - temperature 2.6609125
# mean max of probabilities: 0.48144665 - temperature 2.6550012
# mean max of probabilities: 0.48124838 - temperature 2.6490898
# mean max of probabilities: 0.4804489 - temperature 2.6431785
# mean max of probabilities: 0.47965616 - temperature 2.637267
# mean max of probabilities: 0.47912318 - temperature 2.6313558
# mean max of probabilities: 0.47837844 - temperature 2.6254444
# mean max of probabilities: 0.4780237 - temperature 2.619533
# mean max of probabilities: 0.4773759 - temperature 2.6136217
# mean max of probabilities: 0.47687387 - temperature 2.6077104
# mean max of probabilities: 0.47671717 - temperature 2.601799
# mean max of probabilities: 0.47625947 - temperature 2.5958877
# mean max of probabilities: 0.47589263 - temperature 2.5899763
# mean max of probabilities: 0.4752252 - temperature 2.584065
# mean max of probabilities: 0.47475109 - temperature 2.5781536
# mean max of probabilities: 0.47390002 - temperature 2.5722423
# mean max of probabilities: 0.47354412 - temperature 2.566331
# mean max of probabilities: 0.47332814 - temperature 2.5604196
# mean max of probabilities: 0.47281206 - temperature 2.5545082
# mean max of probabilities: 0.47234157 - temperature 2.5485969
# mean max of probabilities: 0.4721374 - temperature 2.5426855
# mean max of probabilities: 0.4716356 - temperature 2.5367742
# mean max of probabilities: 0.47104824 - temperature 2.5308628
# mean max of probabilities: 0.4707271 - temperature 2.5249515
# mean max of probabilities: 0.47012615 - temperature 2.51904
# mean max of probabilities: 0.46978325 - temperature 2.5131288
# mean max of probabilities: 0.4694095 - temperature 2.5072174
# mean max of probabilities: 0.46902233 - temperature 2.501306
# mean max of probabilities: 0.46857938 - temperature 2.4953947
# mean max of probabilities: 0.46819046 - temperature 2.4894834
# mean max of probabilities: 0.46744496 - temperature 2.483572
# mean max of probabilities: 0.4669837 - temperature 2.4776607
# mean max of probabilities: 0.4660874 - temperature 2.4717493
# mean max of probabilities: 0.46585158 - temperature 2.4662697
# mean max of probabilities: 0.4652617 - temperature 2.4608958
# mean max of probabilities: 0.4648069 - temperature 2.4555218
# mean max of probabilities: 0.46425173 - temperature 2.4501479
# mean max of probabilities: 0.46374443 - temperature 2.444774
# mean max of probabilities: 0.46297866 - temperature 2.4394
# mean max of probabilities: 0.46307755 - temperature 2.434026
# mean max of probabilities: 0.46305037 - temperature 2.428652
# mean max of probabilities: 0.4626693 - temperature 2.423278
# mean max of probabilities: 0.4624731 - temperature 2.4179041
# mean max of probabilities: 0.46221632 - temperature 2.4125302
# mean max of probabilities: 0.46176413 - temperature 2.4071562
# mean max of probabilities: 0.46158838 - temperature 2.4017823
# mean max of probabilities: 0.46120977 - temperature 2.3964083
# mean max of probabilities: 0.46059856 - temperature 2.3910344
# mean max of probabilities: 0.45996162 - temperature 2.3856604
# mean max of probabilities: 0.45966622 - temperature 2.3802865
# mean max of probabilities: 0.45913038 - temperature 2.3749125
# mean max of probabilities: 0.4593595 - temperature 2.3695385
# mean max of probabilities: 0.4589964 - temperature 2.3641646
# mean max of probabilities: 0.45933038 - temperature 2.3587906
# mean max of probabilities: 0.4596 - temperature 2.3534167
# mean max of probabilities: 0.46006662 - temperature 2.3480427
# mean max of probabilities: 0.45981652 - temperature 2.3426688
# mean max of probabilities: 0.45995897 - temperature 2.3372948
# mean max of probabilities: 0.46035418 - temperature 2.3319209
# mean max of probabilities: 0.4603808 - temperature 2.326547
# mean max of probabilities: 0.4606216 - temperature 2.321173
# mean max of probabilities: 0.46100086 - temperature 2.315799
# mean max of probabilities: 0.461423 - temperature 2.310425
# mean max of probabilities: 0.46113762 - temperature 2.305051
# mean max of probabilities: 0.4611843 - temperature 2.2996771
# mean max of probabilities: 0.46107632 - temperature 2.2943032
# mean max of probabilities: 0.46102864 - temperature 2.2889292
# mean max of probabilities: 0.46100214 - temperature 2.2835553
# mean max of probabilities: 0.4610745 - temperature 2.2781813
# mean max of probabilities: 0.46145815 - temperature 2.2728074
# mean max of probabilities: 0.46156526 - temperature 2.2674334
# mean max of probabilities: 0.45823672 - temperature 2.2620595
# mean max of probabilities: 0.45839775 - temperature 2.2566855
# mean max of probabilities: 0.4588695 - temperature 2.2513115
# mean max of probabilities: 0.4596525 - temperature 2.2459376
# mean max of probabilities: 0.4603997 - temperature 2.2405636
# mean max of probabilities: 0.46140623 - temperature 2.2352
# mean max of probabilities: 0.4618705 - temperature 2.2303634
# mean max of probabilities: 0.46207973 - temperature 2.2255268
# mean max of probabilities: 0.46232098 - temperature 2.2206903
# mean max of probabilities: 0.46254423 - temperature 2.2158537
# mean max of probabilities: 0.46232942 - temperature 2.2110171
# mean max of probabilities: 0.4628859 - temperature 2.2061806
# mean max of probabilities: 0.46294403 - temperature 2.201344
# mean max of probabilities: 0.46316153 - temperature 2.1965075
# mean max of probabilities: 0.4634344 - temperature 2.191671
# mean max of probabilities: 0.46328864 - temperature 2.1868343
# mean max of probabilities: 0.46359912 - temperature 2.1819978
# mean max of probabilities: 0.4640452 - temperature 2.1771612
# mean max of probabilities: 0.4643427 - temperature 2.1723247
# mean max of probabilities: 0.464905 - temperature 2.167488
# mean max of probabilities: 0.46525627 - temperature 2.1626515
# mean max of probabilities: 0.46561563 - temperature 2.157815
# mean max of probabilities: 0.4658203 - temperature 2.1529784
# mean max of probabilities: 0.46617964 - temperature 2.1481419
# mean max of probabilities: 0.4666177 - temperature 2.1433053
# mean max of probabilities: 0.4667351 - temperature 2.1384687
# mean max of probabilities: 0.4670245 - temperature 2.1336322
# mean max of probabilities: 0.46776992 - temperature 2.1287956
# mean max of probabilities: 0.46822986 - temperature 2.123959
# mean max of probabilities: 0.46844977 - temperature 2.1191225
# mean max of probabilities: 0.4680941 - temperature 2.114286
# mean max of probabilities: 0.46822453 - temperature 2.1094494
# mean max of probabilities: 0.46900558 - temperature 2.1046128
# mean max of probabilities: 0.46917984 - temperature 2.0997763
# mean max of probabilities: 0.46872896 - temperature 2.0949397
# mean max of probabilities: 0.4688145 - temperature 2.0901031
# mean max of probabilities: 0.46928918 - temperature 2.0852666
# mean max of probabilities: 0.46932903 - temperature 2.08043
# mean max of probabilities: 0.46937138 - temperature 2.0755935
# mean max of probabilities: 0.46952188 - temperature 2.070757
# mean max of probabilities: 0.46968654 - temperature 2.0659204
# mean max of probabilities: 0.47042713 - temperature 2.0610838
# mean max of probabilities: 0.47070333 - temperature 2.0562472
# mean max of probabilities: 0.4660454 - temperature 2.0514107
# mean max of probabilities: 0.46646973 - temperature 2.046574
# mean max of probabilities: 0.46773905 - temperature 2.0417376
# mean max of probabilities: 0.4688444 - temperature 2.036901
# mean max of probabilities: 0.46943596 - temperature 2.0320644
# mean max of probabilities: 0.46954358 - temperature 2.0272279
# mean max of probabilities: 0.47011036 - temperature 2.0223913
# mean max of probabilities: 0.4701609 - temperature 2.0175548
# mean max of probabilities: 0.4700885 - temperature 2.0127182
# mean max of probabilities: 0.4705592 - temperature 2.0078816
# mean max of probabilities: 0.4705968 - temperature 2.003045
# mean max of probabilities: 0.4711203 - temperature 1.9983081
# mean max of probabilities: 0.471593 - temperature 1.9937402
# mean max of probabilities: 0.47156563 - temperature 1.9891723
# mean max of probabilities: 0.4712951 - temperature 1.9846045
# mean max of probabilities: 0.47120315 - temperature 1.9800366
# mean max of probabilities: 0.4709012 - temperature 1.9754688
# mean max of probabilities: 0.47083429 - temperature 1.9709009
# mean max of probabilities: 0.470576 - temperature 1.966333
# mean max of probabilities: 0.47057295 - temperature 1.9617652
# mean max of probabilities: 0.47045612 - temperature 1.9571973
# mean max of probabilities: 0.4704244 - temperature 1.9526294
# mean max of probabilities: 0.47065958 - temperature 1.9480616
# mean max of probabilities: 0.47068256 - temperature 1.9434937
# mean max of probabilities: 0.4709076 - temperature 1.9390582
# mean max of probabilities: 0.47089714 - temperature 1.934759
# mean max of probabilities: 0.47077626 - temperature 1.9304599
# mean max of probabilities: 0.47082812 - temperature 1.9261607
# mean max of probabilities: 0.4712445 - temperature 1.9218615
# mean max of probabilities: 0.47123012 - temperature 1.9175624
# mean max of probabilities: 0.47091034 - temperature 1.9132632
# mean max of probabilities: 0.4709635 - temperature 1.908964
# mean max of probabilities: 0.47067973 - temperature 1.9046649
# mean max of probabilities: 0.4709844 - temperature 1.9003657
# mean max of probabilities: 0.47073323 - temperature 1.8960665
# mean max of probabilities: 0.47081235 - temperature 1.8917674
# mean max of probabilities: 0.47104686 - temperature 1.8874682
# mean max of probabilities: 0.47145113 - temperature 1.883169
# mean max of probabilities: 0.4718255 - temperature 1.8788699
# mean max of probabilities: 0.4719643 - temperature 1.8745707
# mean max of probabilities: 0.47223517 - temperature 1.8702716
# mean max of probabilities: 0.47220552 - temperature 1.8659724
# mean max of probabilities: 0.47257784 - temperature 1.8616732
# mean max of probabilities: 0.47292727 - temperature 1.8573741
# mean max of probabilities: 0.47322565 - temperature 1.8530749
# mean max of probabilities: 0.47375396 - temperature 1.8487757
# mean max of probabilities: 0.47388193 - temperature 1.8444766
# mean max of probabilities: 0.4740974 - temperature 1.8401774
# mean max of probabilities: 0.47451288 - temperature 1.8358783
# mean max of probabilities: 0.4750102 - temperature 1.8315791
# mean max of probabilities: 0.47537774 - temperature 1.8272799
# mean max of probabilities: 0.47614166 - temperature 1.823015
# mean max of probabilities: 0.47606984 - temperature 1.8189845
# mean max of probabilities: 0.4765278 - temperature 1.814954
# mean max of probabilities: 0.47346118 - temperature 1.8109236
# mean max of probabilities: 0.47380915 - temperature 1.8068931
# mean max of probabilities: 0.47424904 - temperature 1.8028626
# mean max of probabilities: 0.47507074 - temperature 1.7988322
# mean max of probabilities: 0.47553647 - temperature 1.7948017
# mean max of probabilities: 0.475911 - temperature 1.7907712
# mean max of probabilities: 0.4760149 - temperature 1.7867408
# ...
# mean max of probabilities: 0.99980646 - temperature 0.18528526
# mean max of probabilities: 0.999807 - temperature 0.18484862
# mean max of probabilities: 0.99980706 - temperature 0.18441199
# mean max of probabilities: 0.9998075 - temperature 0.18397535
# mean max of probabilities: 0.99980867 - temperature 0.18356062
# mean max of probabilities: 0.99980885 - temperature 0.18315758
# mean max of probabilities: 0.9998097 - temperature 0.18275453
# mean max of probabilities: 0.99981076 - temperature 0.18235148
# mean max of probabilities: 0.99981177 - temperature 0.18194844
# mean max of probabilities: 0.99981207 - temperature 0.18154539
# mean max of probabilities: 0.99981266 - temperature 0.18114235
# mean max of probabilities: 0.9998141 - temperature 0.1807393
# mean max of probabilities: 0.99981385 - temperature 0.18033625
# mean max of probabilities: 0.9998147 - temperature 0.1799332
# mean max of probabilities: 0.9998155 - temperature 0.17953016
# mean max of probabilities: 0.9998158 - temperature 0.17912711
# mean max of probabilities: 0.9998155 - temperature 0.17872407
# mean max of probabilities: 0.9998159 - temperature 0.17832102
# mean max of probabilities: 0.99981636 - temperature 0.17791797
# mean max of probabilities: 0.999819 - temperature 0.17751493
# mean max of probabilities: 0.999819 - temperature 0.17711188
# mean max of probabilities: 0.9998195 - temperature 0.17670883
# mean max of probabilities: 0.99982 - temperature 0.17630579
# mean max of probabilities: 0.9998202 - temperature 0.17590274
# mean max of probabilities: 0.9998214 - temperature 0.1754997
# mean max of probabilities: 0.9998213 - temperature 0.17509665
# mean max of probabilities: 0.99982166 - temperature 0.1746936
# mean max of probabilities: 0.99982166 - temperature 0.17429055
# mean max of probabilities: 0.9998224 - temperature 0.1738875
# mean max of probabilities: 0.9998219 - temperature 0.17348446
# mean max of probabilities: 0.99982166 - temperature 0.17308141
# mean max of probabilities: 0.999822 - temperature 0.17267837
# mean max of probabilities: 0.9998225 - temperature 0.17227532
# mean max of probabilities: 0.99982285 - temperature 0.17187227
# mean max of probabilities: 0.9998228 - temperature 0.17146923
# mean max of probabilities: 0.9998224 - temperature 0.17106618
# mean max of probabilities: 0.9998229 - temperature 0.17066313
# mean max of probabilities: 0.9998234 - temperature 0.17026009
# mean max of probabilities: 0.9998232 - temperature 0.16985704
# mean max of probabilities: 0.99982375 - temperature 0.169454
# mean max of probabilities: 0.9998236 - temperature 0.1690565
# mean max of probabilities: 0.999824 - temperature 0.16868705
# mean max of probabilities: 0.99982476 - temperature 0.16831759
# mean max of probabilities: 0.9998247 - temperature 0.16794813
# mean max of probabilities: 0.9998248 - temperature 0.16757867
# mean max of probabilities: 0.99982554 - temperature 0.16720921
# mean max of probabilities: 0.99982506 - temperature 0.16683975
# mean max of probabilities: 0.999826 - temperature 0.16647029
# mean max of probabilities: 0.9998252 - temperature 0.16610083
# mean max of probabilities: 0.99982476 - temperature 0.16573137
# mean max of probabilities: 0.9998244 - temperature 0.16536191
# mean max of probabilities: 0.99982464 - temperature 0.16499245
# mean max of probabilities: 0.99982476 - temperature 0.16462299
# mean max of probabilities: 0.99982375 - temperature 0.16425353
# mean max of probabilities: 0.9998246 - temperature 0.16388407
# mean max of probabilities: 0.99982667 - temperature 0.16351461
# mean max of probabilities: 0.99982727 - temperature 0.16314515
# mean max of probabilities: 0.9998273 - temperature 0.1627757
# mean max of probabilities: 0.99982804 - temperature 0.16240624
# mean max of probabilities: 0.9998282 - temperature 0.16203678
# mean max of probabilities: 0.9998291 - temperature 0.16166732
# mean max of probabilities: 0.9998297 - temperature 0.16129786
# mean max of probabilities: 0.99983007 - temperature 0.1609284
# mean max of probabilities: 0.9998298 - temperature 0.16055894
# mean max of probabilities: 0.9998311 - temperature 0.16018948
# mean max of probabilities: 0.9998319 - temperature 0.15982002
# mean max of probabilities: 0.9998317 - temperature 0.15945056
# mean max of probabilities: 0.9998317 - temperature 0.1590811
# mean max of probabilities: 0.999832 - temperature 0.15871164
# mean max of probabilities: 0.9998325 - temperature 0.15834218
# mean max of probabilities: 0.9998328 - temperature 0.15797272
# mean max of probabilities: 0.9998329 - temperature 0.15760326
# mean max of probabilities: 0.99983263 - temperature 0.1572338
# mean max of probabilities: 0.9998326 - temperature 0.15686435
# mean max of probabilities: 0.9998331 - temperature 0.15649489
# mean max of probabilities: 0.99983287 - temperature 0.15612543
# mean max of probabilities: 0.99983376 - temperature 0.15575597
# mean max of probabilities: 0.9998333 - temperature 0.15538651
# mean max of probabilities: 0.9998329 - temperature 0.15501705
# mean max of probabilities: 0.99983406 - temperature 0.15464759
# mean max of probabilities: 0.99983364 - temperature 0.15429027
# mean max of probabilities: 0.99983376 - temperature 0.1539544
# mean max of probabilities: 0.99983275 - temperature 0.15361853
# mean max of probabilities: 0.99983305 - temperature 0.15328266
# mean max of probabilities: 0.99983376 - temperature 0.15294679
# mean max of probabilities: 0.9998342 - temperature 0.15261091
# mean max of probabilities: 0.9998343 - temperature 0.15227504
# mean max of probabilities: 0.9998343 - temperature 0.15193917
# mean max of probabilities: 0.9998347 - temperature 0.1516033
# mean max of probabilities: 0.99983436 - temperature 0.15126742
# mean max of probabilities: 0.99983484 - temperature 0.15093155
# mean max of probabilities: 0.9998348 - temperature 0.15059568
# mean max of probabilities: 0.9998343 - temperature 0.15025981
# mean max of probabilities: 0.9998338 - temperature 0.14992394
# mean max of probabilities: 0.9998346 - temperature 0.14958806
# mean max of probabilities: 0.9998351 - temperature 0.14925219
# mean max of probabilities: 0.9998344 - temperature 0.14891632
# mean max of probabilities: 0.99983495 - temperature 0.14858045
# mean max of probabilities: 0.99983585 - temperature 0.14824457
# mean max of probabilities: 0.99983615 - temperature 0.1479087
# mean max of probabilities: 0.9998367 - temperature 0.14757283
# mean max of probabilities: 0.9998377 - temperature 0.14723696
# mean max of probabilities: 0.9998374 - temperature 0.14690109
# mean max of probabilities: 0.99983734 - temperature 0.14656521
# mean max of probabilities: 0.99983793 - temperature 0.14622934
# mean max of probabilities: 0.999839 - temperature 0.14589347
# mean max of probabilities: 0.9998393 - temperature 0.1455576
# mean max of probabilities: 0.9998403 - temperature 0.14522173
# mean max of probabilities: 0.9998411 - temperature 0.14488585
# mean max of probabilities: 0.99984163 - temperature 0.14454998
# mean max of probabilities: 0.99984175 - temperature 0.14421411
# mean max of probabilities: 0.99984145 - temperature 0.14387824
# mean max of probabilities: 0.9998419 - temperature 0.14354236
# mean max of probabilities: 0.9998422 - temperature 0.14320649
# mean max of probabilities: 0.9998432 - temperature 0.14287062
# mean max of probabilities: 0.9998448 - temperature 0.14253475
# mean max of probabilities: 0.9998453 - temperature 0.14219888
# mean max of probabilities: 0.99984485 - temperature 0.141863
# mean max of probabilities: 0.9998449 - temperature 0.14152713
# mean max of probabilities: 0.99984527 - temperature 0.14119126
# mean max of probabilities: 0.9998456 - temperature 0.14085539
# mean max of probabilities: 0.99984586 - temperature 0.14051951
# mean max of probabilities: 0.99984586 - temperature 0.14018364
# mean max of probabilities: 0.9998461 - temperature 0.13984777
# mean max of probabilities: 0.99984574 - temperature 0.13953128
# mean max of probabilities: 0.9998466 - temperature 0.139229
# mean max of probabilities: 0.99984705 - temperature 0.13892671
# mean max of probabilities: 0.9998472 - temperature 0.13862443
# mean max of probabilities: 0.9998472 - temperature 0.13832214
# mean max of probabilities: 0.9998464 - temperature 0.13801986
# mean max of probabilities: 0.9998466 - temperature 0.13771757
# mean max of probabilities: 0.99984646 - temperature 0.13741529
# mean max of probabilities: 0.999847 - temperature 0.137113
# mean max of probabilities: 0.9998471 - temperature 0.13681072
# mean max of probabilities: 0.99984753 - temperature 0.13650844
# mean max of probabilities: 0.99984825 - temperature 0.13620615
# mean max of probabilities: 0.99984854 - temperature 0.13590387
# mean max of probabilities: 0.9998486 - temperature 0.13560158
# mean max of probabilities: 0.9998481 - temperature 0.1352993
# mean max of probabilities: 0.99984837 - temperature 0.13499701
# mean max of probabilities: 0.999849 - temperature 0.13469473
# mean max of probabilities: 0.9998498 - temperature 0.13439244
# mean max of probabilities: 0.99985087 - temperature 0.13409016
# mean max of probabilities: 0.9998506 - temperature 0.13378787
# mean max of probabilities: 0.9998506 - temperature 0.13348559
# mean max of probabilities: 0.9998504 - temperature 0.1331833
# mean max of probabilities: 0.99985063 - temperature 0.13288102
# mean max of probabilities: 0.99985063 - temperature 0.13257873
# mean max of probabilities: 0.99985105 - temperature 0.13227645
# mean max of probabilities: 0.9998514 - temperature 0.13197416
# mean max of probabilities: 0.99985296 - temperature 0.13167188
# mean max of probabilities: 0.9998519 - temperature 0.13136959
# mean max of probabilities: 0.9998517 - temperature 0.1310673
# mean max of probabilities: 0.99985194 - temperature 0.13076502
# mean max of probabilities: 0.99985206 - temperature 0.13046274
# mean max of probabilities: 0.9998523 - temperature 0.13016045
# mean max of probabilities: 0.9998523 - temperature 0.12985817
# mean max of probabilities: 0.99985164 - temperature 0.12955588
# mean max of probabilities: 0.9998515 - temperature 0.1292536
# mean max of probabilities: 0.99985147 - temperature 0.12895131
# mean max of probabilities: 0.9998517 - temperature 0.12864903
# mean max of probabilities: 0.9998515 - temperature 0.12834674
# mean max of probabilities: 0.9998525 - temperature 0.12804446
# mean max of probabilities: 0.99985313 - temperature 0.12774217
# mean max of probabilities: 0.99985397 - temperature 0.12743989
# mean max of probabilities: 0.99985427 - temperature 0.1271376
# mean max of probabilities: 0.99985456 - temperature 0.12683532
# mean max of probabilities: 0.9998547 - temperature 0.12653303
# mean max of probabilities: 0.999855 - temperature 0.12623075
# mean max of probabilities: 0.9998557 - temperature 0.12592846
# mean max of probabilities: 0.9998557 - temperature 0.12562618
# mean max of probabilities: 0.9998559 - temperature 0.12532389
# mean max of probabilities: 0.9998557 - temperature 0.1250216
# mean max of probabilities: 0.9998555 - temperature 0.124734916
# mean max of probabilities: 0.99985594 - temperature 0.124449424
# mean max of probabilities: 0.9998564 - temperature 0.12416393
# mean max of probabilities: 0.9998569 - temperature 0.12387844
# mean max of probabilities: 0.9998571 - temperature 0.12359295
# mean max of probabilities: 0.99985635 - temperature 0.12330746
# mean max of probabilities: 0.9998574 - temperature 0.12302197
# mean max of probabilities: 0.99985635 - temperature 0.12273648
# mean max of probabilities: 0.9998566 - temperature 0.122450985
# mean max of probabilities: 0.9998569 - temperature 0.12216549
# mean max of probabilities: 0.9998573 - temperature 0.12188
# mean max of probabilities: 0.99985653 - temperature 0.12159451
# mean max of probabilities: 0.99985725 - temperature 0.12130987
# mean max of probabilities: 0.99985826 - temperature 0.12104117
# mean max of probabilities: 0.9998593 - temperature 0.12077247
# mean max of probabilities: 0.9998602 - temperature 0.120503776
# mean max of probabilities: 0.9998606 - temperature 0.12023508
# mean max of probabilities: 0.99986047 - temperature 0.11996638
# mean max of probabilities: 0.99986064 - temperature 0.11969768
# mean max of probabilities: 0.99986124 - temperature 0.119428985
# mean max of probabilities: 0.9998616 - temperature 0.11916029
# mean max of probabilities: 0.9998622 - temperature 0.11889159
# mean max of probabilities: 0.99986243 - temperature 0.11862289
# mean max of probabilities: 0.99986196 - temperature 0.118354194
# mean max of probabilities: 0.99986213 - temperature 0.118085496
# mean max of probabilities: 0.99986225 - temperature 0.1178168
# mean max of probabilities: 0.99986243 - temperature 0.1175481
# mean max of probabilities: 0.9998629 - temperature 0.1172794
# mean max of probabilities: 0.99986315 - temperature 0.117010705
# mean max of probabilities: 0.9998631 - temperature 0.11674201
# mean max of probabilities: 0.9998636 - temperature 0.11647331
# mean max of probabilities: 0.99986386 - temperature 0.11620461
# mean max of probabilities: 0.9998648 - temperature 0.115935914
# mean max of probabilities: 0.99986464 - temperature 0.11566722
# mean max of probabilities: 0.9998649 - temperature 0.11539852
# mean max of probabilities: 0.99986506 - temperature 0.11512982
# mean max of probabilities: 0.99986553 - temperature 0.11486112
# mean max of probabilities: 0.99986535 - temperature 0.114592426
# mean max of probabilities: 0.9998659 - temperature 0.11432373
# mean max of probabilities: 0.9998661 - temperature 0.11405503
# mean max of probabilities: 0.99986625 - temperature 0.11379784
# mean max of probabilities: 0.99986625 - temperature 0.11354594
# mean max of probabilities: 0.9998666 - temperature 0.113294035
# mean max of probabilities: 0.9998671 - temperature 0.11304213
# mean max of probabilities: 0.9998677 - temperature 0.11279023
# mean max of probabilities: 0.99986774 - temperature 0.11253832
# mean max of probabilities: 0.9998683 - temperature 0.11228642
# mean max of probabilities: 0.9998685 - temperature 0.112034515
# mean max of probabilities: 0.99986863 - temperature 0.11178261
# mean max of probabilities: 0.99986863 - temperature 0.11153071
# mean max of probabilities: 0.9998696 - temperature 0.1112788
# mean max of probabilities: 0.99986935 - temperature 0.1110269
# mean max of probabilities: 0.9998703 - temperature 0.110774994
# mean max of probabilities: 0.99987024 - temperature 0.11052309
# mean max of probabilities: 0.99987036 - temperature 0.110271186
# mean max of probabilities: 0.9998708 - temperature 0.11001928
# mean max of probabilities: 0.99987066 - temperature 0.10976738
# mean max of probabilities: 0.9998706 - temperature 0.10951547
# mean max of probabilities: 0.99987084 - temperature 0.10926357
# mean max of probabilities: 0.9998708 - temperature 0.109011665
# mean max of probabilities: 0.9998706 - temperature 0.10875976
# mean max of probabilities: 0.9998709 - temperature 0.10850786
# mean max of probabilities: 0.99987084 - temperature 0.10825595
# mean max of probabilities: 0.9998707 - temperature 0.10800405
# mean max of probabilities: 0.9998703 - temperature 0.107752144
# mean max of probabilities: 0.9998706 - temperature 0.10750024
# mean max of probabilities: 0.99987084 - temperature 0.107248336
# mean max of probabilities: 0.99987084 - temperature 0.10699643
# mean max of probabilities: 0.9998707 - temperature 0.10674453
# mean max of probabilities: 0.99987066 - temperature 0.10650095
# mean max of probabilities: 0.9998707 - temperature 0.10626584
# mean max of probabilities: 0.9998709 - temperature 0.10603073
# mean max of probabilities: 0.99987084 - temperature 0.10579562
# mean max of probabilities: 0.99987066 - temperature 0.10556051
# mean max of probabilities: 0.9998708 - temperature 0.1053254
# mean max of probabilities: 0.9998711 - temperature 0.10509029
# mean max of probabilities: 0.9998709 - temperature 0.10485518
# mean max of probabilities: 0.9998715 - temperature 0.10462007
# mean max of probabilities: 0.9998718 - temperature 0.10438496
# mean max of probabilities: 0.9998727 - temperature 0.10414985
# mean max of probabilities: 0.9998729 - temperature 0.10391474
# mean max of probabilities: 0.99987316 - temperature 0.10367963
# mean max of probabilities: 0.99987316 - temperature 0.10344452
