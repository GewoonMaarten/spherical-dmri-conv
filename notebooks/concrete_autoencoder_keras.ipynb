# %% [markdown]
# # Concrete Autoencoders dMRI for Tensorflow

# %%
import project_path # Always import this first

# %%
from pathlib import Path

import tensorflow as tf
import pandas as pd
import os
import numpy as np
import h5py
from datetime import datetime

from utils.env import DATA_PATH
from utils.logger import logger

# %%
logger.info('Tensorflow versionL: %s', tf.__version__)
logger.info("Num GPUs Available: %s", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2021-06-12 21:02:29,332 - geometric-dl - INFO - Tensorflow versionL: 2.6.0-dev20210611 (<ipython-input-9-9638a48e88ea>:1)
# 2021-06-12 21:02:29,437 - geometric-dl - INFO - Num GPUs Available: 1 (<ipython-input-9-9638a48e88ea>:2)

# %%
PROJECT_PATH = Path().cwd().parent

# %% [markdown]
# ## MUDI data

# %%
# split dataset into batches
class MRISelectorSubjDataset(tf.keras.utils.Sequence):
    """MRI dataset to select features from."""

    def __init__(self, root_dir, dataf, headerf, subj_list, batch_size=100, shuffle=False):
        """
        Args:
            root_dir (string): Directory with the .csv files
            data (string): Data .csv file
            header (string): Header .csv file
            subj_list (list): list of all the subjects to include
        """
        
        self.root_dir = root_dir
        self.dataf = dataf
        self.headerf = headerf
        self.subj_list = subj_list
        self.batch_size = batch_size
        self.shuffle = shuffle
        
        # load the header
        subj = self.subj_list[0]
        self.header = pd.read_csv(os.path.join(self.root_dir,
                                             self.headerf), index_col=0).to_numpy()
        self.ind = self.header[np.isin(self.header[:,1],self.subj_list),0]
#         print(self.ind)
        
        self.indexes = np.arange(len(self.ind)) 

    def __len__(self):
        return int(np.ceil(len(self.ind) / float(self.batch_size)))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
#         print(indexes)

        # Find list of IDs
        list_IDs_temp = [self.ind[k] for k in indexes]
#         print(list_IDs_temp)

        # Generate data
        signals = self.__data_generation(list_IDs_temp)

        return signals, signals

    def on_epoch_end(self):
        self.indexes = np.arange(len(self.ind)) 
        'Updates indexes after each epoch'
        if self.shuffle == True:
            np.random.shuffle(self.indexes)
            
    def __data_generation(self, list_IDs_temp):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Generate data
        # X = pd.read_csv(os.path.join(self.root_dir, self.dataf), index_col=0, skiprows=lambda x: x not in list_IDs_temp).to_numpy()
        h5f = h5py.File(os.path.join(self.root_dir, self.dataf), 'r')
        X = h5f.get('data1')
        X = X[list_IDs_temp,:]

        return X

# %% [markdown]
# ## Autoencoder

# %%
from tensorflow.keras.layers import Dense, LeakyReLU
import numpy as np

def decoder(x):
    x = Dense(1344)(x)
    return x

def decoder_2l(x):
    x = Dense(800)(x)
    x = LeakyReLU(0.2)(x)
#    x = Dropout(0.1)(x)
    x = Dense(1000)(x)
    x = LeakyReLU(0.2)(x)
#    x = Dropout(0.1)(x)
    x = Dense(1344)(x)
    return x

def decoder_1l(x):
    x = Dense(1000)(x)
    x = LeakyReLU(0.2)(x)
#    x = Dropout(0.1)(x)
    x = Dense(1344)(x)
    return x

# %%
import math
from tensorflow.keras import backend as K
from tensorflow.keras import Model
from tensorflow.keras.layers import Layer, Softmax, Input
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import Constant, glorot_normal
from tensorflow.keras.optimizers import Adam

class ConcreteSelect(Layer):
    
    def __init__(self, output_dim, start_temp = 10.0, min_temp = 0.1, alpha = 0.99999, **kwargs):
        self.output_dim = output_dim
        self.start_temp = start_temp
        self.min_temp = K.constant(min_temp)
        self.alpha = K.constant(alpha)
        super(ConcreteSelect, self).__init__(**kwargs)
        
    def build(self, input_shape):
        self.temp = self.add_weight(name = 'temp', shape = [], initializer = Constant(self.start_temp), trainable = False)
        self.logits = self.add_weight(name = 'logits', shape = [self.output_dim, input_shape[1]], initializer = glorot_normal(), trainable = True)
        super(ConcreteSelect, self).build(input_shape)
        
    def call(self, X, training = None):
        uniform = K.random_uniform(self.logits.shape, K.epsilon(), 1.0)
        gumbel = -K.log(-K.log(uniform))
        temp = K.update(self.temp, K.maximum(self.min_temp, self.temp * self.alpha))
        noisy_logits = (self.logits + gumbel) / temp
        samples = K.softmax(noisy_logits)
        
        discrete_logits = K.one_hot(K.argmax(self.logits), self.logits.shape[1])
        
        self.selections = K.in_train_phase(samples, discrete_logits, training)
        Y = K.dot(X, K.transpose(self.selections))
        
        return Y
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.output_dim)
    
    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'output_dim': self.output_dim,
            'start_temp': self.start_temp,
            'min_temp': self.min_temp.numpy(),
            'alpha': self.alpha.numpy()
        })
        return config

class StopperCallback(EarlyStopping):
    
    def __init__(self, mean_max_target = 0.998):#, writer=None):
        self.mean_max_target = mean_max_target
        #self.writer = writer
        super(StopperCallback, self).__init__(monitor = '', patience = float('inf'), verbose = 1, mode = 'max')#, baseline = self.mean_max_target)
    
    def on_epoch_begin(self, epoch, logs = None):
        logger.info('mean max of probabilities: %.8f %s %.8f', self.get_monitor_value(logs), '- temperature', K.get_value(self.model.get_layer('concrete_select').temp))
        #s1 = self.get_monitor_value(logs)
        #print(s1)
        #s2 = K.get_value(self.model.get_layer('concrete_select').temp)
        #s1 = tf.summary.scalar('mean_max', s1)
        #s2 = tf.summary.scalar('temperature', s2)
        #print(s1)
        #self.writer.add_summary(s1)
        #self.writer.add_summary(s2)
        #print( K.get_value(K.max(K.softmax(self.model.get_layer('concrete_select').logits), axis = -1)))
        #print(K.get_value(K.max(self.model.get_layer('concrete_select').selections, axis = -1)))
    
    def get_monitor_value(self, logs):
        monitor_value = K.get_value(K.mean(K.max(K.softmax(self.model.get_layer('concrete_select').logits), axis = -1)))
        return monitor_value

class ConcreteAutoencoderFeatureSelector():
    
    def __init__(self, K, output_function, num_epochs = 100, learning_rate = 0.001, start_temp = 10.0, min_temp = 0.1, tryout_limit = 5, input_dim = 1344, callback=[]):#, writer=None): #batch_size = None, 
        self.K = K
        self.output_function = output_function
        self.num_epochs = num_epochs
#         self.batch_size = batch_size
        self.learning_rate = learning_rate
        self.start_temp = start_temp
        self.min_temp = min_temp
        self.tryout_limit = tryout_limit
        self.input_dim = input_dim
        self.callback = callback
        #self.writer = writer
        
    def fit(self, X, val_X=None):
#         if self.batch_size is None:
#             self.batch_size = max(len(X) // 256, 16)
        
        num_epochs = self.num_epochs
        steps_per_epoch = X.__len__()#(len(X) + self.batch_size - 1) // self.batch_size
        
        for i in range(self.tryout_limit):
            K.set_learning_phase(1)
            
            inputs = Input(shape = (self.input_dim,))#X.shape[1:])
            
            alpha = math.exp(math.log(self.min_temp / self.start_temp) / (num_epochs * steps_per_epoch))
            
            self.concrete_select = ConcreteSelect(self.K, self.start_temp, self.min_temp, alpha, name = 'concrete_select')
            
            selected_features = self.concrete_select(inputs)
            outputs = self.output_function(selected_features)

            self.model = Model(inputs, outputs)
            self.model.compile(Adam(self.learning_rate), loss = 'mean_squared_error')
    
            logger.info('%s', self.model.summary())
            
            stopper_callback = StopperCallback()#writer=self.writer)
                        
            # hist = self.model.fit(X, Y, self.batch_size, num_epochs, verbose = 1, callbacks = [stopper_callback, tensorboard_callback], validation_data = validation_data)#, validation_freq = 10)
            hist = self.model.fit_generator(X, epochs=num_epochs, callbacks = [stopper_callback] + self.callback, validation_data=val_X, verbose=0)#, validation_freq = 10) workers=8, use_multiprocessing=True, 
            #fit_generator(generator, steps_per_epoch=None, epochs=1, verbose=1, callbacks=None, validation_data=None, validation_steps=None, validation_freq=1, 
            #              class_weight=None, max_queue_size=10, workers=1, use_multiprocessing=False, shuffle=True, initial_epoch=0)
            
            if K.get_value(K.mean(K.max(K.softmax(self.concrete_select.logits, axis = -1)))) >= stopper_callback.mean_max_target:
                break
            
            num_epochs *= 2
        
        self.probabilities = K.get_value(K.softmax(self.model.get_layer('concrete_select').logits))
        self.indices = K.get_value(K.argmax(self.model.get_layer('concrete_select').logits))
            
        return self
    
    def get_indices(self):
        return K.get_value(K.argmax(self.model.get_layer('concrete_select').logits))
    
    def get_mask(self):
        return K.get_value(K.sum(K.one_hot(K.argmax(self.model.get_layer('concrete_select').logits), self.model.get_layer('concrete_select').logits.shape[1]), axis = 0))
    
#     def transform(self, X):
#         return X[self.get_indices()]
    
#     def fit_transform(self, X, y):
#         self.fit(X, y)
#         return self.transform(X)
    
    def get_support(self, indices = False):
        return self.get_indices() if indices else self.get_mask()
    
    def get_params(self):
        return self.model

# %% [markdown]
# ## Experiments

# %%
def run_model(train_subject, 
              test_subject, 
              n_features = 500, 
              batch_size = 256, 
              num_epochs = 2000, 
              learning_rate = .001,
              decoder_architecture = decoder_2l, 
              decoder_name = 'l2'):
    """
    Trains the ConcreteAutoencoderFeatureSelector
    
    Parameters:
        train_subject (List): subjects to train on
        test_subject (List): subjects to test on
        n_features (int): number of features for the encoder output/decoder input
        batch_size (int): batch size for the ConcreteAutoencoderFeatureSelector
        num_epochs (int): number of epochs
        learning_rate (int): learning rate
        decoder_architecture (keras layer): decoder network architecture for the ConcreteAutoencoderFeatureSelector
        decoder_name (str): name to describe the `decoder_architecture`. Used for logging
        
    Returns:
        indices (List[int]): indices of the features selected by the autoencoder
    """
    data_file = 'data_.hdf5'
    header_file = 'header_.csv'
    date_str = datetime.now().strftime("%Y%m%d-%H%M%S")
    run_info_str = f'{date_str}_K={n_features}_epoch={num_epochs}_test={test_subject[0]}_dec={decoder_name}'
 
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=Path(PROJECT_PATH, 'logs', run_info_str))
    monitor_callback = tf.keras.callbacks.ModelCheckpoint(Path(PROJECT_PATH, 'runs', 'models', f'{run_info_str}_runtime.h5'), 
                                                          monitor='val_loss', 
                                                          verbose=0)
    
    trainset = MRISelectorSubjDataset(root_dir=DATA_PATH, 
                                      dataf=data_file, 
                                      headerf ='header_.csv',
                                      subj_list=np.array(train_subject), 
                                      batch_size=batch_size)
    
    testset = MRISelectorSubjDataset(root_dir=DATA_PATH, 
                                     dataf=data_file, 
                                     headerf=header_file,
                                     subj_list=np.array(test_subject), 
                                     batch_size=batch_size)

    selector = ConcreteAutoencoderFeatureSelector(K=n_features, 
                                                  output_function=decoder_architecture, 
                                                  num_epochs=num_epochs, 
                                                  learning_rate=learning_rate, 
                                                  start_temp=10.0, 
                                                  min_temp=0.1, 
                                                  tryout_limit=5, 
                                                  input_dim=1344, 
                                                  callback=[tensorboard_callback, monitor_callback])
    
    selector.fit(X=trainset, val_X=testset)
    
    model = selector.get_params()
    indices = selector.get_indices()

    model.save(Path(PROJECT_PATH, 'runs', 'models', f'{run_info_str}.h5'))
    
    indices_save_path = Path(PROJECT_PATH, 'runs', 'textfiles', f'{run_info_str}.txt')
    indices_save_path.parent.mkdir(parents=True, exist_ok=True) 
    np.savetxt(indices_save_path, np.array(indices, dtype=int), fmt='%d') 
    
    return indices

# %% [markdown]
# ### Test Subject 15, default values
# Training on subjects 11,12,13,14 and testing on 15. Default values for the `run_model` function.

# %%
result_run_0 = run_model([11, 12, 13, 14], [15])
# Out:
# 2021-06-11 22:53:25,521 - geometric-dl - INFO - None (<ipython-input-38-0e838eedc6e0>:118)
# 2021-06-11 22:53:25,574 - geometric-dl - INFO - mean max of probabilities: 0.00080113 - temperature 10.00000000 (<ipython-input-38-0e838eedc6e0>:60)
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 1344)]            0
# _________________________________________________________________
# concrete_select (ConcreteSel (None, 500)               672001
# _________________________________________________________________
# dense_15 (Dense)             (None, 800)               400800
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 800)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1000)              801000
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 1000)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1344)              1345344
# =================================================================
# Total params: 3,219,145
# Trainable params: 3,219,144
# Non-trainable params: 1
# _________________________________________________________________
# WARNING:tensorflow:Callback method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0069s vs `on_train_batch_begin` time: 0.0275s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0069s vs `on_train_batch_end` time: 0.0133s). Check your callbacks.
# 2021-06-11 22:53:33,415 - geometric-dl - INFO - mean max of probabilities: 0.00085819 - temperature 9.97203064 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:53:40,438 - geometric-dl - INFO - mean max of probabilities: 0.00096117 - temperature 9.94406128 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:53:48,573 - geometric-dl - INFO - mean max of probabilities: 0.00110152 - temperature 9.91609192 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:53:55,490 - geometric-dl - INFO - mean max of probabilities: 0.00130152 - temperature 9.88812256 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:54:03,433 - geometric-dl - INFO - mean max of probabilities: 0.00160927 - temperature 9.86015320 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:54:11,075 - geometric-dl - INFO - mean max of probabilities: 0.00238046 - temperature 9.83218384 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:54:18,925 - geometric-dl - INFO - mean max of probabilities: 0.00379900 - temperature 9.80421448 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:54:26,203 - geometric-dl - INFO - mean max of probabilities: 0.00420340 - temperature 9.77624512 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:54:34,041 - geometric-dl - INFO - mean max of probabilities: 0.00461261 - temperature 9.74827576 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:54:41,345 - geometric-dl - INFO - mean max of probabilities: 0.00497497 - temperature 9.72030640 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:54:49,211 - geometric-dl - INFO - mean max of probabilities: 0.00530791 - temperature 9.69318104 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:54:56,812 - geometric-dl - INFO - mean max of probabilities: 0.00570976 - temperature 9.66628742 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:55:03,865 - geometric-dl - INFO - mean max of probabilities: 0.00597690 - temperature 9.63939381 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:55:11,092 - geometric-dl - INFO - mean max of probabilities: 0.00627319 - temperature 9.61250019 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:55:18,254 - geometric-dl - INFO - mean max of probabilities: 0.00654143 - temperature 9.58560658 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:55:26,253 - geometric-dl - INFO - mean max of probabilities: 0.00679543 - temperature 9.55871296 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:55:33,706 - geometric-dl - INFO - mean max of probabilities: 0.00711467 - temperature 9.53181934 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:55:41,503 - geometric-dl - INFO - mean max of probabilities: 0.00735343 - temperature 9.50492573 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:55:49,339 - geometric-dl - INFO - mean max of probabilities: 0.00763248 - temperature 9.47803211 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:55:56,707 - geometric-dl - INFO - mean max of probabilities: 0.00786572 - temperature 9.45113850 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:56:04,327 - geometric-dl - INFO - mean max of probabilities: 0.00811532 - temperature 9.42424488 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:56:11,579 - geometric-dl - INFO - mean max of probabilities: 0.00836497 - temperature 9.39735126 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:56:19,277 - geometric-dl - INFO - mean max of probabilities: 0.00864541 - temperature 9.37045765 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:56:26,485 - geometric-dl - INFO - mean max of probabilities: 0.00881832 - temperature 9.34356403 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:56:33,908 - geometric-dl - INFO - mean max of probabilities: 0.00906332 - temperature 9.31733608 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:56:41,909 - geometric-dl - INFO - mean max of probabilities: 0.00919028 - temperature 9.29151821 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:56:49,393 - geometric-dl - INFO - mean max of probabilities: 0.00942851 - temperature 9.26570034 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:56:57,161 - geometric-dl - INFO - mean max of probabilities: 0.00952204 - temperature 9.23988247 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:57:04,318 - geometric-dl - INFO - mean max of probabilities: 0.00979018 - temperature 9.21406460 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:57:11,362 - geometric-dl - INFO - mean max of probabilities: 0.00991884 - temperature 9.18824673 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:57:18,683 - geometric-dl - INFO - mean max of probabilities: 0.01013072 - temperature 9.16242886 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:57:26,780 - geometric-dl - INFO - mean max of probabilities: 0.01029636 - temperature 9.13661098 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:57:34,916 - geometric-dl - INFO - mean max of probabilities: 0.01056444 - temperature 9.11079311 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:57:42,445 - geometric-dl - INFO - mean max of probabilities: 0.01072912 - temperature 9.08497524 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:57:49,454 - geometric-dl - INFO - mean max of probabilities: 0.01091860 - temperature 9.05915737 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:57:57,009 - geometric-dl - INFO - mean max of probabilities: 0.01110751 - temperature 9.03333950 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:58:04,667 - geometric-dl - INFO - mean max of probabilities: 0.01132347 - temperature 9.00752163 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:58:11,806 - geometric-dl - INFO - mean max of probabilities: 0.01151512 - temperature 8.98170376 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:58:19,685 - geometric-dl - INFO - mean max of probabilities: 0.01166617 - temperature 8.95588589 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:58:27,585 - geometric-dl - INFO - mean max of probabilities: 0.01193126 - temperature 8.93099689 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:58:35,572 - geometric-dl - INFO - mean max of probabilities: 0.01220577 - temperature 8.90625477 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:58:42,661 - geometric-dl - INFO - mean max of probabilities: 0.01241169 - temperature 8.88151264 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:58:50,965 - geometric-dl - INFO - mean max of probabilities: 0.01277955 - temperature 8.85677052 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:58:58,953 - geometric-dl - INFO - mean max of probabilities: 0.01314007 - temperature 8.83202839 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:59:07,200 - geometric-dl - INFO - mean max of probabilities: 0.01349363 - temperature 8.80728626 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:59:15,187 - geometric-dl - INFO - mean max of probabilities: 0.01396954 - temperature 8.78254414 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:59:23,736 - geometric-dl - INFO - mean max of probabilities: 0.01450511 - temperature 8.75780201 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:59:31,458 - geometric-dl - INFO - mean max of probabilities: 0.01527759 - temperature 8.73305988 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:59:39,177 - geometric-dl - INFO - mean max of probabilities: 0.01632815 - temperature 8.70831776 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:59:46,675 - geometric-dl - INFO - mean max of probabilities: 0.01772532 - temperature 8.68357563 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 22:59:54,019 - geometric-dl - INFO - mean max of probabilities: 0.02014346 - temperature 8.65883350 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:00:01,598 - geometric-dl - INFO - mean max of probabilities: 0.02343388 - temperature 8.63409138 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:00:09,836 - geometric-dl - INFO - mean max of probabilities: 0.02619640 - temperature 8.60934925 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:00:18,251 - geometric-dl - INFO - mean max of probabilities: 0.02776359 - temperature 8.58460712 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:00:25,344 - geometric-dl - INFO - mean max of probabilities: 0.02905599 - temperature 8.56036758 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:00:33,173 - geometric-dl - INFO - mean max of probabilities: 0.03019416 - temperature 8.53670120 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:00:40,834 - geometric-dl - INFO - mean max of probabilities: 0.03133108 - temperature 8.51303482 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:00:48,993 - geometric-dl - INFO - mean max of probabilities: 0.03236051 - temperature 8.48936844 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:00:56,667 - geometric-dl - INFO - mean max of probabilities: 0.03352337 - temperature 8.46570206 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:01:04,502 - geometric-dl - INFO - mean max of probabilities: 0.03469926 - temperature 8.44203568 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:01:12,306 - geometric-dl - INFO - mean max of probabilities: 0.03580693 - temperature 8.41836929 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:01:19,540 - geometric-dl - INFO - mean max of probabilities: 0.03712202 - temperature 8.39470291 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:01:26,820 - geometric-dl - INFO - mean max of probabilities: 0.03832871 - temperature 8.37103653 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:01:34,255 - geometric-dl - INFO - mean max of probabilities: 0.03940075 - temperature 8.34737015 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:01:41,387 - geometric-dl - INFO - mean max of probabilities: 0.04056357 - temperature 8.32370377 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:01:48,866 - geometric-dl - INFO - mean max of probabilities: 0.04182705 - temperature 8.30003738 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:01:56,764 - geometric-dl - INFO - mean max of probabilities: 0.04303271 - temperature 8.27637100 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:02:04,138 - geometric-dl - INFO - mean max of probabilities: 0.04426069 - temperature 8.25270462 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:02:11,937 - geometric-dl - INFO - mean max of probabilities: 0.04537191 - temperature 8.22903824 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:02:18,895 - geometric-dl - INFO - mean max of probabilities: 0.04662712 - temperature 8.20537186 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:02:25,691 - geometric-dl - INFO - mean max of probabilities: 0.04785508 - temperature 8.18210411 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:02:33,038 - geometric-dl - INFO - mean max of probabilities: 0.04917237 - temperature 8.15951347 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:02:40,540 - geometric-dl - INFO - mean max of probabilities: 0.05043462 - temperature 8.13692284 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:02:48,174 - geometric-dl - INFO - mean max of probabilities: 0.05171330 - temperature 8.11433220 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:02:55,823 - geometric-dl - INFO - mean max of probabilities: 0.05292106 - temperature 8.09174156 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:03:03,015 - geometric-dl - INFO - mean max of probabilities: 0.05425378 - temperature 8.06915092 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:03:10,284 - geometric-dl - INFO - mean max of probabilities: 0.05543025 - temperature 8.04656029 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:03:17,853 - geometric-dl - INFO - mean max of probabilities: 0.05657002 - temperature 8.02396965 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:03:24,737 - geometric-dl - INFO - mean max of probabilities: 0.05783545 - temperature 8.00137901 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:03:32,952 - geometric-dl - INFO - mean max of probabilities: 0.05903408 - temperature 7.97878838 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:03:40,330 - geometric-dl - INFO - mean max of probabilities: 0.06033929 - temperature 7.95619774 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:03:47,312 - geometric-dl - INFO - mean max of probabilities: 0.06162768 - temperature 7.93360710 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:03:54,841 - geometric-dl - INFO - mean max of probabilities: 0.06292287 - temperature 7.91101646 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:04:02,717 - geometric-dl - INFO - mean max of probabilities: 0.06412169 - temperature 7.88881445 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:04:10,656 - geometric-dl - INFO - mean max of probabilities: 0.06536864 - temperature 7.86676168 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:04:18,353 - geometric-dl - INFO - mean max of probabilities: 0.06668118 - temperature 7.84470892 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:04:25,679 - geometric-dl - INFO - mean max of probabilities: 0.06792840 - temperature 7.82265615 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:04:33,128 - geometric-dl - INFO - mean max of probabilities: 0.06913306 - temperature 7.80060339 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:04:40,841 - geometric-dl - INFO - mean max of probabilities: 0.07046308 - temperature 7.77855062 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:04:48,348 - geometric-dl - INFO - mean max of probabilities: 0.07173736 - temperature 7.75649786 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:04:55,310 - geometric-dl - INFO - mean max of probabilities: 0.07311399 - temperature 7.73444510 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:05:03,053 - geometric-dl - INFO - mean max of probabilities: 0.07436433 - temperature 7.71243811 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:05:10,686 - geometric-dl - INFO - mean max of probabilities: 0.07569590 - temperature 7.69092321 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:05:17,729 - geometric-dl - INFO - mean max of probabilities: 0.07554126 - temperature 7.66940832 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:05:24,703 - geometric-dl - INFO - mean max of probabilities: 0.07676923 - temperature 7.64789343 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:05:32,406 - geometric-dl - INFO - mean max of probabilities: 0.07824478 - temperature 7.62637854 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:05:39,832 - geometric-dl - INFO - mean max of probabilities: 0.07995468 - temperature 7.60486364 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:05:47,290 - geometric-dl - INFO - mean max of probabilities: 0.08164702 - temperature 7.58334875 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:05:54,120 - geometric-dl - INFO - mean max of probabilities: 0.08311340 - temperature 7.56183386 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:06:02,134 - geometric-dl - INFO - mean max of probabilities: 0.08470097 - temperature 7.54031897 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:06:09,429 - geometric-dl - INFO - mean max of probabilities: 0.08612097 - temperature 7.51892900 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:06:16,586 - geometric-dl - INFO - mean max of probabilities: 0.08776079 - temperature 7.49795198 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:06:24,326 - geometric-dl - INFO - mean max of probabilities: 0.08908211 - temperature 7.47697496 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:06:32,070 - geometric-dl - INFO - mean max of probabilities: 0.09043832 - temperature 7.45599794 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:06:40,085 - geometric-dl - INFO - mean max of probabilities: 0.09154121 - temperature 7.43502092 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:06:48,529 - geometric-dl - INFO - mean max of probabilities: 0.09272076 - temperature 7.41404390 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:06:56,566 - geometric-dl - INFO - mean max of probabilities: 0.09411061 - temperature 7.39306688 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:07:04,196 - geometric-dl - INFO - mean max of probabilities: 0.09525312 - temperature 7.37208986 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:07:11,342 - geometric-dl - INFO - mean max of probabilities: 0.09644575 - temperature 7.35111284 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:07:18,568 - geometric-dl - INFO - mean max of probabilities: 0.09759447 - temperature 7.33021736 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:07:26,775 - geometric-dl - INFO - mean max of probabilities: 0.09877271 - temperature 7.30977821 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:07:33,985 - geometric-dl - INFO - mean max of probabilities: 0.09991352 - temperature 7.28933907 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:07:41,284 - geometric-dl - INFO - mean max of probabilities: 0.10111546 - temperature 7.26889992 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:07:48,402 - geometric-dl - INFO - mean max of probabilities: 0.10226760 - temperature 7.24846077 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:07:57,063 - geometric-dl - INFO - mean max of probabilities: 0.10346679 - temperature 7.22802162 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:08:04,289 - geometric-dl - INFO - mean max of probabilities: 0.10473511 - temperature 7.20758247 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:08:12,164 - geometric-dl - INFO - mean max of probabilities: 0.10595431 - temperature 7.18714333 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:08:19,735 - geometric-dl - INFO - mean max of probabilities: 0.10724204 - temperature 7.16670418 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:08:27,339 - geometric-dl - INFO - mean max of probabilities: 0.10850994 - temperature 7.14626503 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:08:35,878 - geometric-dl - INFO - mean max of probabilities: 0.10968486 - temperature 7.12627363 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:08:43,561 - geometric-dl - INFO - mean max of probabilities: 0.11088835 - temperature 7.10637236 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:08:51,867 - geometric-dl - INFO - mean max of probabilities: 0.11207054 - temperature 7.08647108 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:08:59,549 - geometric-dl - INFO - mean max of probabilities: 0.11327441 - temperature 7.06656981 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:09:06,773 - geometric-dl - INFO - mean max of probabilities: 0.11452128 - temperature 7.04666853 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:09:13,901 - geometric-dl - INFO - mean max of probabilities: 0.11575192 - temperature 7.02676725 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:09:21,259 - geometric-dl - INFO - mean max of probabilities: 0.11699924 - temperature 7.00686598 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:09:29,163 - geometric-dl - INFO - mean max of probabilities: 0.11819826 - temperature 6.98696470 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:09:37,014 - geometric-dl - INFO - mean max of probabilities: 0.11934364 - temperature 6.96706343 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:09:44,874 - geometric-dl - INFO - mean max of probabilities: 0.12060089 - temperature 6.94730282 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:09:52,195 - geometric-dl - INFO - mean max of probabilities: 0.12174687 - temperature 6.92793941 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:10:00,377 - geometric-dl - INFO - mean max of probabilities: 0.12295283 - temperature 6.90857601 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:10:08,048 - geometric-dl - INFO - mean max of probabilities: 0.12426692 - temperature 6.88921261 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:10:16,832 - geometric-dl - INFO - mean max of probabilities: 0.12543254 - temperature 6.86984921 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:10:24,711 - geometric-dl - INFO - mean max of probabilities: 0.12683313 - temperature 6.85048580 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:10:32,679 - geometric-dl - INFO - mean max of probabilities: 0.12810107 - temperature 6.83112240 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:10:40,879 - geometric-dl - INFO - mean max of probabilities: 0.12945454 - temperature 6.81175900 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:10:50,256 - geometric-dl - INFO - mean max of probabilities: 0.13085493 - temperature 6.79239559 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:10:58,075 - geometric-dl - INFO - mean max of probabilities: 0.13222492 - temperature 6.77303219 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:11:05,496 - geometric-dl - INFO - mean max of probabilities: 0.13363075 - temperature 6.75389719 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:11:13,537 - geometric-dl - INFO - mean max of probabilities: 0.13494357 - temperature 6.73507166 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:11:21,413 - geometric-dl - INFO - mean max of probabilities: 0.13648674 - temperature 6.71624613 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:11:29,150 - geometric-dl - INFO - mean max of probabilities: 0.13800290 - temperature 6.69742060 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:11:36,402 - geometric-dl - INFO - mean max of probabilities: 0.13950455 - temperature 6.67859507 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:11:43,979 - geometric-dl - INFO - mean max of probabilities: 0.14113840 - temperature 6.65976954 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:11:50,701 - geometric-dl - INFO - mean max of probabilities: 0.14279196 - temperature 6.64094400 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:11:58,643 - geometric-dl - INFO - mean max of probabilities: 0.14448154 - temperature 6.62211847 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:12:06,192 - geometric-dl - INFO - mean max of probabilities: 0.14615712 - temperature 6.60329294 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:12:14,780 - geometric-dl - INFO - mean max of probabilities: 0.14785466 - temperature 6.58446741 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:12:22,443 - geometric-dl - INFO - mean max of probabilities: 0.14948706 - temperature 6.56580687 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:12:30,285 - geometric-dl - INFO - mean max of probabilities: 0.15124983 - temperature 6.54751921 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:12:38,042 - geometric-dl - INFO - mean max of probabilities: 0.15288296 - temperature 6.52923155 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:12:45,674 - geometric-dl - INFO - mean max of probabilities: 0.15448004 - temperature 6.51094389 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:12:53,261 - geometric-dl - INFO - mean max of probabilities: 0.15606111 - temperature 6.49265623 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:13:00,566 - geometric-dl - INFO - mean max of probabilities: 0.15778230 - temperature 6.47436857 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:13:08,913 - geometric-dl - INFO - mean max of probabilities: 0.15951170 - temperature 6.45608091 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:13:16,160 - geometric-dl - INFO - mean max of probabilities: 0.16107500 - temperature 6.43779325 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:13:23,933 - geometric-dl - INFO - mean max of probabilities: 0.16259897 - temperature 6.41950560 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:13:31,910 - geometric-dl - INFO - mean max of probabilities: 0.16414550 - temperature 6.40121794 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:13:39,848 - geometric-dl - INFO - mean max of probabilities: 0.16574953 - temperature 6.38293028 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:13:47,062 - geometric-dl - INFO - mean max of probabilities: 0.16713932 - temperature 6.36512232 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:13:55,058 - geometric-dl - INFO - mean max of probabilities: 0.16857219 - temperature 6.34737253 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:14:02,690 - geometric-dl - INFO - mean max of probabilities: 0.16998968 - temperature 6.32962275 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:14:10,439 - geometric-dl - INFO - mean max of probabilities: 0.17141768 - temperature 6.31187296 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:14:19,200 - geometric-dl - INFO - mean max of probabilities: 0.17277461 - temperature 6.29412317 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:14:26,795 - geometric-dl - INFO - mean max of probabilities: 0.17414983 - temperature 6.27637339 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:14:35,112 - geometric-dl - INFO - mean max of probabilities: 0.17553894 - temperature 6.25862360 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:14:42,190 - geometric-dl - INFO - mean max of probabilities: 0.17686313 - temperature 6.24087381 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:14:49,631 - geometric-dl - INFO - mean max of probabilities: 0.17824098 - temperature 6.22312403 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:14:57,938 - geometric-dl - INFO - mean max of probabilities: 0.17966565 - temperature 6.20537424 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:15:05,240 - geometric-dl - INFO - mean max of probabilities: 0.18112756 - temperature 6.18771076 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:15:12,531 - geometric-dl - INFO - mean max of probabilities: 0.18248864 - temperature 6.17049885 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:15:20,008 - geometric-dl - INFO - mean max of probabilities: 0.18392397 - temperature 6.15328693 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:15:27,580 - geometric-dl - INFO - mean max of probabilities: 0.18535782 - temperature 6.13607502 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:15:35,174 - geometric-dl - INFO - mean max of probabilities: 0.18703167 - temperature 6.11886311 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:15:43,107 - geometric-dl - INFO - mean max of probabilities: 0.18873684 - temperature 6.10165119 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:15:50,348 - geometric-dl - INFO - mean max of probabilities: 0.19072095 - temperature 6.08443928 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:15:58,740 - geometric-dl - INFO - mean max of probabilities: 0.19264372 - temperature 6.06722736 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:16:06,113 - geometric-dl - INFO - mean max of probabilities: 0.19477746 - temperature 6.05001545 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:16:13,932 - geometric-dl - INFO - mean max of probabilities: 0.19706124 - temperature 6.03280354 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:16:21,741 - geometric-dl - INFO - mean max of probabilities: 0.19924183 - temperature 6.01559162 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:16:29,390 - geometric-dl - INFO - mean max of probabilities: 0.20154600 - temperature 5.99843025 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:16:37,179 - geometric-dl - INFO - mean max of probabilities: 0.20397432 - temperature 5.98175621 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:16:44,538 - geometric-dl - INFO - mean max of probabilities: 0.20630914 - temperature 5.96508217 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:16:51,738 - geometric-dl - INFO - mean max of probabilities: 0.20871034 - temperature 5.94840813 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:16:59,485 - geometric-dl - INFO - mean max of probabilities: 0.21112072 - temperature 5.93173409 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:17:07,364 - geometric-dl - INFO - mean max of probabilities: 0.21332939 - temperature 5.91506004 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:17:14,518 - geometric-dl - INFO - mean max of probabilities: 0.21549585 - temperature 5.89838600 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:17:22,283 - geometric-dl - INFO - mean max of probabilities: 0.21756318 - temperature 5.88171196 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:17:29,466 - geometric-dl - INFO - mean max of probabilities: 0.21970046 - temperature 5.86503792 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:17:37,081 - geometric-dl - INFO - mean max of probabilities: 0.22170913 - temperature 5.84836388 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:17:45,449 - geometric-dl - INFO - mean max of probabilities: 0.22357857 - temperature 5.83168983 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:17:53,278 - geometric-dl - INFO - mean max of probabilities: 0.22533217 - temperature 5.81501579 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:18:01,195 - geometric-dl - INFO - mean max of probabilities: 0.22709025 - temperature 5.79870224 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:18:08,747 - geometric-dl - INFO - mean max of probabilities: 0.22878036 - temperature 5.78256607 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:18:16,539 - geometric-dl - INFO - mean max of probabilities: 0.23034750 - temperature 5.76642990 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:18:25,091 - geometric-dl - INFO - mean max of probabilities: 0.23185264 - temperature 5.75029373 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:18:32,789 - geometric-dl - INFO - mean max of probabilities: 0.23335557 - temperature 5.73415756 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:18:40,135 - geometric-dl - INFO - mean max of probabilities: 0.23488636 - temperature 5.71802139 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:18:47,379 - geometric-dl - INFO - mean max of probabilities: 0.23635033 - temperature 5.70188522 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:18:54,394 - geometric-dl - INFO - mean max of probabilities: 0.23763718 - temperature 5.68574905 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:19:01,340 - geometric-dl - INFO - mean max of probabilities: 0.23902811 - temperature 5.66961288 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:19:09,114 - geometric-dl - INFO - mean max of probabilities: 0.24021217 - temperature 5.65347672 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:19:16,074 - geometric-dl - INFO - mean max of probabilities: 0.24133204 - temperature 5.63734055 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:19:24,709 - geometric-dl - INFO - mean max of probabilities: 0.24232525 - temperature 5.62120438 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:19:32,213 - geometric-dl - INFO - mean max of probabilities: 0.24320014 - temperature 5.60553408 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:19:40,344 - geometric-dl - INFO - mean max of probabilities: 0.24408807 - temperature 5.58993578 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:19:48,511 - geometric-dl - INFO - mean max of probabilities: 0.24480526 - temperature 5.57433748 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:19:55,974 - geometric-dl - INFO - mean max of probabilities: 0.24543083 - temperature 5.55873919 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:20:03,101 - geometric-dl - INFO - mean max of probabilities: 0.24595284 - temperature 5.54314089 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:20:10,458 - geometric-dl - INFO - mean max of probabilities: 0.24641067 - temperature 5.52754259 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:20:17,981 - geometric-dl - INFO - mean max of probabilities: 0.24668670 - temperature 5.51194429 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:20:26,286 - geometric-dl - INFO - mean max of probabilities: 0.24678758 - temperature 5.49634600 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:20:34,022 - geometric-dl - INFO - mean max of probabilities: 0.24712792 - temperature 5.48074770 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:20:41,443 - geometric-dl - INFO - mean max of probabilities: 0.24751556 - temperature 5.46514940 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:20:48,954 - geometric-dl - INFO - mean max of probabilities: 0.24772401 - temperature 5.44955111 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:20:56,355 - geometric-dl - INFO - mean max of probabilities: 0.24784876 - temperature 5.43395281 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:21:04,319 - geometric-dl - INFO - mean max of probabilities: 0.24814807 - temperature 5.41870642 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:21:12,018 - geometric-dl - INFO - mean max of probabilities: 0.24846713 - temperature 5.40364599 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:21:19,449 - geometric-dl - INFO - mean max of probabilities: 0.24877734 - temperature 5.38858557 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:21:27,648 - geometric-dl - INFO - mean max of probabilities: 0.24908435 - temperature 5.37352514 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:21:34,688 - geometric-dl - INFO - mean max of probabilities: 0.24938257 - temperature 5.35846472 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:21:42,284 - geometric-dl - INFO - mean max of probabilities: 0.24954630 - temperature 5.34340429 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:21:49,426 - geometric-dl - INFO - mean max of probabilities: 0.24963789 - temperature 5.32834387 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:21:57,892 - geometric-dl - INFO - mean max of probabilities: 0.24987832 - temperature 5.31328344 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:22:05,999 - geometric-dl - INFO - mean max of probabilities: 0.25000265 - temperature 5.29822302 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:22:13,367 - geometric-dl - INFO - mean max of probabilities: 0.25012952 - temperature 5.28316259 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:22:20,494 - geometric-dl - INFO - mean max of probabilities: 0.25039086 - temperature 5.26810217 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:22:27,786 - geometric-dl - INFO - mean max of probabilities: 0.25049397 - temperature 5.25304174 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:22:35,028 - geometric-dl - INFO - mean max of probabilities: 0.25053671 - temperature 5.23798513 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:22:42,179 - geometric-dl - INFO - mean max of probabilities: 0.25061816 - temperature 5.22346258 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:22:49,357 - geometric-dl - INFO - mean max of probabilities: 0.25054017 - temperature 5.20894003 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:22:57,153 - geometric-dl - INFO - mean max of probabilities: 0.25061578 - temperature 5.19441748 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:23:04,422 - geometric-dl - INFO - mean max of probabilities: 0.25049236 - temperature 5.17989492 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:23:12,019 - geometric-dl - INFO - mean max of probabilities: 0.25059164 - temperature 5.16537237 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:23:20,252 - geometric-dl - INFO - mean max of probabilities: 0.25057444 - temperature 5.15084982 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:23:27,319 - geometric-dl - INFO - mean max of probabilities: 0.25059542 - temperature 5.13632727 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:23:34,780 - geometric-dl - INFO - mean max of probabilities: 0.25058100 - temperature 5.12180471 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:23:42,719 - geometric-dl - INFO - mean max of probabilities: 0.25078949 - temperature 5.10728216 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:23:50,410 - geometric-dl - INFO - mean max of probabilities: 0.25098270 - temperature 5.09275961 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:23:58,267 - geometric-dl - INFO - mean max of probabilities: 0.25107971 - temperature 5.07823706 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:24:06,333 - geometric-dl - INFO - mean max of probabilities: 0.25109407 - temperature 5.06371450 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:24:13,575 - geometric-dl - INFO - mean max of probabilities: 0.25132656 - temperature 5.04919195 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:24:20,948 - geometric-dl - INFO - mean max of probabilities: 0.25146145 - temperature 5.03514862 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:24:28,403 - geometric-dl - INFO - mean max of probabilities: 0.25156933 - temperature 5.02116394 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:24:35,757 - geometric-dl - INFO - mean max of probabilities: 0.25174904 - temperature 5.00717926 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:24:43,292 - geometric-dl - INFO - mean max of probabilities: 0.25193766 - temperature 4.99319458 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:24:50,619 - geometric-dl - INFO - mean max of probabilities: 0.25210261 - temperature 4.97920990 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:24:57,997 - geometric-dl - INFO - mean max of probabilities: 0.25220150 - temperature 4.96522522 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:25:04,986 - geometric-dl - INFO - mean max of probabilities: 0.25242013 - temperature 4.95124054 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:25:12,010 - geometric-dl - INFO - mean max of probabilities: 0.25254673 - temperature 4.93725586 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:25:19,161 - geometric-dl - INFO - mean max of probabilities: 0.25272426 - temperature 4.92327118 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:25:26,193 - geometric-dl - INFO - mean max of probabilities: 0.25295925 - temperature 4.90928650 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:25:34,055 - geometric-dl - INFO - mean max of probabilities: 0.25303292 - temperature 4.89530182 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:25:41,423 - geometric-dl - INFO - mean max of probabilities: 0.25311485 - temperature 4.88131714 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:25:48,799 - geometric-dl - INFO - mean max of probabilities: 0.25323012 - temperature 4.86733246 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:25:55,988 - geometric-dl - INFO - mean max of probabilities: 0.25326535 - temperature 4.85349369 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:26:04,070 - geometric-dl - INFO - mean max of probabilities: 0.25330275 - temperature 4.84004688 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:26:10,651 - geometric-dl - INFO - mean max of probabilities: 0.25341907 - temperature 4.82660007 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:26:17,796 - geometric-dl - INFO - mean max of probabilities: 0.25350696 - temperature 4.81315327 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:26:25,464 - geometric-dl - INFO - mean max of probabilities: 0.25355765 - temperature 4.79970646 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:26:32,191 - geometric-dl - INFO - mean max of probabilities: 0.25360045 - temperature 4.78625965 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:26:40,071 - geometric-dl - INFO - mean max of probabilities: 0.25369522 - temperature 4.77281284 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:26:48,017 - geometric-dl - INFO - mean max of probabilities: 0.25393462 - temperature 4.75936604 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:26:55,526 - geometric-dl - INFO - mean max of probabilities: 0.25394410 - temperature 4.74591923 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:27:03,580 - geometric-dl - INFO - mean max of probabilities: 0.25405362 - temperature 4.73247242 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:27:11,041 - geometric-dl - INFO - mean max of probabilities: 0.25414678 - temperature 4.71902561 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:27:18,896 - geometric-dl - INFO - mean max of probabilities: 0.25421500 - temperature 4.70557880 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:27:27,087 - geometric-dl - INFO - mean max of probabilities: 0.25454032 - temperature 4.69213200 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:27:33,835 - geometric-dl - INFO - mean max of probabilities: 0.25464389 - temperature 4.67868519 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:27:40,944 - geometric-dl - INFO - mean max of probabilities: 0.25469014 - temperature 4.66529512 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:27:49,076 - geometric-dl - INFO - mean max of probabilities: 0.25498402 - temperature 4.65238619 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:27:56,073 - geometric-dl - INFO - mean max of probabilities: 0.25517383 - temperature 4.63947725 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:28:03,503 - geometric-dl - INFO - mean max of probabilities: 0.25550702 - temperature 4.62656832 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:28:11,316 - geometric-dl - INFO - mean max of probabilities: 0.25580138 - temperature 4.61365938 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:28:19,864 - geometric-dl - INFO - mean max of probabilities: 0.25594643 - temperature 4.60075045 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:28:27,082 - geometric-dl - INFO - mean max of probabilities: 0.25619924 - temperature 4.58784151 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:28:34,392 - geometric-dl - INFO - mean max of probabilities: 0.25662109 - temperature 4.57493258 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:28:41,344 - geometric-dl - INFO - mean max of probabilities: 0.25699630 - temperature 4.56202364 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:28:49,714 - geometric-dl - INFO - mean max of probabilities: 0.25745952 - temperature 4.54911470 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:28:57,075 - geometric-dl - INFO - mean max of probabilities: 0.25794962 - temperature 4.53620577 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:29:04,524 - geometric-dl - INFO - mean max of probabilities: 0.25843206 - temperature 4.52329683 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:29:12,768 - geometric-dl - INFO - mean max of probabilities: 0.25878215 - temperature 4.51038790 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:29:20,073 - geometric-dl - INFO - mean max of probabilities: 0.25938118 - temperature 4.49747896 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:29:28,342 - geometric-dl - INFO - mean max of probabilities: 0.25976565 - temperature 4.48457003 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:29:35,529 - geometric-dl - INFO - mean max of probabilities: 0.26029322 - temperature 4.47184944 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:29:42,794 - geometric-dl - INFO - mean max of probabilities: 0.26080120 - temperature 4.45947838 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:29:50,096 - geometric-dl - INFO - mean max of probabilities: 0.26136309 - temperature 4.44710732 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:29:57,616 - geometric-dl - INFO - mean max of probabilities: 0.26182765 - temperature 4.43473625 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:30:04,921 - geometric-dl - INFO - mean max of probabilities: 0.26247934 - temperature 4.42236519 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:30:13,353 - geometric-dl - INFO - mean max of probabilities: 0.26298869 - temperature 4.40999413 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:30:21,241 - geometric-dl - INFO - mean max of probabilities: 0.26334819 - temperature 4.39762306 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:30:28,797 - geometric-dl - INFO - mean max of probabilities: 0.26380798 - temperature 4.38525200 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:30:36,886 - geometric-dl - INFO - mean max of probabilities: 0.26428401 - temperature 4.37288094 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:30:44,645 - geometric-dl - INFO - mean max of probabilities: 0.26466927 - temperature 4.36050987 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:30:51,990 - geometric-dl - INFO - mean max of probabilities: 0.26513532 - temperature 4.34813881 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:30:59,612 - geometric-dl - INFO - mean max of probabilities: 0.26568899 - temperature 4.33576775 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:31:06,919 - geometric-dl - INFO - mean max of probabilities: 0.26617739 - temperature 4.32339668 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:31:14,884 - geometric-dl - INFO - mean max of probabilities: 0.26665318 - temperature 4.31102562 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:31:22,281 - geometric-dl - INFO - mean max of probabilities: 0.26715183 - temperature 4.29865456 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:31:30,115 - geometric-dl - INFO - mean max of probabilities: 0.26766330 - temperature 4.28628349 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:31:38,300 - geometric-dl - INFO - mean max of probabilities: 0.26826811 - temperature 4.27442551 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:31:45,275 - geometric-dl - INFO - mean max of probabilities: 0.26865992 - temperature 4.26259232 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:31:52,921 - geometric-dl - INFO - mean max of probabilities: 0.26902521 - temperature 4.25075912 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:32:00,558 - geometric-dl - INFO - mean max of probabilities: 0.26948345 - temperature 4.23892593 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:32:08,026 - geometric-dl - INFO - mean max of probabilities: 0.26977310 - temperature 4.22709274 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:32:15,791 - geometric-dl - INFO - mean max of probabilities: 0.27031940 - temperature 4.21525955 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:32:23,552 - geometric-dl - INFO - mean max of probabilities: 0.27058136 - temperature 4.20342636 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:32:30,893 - geometric-dl - INFO - mean max of probabilities: 0.27092487 - temperature 4.19159317 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:32:38,692 - geometric-dl - INFO - mean max of probabilities: 0.27116367 - temperature 4.17975998 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:32:46,531 - geometric-dl - INFO - mean max of probabilities: 0.27136251 - temperature 4.16792679 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-11 23:32:53,237 - geometric-dl - INFO - mean max of probabilities: 0.27167302 - temperature 4.15609360 (<ipython-input-38-0e838eedc6e0>:60)
# ...
# 2021-06-12 03:00:58,396 - geometric-dl - INFO - mean max of probabilities: 0.99488801 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:01:06,242 - geometric-dl - INFO - mean max of probabilities: 0.99489796 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:01:15,049 - geometric-dl - INFO - mean max of probabilities: 0.99490458 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:01:23,132 - geometric-dl - INFO - mean max of probabilities: 0.99489063 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:01:30,503 - geometric-dl - INFO - mean max of probabilities: 0.99491149 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:01:37,738 - geometric-dl - INFO - mean max of probabilities: 0.99492449 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:01:45,741 - geometric-dl - INFO - mean max of probabilities: 0.99494106 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:01:53,745 - geometric-dl - INFO - mean max of probabilities: 0.99493808 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:02:02,775 - geometric-dl - INFO - mean max of probabilities: 0.99496949 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:02:10,121 - geometric-dl - INFO - mean max of probabilities: 0.99500018 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:02:17,573 - geometric-dl - INFO - mean max of probabilities: 0.99498773 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:02:25,530 - geometric-dl - INFO - mean max of probabilities: 0.99497926 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:02:33,226 - geometric-dl - INFO - mean max of probabilities: 0.99500012 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:02:41,806 - geometric-dl - INFO - mean max of probabilities: 0.99499655 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:02:49,260 - geometric-dl - INFO - mean max of probabilities: 0.99500477 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:02:56,701 - geometric-dl - INFO - mean max of probabilities: 0.99500257 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:03:04,406 - geometric-dl - INFO - mean max of probabilities: 0.99501806 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:03:12,080 - geometric-dl - INFO - mean max of probabilities: 0.99501079 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:03:19,992 - geometric-dl - INFO - mean max of probabilities: 0.99504167 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:03:28,179 - geometric-dl - INFO - mean max of probabilities: 0.99504715 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:03:36,469 - geometric-dl - INFO - mean max of probabilities: 0.99504089 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:03:44,974 - geometric-dl - INFO - mean max of probabilities: 0.99503851 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:03:52,534 - geometric-dl - INFO - mean max of probabilities: 0.99504548 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:04:00,389 - geometric-dl - INFO - mean max of probabilities: 0.99509901 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:04:08,607 - geometric-dl - INFO - mean max of probabilities: 0.99511027 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:04:16,957 - geometric-dl - INFO - mean max of probabilities: 0.99510151 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:04:24,842 - geometric-dl - INFO - mean max of probabilities: 0.99510384 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:04:32,902 - geometric-dl - INFO - mean max of probabilities: 0.99510717 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:04:40,318 - geometric-dl - INFO - mean max of probabilities: 0.99507511 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:04:48,122 - geometric-dl - INFO - mean max of probabilities: 0.99510199 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:04:57,352 - geometric-dl - INFO - mean max of probabilities: 0.99510700 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:05:04,783 - geometric-dl - INFO - mean max of probabilities: 0.99510801 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:05:12,651 - geometric-dl - INFO - mean max of probabilities: 0.99512506 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:05:19,973 - geometric-dl - INFO - mean max of probabilities: 0.99511474 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:05:28,313 - geometric-dl - INFO - mean max of probabilities: 0.99512756 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:05:36,342 - geometric-dl - INFO - mean max of probabilities: 0.99511743 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:05:43,502 - geometric-dl - INFO - mean max of probabilities: 0.99511898 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:05:51,077 - geometric-dl - INFO - mean max of probabilities: 0.99513078 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:05:58,622 - geometric-dl - INFO - mean max of probabilities: 0.99510616 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:06:06,702 - geometric-dl - INFO - mean max of probabilities: 0.99510229 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:06:14,209 - geometric-dl - INFO - mean max of probabilities: 0.99508661 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:06:21,988 - geometric-dl - INFO - mean max of probabilities: 0.99509984 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:06:29,820 - geometric-dl - INFO - mean max of probabilities: 0.99508238 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:06:38,517 - geometric-dl - INFO - mean max of probabilities: 0.99515092 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:06:46,390 - geometric-dl - INFO - mean max of probabilities: 0.99518532 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:06:53,712 - geometric-dl - INFO - mean max of probabilities: 0.99522966 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:07:01,849 - geometric-dl - INFO - mean max of probabilities: 0.99528402 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:07:09,549 - geometric-dl - INFO - mean max of probabilities: 0.99532998 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:07:16,767 - geometric-dl - INFO - mean max of probabilities: 0.99535984 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:07:24,335 - geometric-dl - INFO - mean max of probabilities: 0.99546921 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:07:32,583 - geometric-dl - INFO - mean max of probabilities: 0.99549669 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:07:39,994 - geometric-dl - INFO - mean max of probabilities: 0.99553680 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:07:47,516 - geometric-dl - INFO - mean max of probabilities: 0.99558353 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:07:55,341 - geometric-dl - INFO - mean max of probabilities: 0.99561089 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:08:03,731 - geometric-dl - INFO - mean max of probabilities: 0.99565256 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:08:11,264 - geometric-dl - INFO - mean max of probabilities: 0.99569458 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:08:19,215 - geometric-dl - INFO - mean max of probabilities: 0.99573177 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:08:27,449 - geometric-dl - INFO - mean max of probabilities: 0.99578834 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:08:34,696 - geometric-dl - INFO - mean max of probabilities: 0.99590492 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:08:41,779 - geometric-dl - INFO - mean max of probabilities: 0.99598718 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:08:49,776 - geometric-dl - INFO - mean max of probabilities: 0.99599391 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:08:57,572 - geometric-dl - INFO - mean max of probabilities: 0.99613255 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:09:05,803 - geometric-dl - INFO - mean max of probabilities: 0.99614662 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:09:14,018 - geometric-dl - INFO - mean max of probabilities: 0.99615979 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:09:22,290 - geometric-dl - INFO - mean max of probabilities: 0.99616259 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:09:29,775 - geometric-dl - INFO - mean max of probabilities: 0.99617082 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:09:37,468 - geometric-dl - INFO - mean max of probabilities: 0.99618715 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:09:45,544 - geometric-dl - INFO - mean max of probabilities: 0.99620169 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:09:53,499 - geometric-dl - INFO - mean max of probabilities: 0.99623019 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:10:00,534 - geometric-dl - INFO - mean max of probabilities: 0.99626565 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:10:07,994 - geometric-dl - INFO - mean max of probabilities: 0.99631858 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:10:16,201 - geometric-dl - INFO - mean max of probabilities: 0.99633282 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:10:24,112 - geometric-dl - INFO - mean max of probabilities: 0.99637127 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:10:31,441 - geometric-dl - INFO - mean max of probabilities: 0.99641669 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:10:39,355 - geometric-dl - INFO - mean max of probabilities: 0.99646348 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:10:47,377 - geometric-dl - INFO - mean max of probabilities: 0.99651784 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:10:55,282 - geometric-dl - INFO - mean max of probabilities: 0.99653715 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:11:03,061 - geometric-dl - INFO - mean max of probabilities: 0.99659252 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:11:10,623 - geometric-dl - INFO - mean max of probabilities: 0.99663496 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:11:19,871 - geometric-dl - INFO - mean max of probabilities: 0.99669307 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:11:27,117 - geometric-dl - INFO - mean max of probabilities: 0.99672633 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:11:34,449 - geometric-dl - INFO - mean max of probabilities: 0.99677259 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:11:42,033 - geometric-dl - INFO - mean max of probabilities: 0.99680740 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:11:50,719 - geometric-dl - INFO - mean max of probabilities: 0.99686152 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:11:59,351 - geometric-dl - INFO - mean max of probabilities: 0.99688822 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:12:07,670 - geometric-dl - INFO - mean max of probabilities: 0.99693322 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:12:15,423 - geometric-dl - INFO - mean max of probabilities: 0.99696583 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:12:22,552 - geometric-dl - INFO - mean max of probabilities: 0.99700809 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:12:30,391 - geometric-dl - INFO - mean max of probabilities: 0.99704498 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:12:37,714 - geometric-dl - INFO - mean max of probabilities: 0.99706042 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:12:46,390 - geometric-dl - INFO - mean max of probabilities: 0.99708563 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:12:54,112 - geometric-dl - INFO - mean max of probabilities: 0.99713039 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:13:01,822 - geometric-dl - INFO - mean max of probabilities: 0.99716049 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:13:10,423 - geometric-dl - INFO - mean max of probabilities: 0.99720424 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:13:18,230 - geometric-dl - INFO - mean max of probabilities: 0.99723148 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:13:25,614 - geometric-dl - INFO - mean max of probabilities: 0.99726421 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:13:32,942 - geometric-dl - INFO - mean max of probabilities: 0.99727196 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:13:41,434 - geometric-dl - INFO - mean max of probabilities: 0.99728256 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# 2021-06-12 03:13:49,413 - geometric-dl - INFO - mean max of probabilities: 0.99729800 - temperature 0.10000000 (<ipython-input-38-0e838eedc6e0>:60)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-c86e0313e472> in <module>
# ----> 1 result_run_0 = run_model([11, 12, 13, 14], [15])
#
# <ipython-input-39-fbe6cb0282fa> in run_model(train_subject, test_subject, n_features, batch_size, num_epochs, learning_rate, decoder_architecture, decoder_name)
#      46
#      47     model.save(Path(PROJECT_PATH, 'runs', 'models', f'{run_info_str}.h5'))
# ---> 48     np.savetxt(Path(PROJECT_PATH, 'runs', 'textfiles', f'{run_info_str}.txt'), np.array(indices, dtype=int), fmt='%d')
#      49
#      50     return indices
#
# <__array_function__ internals> in savetxt(*args, **kwargs)
#
# ~/miniconda3/envs/mudi/lib/python3.8/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1355     if _is_string_like(fname):
#    1356         # datasource doesn't support creating a new file ...
# -> 1357         open(fname, 'wt').close()
#    1358         fh = np.lib._datasource.open(fname, 'wt', encoding=encoding)
#    1359         own_fh = True
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/maarten/Workspace/School/uu/thesis/geometric-dl-dmri/runs/textfiles/20210611-22:53:25_K=500_epoch=2000_test=15_dec=l2.txt'

# %%
logger.info('%s', result_run_0)
